# %%
from urllib.request import urlopen, Request
import json
import time
# import os

# %%
guild_name = "Godly"
# player1 = "Krijer1?fullResult"
player1 = "Krijer1"
start_url = "https://api.wynncraft.com/v3/"
player_url = start_url + "player/"
guild_url = start_url + "guild/"
weekly_csv_file = "./weekly_data.csv"
monthly_csv_file = "./monthly_data.csv"
dev_weekly_file = "./dev_weekly_data.csv"
dev_monthly_file = "./dev_monthly_data.csv"

# %%
class Response:
    def __init__(self, text, status_code, headers):
        self.text = text
        self.status_code = status_code
        self.headers = headers
    def json(self):
        return json.loads(self.text)
class Requests():
    def __init__(self):
        self.headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                      "AppleWebKit/537.36 (KHTML, like Gecko) "
                      "Chrome/116.0.5845.97 Safari/537.36"
        }
    def get(self, url):
        req = Request(url, headers=self.headers)
        with urlopen(req) as response:
            data = response.read()
            encoding = response.info().get_content_charset("utf-8")
            text = data.decode(encoding)
            return Response(text, response.getcode(), dict(response.info()))
requests = Requests()

# %%
response = requests.get(player_url + "H1V")

# %%
print(json.dumps(response.json(), indent=2))
# Out:
# {
#   "username": "H1V",
#   "online": false,
#   "server": "NA37",
#   "activeCharacter": "1b875995-3197-47a2-aea2-1c10c2bfb963",
#   "nickname": null,
#   "uuid": "845eed02-175a-44b4-87a2-0228b1fbc3ee",
#   "rank": "Player",
#   "rankBadge": "nextgen/badges/rank_hero.svg",
#   "legacyRankColour": {
#     "main": "#AA00AA",
#     "sub": "#FF55FF"
#   },
#   "shortenedRank": null,
#   "supportRank": "hero",
#   "veteran": null,
#   "lastJoin": "2026-02-24T05:20:50.897000Z",
#   "guild": {
#     "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#     "name": "Godly",
#     "prefix": "grey",
#     "rank": "CHIEF",
#     "rankStars": "\u2605\u2605\u2605\u2605"
#   },
#   "ranking": {
#     "playerContent": 699,
#     "orphionSrPlayers": 1426,
#     "huntedContent": 1655,
#     "orphionCompletion": 1676,
#     "globalPlayerContent": 1944,
#     "woodcuttingLevel": 1992,
#     "namelessSrPlayers": 1992,
#     "guildRaids": 2032,
#     "farmingLevel": 2162,
#     "miningLevel": 2578,
#     "fishingLevel": 2910,
#     "grootslangSrPlayers": 3551,
#     "namelessCompletion": 3731,
#     "grootslangCompletion": 3747,
#     "colossusSrPlayers": 3848,
#     "combatSoloLevel": 4601,
#     "colossusCompletion": 4920,
#     "combatGlobalLevel": 7482,
#     "warsCompletion": 8863,
#     "totalGlobalLevel": 11074,
#     "totalSoloLevel": 11170,
#     "professionsSoloLevel": 11813,
#     "professionsGlobalLevel": 17010,
#     "jewelingLevel": 35899,
#     "cookingLevel": 54144,
#     "weaponsmithingLevel": 112440,
#     "woodworkingLevel": 132588,
#     "alchemismLevel": 1617584,
#     "scribingLevel": 1633883,
#     "tailoringLevel": 1636090,
#     "armouringLevel": 1649902
#   },
#   "previousRanking": {},
#   "firstJoin": "2017-05-26T22:42:00.776000Z",
#   "playtime": 1144.33,
#   "globalData": {
#     "contentCompletion": 3381,
#     "wars": 28,
#     "totalLevel": 3243,
#     "mobsKilled": 230530,
#     "chestsFound": 5699,
#     "dungeons": {
#       "total": 366,
#       "list": {
#         "Decrepit Sewers": 27,
#         "Infested Pit": 33,
#         "Lost Sanctuary": 14,
#         "Underworld Crypt": 12,
#         "Ice Barrows": 17,
#         "Undergrowth Ruins": 13,
#         "Galleon's Graveyard": 9,
#         "Corrupted Lost Sanctuary": 11,
#         "Fallen Factory": 8,
#         "Corrupted Decrepit Sewers": 12,
#         "Corrupted Infested Pit": 12,
#         "Corrupted Underworld Crypt": 17,
#         "Corrupted Sand-Swept Tomb": 116,
#         "Corrupted Ice Barrows": 9,
#         "Corrupted Undergrowth Ruins": 10,
#         "Corrupted Galleon's Graveyard": 13,
#         "Eldritch Outlook": 15,
#         "Timelost Sanctum": 3,
#         "Sand-Swept Tomb": 15
#       }
#     },
#     "raids": {
#       "total": 436,
#       "list": {
#         "The Canyon Colossus": 95,
#         "Orphion's Nexus of Light": 90,
#         "The Nameless Anomaly": 136,
#         "Nest of the Grootslangs": 115
#       }
#     },
#     "worldEvents": 66,
#     "lootruns": 5,
#     "caves": 487,
#     "completedQuests": 549,
#     "pvp": {
#       "kills": 0,
#       "deaths": 0
#     },
#     "guildRaids": {
#       "total": 159,
#       "list": {
#         "The Canyon Colossus": 11,
#         "Orphion's Nexus of Light": 39,
#         "Nest of the Grootslangs": 47,
#         "The Nameless Anomaly": 62
#       }
#     }
#   },
#   "featuredStats": {
#     "firstJoin": "2017-05-26T22:42:00.776000Z",
#     "playtime": 1144.33,
#     "globalData.totalLevel": 3243,
#     "globalData.mobsKilled": 230530,
#     "globalData.completedQuests": 549
#   },
#   "wallpaper": "home",
#   "avatar": "player",
#   "restrictions": {
#     "mainAccess": false,
#     "onlineStatus": false
#   }
# }

# %%
player1Req = requests.get(player_url + player1)
# player2Req = requests.get(player_url + player2)

# %%
player1Data = player1Req.json()
print(json.dumps(player1Data, indent=2))
# Out:
# {
#   "username": "Krijer1",
#   "online": true,
#   "server": "EU25",
#   "activeCharacter": "a1945914-e28a-4d75-b5a4-2e1a35d0030f",
#   "nickname": null,
#   "uuid": "4a82c3ac-be5d-4115-a822-f2a9c7bdb096",
#   "rank": "Player",
#   "rankBadge": "nextgen/badges/rank_hero.svg",
#   "legacyRankColour": {
#     "main": "#AA00AA",
#     "sub": "#FF55FF"
#   },
#   "shortenedRank": null,
#   "supportRank": "hero",
#   "veteran": null,
#   "lastJoin": "2026-02-25T20:26:25.749000Z",
#   "guild": {
#     "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#     "name": "Godly",
#     "prefix": "grey",
#     "rank": "CHIEF",
#     "rankStars": "\u2605\u2605\u2605\u2605"
#   },
#   "ranking": {
#     "cookingLevel": 2249,
#     "farmingLevel": 3196,
#     "fishingLevel": 3369,
#     "jewelingLevel": 3423,
#     "namelessSrPlayers": 3641,
#     "warsCompletion": 3817,
#     "totalSoloLevel": 4776,
#     "professionsSoloLevel": 4828,
#     "miningLevel": 4946,
#     "tailoringLevel": 5139,
#     "armouringLevel": 6476,
#     "guildRaids": 6597,
#     "playerContent": 6621,
#     "namelessCompletion": 6876,
#     "grootslangSrPlayers": 7089,
#     "grootslangCompletion": 7094,
#     "totalGlobalLevel": 8180,
#     "colossusSrPlayers": 8935,
#     "combatGlobalLevel": 8964,
#     "professionsGlobalLevel": 9370,
#     "orphionSrPlayers": 10527,
#     "scribingLevel": 11253,
#     "globalPlayerContent": 11366,
#     "orphionCompletion": 12465,
#     "colossusCompletion": 12851,
#     "woodcuttingLevel": 15327,
#     "combatSoloLevel": 18893,
#     "weaponsmithingLevel": 45936,
#     "woodworkingLevel": 105851,
#     "alchemismLevel": 2325100
#   },
#   "previousRanking": {},
#   "firstJoin": "2018-03-07T16:26:49.359000Z",
#   "playtime": 583.08,
#   "globalData": {
#     "contentCompletion": 1745,
#     "wars": 165,
#     "totalLevel": 3363,
#     "mobsKilled": 226501,
#     "chestsFound": 2610,
#     "dungeons": {
#       "total": 167,
#       "list": {
#         "Decrepit Sewers": 38,
#         "Infested Pit": 16,
#         "Underworld Crypt": 10,
#         "Sand-Swept Tomb": 18,
#         "Ice Barrows": 14,
#         "Undergrowth Ruins": 12,
#         "Lost Sanctuary": 2,
#         "Galleon's Graveyard": 5,
#         "Corrupted Decrepit Sewers": 10,
#         "Corrupted Lost Sanctuary": 7,
#         "Corrupted Infested Pit": 7,
#         "Corrupted Underworld Crypt": 6,
#         "Corrupted Sand-Swept Tomb": 6,
#         "Corrupted Ice Barrows": 6,
#         "Corrupted Undergrowth Ruins": 2,
#         "Eldritch Outlook": 2,
#         "Fallen Factory": 3,
#         "Corrupted Galleon's Graveyard": 2,
#         "Timelost Sanctum": 1
#       }
#     },
#     "raids": {
#       "total": 147,
#       "list": {
#         "The Canyon Colossus": 20,
#         "Orphion's Nexus of Light": 10,
#         "The Nameless Anomaly": 57,
#         "Nest of the Grootslangs": 60
#       }
#     },
#     "worldEvents": 25,
#     "lootruns": 5,
#     "caves": 167,
#     "completedQuests": 262,
#     "pvp": {
#       "kills": 0,
#       "deaths": 0
#     },
#     "guildRaids": {
#       "total": 22,
#       "list": {
#         "The Canyon Colossus": 6,
#         "Orphion's Nexus of Light": 0,
#         "Nest of the Grootslangs": 2,
#         "The Nameless Anomaly": 14
#       }
#     }
#   },
#   "featuredStats": {
#     "firstJoin": "2018-03-07T16:26:49.359000Z",
#     "playtime": 583.08,
#     "globalData.totalLevel": 3363,
#     "globalData.mobsKilled": 226501,
#     "globalData.completedQuests": 262
#   },
#   "wallpaper": "home",
#   "avatar": "player",
#   "restrictions": {
#     "mainAccess": false,
#     "onlineStatus": false
#   }
# }

# %%
#Player info
# print(json.dumps(response.json(), indent=2))
# print(response.json()['playtime'])
# print(json.dumps(player1Data, indent=2))
player1time = player1Data["playtime"]
print(player1time)
# Out:
# 583.08

# %%
guild_req = requests.get(guild_url + guild_name)

# %%
print(json.dumps(guild_req.json(), indent=2))
# Out:
# {
#   "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#   "name": "Godly",
#   "prefix": "grey",
#   "level": 70,
#   "xpPercent": 99,
#   "territories": 0,
#   "wars": 1441,
#   "created": "2025-08-20T06:59:13.342000Z",
#   "members": {
#     "total": 80,
#     "owner": {
#       "Nqn": {
#         "uuid": "a8e5c7c3-444f-4436-b69f-a8db58cdf40d",
#         "online": false,
#         "server": null,
#         "contributed": 4284462682,
#         "contributionRank": 2,
#         "joined": "2025-08-20T06:59:13.342000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       }
#     },
#     "chief": {
#       "Tisumi": {
#         "uuid": "91be9a75-7398-47e0-8c4d-f79df2fc035f",
#         "online": true,
#         "server": "NA16",
#         "contributed": 8958067763,
#         "contributionRank": 1,
#         "joined": "2025-09-27T06:58:29.986000Z",
#         "guildRaids": {
#           "total": 142,
#           "list": {
#             "The Canyon Colossus": 22,
#             "Orphion's Nexus of Light": 6,
#             "Nest of the Grootslangs": 23,
#             "The Nameless Anomaly": 91
#           }
#         }
#       },
#       "_N8": {
#         "uuid": "5652732f-e36b-4ca4-87ca-59f9c6dc3ba1",
#         "online": false,
#         "server": null,
#         "contributed": 1891441538,
#         "contributionRank": 3,
#         "joined": "2025-08-20T06:59:30.170000Z",
#         "guildRaids": {
#           "total": 8,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 1,
#             "Nest of the Grootslangs": 5,
#             "The Nameless Anomaly": 2
#           }
#         }
#       },
#       "GigaFanDeJul": {
#         "uuid": "0a19dd60-254e-4c48-9d76-1b57a2f12c7f",
#         "online": false,
#         "server": null,
#         "contributed": 1080332400,
#         "contributionRank": 4,
#         "joined": "2026-01-17T14:55:37.482000Z",
#         "guildRaids": {
#           "total": 97,
#           "list": {
#             "The Canyon Colossus": 4,
#             "Orphion's Nexus of Light": 14,
#             "Nest of the Grootslangs": 31,
#             "The Nameless Anomaly": 48
#           }
#         }
#       },
#       "Krijer1": {
#         "uuid": "4a82c3ac-be5d-4115-a822-f2a9c7bdb096",
#         "online": true,
#         "server": "EU25",
#         "contributed": 181717348,
#         "contributionRank": 5,
#         "joined": "2026-01-16T18:40:55.478000Z",
#         "guildRaids": {
#           "total": 22,
#           "list": {
#             "The Canyon Colossus": 6,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 2,
#             "The Nameless Anomaly": 14
#           }
#         }
#       },
#       "Shivnitzl19": {
#         "uuid": "bd5c1697-4d42-41dd-a4f2-2c8a3a669104",
#         "online": false,
#         "server": null,
#         "contributed": 87695894,
#         "contributionRank": 8,
#         "joined": "2025-08-20T11:17:53.604000Z",
#         "guildRaids": {
#           "total": 19,
#           "list": {
#             "The Canyon Colossus": 1,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 10,
#             "The Nameless Anomaly": 8
#           }
#         }
#       },
#       "Xentell": {
#         "uuid": "1a3f6b2a-993b-49ed-8542-7584081864b6",
#         "online": false,
#         "server": null,
#         "contributed": 30281450,
#         "contributionRank": 13,
#         "joined": "2025-11-12T15:27:54.940000Z",
#         "guildRaids": {
#           "total": 9,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 1,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 8
#           }
#         }
#       },
#       "H1V": {
#         "uuid": "845eed02-175a-44b4-87a2-0228b1fbc3ee",
#         "online": false,
#         "server": null,
#         "contributed": 26185368,
#         "contributionRank": 18,
#         "joined": "2026-01-19T01:16:08.956000Z",
#         "guildRaids": {
#           "total": 159,
#           "list": {
#             "The Canyon Colossus": 11,
#             "Orphion's Nexus of Light": 39,
#             "Nest of the Grootslangs": 47,
#             "The Nameless Anomaly": 62
#           }
#         }
#       },
#       "ewenfi": {
#         "uuid": "89cdeb83-0958-4563-a606-0a460e13abfa",
#         "online": false,
#         "server": null,
#         "contributed": 16143010,
#         "contributionRank": 31,
#         "joined": "2026-01-17T14:57:25.432000Z",
#         "guildRaids": {
#           "total": 79,
#           "list": {
#             "The Canyon Colossus": 2,
#             "Orphion's Nexus of Light": 12,
#             "Nest of the Grootslangs": 21,
#             "The Nameless Anomaly": 44
#           }
#         }
#       },
#       "KirouXD": {
#         "uuid": "4470c807-1394-4930-937d-1680d508d22d",
#         "online": false,
#         "server": null,
#         "contributed": 7389963,
#         "contributionRank": 38,
#         "joined": "2026-01-17T14:36:32.901000Z",
#         "guildRaids": {
#           "total": 47,
#           "list": {
#             "The Canyon Colossus": 2,
#             "Orphion's Nexus of Light": 17,
#             "Nest of the Grootslangs": 11,
#             "The Nameless Anomaly": 17
#           }
#         }
#       },
#       "Chevacchi": {
#         "uuid": "eb33d516-a34b-4050-bd2c-69a24bf0bd75",
#         "online": false,
#         "server": null,
#         "contributed": 2364628,
#         "contributionRank": 45,
#         "joined": "2026-02-16T00:35:06.942000Z",
#         "guildRaids": {
#           "total": 7,
#           "list": {
#             "The Canyon Colossus": 3,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 4
#           }
#         }
#       }
#     },
#     "strategist": {
#       "clohi": {
#         "uuid": "1b6568dd-4e58-442f-918f-90926f58de0c",
#         "online": true,
#         "server": "NA16",
#         "contributed": 164177161,
#         "contributionRank": 6,
#         "joined": "2026-02-07T19:57:11.309000Z",
#         "guildRaids": {
#           "total": 4,
#           "list": {
#             "The Canyon Colossus": 3,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 1
#           }
#         }
#       },
#       "_Snoopers_": {
#         "uuid": "130612b6-1d46-49c7-b06e-3200959254c7",
#         "online": true,
#         "server": "NA16",
#         "contributed": 43083305,
#         "contributionRank": 10,
#         "joined": "2026-01-16T19:11:52.855000Z",
#         "guildRaids": {
#           "total": 21,
#           "list": {
#             "The Canyon Colossus": 5,
#             "Orphion's Nexus of Light": 1,
#             "Nest of the Grootslangs": 12,
#             "The Nameless Anomaly": 3
#           }
#         }
#       },
#       "LaserX": {
#         "uuid": "a8ff0b79-9511-47b7-8705-b657eba980aa",
#         "online": false,
#         "server": null,
#         "contributed": 24076709,
#         "contributionRank": 20,
#         "joined": "2026-01-17T16:58:35.099000Z",
#         "guildRaids": {
#           "total": 41,
#           "list": {
#             "The Canyon Colossus": 2,
#             "Orphion's Nexus of Light": 11,
#             "Nest of the Grootslangs": 25,
#             "The Nameless Anomaly": 3
#           }
#         }
#       },
#       "WhiteNoise0113": {
#         "uuid": "f46a3aa1-ed18-48f4-bcf9-594e0ff19842",
#         "online": false,
#         "server": null,
#         "contributed": 20412697,
#         "contributionRank": 26,
#         "joined": "2026-02-10T14:20:22.052000Z",
#         "guildRaids": {
#           "total": 97,
#           "list": {
#             "The Canyon Colossus": 33,
#             "Orphion's Nexus of Light": 8,
#             "Nest of the Grootslangs": 35,
#             "The Nameless Anomaly": 21
#           }
#         }
#       },
#       "StyNath": {
#         "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3",
#         "online": false,
#         "server": null,
#         "contributed": 2777455,
#         "contributionRank": 43,
#         "joined": "2026-01-17T22:49:33.209000Z",
#         "guildRaids": {
#           "total": 23,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 1,
#             "Nest of the Grootslangs": 19,
#             "The Nameless Anomaly": 3
#           }
#         }
#       },
#       "kcsato": {
#         "uuid": "ce2fc852-9b0e-41d2-a323-603be70f5b69",
#         "online": false,
#         "server": null,
#         "contributed": 1507251,
#         "contributionRank": 48,
#         "joined": "2026-01-17T14:36:37.544000Z",
#         "guildRaids": {
#           "total": 10,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 3,
#             "Nest of the Grootslangs": 4,
#             "The Nameless Anomaly": 3
#           }
#         }
#       },
#       "imNaphy": {
#         "uuid": "9604c081-52b1-4224-8107-b00885644c84",
#         "online": false,
#         "server": null,
#         "contributed": 509741,
#         "contributionRank": 58,
#         "joined": "2025-08-20T12:35:13.228000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "FireGamingDK": {
#         "uuid": "96512a2a-4200-463e-8974-27a4c81947cd",
#         "online": false,
#         "server": null,
#         "contributed": 221976,
#         "contributionRank": 66,
#         "joined": "2026-01-16T18:41:23.015000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       }
#     },
#     "captain": {
#       "xEagless": {
#         "uuid": "a27ae078-8209-4c2e-85ea-57de6168cc9b",
#         "online": false,
#         "server": null,
#         "contributed": 129392767,
#         "contributionRank": 7,
#         "joined": "2026-01-17T18:00:19.960000Z",
#         "guildRaids": {
#           "total": 24,
#           "list": {
#             "The Canyon Colossus": 7,
#             "Orphion's Nexus of Light": 1,
#             "Nest of the Grootslangs": 6,
#             "The Nameless Anomaly": 10
#           }
#         }
#       },
#       "WynnDestroyer": {
#         "uuid": "81c0cf7a-43f9-4aaf-8783-4953970e394d",
#         "online": false,
#         "server": null,
#         "contributed": 77665432,
#         "contributionRank": 9,
#         "joined": "2026-01-03T10:54:17.217000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "BlueSkyMoose": {
#         "uuid": "b3be31d6-e441-4299-a342-685898f35f30",
#         "online": false,
#         "server": null,
#         "contributed": 33121564,
#         "contributionRank": 12,
#         "joined": "2026-02-13T03:36:59.937000Z",
#         "guildRaids": {
#           "total": 62,
#           "list": {
#             "The Canyon Colossus": 17,
#             "Orphion's Nexus of Light": 3,
#             "Nest of the Grootslangs": 1,
#             "The Nameless Anomaly": 41
#           }
#         }
#       },
#       "MoondustPeachy": {
#         "uuid": "06793d89-e8ea-4ec2-aa55-4c5f03b93026",
#         "online": false,
#         "server": null,
#         "contributed": 23258957,
#         "contributionRank": 22,
#         "joined": "2026-02-13T22:21:27.329000Z",
#         "guildRaids": {
#           "total": 12,
#           "list": {
#             "The Canyon Colossus": 2,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 10
#           }
#         }
#       },
#       "kanyo0904": {
#         "uuid": "ae32ae54-c15c-4c6d-ab46-3bdcec6e2e7f",
#         "online": false,
#         "server": null,
#         "contributed": 21727159,
#         "contributionRank": 24,
#         "joined": "2026-01-28T08:18:54.212000Z",
#         "guildRaids": {
#           "total": 1,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 1
#           }
#         }
#       },
#       "YBN": {
#         "uuid": "3ed556ef-70ef-4d27-8bae-c2cff73f9b20",
#         "online": false,
#         "server": null,
#         "contributed": 21033900,
#         "contributionRank": 25,
#         "joined": "2026-02-11T07:18:34.778000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "Gurlic": {
#         "uuid": "bf6fd3d8-f0b2-4831-9dc2-77db02b015d7",
#         "online": false,
#         "server": null,
#         "contributed": 17752217,
#         "contributionRank": 28,
#         "joined": "2026-01-30T10:39:02.737000Z",
#         "guildRaids": {
#           "total": 4,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 2,
#             "The Nameless Anomaly": 2
#           }
#         }
#       },
#       "ddxWeCraft": {
#         "uuid": "d680883b-e7b2-4bfc-bad7-79372d97c60d",
#         "online": true,
#         "server": "NA16",
#         "contributed": 14447471,
#         "contributionRank": 32,
#         "joined": "2026-02-18T21:33:06.478000Z",
#         "guildRaids": {
#           "total": 9,
#           "list": {
#             "The Canyon Colossus": 3,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 1,
#             "The Nameless Anomaly": 5
#           }
#         }
#       },
#       "wrggg": {
#         "uuid": "2ad7fd38-792d-4862-ba2a-b7e1c1723b18",
#         "online": true,
#         "server": "EU3",
#         "contributed": 13273891,
#         "contributionRank": 34,
#         "joined": "2026-02-10T12:55:21.967000Z",
#         "guildRaids": {
#           "total": 192,
#           "list": {
#             "The Canyon Colossus": 7,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 100,
#             "The Nameless Anomaly": 85
#           }
#         }
#       },
#       "parrandeno": {
#         "uuid": "065f7a4a-e15a-4bbf-ab2f-b55051e0b6de",
#         "online": false,
#         "server": null,
#         "contributed": 12939677,
#         "contributionRank": 35,
#         "joined": "2026-01-31T01:31:02.265000Z",
#         "guildRaids": {
#           "total": 4,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 4
#           }
#         }
#       },
#       "Ecmz": {
#         "uuid": "cff26bb4-bad0-4de2-8559-19d23e2d9d41",
#         "online": false,
#         "server": null,
#         "contributed": 2627208,
#         "contributionRank": 44,
#         "joined": "2026-02-13T07:46:17.033000Z",
#         "guildRaids": {
#           "total": 1,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 1
#           }
#         }
#       },
#       "Liciela": {
#         "uuid": "823ee888-e114-4ca9-9781-7086b5430a54",
#         "online": false,
#         "server": null,
#         "contributed": 1620644,
#         "contributionRank": 47,
#         "joined": "2026-02-03T15:51:05.744000Z",
#         "guildRaids": {
#           "total": 7,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 3,
#             "The Nameless Anomaly": 4
#           }
#         }
#       },
#       "Megawati": {
#         "uuid": "9ce7b212-c818-41cf-bd2a-9a2ad4f0e5df",
#         "online": false,
#         "server": null,
#         "contributed": 1329288,
#         "contributionRank": 49,
#         "joined": "2026-01-18T10:28:12.188000Z",
#         "guildRaids": {
#           "total": 3,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 1,
#             "The Nameless Anomaly": 2
#           }
#         }
#       },
#       "cresseliah": {
#         "uuid": "b7d4a9f2-73ba-47b6-bc7c-d8db98ad6a2e",
#         "online": false,
#         "server": null,
#         "contributed": 1312843,
#         "contributionRank": 50,
#         "joined": "2026-02-20T06:58:27.525000Z",
#         "guildRaids": {
#           "total": 1,
#           "list": {
#             "The Canyon Colossus": 1,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "gauvinsteven": {
#         "uuid": "d0344f4e-a5fb-48ee-9359-1c82fb2320aa",
#         "online": false,
#         "server": null,
#         "contributed": 1149377,
#         "contributionRank": 51,
#         "joined": "2026-01-18T15:22:11.811000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "MelinoeNemesis": {
#         "uuid": "9c413f4a-9e5f-46e9-8b89-abdd46f3f74b",
#         "online": false,
#         "server": null,
#         "contributed": 653536,
#         "contributionRank": 55,
#         "joined": "2026-01-17T11:13:30.901000Z",
#         "guildRaids": {
#           "total": 13,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 13,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "EdouardpheoIII": {
#         "uuid": "b0135e82-95b5-432b-a008-d7a8d6829e07",
#         "online": false,
#         "server": null,
#         "contributed": 529851,
#         "contributionRank": 57,
#         "joined": "2026-01-17T15:33:41.365000Z",
#         "guildRaids": {
#           "total": 9,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 9,
#             "The Nameless Anomaly": 0
#           }
#         }
#       }
#     },
#     "recruiter": {
#       "Riku_56rr": {
#         "uuid": "9731aa53-56d8-43e2-99d1-86e5e2efd7de",
#         "online": false,
#         "server": null,
#         "contributed": 38476943,
#         "contributionRank": 11,
#         "joined": "2026-02-03T13:25:48.520000Z",
#         "guildRaids": {
#           "total": 3,
#           "list": {
#             "The Canyon Colossus": 3,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "jayandjef": {
#         "uuid": "c837e8b4-4e0a-41c4-b397-7b02f8f35f2a",
#         "online": false,
#         "server": null,
#         "contributed": 30196248,
#         "contributionRank": 14,
#         "joined": "2026-01-24T21:07:00.006000Z",
#         "guildRaids": {
#           "total": 35,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 3,
#             "Nest of the Grootslangs": 26,
#             "The Nameless Anomaly": 6
#           }
#         }
#       },
#       "roll_54": {
#         "uuid": "04be2792-d567-4c0a-aa1d-67242dbcf0a8",
#         "online": false,
#         "server": null,
#         "contributed": 28825843,
#         "contributionRank": 15,
#         "joined": "2026-01-13T12:46:46.051000Z",
#         "guildRaids": {
#           "total": 2,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 2
#           }
#         }
#       },
#       "jeff1234567842": {
#         "uuid": "c77bcc5e-ad22-478d-a70e-fa3a255f2f86",
#         "online": false,
#         "server": null,
#         "contributed": 20233322,
#         "contributionRank": 27,
#         "joined": "2026-02-01T03:33:39.394000Z",
#         "guildRaids": {
#           "total": 21,
#           "list": {
#             "The Canyon Colossus": 1,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 2,
#             "The Nameless Anomaly": 18
#           }
#         }
#       },
#       "AmasoXd": {
#         "uuid": "423997a0-9626-479c-97e5-d3517b93083c",
#         "online": false,
#         "server": null,
#         "contributed": 17547352,
#         "contributionRank": 29,
#         "joined": "2026-02-01T06:53:43.371000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "Aqimcrafty": {
#         "uuid": "3823b995-b8fa-49f5-8c68-6d1a66bdf215",
#         "online": false,
#         "server": null,
#         "contributed": 17444382,
#         "contributionRank": 30,
#         "joined": "2026-02-03T15:54:49.846000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "evbubba": {
#         "uuid": "1af5a66a-9337-4e66-a69b-35d825f4a62b",
#         "online": false,
#         "server": null,
#         "contributed": 13772282,
#         "contributionRank": 33,
#         "joined": "2026-01-17T22:47:38.178000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "squirley": {
#         "uuid": "b9112e4d-7141-4922-9fca-47430268445e",
#         "online": false,
#         "server": null,
#         "contributed": 11288654,
#         "contributionRank": 36,
#         "joined": "2026-01-29T07:00:26.907000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "Thund3rMC": {
#         "uuid": "0254668f-5453-408d-aa18-d44d8619c215",
#         "online": false,
#         "server": null,
#         "contributed": 7267230,
#         "contributionRank": 39,
#         "joined": "2026-01-29T18:40:14.004000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "JJCourts": {
#         "uuid": "0cea76a6-b7a3-4537-8b64-f98ab836a1e2",
#         "online": false,
#         "server": null,
#         "contributed": 2987518,
#         "contributionRank": 42,
#         "joined": "2026-01-08T18:39:54.463000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "AlleNupY": {
#         "uuid": "ec784aab-d88e-40df-a5ab-c6a26fc9c671",
#         "online": false,
#         "server": null,
#         "contributed": 961513,
#         "contributionRank": 52,
#         "joined": "2026-02-03T13:49:15.749000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "Zytiv": {
#         "uuid": "5e3c6983-b267-49be-b6f8-7eedb09fddb4",
#         "online": false,
#         "server": null,
#         "contributed": 787108,
#         "contributionRank": 54,
#         "joined": "2026-01-23T02:13:31.299000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "Firetornado2312": {
#         "uuid": "4c0e0ac7-49e1-4590-b4d6-8fe2f1ca1e26",
#         "online": false,
#         "server": null,
#         "contributed": 600705,
#         "contributionRank": 56,
#         "joined": "2026-01-25T00:45:32.978000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "mirceatim": {
#         "uuid": "aed8039a-4d4e-40e9-ab22-d1ec544ba155",
#         "online": false,
#         "server": null,
#         "contributed": 332244,
#         "contributionRank": 61,
#         "joined": "2026-02-12T20:54:17.917000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "Rinnn0424": {
#         "uuid": "467ed4aa-50fe-45b3-8705-b65d2a713a8c",
#         "online": false,
#         "server": null,
#         "contributed": 289292,
#         "contributionRank": 62,
#         "joined": "2026-01-26T02:06:41.243000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "White_plague": {
#         "uuid": "6f327520-de36-4695-b8f1-f67558d0d4fc",
#         "online": false,
#         "server": null,
#         "contributed": 265636,
#         "contributionRank": 63,
#         "joined": "2026-02-13T09:52:38.716000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "vamqir": {
#         "uuid": "85017f3e-4643-454b-a315-f158dd3971dd",
#         "online": false,
#         "server": null,
#         "contributed": 255846,
#         "contributionRank": 64,
#         "joined": "2026-02-04T06:26:27.618000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "ottehall": {
#         "uuid": "d99b449a-7b7b-4561-a646-459bf8ab0825",
#         "online": false,
#         "server": null,
#         "contributed": 253030,
#         "contributionRank": 65,
#         "joined": "2026-02-03T12:45:42.778000Z",
#         "guildRaids": {
#           "total": 1,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 1,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "DynemoRC": {
#         "uuid": "cfc0ef1a-1951-4343-9adb-7ceb949b06c0",
#         "online": false,
#         "server": null,
#         "contributed": 179165,
#         "contributionRank": 68,
#         "joined": "2026-02-12T20:53:31.387000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "VenonatGX": {
#         "uuid": "9867e87a-e526-4da0-8945-e91f339409cc",
#         "online": false,
#         "server": null,
#         "contributed": 159340,
#         "contributionRank": 69,
#         "joined": "2026-01-26T08:59:32.851000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "djderpcat": {
#         "uuid": "eb1d2b6f-cd58-4cc8-b389-05bbfa831a3e",
#         "online": false,
#         "server": null,
#         "contributed": 23290,
#         "contributionRank": 70,
#         "joined": "2026-01-31T07:22:05.532000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "S6kuna": {
#         "uuid": "d3abfd17-2a07-45b1-a5b0-9b76800b53f4",
#         "online": false,
#         "server": null,
#         "contributed": 6976,
#         "contributionRank": 71,
#         "joined": "2026-02-03T15:57:33.408000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "SoupSkids": {
#         "uuid": "4ee827d7-5300-4f49-a5ba-3945e454460a",
#         "online": false,
#         "server": null,
#         "contributed": 0,
#         "contributionRank": 74,
#         "joined": "2025-10-28T15:42:04.073000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       }
#     },
#     "recruit": {
#       "Feather_Storm": {
#         "uuid": "6582d74d-9b97-435e-9781-66cf2aedb17a",
#         "online": false,
#         "server": null,
#         "contributed": 28143828,
#         "contributionRank": 16,
#         "joined": "2026-02-21T00:07:34.033000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "notBirdblade": {
#         "uuid": "283536d3-5e6f-4c8d-a23b-9fa8a8b50f18",
#         "online": true,
#         "server": "NA16",
#         "contributed": 27359608,
#         "contributionRank": 17,
#         "joined": "2026-02-21T23:55:37.648000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "SewageFarts": {
#         "uuid": "b22cfe82-4f5d-4b43-b63f-8e33bf3d7835",
#         "online": false,
#         "server": null,
#         "contributed": 24285829,
#         "contributionRank": 19,
#         "joined": "2026-02-14T00:43:18.689000Z",
#         "guildRaids": {
#           "total": 1,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 1
#           }
#         }
#       },
#       "ZicZac": {
#         "uuid": "fff311d0-b571-4b80-baa2-43adfe981448",
#         "online": false,
#         "server": null,
#         "contributed": 23703602,
#         "contributionRank": 21,
#         "joined": "2026-02-19T19:53:08.815000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "iParadox1122": {
#         "uuid": "bd589667-31d5-4f6c-95b8-04ddad4b241f",
#         "online": false,
#         "server": null,
#         "contributed": 22608037,
#         "contributionRank": 23,
#         "joined": "2026-02-11T14:51:47.432000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "Ryuuchen": {
#         "uuid": "4bfb9baf-7347-43c8-9c4d-5c55b27c780e",
#         "online": false,
#         "server": null,
#         "contributed": 8652184,
#         "contributionRank": 37,
#         "joined": "2026-01-31T01:12:04.876000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "Kanaefx": {
#         "uuid": "1b6b5470-e8d6-48c8-a553-5bb52395a662",
#         "online": false,
#         "server": null,
#         "contributed": 6703471,
#         "contributionRank": 40,
#         "joined": "2026-02-03T05:50:22.212000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "_Hammie_": {
#         "uuid": "2adb411c-37e2-491c-8afd-9a38fc4fdf06",
#         "online": false,
#         "server": null,
#         "contributed": 5356119,
#         "contributionRank": 41,
#         "joined": "2026-02-06T21:37:14.461000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "Endyre": {
#         "uuid": "502073b4-06bc-4f30-8a4f-115e6c9e35af",
#         "online": false,
#         "server": null,
#         "contributed": 1844442,
#         "contributionRank": 46,
#         "joined": "2026-02-20T03:17:25.645000Z",
#         "guildRaids": {
#           "total": 14,
#           "list": {
#             "The Canyon Colossus": 1,
#             "Orphion's Nexus of Light": 1,
#             "Nest of the Grootslangs": 12,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "nawe69": {
#         "uuid": "3ee651c0-59d3-452d-a98d-214d717bef83",
#         "online": false,
#         "server": null,
#         "contributed": 855964,
#         "contributionRank": 53,
#         "joined": "2026-02-11T11:52:18.106000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "F1NLAY01": {
#         "uuid": "733e86a2-b926-4257-9658-81a990d2ac0a",
#         "online": false,
#         "server": null,
#         "contributed": 470120,
#         "contributionRank": 59,
#         "joined": "2026-02-03T14:26:38.018000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "aIfaa": {
#         "uuid": "511c4018-f6ca-4ccb-a698-9b64b07c6ad3",
#         "online": false,
#         "server": null,
#         "contributed": 409244,
#         "contributionRank": 60,
#         "joined": "2026-02-22T21:11:42.877000Z",
#         "guildRaids": {
#           "total": 1,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 1,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "erik_9453": {
#         "uuid": "1ebcb3ff-2695-4a54-b482-a22081cb024a",
#         "online": false,
#         "server": null,
#         "contributed": 221688,
#         "contributionRank": 67,
#         "joined": "2026-02-04T06:29:18.410000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "TheKzR": {
#         "uuid": "31cc44b4-4c2d-4d88-8e41-f4a4b0337346",
#         "online": false,
#         "server": null,
#         "contributed": 491,
#         "contributionRank": 72,
#         "joined": "2026-02-22T22:39:44.498000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "GrayR0ot": {
#         "uuid": "a4fa7dd2-7cd7-4626-b9f6-3284fc16557a",
#         "online": false,
#         "server": null,
#         "contributed": 365,
#         "contributionRank": 73,
#         "joined": "2026-02-14T11:49:09.064000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "Budiono": {
#         "uuid": "02115748-53c2-4a43-afd7-5412d8e01f8a",
#         "online": false,
#         "server": null,
#         "contributed": 0,
#         "contributionRank": 75,
#         "joined": "2026-02-03T13:37:48.695000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "cheeseball01": {
#         "uuid": "94591244-b96c-4675-99fc-b4e9abfac6de",
#         "online": false,
#         "server": null,
#         "contributed": 0,
#         "contributionRank": 76,
#         "joined": "2026-02-15T20:30:48.258000Z",
#         "guildRaids": {
#           "total": 71,
#           "list": {
#             "The Canyon Colossus": 7,
#             "Orphion's Nexus of Light": 15,
#             "Nest of the Grootslangs": 35,
#             "The Nameless Anomaly": 14
#           }
#         }
#       },
#       "skrybs": {
#         "uuid": "1285f316-0b50-4d36-ae61-a02ed620c8ff",
#         "online": false,
#         "server": null,
#         "contributed": 0,
#         "contributionRank": 77,
#         "joined": "2026-02-21T21:33:09.719000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "Bluvey": {
#         "uuid": "e781dac3-37b9-48e8-b588-dc8b5a1e0200",
#         "online": false,
#         "server": null,
#         "contributed": 0,
#         "contributionRank": 78,
#         "joined": "2026-02-22T03:04:42.171000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "Laborious": {
#         "uuid": "4489c7f5-9d5a-4b32-b0a3-e2dd9ae619ab",
#         "online": false,
#         "server": null,
#         "contributed": 0,
#         "contributionRank": 79,
#         "joined": "2026-02-22T05:07:24.051000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       },
#       "Pogo_Duck": {
#         "uuid": "f2fb427f-1ccc-495f-90f1-d40ad5de42f9",
#         "online": false,
#         "server": null,
#         "contributed": 0,
#         "contributionRank": 80,
#         "joined": "2026-02-24T23:40:27.364000Z",
#         "guildRaids": {
#           "total": 0,
#           "list": {
#             "The Canyon Colossus": 0,
#             "Orphion's Nexus of Light": 0,
#             "Nest of the Grootslangs": 0,
#             "The Nameless Anomaly": 0
#           }
#         }
#       }
#     }
#   },
#   "online": 7,
#   "banner": {
#     "base": "BLACK",
#     "tier": 3,
#     "structure": "tier3",
#     "layers": [
#       {
#         "colour": "SILVER",
#         "pattern": "FLOWER"
#       },
#       {
#         "colour": "BLACK",
#         "pattern": "SKULL"
#       },
#       {
#         "colour": "GRAY",
#         "pattern": "RHOMBUS_MIDDLE"
#       },
#       {
#         "colour": "BLACK",
#         "pattern": "CIRCLE_MIDDLE"
#       },
#       {
#         "colour": "BLACK",
#         "pattern": "TRIANGLE_TOP"
#       }
#     ]
#   },
#   "seasonRanks": {
#     "29": {
#       "rating": 470918,
#       "finalTerritories": 0
#     }
#   }
# }

# %%
guild_data = guild_req.json()
# print(guild_data["members"])
all_members = []
guild_break_username = {}
guild_break_down = {}
for key in guild_data['members'].keys():
    if key =="total":
        continue
    guild_break_down[key] = []
    guild_break_username[key] = []
    for member in guild_data['members'][key]:
        guild_break_username[key].append(member)
        guild_break_down[key].append(guild_data['members'][key][member]['uuid'])
        all_members.append(guild_data['members'][key][member]['uuid'])

# %%
print(json.dumps(guild_data['members']['recruiter']['Thund3rMC'], indent=2))
# Out:
# {
#   "uuid": "0254668f-5453-408d-aa18-d44d8619c215",
#   "online": false,
#   "server": null,
#   "contributed": 7267230,
#   "contributionRank": 39,
#   "joined": "2026-01-29T18:40:14.004000Z",
#   "guildRaids": {
#     "total": 0,
#     "list": {
#       "The Canyon Colossus": 0,
#       "Orphion's Nexus of Light": 0,
#       "Nest of the Grootslangs": 0,
#       "The Nameless Anomaly": 0
#     }
#   }
# }

# %%
# print(json.dumps(guild_break_username, indent=2))
for key in guild_break_down.keys():
    print(f"There are {len(guild_break_down[key])} {key}'s")
# print(f"And {len(all_members)} total members")
# print(guild_break_down)
# Out:
# There are 1 owner's
# There are 10 chief's
# There are 8 strategist's
# There are 17 captain's
# There are 23 recruiter's
# There are 21 recruit's

# %%
print(json.dumps(guild_break_down, indent=2))
# Out:
# {
#   "owner": [
#     "a8e5c7c3-444f-4436-b69f-a8db58cdf40d"
#   ],
#   "chief": [
#     "91be9a75-7398-47e0-8c4d-f79df2fc035f",
#     "5652732f-e36b-4ca4-87ca-59f9c6dc3ba1",
#     "0a19dd60-254e-4c48-9d76-1b57a2f12c7f",
#     "4a82c3ac-be5d-4115-a822-f2a9c7bdb096",
#     "bd5c1697-4d42-41dd-a4f2-2c8a3a669104",
#     "1a3f6b2a-993b-49ed-8542-7584081864b6",
#     "845eed02-175a-44b4-87a2-0228b1fbc3ee",
#     "89cdeb83-0958-4563-a606-0a460e13abfa",
#     "4470c807-1394-4930-937d-1680d508d22d",
#     "eb33d516-a34b-4050-bd2c-69a24bf0bd75"
#   ],
#   "strategist": [
#     "1b6568dd-4e58-442f-918f-90926f58de0c",
#     "130612b6-1d46-49c7-b06e-3200959254c7",
#     "a8ff0b79-9511-47b7-8705-b657eba980aa",
#     "f46a3aa1-ed18-48f4-bcf9-594e0ff19842",
#     "c32bfbf5-9665-4ad1-837e-92fa882288a3",
#     "ce2fc852-9b0e-41d2-a323-603be70f5b69",
#     "9604c081-52b1-4224-8107-b00885644c84",
#     "96512a2a-4200-463e-8974-27a4c81947cd"
#   ],
#   "captain": [
#     "a27ae078-8209-4c2e-85ea-57de6168cc9b",
#     "81c0cf7a-43f9-4aaf-8783-4953970e394d",
#     "b3be31d6-e441-4299-a342-685898f35f30",
#     "06793d89-e8ea-4ec2-aa55-4c5f03b93026",
#     "ae32ae54-c15c-4c6d-ab46-3bdcec6e2e7f",
#     "3ed556ef-70ef-4d27-8bae-c2cff73f9b20",
#     "bf6fd3d8-f0b2-4831-9dc2-77db02b015d7",
#     "d680883b-e7b2-4bfc-bad7-79372d97c60d",
#     "2ad7fd38-792d-4862-ba2a-b7e1c1723b18",
#     "065f7a4a-e15a-4bbf-ab2f-b55051e0b6de",
#     "cff26bb4-bad0-4de2-8559-19d23e2d9d41",
#     "823ee888-e114-4ca9-9781-7086b5430a54",
#     "9ce7b212-c818-41cf-bd2a-9a2ad4f0e5df",
#     "b7d4a9f2-73ba-47b6-bc7c-d8db98ad6a2e",
#     "d0344f4e-a5fb-48ee-9359-1c82fb2320aa",
#     "9c413f4a-9e5f-46e9-8b89-abdd46f3f74b",
#     "b0135e82-95b5-432b-a008-d7a8d6829e07"
#   ],
#   "recruiter": [
#     "9731aa53-56d8-43e2-99d1-86e5e2efd7de",
#     "c837e8b4-4e0a-41c4-b397-7b02f8f35f2a",
#     "04be2792-d567-4c0a-aa1d-67242dbcf0a8",
#     "c77bcc5e-ad22-478d-a70e-fa3a255f2f86",
#     "423997a0-9626-479c-97e5-d3517b93083c",
#     "3823b995-b8fa-49f5-8c68-6d1a66bdf215",
#     "1af5a66a-9337-4e66-a69b-35d825f4a62b",
#     "b9112e4d-7141-4922-9fca-47430268445e",
#     "0254668f-5453-408d-aa18-d44d8619c215",
#     "0cea76a6-b7a3-4537-8b64-f98ab836a1e2",
#     "ec784aab-d88e-40df-a5ab-c6a26fc9c671",
#     "5e3c6983-b267-49be-b6f8-7eedb09fddb4",
#     "4c0e0ac7-49e1-4590-b4d6-8fe2f1ca1e26",
#     "aed8039a-4d4e-40e9-ab22-d1ec544ba155",
#     "467ed4aa-50fe-45b3-8705-b65d2a713a8c",
#     "6f327520-de36-4695-b8f1-f67558d0d4fc",
#     "85017f3e-4643-454b-a315-f158dd3971dd",
#     "d99b449a-7b7b-4561-a646-459bf8ab0825",
#     "cfc0ef1a-1951-4343-9adb-7ceb949b06c0",
#     "9867e87a-e526-4da0-8945-e91f339409cc",
#     "eb1d2b6f-cd58-4cc8-b389-05bbfa831a3e",
#     "d3abfd17-2a07-45b1-a5b0-9b76800b53f4",
#     "4ee827d7-5300-4f49-a5ba-3945e454460a"
#   ],
#   "recruit": [
#     "6582d74d-9b97-435e-9781-66cf2aedb17a",
#     "283536d3-5e6f-4c8d-a23b-9fa8a8b50f18",
#     "b22cfe82-4f5d-4b43-b63f-8e33bf3d7835",
#     "fff311d0-b571-4b80-baa2-43adfe981448",
#     "bd589667-31d5-4f6c-95b8-04ddad4b241f",
#     "4bfb9baf-7347-43c8-9c4d-5c55b27c780e",
#     "1b6b5470-e8d6-48c8-a553-5bb52395a662",
#     "2adb411c-37e2-491c-8afd-9a38fc4fdf06",
#     "502073b4-06bc-4f30-8a4f-115e6c9e35af",
#     "3ee651c0-59d3-452d-a98d-214d717bef83",
#     "733e86a2-b926-4257-9658-81a990d2ac0a",
#     "511c4018-f6ca-4ccb-a698-9b64b07c6ad3",
#     "1ebcb3ff-2695-4a54-b482-a22081cb024a",
#     "31cc44b4-4c2d-4d88-8e41-f4a4b0337346",
#     "a4fa7dd2-7cd7-4626-b9f6-3284fc16557a",
#     "02115748-53c2-4a43-afd7-5412d8e01f8a",
#     "94591244-b96c-4675-99fc-b4e9abfac6de",
#     "1285f316-0b50-4d36-ae61-a02ed620c8ff",
#     "e781dac3-37b9-48e8-b588-dc8b5a1e0200",
#     "4489c7f5-9d5a-4b32-b0a3-e2dd9ae619ab",
#     "f2fb427f-1ccc-495f-90f1-d40ad5de42f9"
#   ]
# }

# %%
member_stats = {}
for member in all_members:
    member_data = json.loads(json.dumps(requests.get(player_url + member).json(), default=str))
    
    member_stats[member.lower()] = member_data
    time.sleep(2)
    # print(json.dumps(member_data, indent=2))
    # break

# %%
print(json.dumps(member_stats, indent=2))
# Out:
# {
#   "a8e5c7c3-444f-4436-b69f-a8db58cdf40d": {
#     "username": "Nqn",
#     "online": false,
#     "server": null,
#     "activeCharacter": "429af94a-691d-4f94-b70c-eb944c20b210",
#     "nickname": null,
#     "uuid": "a8e5c7c3-444f-4436-b69f-a8db58cdf40d",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_hero.svg",
#     "legacyRankColour": {
#       "main": "#AA00AA",
#       "sub": "#FF55FF"
#     },
#     "shortenedRank": null,
#     "supportRank": "hero",
#     "veteran": null,
#     "lastJoin": "2026-02-24T00:37:27.444000Z",
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "OWNER",
#       "rankStars": "\u2605\u2605\u2605\u2605\u2605"
#     },
#     "ranking": {
#       "combatSoloLevel": 729,
#       "namelessSrPlayers": 826,
#       "orphionSrPlayers": 1616,
#       "woodcuttingLevel": 1743,
#       "namelessCompletion": 1988,
#       "orphionCompletion": 2168,
#       "fishingLevel": 2244,
#       "warsCompletion": 2274,
#       "guildRaids": 3921,
#       "scribingLevel": 4101,
#       "colossusSrPlayers": 5093,
#       "grootslangSrPlayers": 7087,
#       "colossusCompletion": 7778,
#       "grootslangCompletion": 8856,
#       "farmingLevel": 11532,
#       "totalSoloLevel": 13840,
#       "professionsSoloLevel": 14821,
#       "professionsGlobalLevel": 26784,
#       "totalGlobalLevel": 32087,
#       "playerContent": 32212,
#       "globalPlayerContent": 45337,
#       "combatGlobalLevel": 54876,
#       "weaponsmithingLevel": 74053,
#       "miningLevel": 77249,
#       "armouringLevel": 106672,
#       "alchemismLevel": 1171932,
#       "tailoringLevel": 1195783,
#       "jewelingLevel": 1198700,
#       "cookingLevel": 1227669,
#       "woodworkingLevel": 1595257
#     },
#     "previousRanking": {},
#     "firstJoin": "2022-10-27T09:09:48.757000Z",
#     "playtime": 593.58,
#     "globalData": {
#       "contentCompletion": 789,
#       "wars": 400,
#       "totalLevel": 1543,
#       "mobsKilled": 120545,
#       "chestsFound": 1930,
#       "dungeons": {
#         "total": 204,
#         "list": {
#           "Decrepit Sewers": 29,
#           "Sand-Swept Tomb": 4,
#           "Ice Barrows": 7,
#           "Eldritch Outlook": 8,
#           "Corrupted Galleon's Graveyard": 22,
#           "Corrupted Decrepit Sewers": 22,
#           "Corrupted Infested Pit": 19,
#           "Corrupted Lost Sanctuary": 17,
#           "Corrupted Underworld Crypt": 18,
#           "Corrupted Sand-Swept Tomb": 22,
#           "Corrupted Ice Barrows": 16,
#           "Corrupted Undergrowth Ruins": 16,
#           "Underworld Crypt": 1,
#           "Infested Pit": 2,
#           "Timelost Sanctum": 1
#         }
#       },
#       "raids": {
#         "total": 458,
#         "list": {
#           "The Canyon Colossus": 50,
#           "Orphion's Nexus of Light": 72,
#           "The Nameless Anomaly": 289,
#           "Nest of the Grootslangs": 47
#         }
#       },
#       "worldEvents": 10,
#       "lootruns": 2,
#       "caves": 34,
#       "completedQuests": 72,
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 59,
#         "list": {
#           "The Canyon Colossus": 2,
#           "Orphion's Nexus of Light": 5,
#           "Nest of the Grootslangs": 9,
#           "The Nameless Anomaly": 43
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2022-10-27T09:09:48.757000Z",
#       "playtime": 593.58,
#       "globalData.totalLevel": 1543,
#       "globalData.mobsKilled": 120545,
#       "globalData.completedQuests": 72
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false
#     }
#   },
#   "91be9a75-7398-47e0-8c4d-f79df2fc035f": {
#     "username": "Tisumi",
#     "online": true,
#     "server": "NA16",
#     "activeCharacter": "d94d25fc-d4c2-428d-8d27-5bd36c3a6f64",
#     "nickname": null,
#     "uuid": "91be9a75-7398-47e0-8c4d-f79df2fc035f",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_champion.svg",
#     "legacyRankColour": {
#       "main": "#ffff55",
#       "sub": "#ffaa00"
#     },
#     "shortenedRank": null,
#     "supportRank": "champion",
#     "veteran": null,
#     "lastJoin": "2026-02-25T20:27:08.561000Z",
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "CHIEF",
#       "rankStars": "\u2605\u2605\u2605\u2605"
#     },
#     "ranking": {
#       "orphionSrPlayers": 311,
#       "orphionCompletion": 379,
#       "namelessSrPlayers": 812,
#       "combatSoloLevel": 1235,
#       "namelessCompletion": 1754,
#       "colossusSrPlayers": 2009,
#       "warsCompletion": 2043,
#       "guildRaids": 2216,
#       "colossusCompletion": 2852,
#       "grootslangSrPlayers": 3317,
#       "grootslangCompletion": 3535,
#       "alchemismLevel": 3611,
#       "farmingLevel": 6119,
#       "combatGlobalLevel": 6385,
#       "fishingLevel": 7184,
#       "globalPlayerContent": 8936,
#       "scribingLevel": 10562,
#       "totalGlobalLevel": 13715,
#       "totalSoloLevel": 14665,
#       "professionsSoloLevel": 15760,
#       "playerContent": 17884,
#       "woodcuttingLevel": 24029,
#       "professionsGlobalLevel": 27866,
#       "weaponsmithingLevel": 89150,
#       "miningLevel": 115214,
#       "cookingLevel": 122860,
#       "woodworkingLevel": 149313,
#       "tailoringLevel": 1475155,
#       "jewelingLevel": 1477723,
#       "armouringLevel": 1490494
#     },
#     "previousRanking": {},
#     "firstJoin": "2025-09-27T06:31:50.118000Z",
#     "playtime": 954.42,
#     "globalData": {
#       "contentCompletion": 1945,
#       "wars": 477,
#       "totalLevel": 2534,
#       "mobsKilled": 356003,
#       "chestsFound": 1665,
#       "dungeons": {
#         "total": 178,
#         "list": {
#           "Decrepit Sewers": 17,
#           "Infested Pit": 29,
#           "Timelost Sanctum": 14,
#           "Corrupted Decrepit Sewers": 10,
#           "Corrupted Undergrowth Ruins": 14,
#           "Corrupted Infested Pit": 8,
#           "Corrupted Lost Sanctuary": 9,
#           "Corrupted Underworld Crypt": 9,
#           "Corrupted Sand-Swept Tomb": 7,
#           "Corrupted Ice Barrows": 8,
#           "Corrupted Galleon's Graveyard": 6,
#           "Eldritch Outlook": 5,
#           "Underworld Crypt": 12,
#           "Undergrowth Ruins": 13,
#           "Ice Barrows": 12,
#           "Sand-Swept Tomb": 5
#         }
#       },
#       "raids": {
#         "total": 892,
#         "list": {
#           "The Canyon Colossus": 178,
#           "Orphion's Nexus of Light": 261,
#           "The Nameless Anomaly": 331,
#           "Nest of the Grootslangs": 122
#         }
#       },
#       "worldEvents": 37,
#       "lootruns": 2,
#       "caves": 75,
#       "completedQuests": 153,
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 142,
#         "list": {
#           "The Canyon Colossus": 22,
#           "Orphion's Nexus of Light": 6,
#           "Nest of the Grootslangs": 23,
#           "The Nameless Anomaly": 91
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2025-09-27T06:31:50.118000Z",
#       "playtime": 954.42,
#       "globalData.totalLevel": 2534,
#       "globalData.mobsKilled": 356003,
#       "globalData.completedQuests": 153
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false
#     }
#   },
#   "5652732f-e36b-4ca4-87ca-59f9c6dc3ba1": {
#     "username": "_N8",
#     "online": false,
#     "server": "NA33",
#     "activeCharacter": "a0220bdb-9dea-437b-8c00-29f513890c0c",
#     "nickname": null,
#     "uuid": "5652732f-e36b-4ca4-87ca-59f9c6dc3ba1",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_hero.svg",
#     "legacyRankColour": {
#       "main": "#AA00AA",
#       "sub": "#FF55FF"
#     },
#     "shortenedRank": null,
#     "supportRank": "hero",
#     "veteran": null,
#     "lastJoin": "2026-02-25T04:02:03.020000Z",
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "CHIEF",
#       "rankStars": "\u2605\u2605\u2605\u2605"
#     },
#     "ranking": {
#       "combatSoloLevel": 2567,
#       "warsCompletion": 2773,
#       "orphionSrPlayers": 3940,
#       "orphionCompletion": 4562,
#       "woodcuttingLevel": 4675,
#       "namelessSrPlayers": 8317,
#       "guildRaids": 9681,
#       "combatGlobalLevel": 11949,
#       "namelessCompletion": 13332,
#       "globalPlayerContent": 15469,
#       "grootslangSrPlayers": 16938,
#       "grootslangCompletion": 18105,
#       "fishingLevel": 21066,
#       "playerContent": 24008,
#       "totalGlobalLevel": 30300,
#       "totalSoloLevel": 56645,
#       "professionsSoloLevel": 75551,
#       "professionsGlobalLevel": 106469,
#       "miningLevel": 224371,
#       "farmingLevel": 943866,
#       "alchemismLevel": 2181212,
#       "scribingLevel": 2191789,
#       "tailoringLevel": 2193229,
#       "jewelingLevel": 2194805,
#       "armouringLevel": 2202401,
#       "cookingLevel": 2209645,
#       "weaponsmithingLevel": 2388243,
#       "woodworkingLevel": 2397589
#     },
#     "previousRanking": {},
#     "firstJoin": "2014-09-04T02:43:52.467000Z",
#     "playtime": 609.75,
#     "globalData": {
#       "contentCompletion": 1502,
#       "wars": 289,
#       "totalLevel": 1421,
#       "mobsKilled": 250989,
#       "chestsFound": 3609,
#       "dungeons": {
#         "total": 117,
#         "list": {
#           "Skeleton": 3,
#           "Spider": 1,
#           "Animal": 1,
#           "Decrepit Sewers": 9,
#           "Sand-Swept Tomb": 1,
#           "Ice Barrows": 5,
#           "Underworld Crypt": 1,
#           "Timelost Sanctum": 1,
#           "Corrupted Infested Pit": 12,
#           "Corrupted Sand-Swept Tomb": 15,
#           "Corrupted Decrepit Sewers": 14,
#           "Corrupted Lost Sanctuary": 11,
#           "Corrupted Underworld Crypt": 10,
#           "Corrupted Ice Barrows": 12,
#           "Corrupted Undergrowth Ruins": 11,
#           "Corrupted Galleon's Graveyard": 9,
#           "Eldritch Outlook": 1
#         }
#       },
#       "raids": {
#         "total": 72,
#         "list": {
#           "Orphion's Nexus of Light": 36,
#           "The Nameless Anomaly": 16,
#           "Nest of the Grootslangs": 20
#         }
#       },
#       "worldEvents": 10,
#       "lootruns": 1,
#       "caves": 99,
#       "completedQuests": 71,
#       "pvp": {
#         "kills": 127,
#         "deaths": 185
#       },
#       "guildRaids": {
#         "total": 8,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 1,
#           "Nest of the Grootslangs": 5,
#           "The Nameless Anomaly": 2
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2014-09-04T02:43:52.467000Z",
#       "playtime": 609.75,
#       "globalData.totalLevel": 1421,
#       "globalData.mobsKilled": 250989,
#       "globalData.completedQuests": 71
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false
#     }
#   },
#   "0a19dd60-254e-4c48-9d76-1b57a2f12c7f": {
#     "username": "GigaFanDeJul",
#     "online": false,
#     "server": "NA9",
#     "activeCharacter": "61fd827d-a222-4c23-bd3d-e53481174b40",
#     "nickname": null,
#     "uuid": "0a19dd60-254e-4c48-9d76-1b57a2f12c7f",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_champion.svg",
#     "legacyRankColour": {
#       "main": "#ffff55",
#       "sub": "#ffaa00"
#     },
#     "shortenedRank": null,
#     "supportRank": "champion",
#     "veteran": false,
#     "lastJoin": "2026-02-24T11:21:58.673000Z",
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "CHIEF",
#       "rankStars": "\u2605\u2605\u2605\u2605"
#     },
#     "ranking": {
#       "weaponsmithingLevel": 682,
#       "cookingLevel": 732,
#       "alchemismLevel": 1038,
#       "scribingLevel": 1062,
#       "armouringLevel": 1193,
#       "jewelingLevel": 1490,
#       "woodcuttingLevel": 2467,
#       "totalSoloLevel": 2782,
#       "professionsSoloLevel": 2786,
#       "guildRaids": 2899,
#       "fishingLevel": 3207,
#       "warsCompletion": 3610,
#       "orphionSrPlayers": 3774,
#       "namelessSrPlayers": 3823,
#       "professionsGlobalLevel": 4422,
#       "colossusSrPlayers": 4800,
#       "orphionCompletion": 5099,
#       "totalGlobalLevel": 5858,
#       "miningLevel": 6197,
#       "combatSoloLevel": 6482,
#       "colossusCompletion": 6957,
#       "grootslangSrPlayers": 7060,
#       "namelessCompletion": 7125,
#       "grootslangCompletion": 8797,
#       "combatGlobalLevel": 21707,
#       "globalPlayerContent": 22435,
#       "playerContent": 26076,
#       "woodworkingLevel": 33397,
#       "farmingLevel": 41354,
#       "tailoringLevel": 3000000
#     },
#     "previousRanking": {},
#     "firstJoin": "2014-07-20T19:12:41.277000Z",
#     "playtime": 698.75,
#     "globalData": {
#       "contentCompletion": 1224,
#       "wars": 181,
#       "totalLevel": 2680,
#       "mobsKilled": 255366,
#       "chestsFound": 3457,
#       "dungeons": {
#         "total": 94,
#         "list": {
#           "Skeleton": 2,
#           "Spider": 2,
#           "Zombie": 1,
#           "Animal": 5,
#           "Silverfish": 2,
#           "Infested Pit": 7,
#           "Decrepit Sewers": 16,
#           "Lost Sanctuary": 1,
#           "Underworld Crypt": 3,
#           "Sand-Swept Tomb": 8,
#           "Ice Barrows": 9,
#           "Corrupted Decrepit Sewers": 5,
#           "Corrupted Infested Pit": 5,
#           "Eldritch Outlook": 2,
#           "Corrupted Lost Sanctuary": 7,
#           "Corrupted Underworld Crypt": 4,
#           "Corrupted Sand-Swept Tomb": 4,
#           "Corrupted Ice Barrows": 3,
#           "Corrupted Undergrowth Ruins": 3,
#           "Corrupted Galleon's Graveyard": 5
#         }
#       },
#       "raids": {
#         "total": 194,
#         "list": {
#           "The Canyon Colossus": 60,
#           "Orphion's Nexus of Light": 32,
#           "The Nameless Anomaly": 54,
#           "Nest of the Grootslangs": 48
#         }
#       },
#       "worldEvents": 18,
#       "lootruns": 1,
#       "caves": 78,
#       "completedQuests": 111,
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 97,
#         "list": {
#           "The Canyon Colossus": 4,
#           "Orphion's Nexus of Light": 14,
#           "Nest of the Grootslangs": 31,
#           "The Nameless Anomaly": 48
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2014-07-20T19:12:41.277000Z",
#       "playtime": 698.75,
#       "globalData.totalLevel": 2680,
#       "globalData.mobsKilled": 255366,
#       "globalData.completedQuests": 111
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false
#     }
#   },
#   "4a82c3ac-be5d-4115-a822-f2a9c7bdb096": {
#     "username": "Krijer1",
#     "online": true,
#     "server": "EU25",
#     "activeCharacter": "a1945914-e28a-4d75-b5a4-2e1a35d0030f",
#     "nickname": null,
#     "uuid": "4a82c3ac-be5d-4115-a822-f2a9c7bdb096",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_hero.svg",
#     "legacyRankColour": {
#       "main": "#AA00AA",
#       "sub": "#FF55FF"
#     },
#     "shortenedRank": null,
#     "supportRank": "hero",
#     "veteran": null,
#     "lastJoin": "2026-02-25T20:27:23.986000Z",
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "CHIEF",
#       "rankStars": "\u2605\u2605\u2605\u2605"
#     },
#     "ranking": {
#       "cookingLevel": 2249,
#       "farmingLevel": 3196,
#       "fishingLevel": 3369,
#       "jewelingLevel": 3423,
#       "namelessSrPlayers": 3641,
#       "warsCompletion": 3817,
#       "totalSoloLevel": 4776,
#       "professionsSoloLevel": 4828,
#       "miningLevel": 4946,
#       "tailoringLevel": 5139,
#       "armouringLevel": 6476,
#       "guildRaids": 6597,
#       "playerContent": 6621,
#       "namelessCompletion": 6876,
#       "grootslangSrPlayers": 7089,
#       "grootslangCompletion": 7094,
#       "totalGlobalLevel": 8180,
#       "colossusSrPlayers": 8935,
#       "combatGlobalLevel": 8964,
#       "professionsGlobalLevel": 9370,
#       "orphionSrPlayers": 10527,
#       "scribingLevel": 11253,
#       "globalPlayerContent": 11366,
#       "orphionCompletion": 12465,
#       "colossusCompletion": 12851,
#       "woodcuttingLevel": 15327,
#       "combatSoloLevel": 18893,
#       "weaponsmithingLevel": 45936,
#       "woodworkingLevel": 105851,
#       "alchemismLevel": 2325100
#     },
#     "previousRanking": {},
#     "firstJoin": "2018-03-07T16:26:49.359000Z",
#     "playtime": 583.08,
#     "globalData": {
#       "contentCompletion": 1745,
#       "wars": 165,
#       "totalLevel": 3363,
#       "mobsKilled": 226501,
#       "chestsFound": 2610,
#       "dungeons": {
#         "total": 167,
#         "list": {
#           "Decrepit Sewers": 38,
#           "Infested Pit": 16,
#           "Underworld Crypt": 10,
#           "Sand-Swept Tomb": 18,
#           "Ice Barrows": 14,
#           "Undergrowth Ruins": 12,
#           "Lost Sanctuary": 2,
#           "Galleon's Graveyard": 5,
#           "Corrupted Decrepit Sewers": 10,
#           "Corrupted Lost Sanctuary": 7,
#           "Corrupted Infested Pit": 7,
#           "Corrupted Underworld Crypt": 6,
#           "Corrupted Sand-Swept Tomb": 6,
#           "Corrupted Ice Barrows": 6,
#           "Corrupted Undergrowth Ruins": 2,
#           "Eldritch Outlook": 2,
#           "Fallen Factory": 3,
#           "Corrupted Galleon's Graveyard": 2,
#           "Timelost Sanctum": 1
#         }
#       },
#       "raids": {
#         "total": 147,
#         "list": {
#           "The Canyon Colossus": 20,
#           "Orphion's Nexus of Light": 10,
#           "The Nameless Anomaly": 57,
#           "Nest of the Grootslangs": 60
#         }
#       },
#       "worldEvents": 25,
#       "lootruns": 5,
#       "caves": 167,
#       "completedQuests": 262,
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 22,
#         "list": {
#           "The Canyon Colossus": 6,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 2,
#           "The Nameless Anomaly": 14
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2018-03-07T16:26:49.359000Z",
#       "playtime": 583.08,
#       "globalData.totalLevel": 3363,
#       "globalData.mobsKilled": 226501,
#       "globalData.completedQuests": 262
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false
#     }
#   },
#   "bd5c1697-4d42-41dd-a4f2-2c8a3a669104": {
#     "username": "Shivnitzl19",
#     "online": false,
#     "server": "NA16",
#     "activeCharacter": "9320f34b-3e61-4a7a-a45b-ca9b9733006c",
#     "nickname": null,
#     "uuid": "bd5c1697-4d42-41dd-a4f2-2c8a3a669104",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_champion.svg",
#     "legacyRankColour": {
#       "main": "#ffff55",
#       "sub": "#ffaa00"
#     },
#     "shortenedRank": null,
#     "supportRank": "champion",
#     "veteran": null,
#     "lastJoin": "2026-02-24T15:25:51.413000Z",
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "CHIEF",
#       "rankStars": "\u2605\u2605\u2605\u2605"
#     },
#     "ranking": {
#       "orphionCompletion": 390,
#       "globalPlayerContent": 487,
#       "weaponsmithingLevel": 597,
#       "combatSoloLevel": 609,
#       "cookingLevel": 636,
#       "playerContent": 641,
#       "combatGlobalLevel": 659,
#       "totalGlobalLevel": 903,
#       "woodworkingLevel": 907,
#       "alchemismLevel": 912,
#       "totalSoloLevel": 929,
#       "professionsSoloLevel": 933,
#       "tailoringLevel": 1066,
#       "scribingLevel": 1092,
#       "armouringLevel": 1182,
#       "professionsGlobalLevel": 1406,
#       "jewelingLevel": 1442,
#       "fishingLevel": 1459,
#       "woodcuttingLevel": 1575,
#       "farmingLevel": 1640,
#       "miningLevel": 2425,
#       "colossusCompletion": 4116,
#       "grootslangCompletion": 5227,
#       "guildRaids": 6957,
#       "namelessSrPlayers": 7561,
#       "warsCompletion": 7845,
#       "orphionSrPlayers": 10198,
#       "namelessCompletion": 11319,
#       "colossusSrPlayers": 13359,
#       "grootslangSrPlayers": 21192
#     },
#     "previousRanking": {},
#     "firstJoin": "2016-04-15T19:23:37.474000Z",
#     "playtime": 6972.42,
#     "globalData": {
#       "contentCompletion": 4993,
#       "wars": 39,
#       "totalLevel": 18850,
#       "mobsKilled": 1231647,
#       "chestsFound": 26876,
#       "dungeons": {
#         "total": 3651,
#         "list": {
#           "Decrepit Sewers": 137,
#           "Underworld Crypt": 84,
#           "Skeleton": 16,
#           "Spider": 19,
#           "Animal": 14,
#           "Zombie": 18,
#           "Silverfish": 15,
#           "Ice": 1,
#           "Jungle": 37,
#           "Corrupted Decrepit Sewers": 110,
#           "Ice Barrows": 64,
#           "Undergrowth Ruins": 65,
#           "Infested Pit": 62,
#           "Galleon's Graveyard": 39,
#           "Lost Sanctuary": 15,
#           "Corrupted Sand-Swept Tomb": 1710,
#           "Corrupted Undergrowth Ruins": 469,
#           "Sand-Swept Tomb": 63,
#           "Corrupted Lost Sanctuary": 151,
#           "Fallen Factory": 47,
#           "Corrupted Underworld Crypt": 131,
#           "Eldritch Outlook": 111,
#           "Corrupted Infested Pit": 100,
#           "Corrupted Ice Barrows": 105,
#           "Corrupted Galleon's Graveyard": 64,
#           "Timelost Sanctum": 4
#         }
#       },
#       "raids": {
#         "total": 480,
#         "list": {
#           "The Canyon Colossus": 118,
#           "Orphion's Nexus of Light": 257,
#           "The Nameless Anomaly": 23,
#           "Nest of the Grootslangs": 82
#         }
#       },
#       "worldEvents": 66,
#       "lootruns": 5,
#       "caves": 395,
#       "completedQuests": 2212,
#       "pvp": {
#         "kills": 50,
#         "deaths": 30
#       },
#       "guildRaids": {
#         "total": 19,
#         "list": {
#           "The Canyon Colossus": 1,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 10,
#           "The Nameless Anomaly": 8
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2016-04-15T19:23:37.474000Z",
#       "playtime": 6972.42,
#       "globalData.totalLevel": 18850,
#       "globalData.mobsKilled": 1231647,
#       "globalData.completedQuests": 2212
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false
#     }
#   },
#   "1a3f6b2a-993b-49ed-8542-7584081864b6": {
#     "username": "Xentell",
#     "online": false,
#     "server": "NA45",
#     "activeCharacter": "ebb15fb7-c56b-4004-bf94-a0a4f49941ac",
#     "nickname": null,
#     "uuid": "1a3f6b2a-993b-49ed-8542-7584081864b6",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_hero.svg",
#     "legacyRankColour": {
#       "main": "#AA00AA",
#       "sub": "#FF55FF"
#     },
#     "shortenedRank": null,
#     "supportRank": "hero",
#     "veteran": null,
#     "lastJoin": "2026-02-22T07:26:54.193000Z",
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "CHIEF",
#       "rankStars": "\u2605\u2605\u2605\u2605"
#     },
#     "ranking": {
#       "cookingLevel": 2380,
#       "farmingLevel": 3249,
#       "fishingLevel": 3648,
#       "namelessSrPlayers": 5408,
#       "warsCompletion": 7910,
#       "orphionSrPlayers": 8157,
#       "namelessCompletion": 9321,
#       "guildRaids": 9384,
#       "orphionCompletion": 11162,
#       "playerContent": 14780,
#       "totalSoloLevel": 14786,
#       "professionsSoloLevel": 15833,
#       "combatSoloLevel": 16269,
#       "colossusSrPlayers": 18368,
#       "colossusCompletion": 28338,
#       "professionsGlobalLevel": 28568,
#       "miningLevel": 31387,
#       "totalGlobalLevel": 42140,
#       "globalPlayerContent": 46312,
#       "grootslangSrPlayers": 57559,
#       "woodworkingLevel": 63449,
#       "grootslangCompletion": 92003,
#       "combatGlobalLevel": 121499,
#       "weaponsmithingLevel": 153915,
#       "woodcuttingLevel": 159636,
#       "alchemismLevel": 2914142,
#       "scribingLevel": 2917210,
#       "tailoringLevel": 2917807,
#       "jewelingLevel": 2918239,
#       "armouringLevel": 2920548
#     },
#     "previousRanking": {},
#     "firstJoin": "2022-06-06T03:40:15.768000Z",
#     "playtime": 254.92,
#     "globalData": {
#       "contentCompletion": 778,
#       "wars": 37,
#       "totalLevel": 1155,
#       "mobsKilled": 77024,
#       "chestsFound": 2086,
#       "dungeons": {
#         "total": 55,
#         "list": {
#           "Decrepit Sewers": 7,
#           "Infested Pit": 2,
#           "Underworld Crypt": 1,
#           "Timelost Sanctum": 1,
#           "Sand-Swept Tomb": 4,
#           "Ice Barrows": 2,
#           "Undergrowth Ruins": 6,
#           "Galleon's Graveyard": 2,
#           "Eldritch Outlook": 6,
#           "Corrupted Infested Pit": 8,
#           "Corrupted Underworld Crypt": 7,
#           "Corrupted Ice Barrows": 3,
#           "Corrupted Galleon's Graveyard": 2,
#           "Corrupted Undergrowth Ruins": 1,
#           "Corrupted Sand-Swept Tomb": 1,
#           "Corrupted Lost Sanctuary": 1,
#           "Corrupted Decrepit Sewers": 1
#         }
#       },
#       "raids": {
#         "total": 49,
#         "list": {
#           "The Canyon Colossus": 2,
#           "Orphion's Nexus of Light": 12,
#           "The Nameless Anomaly": 34,
#           "Nest of the Grootslangs": 1
#         }
#       },
#       "worldEvents": 6,
#       "lootruns": 5,
#       "caves": 82,
#       "completedQuests": 94,
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 9,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 1,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 8
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2022-06-06T03:40:15.768000Z",
#       "playtime": 254.92,
#       "globalData.totalLevel": 1155,
#       "globalData.mobsKilled": 77024,
#       "globalData.completedQuests": 94
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false
#     }
#   },
#   "845eed02-175a-44b4-87a2-0228b1fbc3ee": {
#     "username": "H1V",
#     "online": false,
#     "server": "NA37",
#     "activeCharacter": "1b875995-3197-47a2-aea2-1c10c2bfb963",
#     "nickname": null,
#     "uuid": "845eed02-175a-44b4-87a2-0228b1fbc3ee",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_hero.svg",
#     "legacyRankColour": {
#       "main": "#AA00AA",
#       "sub": "#FF55FF"
#     },
#     "shortenedRank": null,
#     "supportRank": "hero",
#     "veteran": null,
#     "lastJoin": "2026-02-24T05:20:50.897000Z",
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "CHIEF",
#       "rankStars": "\u2605\u2605\u2605\u2605"
#     },
#     "ranking": {
#       "playerContent": 699,
#       "orphionSrPlayers": 1426,
#       "huntedContent": 1655,
#       "orphionCompletion": 1676,
#       "globalPlayerContent": 1944,
#       "woodcuttingLevel": 1992,
#       "namelessSrPlayers": 1992,
#       "guildRaids": 2032,
#       "farmingLevel": 2162,
#       "miningLevel": 2578,
#       "fishingLevel": 2910,
#       "grootslangSrPlayers": 3551,
#       "namelessCompletion": 3731,
#       "grootslangCompletion": 3747,
#       "colossusSrPlayers": 3848,
#       "combatSoloLevel": 4601,
#       "colossusCompletion": 4920,
#       "combatGlobalLevel": 7482,
#       "warsCompletion": 8863,
#       "totalGlobalLevel": 11074,
#       "totalSoloLevel": 11170,
#       "professionsSoloLevel": 11813,
#       "professionsGlobalLevel": 17010,
#       "jewelingLevel": 35899,
#       "cookingLevel": 54144,
#       "weaponsmithingLevel": 112440,
#       "woodworkingLevel": 132588,
#       "alchemismLevel": 1617584,
#       "scribingLevel": 1633883,
#       "tailoringLevel": 1636090,
#       "armouringLevel": 1649902
#     },
#     "previousRanking": {},
#     "firstJoin": "2017-05-26T22:42:00.776000Z",
#     "playtime": 1144.33,
#     "globalData": {
#       "contentCompletion": 3381,
#       "wars": 28,
#       "totalLevel": 3243,
#       "mobsKilled": 230530,
#       "chestsFound": 5699,
#       "dungeons": {
#         "total": 366,
#         "list": {
#           "Decrepit Sewers": 27,
#           "Infested Pit": 33,
#           "Lost Sanctuary": 14,
#           "Underworld Crypt": 12,
#           "Ice Barrows": 17,
#           "Undergrowth Ruins": 13,
#           "Galleon's Graveyard": 9,
#           "Corrupted Lost Sanctuary": 11,
#           "Fallen Factory": 8,
#           "Corrupted Decrepit Sewers": 12,
#           "Corrupted Infested Pit": 12,
#           "Corrupted Underworld Crypt": 17,
#           "Corrupted Sand-Swept Tomb": 116,
#           "Corrupted Ice Barrows": 9,
#           "Corrupted Undergrowth Ruins": 10,
#           "Corrupted Galleon's Graveyard": 13,
#           "Eldritch Outlook": 15,
#           "Timelost Sanctum": 3,
#           "Sand-Swept Tomb": 15
#         }
#       },
#       "raids": {
#         "total": 436,
#         "list": {
#           "The Canyon Colossus": 95,
#           "Orphion's Nexus of Light": 90,
#           "The Nameless Anomaly": 136,
#           "Nest of the Grootslangs": 115
#         }
#       },
#       "worldEvents": 66,
#       "lootruns": 5,
#       "caves": 487,
#       "completedQuests": 549,
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 159,
#         "list": {
#           "The Canyon Colossus": 11,
#           "Orphion's Nexus of Light": 39,
#           "Nest of the Grootslangs": 47,
#           "The Nameless Anomaly": 62
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2017-05-26T22:42:00.776000Z",
#       "playtime": 1144.33,
#       "globalData.totalLevel": 3243,
#       "globalData.mobsKilled": 230530,
#       "globalData.completedQuests": 549
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false
#     }
#   },
#   "89cdeb83-0958-4563-a606-0a460e13abfa": {
#     "username": "ewenfi",
#     "online": false,
#     "server": "EU2",
#     "activeCharacter": "286b2ef3-6a96-40a5-a72d-0c65b357a099",
#     "nickname": null,
#     "uuid": "89cdeb83-0958-4563-a606-0a460e13abfa",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_vipplus.svg",
#     "legacyRankColour": {
#       "main": "#55ffff",
#       "sub": "#00aaaa"
#     },
#     "shortenedRank": null,
#     "supportRank": "vipplus",
#     "veteran": null,
#     "lastJoin": "2026-02-24T20:52:23.064000Z",
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "CHIEF",
#       "rankStars": "\u2605\u2605\u2605\u2605"
#     },
#     "ranking": {
#       "orphionSrPlayers": 1524,
#       "orphionCompletion": 1961,
#       "colossusSrPlayers": 2340,
#       "colossusCompletion": 2585,
#       "namelessSrPlayers": 3180,
#       "combatSoloLevel": 3189,
#       "guildRaids": 3312,
#       "warsCompletion": 5866,
#       "namelessCompletion": 6257,
#       "grootslangSrPlayers": 7450,
#       "combatGlobalLevel": 8594,
#       "globalPlayerContent": 8816,
#       "grootslangCompletion": 9033,
#       "totalGlobalLevel": 26607,
#       "playerContent": 33600,
#       "miningLevel": 65322,
#       "cookingLevel": 88963,
#       "totalSoloLevel": 93472,
#       "professionsGlobalLevel": 117755,
#       "woodcuttingLevel": 118950,
#       "tailoringLevel": 121007,
#       "weaponsmithingLevel": 125535,
#       "woodworkingLevel": 134488,
#       "farmingLevel": 139526,
#       "professionsSoloLevel": 146086,
#       "armouringLevel": 167338,
#       "fishingLevel": 451749,
#       "alchemismLevel": 1551166,
#       "scribingLevel": 1568154,
#       "jewelingLevel": 1572836
#     },
#     "previousRanking": {},
#     "firstJoin": "2014-10-20T17:11:28.515000Z",
#     "playtime": 954.42,
#     "globalData": {
#       "contentCompletion": 1956,
#       "wars": 71,
#       "totalLevel": 1940,
#       "mobsKilled": 314578,
#       "chestsFound": 10490,
#       "dungeons": {
#         "total": 419,
#         "list": {
#           "Skeleton": 39,
#           "Spider": 34,
#           "Animal": 26,
#           "Zombie": 16,
#           "Silverfish": 12,
#           "Jungle": 6,
#           "Ice Barrows": 14,
#           "Lost Sanctuary": 4,
#           "Undergrowth Ruins": 4,
#           "Decrepit Sewers": 12,
#           "Underworld Crypt": 3,
#           "Fallen Factory": 8,
#           "Corrupted Lost Sanctuary": 37,
#           "Corrupted Sand-Swept Tomb": 53,
#           "Infested Pit": 19,
#           "Sand-Swept Tomb": 20,
#           "Corrupted Infested Pit": 22,
#           "Corrupted Decrepit Sewers": 21,
#           "Corrupted Underworld Crypt": 20,
#           "Corrupted Ice Barrows": 17,
#           "Corrupted Undergrowth Ruins": 16,
#           "Eldritch Outlook": 2,
#           "Corrupted Galleon's Graveyard": 9,
#           "Galleon's Graveyard": 5
#         }
#       },
#       "raids": {
#         "total": 386,
#         "list": {
#           "The Canyon Colossus": 195,
#           "Orphion's Nexus of Light": 79,
#           "The Nameless Anomaly": 66,
#           "Nest of the Grootslangs": 46
#         }
#       },
#       "worldEvents": 4,
#       "lootruns": 2,
#       "caves": 128,
#       "completedQuests": 316,
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 79,
#         "list": {
#           "The Canyon Colossus": 2,
#           "Orphion's Nexus of Light": 12,
#           "Nest of the Grootslangs": 21,
#           "The Nameless Anomaly": 44
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2014-10-20T17:11:28.515000Z",
#       "playtime": 954.42,
#       "globalData.totalLevel": 1940,
#       "globalData.mobsKilled": 314578,
#       "globalData.completedQuests": 316
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false
#     }
#   },
#   "4470c807-1394-4930-937d-1680d508d22d": {
#     "username": "KirouXD",
#     "online": false,
#     "server": "NA13",
#     "activeCharacter": "691aaebd-fdf8-4d07-91a5-24eba41035dc",
#     "nickname": null,
#     "uuid": "4470c807-1394-4930-937d-1680d508d22d",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_hero.svg",
#     "legacyRankColour": {
#       "main": "#AA00AA",
#       "sub": "#FF55FF"
#     },
#     "shortenedRank": null,
#     "supportRank": "hero",
#     "veteran": null,
#     "lastJoin": "2026-02-25T16:49:10.392000Z",
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "CHIEF",
#       "rankStars": "\u2605\u2605\u2605\u2605"
#     },
#     "ranking": {
#       "miningLevel": 501,
#       "fishingLevel": 1264,
#       "woodcuttingLevel": 1404,
#       "jewelingLevel": 1405,
#       "orphionSrPlayers": 2305,
#       "namelessSrPlayers": 3023,
#       "orphionCompletion": 3105,
#       "guildRaids": 4494,
#       "tailoringLevel": 4665,
#       "warsCompletion": 5190,
#       "namelessCompletion": 5927,
#       "colossusSrPlayers": 6677,
#       "totalSoloLevel": 7039,
#       "professionsSoloLevel": 7230,
#       "combatSoloLevel": 8980,
#       "farmingLevel": 9461,
#       "colossusCompletion": 9955,
#       "professionsGlobalLevel": 15124,
#       "grootslangSrPlayers": 16065,
#       "totalGlobalLevel": 21829,
#       "grootslangCompletion": 22575,
#       "playerContent": 28914,
#       "globalPlayerContent": 59454,
#       "combatGlobalLevel": 64652,
#       "cookingLevel": 128480,
#       "weaponsmithingLevel": 149324,
#       "woodworkingLevel": 157345,
#       "alchemismLevel": 2399227,
#       "scribingLevel": 2407536,
#       "armouringLevel": 2416047
#     },
#     "previousRanking": {},
#     "firstJoin": "2025-01-04T18:35:04.361000Z",
#     "playtime": 371.5,
#     "globalData": {
#       "contentCompletion": 655,
#       "wars": 92,
#       "totalLevel": 1136,
#       "mobsKilled": 142615,
#       "chestsFound": 3973,
#       "dungeons": {
#         "total": 65,
#         "list": {
#           "Decrepit Sewers": 14,
#           "Sand-Swept Tomb": 3,
#           "Ice Barrows": 8,
#           "Corrupted Decrepit Sewers": 4,
#           "Corrupted Infested Pit": 3,
#           "Corrupted Lost Sanctuary": 7,
#           "Corrupted Underworld Crypt": 4,
#           "Corrupted Sand-Swept Tomb": 3,
#           "Corrupted Ice Barrows": 8,
#           "Corrupted Undergrowth Ruins": 3,
#           "Corrupted Galleon's Graveyard": 8
#         }
#       },
#       "raids": {
#         "total": 173,
#         "list": {
#           "The Canyon Colossus": 33,
#           "Orphion's Nexus of Light": 53,
#           "The Nameless Anomaly": 72,
#           "Nest of the Grootslangs": 15
#         }
#       },
#       "worldEvents": 7,
#       "lootruns": 3,
#       "caves": 37,
#       "completedQuests": 54,
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 47,
#         "list": {
#           "The Canyon Colossus": 2,
#           "Orphion's Nexus of Light": 17,
#           "Nest of the Grootslangs": 11,
#           "The Nameless Anomaly": 17
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2025-01-04T18:35:04.361000Z",
#       "playtime": 371.5,
#       "globalData.totalLevel": 1136,
#       "globalData.mobsKilled": 142615,
#       "globalData.completedQuests": 54
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false
#     }
#   },
#   "eb33d516-a34b-4050-bd2c-69a24bf0bd75": {
#     "username": "Chevacchi",
#     "online": false,
#     "server": "NA5",
#     "activeCharacter": "b89645ff-332e-4ea7-9dd8-8711f4c5385d",
#     "nickname": null,
#     "uuid": "eb33d516-a34b-4050-bd2c-69a24bf0bd75",
#     "rank": "Player",
#     "rankBadge": null,
#     "legacyRankColour": null,
#     "shortenedRank": null,
#     "supportRank": null,
#     "veteran": null,
#     "lastJoin": "2026-02-25T13:41:06.194000Z",
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "CHIEF",
#       "rankStars": "\u2605\u2605\u2605\u2605"
#     },
#     "ranking": {
#       "warsCompletion": 2004,
#       "guildRaids": 9841,
#       "namelessSrPlayers": 11313,
#       "colossusSrPlayers": 15807,
#       "namelessCompletion": 17436,
#       "grootslangSrPlayers": 20286,
#       "combatGlobalLevel": 20637,
#       "orphionSrPlayers": 23174,
#       "colossusCompletion": 23960,
#       "grootslangCompletion": 25637,
#       "combatSoloLevel": 28492,
#       "orphionCompletion": 31913,
#       "globalPlayerContent": 52638,
#       "totalGlobalLevel": 60279,
#       "playerContent": 78664,
#       "cookingLevel": 95104,
#       "farmingLevel": 110493,
#       "totalSoloLevel": 209785,
#       "alchemismLevel": 361635,
#       "scribingLevel": 390446,
#       "tailoringLevel": 394670,
#       "jewelingLevel": 398876,
#       "armouringLevel": 419720,
#       "professionsGlobalLevel": 426240,
#       "professionsSoloLevel": 504042,
#       "weaponsmithingLevel": 927040,
#       "woodworkingLevel": 951579,
#       "fishingLevel": 1333891,
#       "miningLevel": 1369125,
#       "woodcuttingLevel": 1760700
#     },
#     "previousRanking": {},
#     "firstJoin": "2026-01-06T11:23:14.364000Z",
#     "playtime": 328.58,
#     "globalData": {
#       "contentCompletion": 713,
#       "wars": 489,
#       "totalLevel": 1033,
#       "mobsKilled": 92516,
#       "chestsFound": 6,
#       "dungeons": {
#         "total": 1,
#         "list": {
#           "Eldritch Outlook": 1
#         }
#       },
#       "raids": {
#         "total": 23,
#         "list": {
#           "The Nameless Anomaly": 7,
#           "Nest of the Grootslangs": 12,
#           "The Canyon Colossus": 3,
#           "Orphion's Nexus of Light": 1
#         }
#       },
#       "worldEvents": 1,
#       "lootruns": 0,
#       "caves": 1,
#       "completedQuests": 26,
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 7,
#         "list": {
#           "The Canyon Colossus": 3,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 4
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2026-01-06T11:23:14.364000Z",
#       "playtime": 328.58,
#       "globalData.totalLevel": 1033,
#       "globalData.mobsKilled": 92516,
#       "globalData.completedQuests": 26
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false
#     }
#   },
#   "1b6568dd-4e58-442f-918f-90926f58de0c": {
#     "username": "clohi",
#     "online": true,
#     "server": "NA16",
#     "activeCharacter": "2f9d6120-d3d9-4f15-8bce-c19c85cb3e82",
#     "nickname": null,
#     "uuid": "1b6568dd-4e58-442f-918f-90926f58de0c",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_champion.svg",
#     "legacyRankColour": {
#       "main": "#ffff55",
#       "sub": "#ffaa00"
#     },
#     "shortenedRank": null,
#     "supportRank": "champion",
#     "veteran": null,
#     "lastJoin": "2026-02-25T20:28:08.447000Z",
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "STRATEGIST",
#       "rankStars": "\u2605\u2605\u2605"
#     },
#     "ranking": {
#       "combatGlobalLevel": 1901,
#       "orphionCompletion": 2153,
#       "colossusCompletion": 2325,
#       "globalPlayerContent": 3160,
#       "warsCompletion": 4227,
#       "totalGlobalLevel": 4755,
#       "colossusSrPlayers": 6598,
#       "combatSoloLevel": 7314,
#       "namelessSrPlayers": 8494,
#       "professionsGlobalLevel": 9958,
#       "guildRaids": 12033,
#       "woodcuttingLevel": 13348,
#       "orphionSrPlayers": 13543,
#       "namelessCompletion": 13794,
#       "fishingLevel": 21562,
#       "grootslangCompletion": 22749,
#       "farmingLevel": 36264,
#       "scribingLevel": 47050,
#       "totalSoloLevel": 50920,
#       "grootslangSrPlayers": 57507,
#       "miningLevel": 62297,
#       "playerContent": 64358,
#       "professionsSoloLevel": 65928,
#       "jewelingLevel": 69035,
#       "woodworkingLevel": 82436,
#       "weaponsmithingLevel": 502002,
#       "alchemismLevel": 2900071,
#       "tailoringLevel": 2903874,
#       "armouringLevel": 2906727,
#       "cookingLevel": 2908847
#     },
#     "previousRanking": {},
#     "firstJoin": "2016-08-21T03:15:53.461000Z",
#     "playtime": 2335.92,
#     "globalData": {
#       "contentCompletion": 2896,
#       "wars": 139,
#       "totalLevel": 5094,
#       "mobsKilled": 741887,
#       "chestsFound": 18746,
#       "dungeons": {
#         "total": 2127,
#         "list": {
#           "Decrepit Sewers": 87,
#           "Infested Pit": 22,
#           "Lost Sanctuary": 15,
#           "Underworld Crypt": 75,
#           "Sand-Swept Tomb": 98,
#           "Ice Barrows": 35,
#           "Undergrowth Ruins": 30,
#           "Fallen Factory": 43,
#           "Corrupted Sand-Swept Tomb": 1095,
#           "Corrupted Underworld Crypt": 71,
#           "Corrupted Decrepit Sewers": 141,
#           "Corrupted Infested Pit": 66,
#           "Corrupted Ice Barrows": 98,
#           "Corrupted Lost Sanctuary": 84,
#           "Corrupted Undergrowth Ruins": 108,
#           "Galleon's Graveyard": 18,
#           "Eldritch Outlook": 16,
#           "Corrupted Galleon's Graveyard": 25
#         }
#       },
#       "raids": {
#         "total": 320,
#         "list": {
#           "The Canyon Colossus": 217,
#           "Orphion's Nexus of Light": 73,
#           "Nest of the Grootslangs": 15,
#           "The Nameless Anomaly": 15
#         }
#       },
#       "worldEvents": 8,
#       "lootruns": 2,
#       "caves": 70,
#       "completedQuests": 608,
#       "pvp": {
#         "kills": 107,
#         "deaths": 65
#       },
#       "guildRaids": {
#         "total": 4,
#         "list": {
#           "The Canyon Colossus": 3,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 1
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2016-08-21T03:15:53.461000Z",
#       "playtime": 2335.92,
#       "globalData.totalLevel": 5094,
#       "globalData.mobsKilled": 741887,
#       "globalData.completedQuests": 608
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false
#     }
#   },
#   "130612b6-1d46-49c7-b06e-3200959254c7": {
#     "username": "_Snoopers_",
#     "online": true,
#     "server": "NA16",
#     "activeCharacter": "493271d2-4e50-4082-81aa-c9413698471c",
#     "nickname": null,
#     "uuid": "130612b6-1d46-49c7-b06e-3200959254c7",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_hero.svg",
#     "legacyRankColour": {
#       "main": "#AA00AA",
#       "sub": "#FF55FF"
#     },
#     "shortenedRank": null,
#     "supportRank": "hero",
#     "veteran": null,
#     "lastJoin": "2026-02-25T20:28:07.596000Z",
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "STRATEGIST",
#       "rankStars": "\u2605\u2605\u2605"
#     },
#     "ranking": {
#       "playerContent": 2146,
#       "guildRaids": 6766,
#       "orphionSrPlayers": 7527,
#       "warsCompletion": 8014,
#       "namelessSrPlayers": 9613,
#       "colossusSrPlayers": 9962,
#       "orphionCompletion": 9986,
#       "grootslangSrPlayers": 12983,
#       "colossusCompletion": 15176,
#       "grootslangCompletion": 15270,
#       "namelessCompletion": 15534,
#       "globalPlayerContent": 19868,
#       "combatSoloLevel": 26600,
#       "cookingLevel": 57979,
#       "combatGlobalLevel": 62437,
#       "totalSoloLevel": 87123,
#       "totalGlobalLevel": 92333,
#       "fishingLevel": 96649,
#       "miningLevel": 130143,
#       "professionsSoloLevel": 131674,
#       "woodcuttingLevel": 132593,
#       "professionsGlobalLevel": 153031,
#       "weaponsmithingLevel": 154660,
#       "woodworkingLevel": 162438,
#       "farmingLevel": 326029,
#       "jewelingLevel": 3000000,
#       "scribingLevel": 3000000,
#       "alchemismLevel": 3000000,
#       "armouringLevel": 3000000,
#       "tailoringLevel": 3000000
#     },
#     "previousRanking": {},
#     "firstJoin": "2021-01-24T01:06:25.411000Z",
#     "playtime": 359.17,
#     "globalData": {
#       "contentCompletion": 1313,
#       "wars": 36,
#       "totalLevel": 5262,
#       "mobsKilled": 78689,
#       "chestsFound": 2352,
#       "dungeons": {
#         "total": 115,
#         "list": {
#           "Decrepit Sewers": 22,
#           "Infested Pit": 27,
#           "Lost Sanctuary": 1,
#           "Underworld Crypt": 21,
#           "Timelost Sanctum": 6,
#           "Sand-Swept Tomb": 12,
#           "Ice Barrows": 5,
#           "Undergrowth Ruins": 2,
#           "Galleon's Graveyard": 2,
#           "Corrupted Lost Sanctuary": 1,
#           "Corrupted Underworld Crypt": 6,
#           "Corrupted Decrepit Sewers": 1,
#           "Corrupted Infested Pit": 1,
#           "Fallen Factory": 2,
#           "Eldritch Outlook": 2,
#           "Corrupted Galleon's Graveyard": 4
#         }
#       },
#       "raids": {
#         "total": 65,
#         "list": {
#           "The Canyon Colossus": 15,
#           "Orphion's Nexus of Light": 14,
#           "The Nameless Anomaly": 11,
#           "Nest of the Grootslangs": 25
#         }
#       },
#       "worldEvents": 53,
#       "lootruns": 5,
#       "caves": 205,
#       "completedQuests": 230,
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 21,
#         "list": {
#           "The Canyon Colossus": 5,
#           "Orphion's Nexus of Light": 1,
#           "Nest of the Grootslangs": 12,
#           "The Nameless Anomaly": 3
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2021-01-24T01:06:25.411000Z",
#       "playtime": 359.17,
#       "globalData.totalLevel": 5262,
#       "globalData.mobsKilled": 78689,
#       "globalData.completedQuests": 230
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false
#     }
#   },
#   "a8ff0b79-9511-47b7-8705-b657eba980aa": {
#     "username": "LaserX",
#     "online": false,
#     "server": "EU8",
#     "activeCharacter": "638111c0-ecb0-4ee8-a082-15ecf015ee33",
#     "nickname": null,
#     "uuid": "a8ff0b79-9511-47b7-8705-b657eba980aa",
#     "rank": "Player",
#     "rankBadge": null,
#     "legacyRankColour": null,
#     "shortenedRank": null,
#     "supportRank": null,
#     "veteran": null,
#     "lastJoin": "2026-02-25T16:01:21.154000Z",
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "STRATEGIST",
#       "rankStars": "\u2605\u2605\u2605"
#     },
#     "ranking": {
#       "grootslangSrPlayers": 2786,
#       "grootslangCompletion": 3110,
#       "guildRaids": 4832,
#       "warsCompletion": 5778,
#       "globalPlayerContent": 7388,
# ...
#       "tailoringLevel": 65093,
#       "cookingLevel": 67053,
#       "weaponsmithingLevel": 68901,
#       "armouringLevel": 113117,
#       "woodworkingLevel": 400803,
#       "alchemismLevel": 1423068,
#       "jewelingLevel": 1446469
#     },
#     "previousRanking": {},
#     "firstJoin": "2020-12-01T15:03:33.911000Z",
#     "playtime": 1786.58,
#     "globalData": {
#       "contentCompletion": 2408,
#       "wars": 80,
#       "totalLevel": 5285,
#       "mobsKilled": 745660,
#       "chestsFound": 77224,
#       "dungeons": {
#         "total": 218,
#         "list": {
#           "Decrepit Sewers": 47,
#           "Corrupted Infested Pit": 15,
#           "Corrupted Lost Sanctuary": 23,
#           "Corrupted Sand-Swept Tomb": 11,
#           "Corrupted Undergrowth Ruins": 42,
#           "Eldritch Outlook": 7,
#           "Fallen Factory": 8,
#           "Ice Barrows": 6,
#           "Corrupted Ice Barrows": 9,
#           "Corrupted Decrepit Sewers": 14,
#           "Infested Pit": 21,
#           "Corrupted Underworld Crypt": 9,
#           "Sand-Swept Tomb": 1,
#           "Corrupted Galleon's Graveyard": 3,
#           "Lost Sanctuary": 1,
#           "Underworld Crypt": 1
#         }
#       },
#       "raids": {
#         "total": 342,
#         "list": {
#           "The Canyon Colossus": 131,
#           "Nest of the Grootslangs": 79,
#           "The Nameless Anomaly": 86,
#           "Orphion's Nexus of Light": 46
#         }
#       },
#       "worldEvents": 15,
#       "lootruns": 5,
#       "caves": 110,
#       "completedQuests": 209,
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 71,
#         "list": {
#           "The Canyon Colossus": 7,
#           "Orphion's Nexus of Light": 15,
#           "Nest of the Grootslangs": 35,
#           "The Nameless Anomaly": 14
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2020-12-01T15:03:33.911000Z",
#       "playtime": 1786.58,
#       "globalData.totalLevel": 5285,
#       "globalData.mobsKilled": 745660,
#       "globalData.completedQuests": 209
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false
#     }
#   },
#   "1285f316-0b50-4d36-ae61-a02ed620c8ff": {
#     "username": "skrybs",
#     "online": false,
#     "server": "NA19",
#     "activeCharacter": "dad71a9b-eb0d-4dc1-bd9a-4a6ecbda11e0",
#     "nickname": null,
#     "uuid": "1285f316-0b50-4d36-ae61-a02ed620c8ff",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_champion.svg",
#     "legacyRankColour": {
#       "main": "#ffff55",
#       "sub": "#ffaa00"
#     },
#     "shortenedRank": null,
#     "supportRank": "champion",
#     "veteran": null,
#     "lastJoin": "2026-02-25T02:01:27.901000Z",
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "RECRUIT",
#       "rankStars": null
#     },
#     "ranking": {
#       "globalPlayerContent": 469,
#       "combatGlobalLevel": 978,
#       "totalGlobalLevel": 2105,
#       "weaponsmithingLevel": 3546,
#       "professionsGlobalLevel": 3770,
#       "professionsSoloLevel": 4376,
#       "woodworkingLevel": 4605,
#       "totalSoloLevel": 4665,
#       "alchemismLevel": 4800,
#       "cookingLevel": 5122,
#       "scribingLevel": 5815,
#       "armouringLevel": 6005,
#       "tailoringLevel": 6289,
#       "jewelingLevel": 6587,
#       "woodcuttingLevel": 6631,
#       "playerContent": 7990,
#       "farmingLevel": 9745,
#       "fishingLevel": 10764,
#       "miningLevel": 13215,
#       "combatSoloLevel": 32250,
#       "grootslangSrPlayers": 46467,
#       "grootslangCompletion": 47815
#     },
#     "previousRanking": {},
#     "firstJoin": "2018-02-17T01:00:46.383000Z",
#     "playtime": 1170.5,
#     "globalData": {
#       "contentCompletion": 5045,
#       "wars": 0,
#       "totalLevel": 7766,
#       "mobsKilled": 216695,
#       "chestsFound": 5775,
#       "dungeons": {
#         "total": 809,
#         "list": {
#           "Decrepit Sewers": 20,
#           "Infested Pit": 7,
#           "Corrupted Sand-Swept Tomb": 553,
#           "Sand-Swept Tomb": 18,
#           "Corrupted Ice Barrows": 14,
#           "Ice Barrows": 12,
#           "Corrupted Undergrowth Ruins": 97,
#           "Corrupted Infested Pit": 8,
#           "Corrupted Decrepit Sewers": 16,
#           "Corrupted Lost Sanctuary": 7,
#           "Eldritch Outlook": 2,
#           "Undergrowth Ruins": 14,
#           "Corrupted Underworld Crypt": 6,
#           "Lost Sanctuary": 2,
#           "Underworld Crypt": 15,
#           "Galleon's Graveyard": 10,
#           "Timelost Sanctum": 4,
#           "Fallen Factory": 2,
#           "Corrupted Galleon's Graveyard": 2
#         }
#       },
#       "raids": {
#         "total": 5,
#         "list": {
#           "Nest of the Grootslangs": 5
#         }
#       },
#       "worldEvents": 3,
#       "lootruns": 1,
#       "caves": 570,
#       "completedQuests": 1131,
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2018-02-17T01:00:46.383000Z",
#       "playtime": 1170.5,
#       "globalData.totalLevel": 7766,
#       "globalData.mobsKilled": 216695,
#       "globalData.completedQuests": 1131
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false
#     }
#   },
#   "e781dac3-37b9-48e8-b588-dc8b5a1e0200": {
#     "username": "Bluvey",
#     "online": false,
#     "server": "NA10",
#     "activeCharacter": "b4ad722c-d935-42d6-89e6-1485ccce9c60",
#     "nickname": null,
#     "uuid": "e781dac3-37b9-48e8-b588-dc8b5a1e0200",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_vipplus.svg",
#     "legacyRankColour": {
#       "main": "#55ffff",
#       "sub": "#00aaaa"
#     },
#     "shortenedRank": null,
#     "supportRank": "vipplus",
#     "veteran": null,
#     "lastJoin": "2026-02-25T11:41:52.719000Z",
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "RECRUIT",
#       "rankStars": null
#     },
#     "ranking": {
#       "combatSoloLevel": 8702,
#       "orphionSrPlayers": 8841,
#       "colossusSrPlayers": 10764,
#       "orphionCompletion": 11280,
#       "colossusCompletion": 15752,
#       "namelessSrPlayers": 17599,
#       "grootslangSrPlayers": 17982,
#       "playerContent": 20817,
#       "grootslangCompletion": 22975,
#       "namelessCompletion": 25305,
#       "cookingLevel": 50716,
#       "globalPlayerContent": 51657,
#       "combatGlobalLevel": 74573,
#       "totalGlobalLevel": 160512,
#       "totalSoloLevel": 178622,
#       "fishingLevel": 311394,
#       "professionsSoloLevel": 375989,
#       "alchemismLevel": 407401,
#       "professionsGlobalLevel": 417740,
#       "scribingLevel": 435766,
#       "tailoringLevel": 439878,
#       "jewelingLevel": 444063,
#       "armouringLevel": 464585,
#       "woodcuttingLevel": 465919,
#       "farmingLevel": 537445,
#       "miningLevel": 593369,
#       "weaponsmithingLevel": 963816,
#       "woodworkingLevel": 988112
#     },
#     "previousRanking": {},
#     "firstJoin": "2020-11-21T01:47:09.039000Z",
#     "playtime": 149.83,
#     "globalData": {
#       "contentCompletion": 723,
#       "wars": 0,
#       "totalLevel": 521,
#       "mobsKilled": 46692,
#       "chestsFound": 1398,
#       "dungeons": {
#         "total": 41,
#         "list": {
#           "Decrepit Sewers": 3,
#           "Infested Pit": 8,
#           "Sand-Swept Tomb": 8,
#           "Ice Barrows": 7,
#           "Undergrowth Ruins": 6,
#           "Galleon's Graveyard": 1,
#           "Corrupted Lost Sanctuary": 6,
#           "Corrupted Galleon's Graveyard": 2
#         }
#       },
#       "raids": {
#         "total": 38,
#         "list": {
#           "The Canyon Colossus": 12,
#           "Orphion's Nexus of Light": 11,
#           "The Nameless Anomaly": 1,
#           "Nest of the Grootslangs": 14
#         }
#       },
#       "worldEvents": 15,
#       "lootruns": 5,
#       "caves": 109,
#       "completedQuests": 55,
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2020-11-21T01:47:09.039000Z",
#       "playtime": 149.83,
#       "globalData.totalLevel": 521,
#       "globalData.mobsKilled": 46692,
#       "globalData.completedQuests": 55
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false
#     }
#   },
#   "4489c7f5-9d5a-4b32-b0a3-e2dd9ae619ab": {
#     "username": "Laborious",
#     "online": false,
#     "server": "NA8",
#     "activeCharacter": "1fe4a11f-51b5-4d5e-8b46-ebcd409ff02c",
#     "nickname": null,
#     "uuid": "4489c7f5-9d5a-4b32-b0a3-e2dd9ae619ab",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_vip.svg",
#     "legacyRankColour": {
#       "main": "#00aa00",
#       "sub": "#55ff55"
#     },
#     "shortenedRank": null,
#     "supportRank": "vip",
#     "veteran": false,
#     "lastJoin": "2026-02-25T20:02:34.083000Z",
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "RECRUIT",
#       "rankStars": null
#     },
#     "ranking": {
#       "globalPlayerContent": 5711,
#       "playerContent": 6590,
#       "warsCompletion": 6760,
#       "woodworkingLevel": 6867,
#       "namelessCompletion": 10149,
#       "miningLevel": 13485,
#       "combatGlobalLevel": 13575,
#       "combatSoloLevel": 14174,
#       "totalGlobalLevel": 14873,
#       "colossusCompletion": 17304,
#       "professionsGlobalLevel": 20555,
#       "orphionCompletion": 21391,
#       "fishingLevel": 23760,
#       "woodcuttingLevel": 27951,
#       "totalSoloLevel": 34325,
#       "farmingLevel": 35104,
#       "professionsSoloLevel": 40944,
#       "tailoringLevel": 43669,
#       "grootslangCompletion": 60242,
#       "scribingLevel": 65395,
#       "cookingLevel": 73979,
#       "weaponsmithingLevel": 119563,
#       "alchemismLevel": 2398008,
#       "jewelingLevel": 2408750,
#       "armouringLevel": 2414848
#     },
#     "previousRanking": {},
#     "firstJoin": "2014-02-06T00:07:39Z",
#     "playtime": 783.33,
#     "globalData": {
#       "contentCompletion": 2341,
#       "wars": 52,
#       "totalLevel": 3126,
#       "mobsKilled": 162398,
#       "chestsFound": 4293,
#       "dungeons": {
#         "total": 319,
#         "list": {
#           "Skeleton": 21,
#           "Decrepit Sewers": 36,
#           "Underworld Crypt": 25,
#           "Sand-Swept Tomb": 14,
#           "Zombie": 1,
#           "Infested Pit": 24,
#           "Ice Barrows": 11,
#           "Spider": 1,
#           "Animal": 1,
#           "Jungle": 1,
#           "Undergrowth Ruins": 13,
#           "Galleon's Graveyard": 8,
#           "Corrupted Decrepit Sewers": 9,
#           "Corrupted Sand-Swept Tomb": 73,
#           "Fallen Factory": 2,
#           "Eldritch Outlook": 6,
#           "Corrupted Underworld Crypt": 6,
#           "Corrupted Galleon's Graveyard": 3,
#           "Corrupted Undergrowth Ruins": 23,
#           "Corrupted Ice Barrows": 6,
#           "Corrupted Infested Pit": 15,
#           "Corrupted Lost Sanctuary": 10,
#           "Timelost Sanctum": 3,
#           "Lost Sanctuary": 7
#         }
#       },
#       "raids": {
#         "total": 46,
#         "list": {
#           "The Canyon Colossus": 10,
#           "Orphion's Nexus of Light": 4,
#           "The Nameless Anomaly": 29,
#           "Nest of the Grootslangs": 3
#         }
#       },
#       "worldEvents": 1,
#       "lootruns": 4,
#       "caves": 372,
#       "completedQuests": 598,
#       "pvp": {
#         "kills": 0,
#         "deaths": 1
#       },
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2014-02-06T00:07:39Z",
#       "playtime": 783.33,
#       "globalData.totalLevel": 3126,
#       "globalData.mobsKilled": 162398,
#       "globalData.completedQuests": 598
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false
#     }
#   },
#   "f2fb427f-1ccc-495f-90f1-d40ad5de42f9": {
#     "username": "Pogo_Duck",
#     "online": false,
#     "server": "NA29",
#     "activeCharacter": "25f1ccf5-704a-4c2d-805c-44e1a2670521",
#     "nickname": null,
#     "uuid": "f2fb427f-1ccc-495f-90f1-d40ad5de42f9",
#     "rank": "Player",
#     "rankBadge": null,
#     "legacyRankColour": null,
#     "shortenedRank": null,
#     "supportRank": null,
#     "veteran": null,
#     "lastJoin": "2026-02-25T00:03:49.140000Z",
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "RECRUIT",
#       "rankStars": null
#     },
#     "ranking": {
#       "orphionSrPlayers": 3401,
#       "orphionCompletion": 3533,
#       "ironmanContent": 4785,
#       "namelessSrPlayers": 10056,
#       "grootslangSrPlayers": 10561,
#       "grootslangCompletion": 10809,
#       "namelessCompletion": 11716,
#       "colossusSrPlayers": 14881,
#       "colossusCompletion": 15240,
#       "combatSoloLevel": 32216,
#       "globalPlayerContent": 43709,
#       "playerContent": 57895,
#       "combatGlobalLevel": 65394,
#       "weaponsmithingLevel": 114502,
#       "cookingLevel": 115660,
#       "woodworkingLevel": 139120,
#       "totalGlobalLevel": 143997,
#       "totalSoloLevel": 185825,
#       "alchemismLevel": 266765,
#       "scribingLevel": 296491,
#       "tailoringLevel": 300849,
#       "jewelingLevel": 305168,
#       "armouringLevel": 326735,
#       "professionsSoloLevel": 396889,
#       "professionsGlobalLevel": 397641,
#       "miningLevel": 516619,
#       "farmingLevel": 529145,
#       "woodcuttingLevel": 598844,
#       "fishingLevel": 609903
#     },
#     "previousRanking": {},
#     "firstJoin": "2020-10-25T15:22:54.582000Z",
#     "playtime": 350.33,
#     "globalData": {
#       "contentCompletion": 809,
#       "wars": 0,
#       "totalLevel": 1615,
#       "mobsKilled": 111519,
#       "chestsFound": 1233,
#       "dungeons": {
#         "total": 259,
#         "list": {
#           "Decrepit Sewers": 28,
#           "Infested Pit": 19,
#           "Lost Sanctuary": 6,
#           "Underworld Crypt": 11,
#           "Undergrowth Ruins": 32,
#           "Galleon's Graveyard": 22,
#           "Corrupted Decrepit Sewers": 29,
#           "Corrupted Infested Pit": 39,
#           "Corrupted Lost Sanctuary": 12,
#           "Corrupted Underworld Crypt": 8,
#           "Corrupted Sand-Swept Tomb": 8,
#           "Sand-Swept Tomb": 12,
#           "Ice Barrows": 15,
#           "Fallen Factory": 1,
#           "Corrupted Galleon's Graveyard": 2,
#           "Corrupted Undergrowth Ruins": 3,
#           "Corrupted Ice Barrows": 2,
#           "Eldritch Outlook": 7,
#           "Timelost Sanctum": 3
#         }
#       },
#       "raids": {
#         "total": 117,
#         "list": {
#           "The Canyon Colossus": 13,
#           "Orphion's Nexus of Light": 46,
#           "The Nameless Anomaly": 21,
#           "Nest of the Grootslangs": 37
#         }
#       },
#       "worldEvents": 9,
#       "lootruns": 1,
#       "caves": 23,
#       "completedQuests": 97,
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2020-10-25T15:22:54.582000Z",
#       "playtime": 350.33,
#       "globalData.totalLevel": 1615,
#       "globalData.mobsKilled": 111519,
#       "globalData.completedQuests": 97
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false
#     }
#   }
# }

# %%
# guild_breakdown_username = {}
# for uuid in all_members:
#     member_stats[uuid]['username'] = member_stats[uuid]
print(json.dumps(member_stats["94591244-b96c-4675-99fc-b4e9abfac6de"], indent=2))
# Out:
# {
#   "username": "cheeseball01",
#   "online": false,
#   "server": "NA28",
#   "activeCharacter": "cb1da0e5-3cfd-4c23-aa24-3bdf486c1f65",
#   "nickname": null,
#   "uuid": "94591244-b96c-4675-99fc-b4e9abfac6de",
#   "rank": "Player",
#   "rankBadge": "nextgen/badges/rank_vipplus.svg",
#   "legacyRankColour": {
#     "main": "#55ffff",
#     "sub": "#00aaaa"
#   },
#   "shortenedRank": null,
#   "supportRank": "vipplus",
#   "veteran": null,
#   "lastJoin": "2026-02-21T01:39:04.909000Z",
#   "guild": {
#     "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#     "name": "Godly",
#     "prefix": "grey",
#     "rank": "RECRUIT",
#     "rankStars": null
#   },
#   "ranking": {
#     "huntedContent": 1184,
#     "combatGlobalLevel": 2176,
#     "orphionSrPlayers": 2534,
#     "guildRaids": 3522,
#     "orphionCompletion": 3569,
#     "colossusCompletion": 3779,
#     "namelessSrPlayers": 4602,
#     "colossusSrPlayers": 4845,
#     "namelessCompletion": 5210,
#     "globalPlayerContent": 5285,
#     "grootslangCompletion": 5431,
#     "warsCompletion": 5547,
#     "totalGlobalLevel": 5626,
#     "grootslangSrPlayers": 5706,
#     "combatSoloLevel": 6093,
#     "woodcuttingLevel": 6100,
#     "farmingLevel": 6151,
#     "fishingLevel": 6220,
#     "miningLevel": 7140,
#     "professionsGlobalLevel": 12415,
#     "totalSoloLevel": 16202,
#     "professionsSoloLevel": 17554,
#     "scribingLevel": 36062,
#     "playerContent": 36899,
#     "tailoringLevel": 65093,
#     "cookingLevel": 67053,
#     "weaponsmithingLevel": 68901,
#     "armouringLevel": 113117,
#     "woodworkingLevel": 400803,
#     "alchemismLevel": 1423068,
#     "jewelingLevel": 1446469
#   },
#   "previousRanking": {},
#   "firstJoin": "2020-12-01T15:03:33.911000Z",
#   "playtime": 1786.58,
#   "globalData": {
#     "contentCompletion": 2408,
#     "wars": 80,
#     "totalLevel": 5285,
#     "mobsKilled": 745660,
#     "chestsFound": 77224,
#     "dungeons": {
#       "total": 218,
#       "list": {
#         "Decrepit Sewers": 47,
#         "Corrupted Infested Pit": 15,
#         "Corrupted Lost Sanctuary": 23,
#         "Corrupted Sand-Swept Tomb": 11,
#         "Corrupted Undergrowth Ruins": 42,
#         "Eldritch Outlook": 7,
#         "Fallen Factory": 8,
#         "Ice Barrows": 6,
#         "Corrupted Ice Barrows": 9,
#         "Corrupted Decrepit Sewers": 14,
#         "Infested Pit": 21,
#         "Corrupted Underworld Crypt": 9,
#         "Sand-Swept Tomb": 1,
#         "Corrupted Galleon's Graveyard": 3,
#         "Lost Sanctuary": 1,
#         "Underworld Crypt": 1
#       }
#     },
#     "raids": {
#       "total": 342,
#       "list": {
#         "The Canyon Colossus": 131,
#         "Nest of the Grootslangs": 79,
#         "The Nameless Anomaly": 86,
#         "Orphion's Nexus of Light": 46
#       }
#     },
#     "worldEvents": 15,
#     "lootruns": 5,
#     "caves": 110,
#     "completedQuests": 209,
#     "pvp": {
#       "kills": 0,
#       "deaths": 0
#     },
#     "guildRaids": {
#       "total": 71,
#       "list": {
#         "The Canyon Colossus": 7,
#         "Orphion's Nexus of Light": 15,
#         "Nest of the Grootslangs": 35,
#         "The Nameless Anomaly": 14
#       }
#     }
#   },
#   "featuredStats": {
#     "firstJoin": "2020-12-01T15:03:33.911000Z",
#     "playtime": 1786.58,
#     "globalData.totalLevel": 5285,
#     "globalData.mobsKilled": 745660,
#     "globalData.completedQuests": 209
#   },
#   "wallpaper": "home",
#   "avatar": "player",
#   "restrictions": {
#     "mainAccess": false,
#     "onlineStatus": false
#   }
# }

# %%
# print(member_stats['zytiv'])

# %%
incognito = []
for member in sorted(member_stats.keys()):
    if "playtime" in member_stats[member]:
        # print(f"{member}: {member_stats[member]["playtime"]} {member_stats[member]["restrictions"]}")
        # print(f"{member_stats[member]['username']}: {member_stats[member]['restrictions']}")
        pass
    else:
        # print(f"{member} icognito")
        incognito.append(member)
        print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
        print(f"{member_stats[member]['username']}: {member_stats[member]['restrictions']} : {member} incognito")
        print("++++=====================================================+++++")
# print(sorted(icongnito))
print(incognito)
# Out:
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Ecmz: {'mainAccess': True, 'onlineStatus': True} : cff26bb4-bad0-4de2-8559-19d23e2d9d41 incognito
# ++++=====================================================+++++
# ['cff26bb4-bad0-4de2-8559-19d23e2d9d41']

# %%
# yesterday = ['aqimcrafty', 'ecmz', 'krijer1', 'moondustpeachy', 'soupskids', 'white_plague']
offline_members = ['cff26bb4-bad0-4de2-8559-19d23e2d9d41']
good_members = {k: v for k,v in member_stats.items() if k not in offline_members}

# %%
# print(json.dumps(good_members, indent=2))

for member in sorted(good_members, key=lambda m: good_members[m]["lastJoin"]):
    print(f"{good_members[member]["username"]}: {good_members[member]["lastJoin"]}")
# Out:
# GoDz_OneManArmy: 2026-01-04T08:45:27.880000Z
# ottehall: 2026-02-04T20:01:39.604000Z
# F1NLAY01: 2026-02-09T09:58:36.858000Z
# parrandeno: 2026-02-10T02:09:44.601000Z
# S6kuna: 2026-02-10T10:51:02.452000Z
# erik_9453: 2026-02-11T03:24:11.296000Z
# AmasoXd: 2026-02-13T14:30:13.352000Z
# squirley: 2026-02-14T06:49:30.335000Z
# Rinnn0424: 2026-02-14T08:16:05.625000Z
# imNaphy: 2026-02-16T19:10:01.632000Z
# DynemoRC: 2026-02-16T19:19:37.394000Z
# mirceatim: 2026-02-16T19:29:18.875000Z
# White_plague: 2026-02-18T08:32:06.033000Z
# djderpcat: 2026-02-18T15:20:30.007000Z
# nawe69: 2026-02-18T16:41:05.317000Z
# iParadox1122: 2026-02-19T06:57:07.851000Z
# FireGamingDK: 2026-02-19T09:14:51.145000Z
# kcsato: 2026-02-19T18:29:08.979000Z
# cheeseball01: 2026-02-21T01:39:04.909000Z
# Kanaefx: 2026-02-21T07:50:20.963000Z
# MelinoeNemesis: 2026-02-21T15:31:06.350000Z
# Xentell: 2026-02-22T07:26:54.193000Z
# Liciela: 2026-02-22T08:25:10.680000Z
# Gurlic: 2026-02-22T20:34:01.235000Z
# GrayR0ot: 2026-02-22T22:43:53.646000Z
# VenonatGX: 2026-02-22T23:31:07.006000Z
# jayandjef: 2026-02-23T03:16:06.924000Z
# vamqir: 2026-02-23T18:13:20.206000Z
# evbubba: 2026-02-23T19:12:06.300000Z
# SewageFarts: 2026-02-23T22:50:25.241000Z
# Nqn: 2026-02-24T00:37:27.444000Z
# xEagless: 2026-02-24T01:34:14.599000Z
# ZicZac: 2026-02-24T03:58:48.681000Z
# H1V: 2026-02-24T05:20:50.897000Z
# TheKzR: 2026-02-24T10:01:51.382000Z
# GigaFanDeJul: 2026-02-24T11:21:58.673000Z
# aIfaa: 2026-02-24T11:49:28.720000Z
# Shivnitzl19: 2026-02-24T15:25:51.413000Z
# Feather_Storm: 2026-02-24T19:15:30.864000Z
# ewenfi: 2026-02-24T20:52:23.064000Z
# YBN: 2026-02-24T21:11:10.295000Z
# roll_54: 2026-02-24T23:24:33.925000Z
# Endyre: 2026-02-24T23:25:20.081000Z
# Pogo_Duck: 2026-02-25T00:03:49.140000Z
# Budiono: 2026-02-25T00:39:12.715000Z
# skrybs: 2026-02-25T02:01:27.901000Z
# kanyo0904: 2026-02-25T02:52:56.895000Z
# Firetornado2312: 2026-02-25T03:42:36.933000Z
# _N8: 2026-02-25T04:02:03.020000Z
# WynnDestroyer: 2026-02-25T11:15:54.163000Z
# jeff1234567842: 2026-02-25T12:20:27.748000Z
# Zytiv: 2026-02-25T13:30:12.267000Z
# Chevacchi: 2026-02-25T13:41:06.194000Z
# Megawati: 2026-02-25T14:55:49.728000Z
# LaserX: 2026-02-25T16:01:21.154000Z
# KirouXD: 2026-02-25T16:49:10.392000Z
# JinnMD: 2026-02-25T17:17:24.578000Z
# Riku_56rr: 2026-02-25T17:38:45.428000Z
# WhiteNoise0113: 2026-02-25T19:23:52.135000Z
# gauvinsteven: 2026-02-25T19:29:34.120000Z
# Laborious: 2026-02-25T20:02:34.083000Z
# JJCourts: 2026-02-25T20:07:20.019000Z
# MoondustPeachy: 2026-02-25T20:12:08.872000Z
# Thund3rMC: 2026-02-25T20:24:58.834000Z
# Ryuuchen: 2026-02-25T20:26:22.643000Z
# notBirdblade: 2026-02-25T21:18:58.532000Z
# Krijer1: 2026-02-25T21:55:41.166000Z
# _Snoopers_: 2026-02-25T21:55:57.875000Z
# Tisumi: 2026-02-25T21:55:58.227000Z
# clohi: 2026-02-25T21:55:58.682000Z
# StyNath: 2026-02-25T21:56:01.849000Z
# wrggg: 2026-02-25T21:56:36.098000Z
# BlueSkyMoose: 2026-02-25T21:56:47.681000Z
# ddxWeCraft: 2026-02-25T21:56:57.919000Z
# cresseliah: 2026-02-25T21:57:03.077000Z
# AlleNupY: 2026-02-25T21:57:04.636000Z
# EdouardpheoIII: 2026-02-25T21:57:22.135000Z
# Bluvey: 2026-02-25T21:58:12.447000Z
# _Hammie_: 2026-02-25T21:58:32.178000Z

# %%
for member in sorted(good_members, key=lambda m: good_members[m]["playtime"], reverse=True):
    print(f"\t{good_members[member]["username"]}: {good_members[member]["playtime"]}")
# Out:
# 	Shivnitzl19: 6972.42
# 	WhiteNoise0113: 2872.75
# 	Budiono: 2685.33
# 	clohi: 2337.33
# 	cheeseball01: 1786.58
# 	BlueSkyMoose: 1538.17
# 	Endyre: 1504.92
# 	Liciela: 1427.17
# 	skrybs: 1170.5
# 	H1V: 1144.33
# 	JinnMD: 1080.92
# 	Rinnn0424: 1065.92
# 	EdouardpheoIII: 1002.25
# 	Tisumi: 955.92
# 	ewenfi: 954.42
# 	VenonatGX: 880.33
# 	wrggg: 865.92
# 	Laborious: 783.33
# 	LaserX: 735.67
# 	GigaFanDeJul: 698.75
# 	_N8: 609.75
# 	Nqn: 593.58
# 	Krijer1: 584.67
# 	squirley: 518.75
# 	FireGamingDK: 422.17
# 	jayandjef: 400.42
# 	Thund3rMC: 387.67
# 	KirouXD: 371.5
# 	evbubba: 364.58
# 	_Snoopers_: 360.58
# 	imNaphy: 353.5
# 	Pogo_Duck: 350.33
# 	Feather_Storm: 341.0
# 	xEagless: 332.58
# 	Chevacchi: 328.58
# 	kcsato: 325.25
# 	ZicZac: 323.08
# 	gauvinsteven: 311.83
# 	MoondustPeachy: 303.0
# 	kanyo0904: 261.42
# 	Riku_56rr: 255.58
# 	Xentell: 254.92
# 	Gurlic: 243.83
# 	jeff1234567842: 240.42
# 	ddxWeCraft: 238.08
# 	WynnDestroyer: 231.17
# 	GrayR0ot: 226.5
# 	JJCourts: 176.17
# 	Ryuuchen: 170.0
# 	White_plague: 153.75
# 	F1NLAY01: 151.5
# 	Bluvey: 150.75
# 	AlleNupY: 144.67
# 	cresseliah: 137.75
# 	StyNath: 137.33
# 	Megawati: 136.67
# 	Kanaefx: 135.67
# 	YBN: 114.83
# 	Zytiv: 112.25
# 	notBirdblade: 104.83
# 	AmasoXd: 100.5
# 	iParadox1122: 98.75
# 	TheKzR: 89.5
# 	parrandeno: 85.83
# 	S6kuna: 83.75
# 	_Hammie_: 79.92
# 	roll_54: 75.58
# 	MelinoeNemesis: 70.42
# 	nawe69: 56.42
# 	Firetornado2312: 48.33
# 	SewageFarts: 42.75
# 	erik_9453: 41.5
# 	aIfaa: 37.75
# 	GoDz_OneManArmy: 34.75
# 	vamqir: 30.67
# 	DynemoRC: 26.75
# 	ottehall: 23.25
# 	djderpcat: 23.17
# 	mirceatim: 19.17

# %%
import csv
from datetime import datetime, timezone
output_file = "./devDataCollection.csv"
headers = ["date", "uuid", "rank", "username", "lastJoined", "daysLastJoined", "playtime", "wars",  "graids", "lootruns", "raids", "totalLevel", "contentCompletion"]
time_format = "%Y-%m-%dT%H:%M:%S.%fZ"
guild_members = []
# file_exists = os.path.isfile(output_file)
# file_has_content = file_exists and os.path.getsize(output_file) > 0
now_utc = datetime.now(timezone.utc)

formatted = now_utc.strftime(time_format)
with open(output_file, "a", newline="") as f:
    writer = csv.writer(f)
    if f.tell()==0:
        writer.writerow(headers)
    
    for uuid in member_stats:
        if uuid in incognito:
            continue
        member = member_stats[uuid]
        guild_members.append(member['username'])
        # print(member['globalData']['guildRaids'])
        # print(member['globalData']['raids'])
        # print([member['globalData']['guildRaids'][raid] for raid in member['globalData']['guildRaids']])
        days_last_joined =  now_utc - datetime.strptime(member['lastJoin'], time_format).replace(tzinfo=timezone.utc)
        stats = [formatted, uuid, member['guild']['rank'],member["username"], member['lastJoin'], 
                 round(days_last_joined.total_seconds()/60/60/24, 3) ,member['playtime'], member['globalData']["wars"], member['globalData']['guildRaids']['total'],
                 member['globalData']['lootruns'], member['globalData']["raids"]['total'], member["globalData"]['totalLevel'], member['globalData']['contentCompletion']]
        # print(stats)
        writer.writerow(stats)
        # pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 18
#      15 if f.tell()==0:
#      16     writer.writerow(headers)
# ---> 18 for uuid in member_stats:
#      19     if uuid in incognito:
#      20         continue
#
# NameError: name 'member_stats' is not defined

# %%
from datetime import datetime
output_file = "./devDataCollection.csv"
player_data = {}
with open(output_file, newline="") as f:
    reader = csv.DictReader(f)
    for row in reader:
        uuid = row['uuid']
        if uuid not in player_data:
            player_data[uuid] = []
        player_data[uuid].append(row)
print(json.dumps(player_data["c32bfbf5-9665-4ad1-837e-92fa882288a3"]))
numeric_fields = ["playtime", "wars", "graids", "lootruns", "raids", "totalLevel", "contentCompletion"]
# Prepare CSV rows
csv_rows = []
# players = ["c32bfbf5-9665-4ad1-837e-92fa882288a3", "130612b6-1d46-49c7-b06e-3200959254c7"]
players = ["c32bfbf5-9665-4ad1-837e-92fa882288a3", "f46a3aa1-ed18-48f4-bcf9-594e0ff19842"]
for player in players:
    prev = None
    player_rows = []
    for entry in player_data[player]:
        row = entry.copy()
        if prev:
            for field in numeric_fields:
                row[field] = float(entry[field]) - float(prev[field])
        else:
            for field in numeric_fields:
                row[field] = ""  # first entry has no previous
        player_rows.append(row)
        prev = entry
    csv_rows += player_rows[1:]

# Write to CSV
fieldnames = [
    "date",
    "username",
    "uuid",
    "rank",
    "daysLastJoined",
    "playtime",
    "wars",
    "graids",
    "lootruns",
    "raids",
    "totalLevel",
    "contentCompletion",
    "lastJoined"
]
with open(dev_weekly_file, "w", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(csv_rows)
with open(weekly_csv_file, "w", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(csv_rows)

print("CSV saved as output.csv")
# player_ids = ["c32bfbf5-9665-4ad1-837e-92fa882288a3", "f46a3aa1-ed18-48f4-bcf9-594e0ff19842"]
csv_rows = []
# Convert date strings to datetime objects
for player_id in players:
    player_rows = []
    for entry in player_data[player_id]:
        entry["date_dt"] = datetime.strptime(entry["date"], "%Y-%m-%dT%H:%M:%S.%fZ")

    # Sort by date

    # Fields to compute differences for
    numeric_fields = ["playtime", "wars", "graids", "lootruns", "raids", "totalLevel", "contentCompletion"]

    # Prepare CSV rows

    prev_entry = player_data[player_id][0]  # first entry is reference
    week_counter = 1  # start at week 1
    print(len(player_data[player_id]))
    for entry in player_data[player_id][1:]:  # skip first entry
        week_counter += 1

        # Only generate output for every 4th week (week 5, 9, 13, ...)
        if (week_counter - 1) % 4 == 0:  # week 5 relative to start = 5, 9, 13...

            print(f"weak counter: {week_counter}")
            print(entry)
            row = entry.copy()
            for field in numeric_fields:
                row[field] = float(entry[field]) - float(prev_entry[field])
            player_rows.append(row)
            prev_entry = entry  # update reference for next 4-week diff
    csv_rows += player_rows[:]
    # Remove temporary datetime object before writing CSV
for row in csv_rows:
    del row["date_dt"]

# Write CSV


with open(dev_monthly_file, "w", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(csv_rows)

print(f"CSV saved as {dev_monthly_file} with only 4-week intervals")
with open(monthly_csv_file, "w", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(csv_rows)
# Out:
# [{"date": "2026-01-10T23:10:20.363761Z", "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3", "rank": "STRATEGIST", "username": "StyNath", "lastJoined": "2026-01-05T22:54:55.111000Z", "daysLastJoined": "1.011", "playtime": "135.67", "wars": "9", "graids": "23", "lootruns": "1", "raids": "56", "totalLevel": "882", "contentCompletion": "551"}, {"date": "2026-01-17T23:20:31.952994Z", "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3", "rank": "STRATEGIST", "username": "StyNath", "lastJoined": "2026-01-12T22:54:55.111000Z", "daysLastJoined": "1.018", "playtime": "135.67", "wars": "9", "graids": "23", "lootruns": "1", "raids": "56", "totalLevel": "888", "contentCompletion": "558"}, {"date": "2026-01-24T23:35:33.381786Z", "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3", "rank": "STRATEGIST", "username": "StyNath", "lastJoined": "2026-01-19T23:32:38.599000Z", "daysLastJoined": "0.002", "playtime": "136.0", "wars": "31", "graids": "24", "lootruns": "21", "raids": "96", "totalLevel": "982", "contentCompletion": "571"}, {"date": "2026-02-01T00:00:28.803025Z", "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3", "rank": "STRATEGIST", "username": "StyNath", "lastJoined": "2026-01-26T23:57:39.162000Z", "daysLastJoined": "0.002", "playtime": "136.42", "wars": "9", "graids": "23", "lootruns": "1", "raids": "56", "totalLevel": "882", "contentCompletion": "551"}, {"date": "2026-02-08T00:00:41.938435Z", "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3", "rank": "STRATEGIST", "username": "StyNath", "lastJoined": "2026-02-03T23:57:39.162000Z", "daysLastJoined": "0.002", "playtime": "136.42", "wars": "9", "graids": "23", "lootruns": "1", "raids": "56", "totalLevel": "882", "contentCompletion": "551"}, {"date": "2026-02-15T00:14:52.581935Z", "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3", "rank": "STRATEGIST", "username": "StyNath", "lastJoined": "2026-02-11T00:12:04.478000Z", "daysLastJoined": "0.002", "playtime": "136.67", "wars": "9", "graids": "23", "lootruns": "1", "raids": "56", "totalLevel": "882", "contentCompletion": "551"}, {"date": "2026-02-21T23:34:41.956688Z", "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3", "rank": "STRATEGIST", "username": "StyNath", "lastJoined": "2026-02-18T00:23:29.763000Z", "daysLastJoined": "0.049", "playtime": "136.83", "wars": "9", "graids": "23", "lootruns": "1", "raids": "56", "totalLevel": "882", "contentCompletion": "551"}, {"date": "2026-03-01T00:31:13.565683Z", "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3", "rank": "STRATEGIST", "username": "StyNath", "lastJoined": "2026-02-25T00:23:29.763000Z", "daysLastJoined": "0.839", "playtime": "136.83", "wars": "9", "graids": "23", "lootruns": "1", "raids": "56", "totalLevel": "882", "contentCompletion": "551"}, {"date": "2026-03-08T00:00:23.653376Z", "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3", "rank": "STRATEGIST", "username": "StyNath", "lastJoined": "2026-02-25T21:56:01.849000Z", "daysLastJoined": "0.003", "playtime": "137.33", "wars": "9", "graids": "23", "lootruns": "1", "raids": "56", "totalLevel": "882", "contentCompletion": "551"}]
# CSV saved as output.csv
# 9
# weak counter: 5
# {'date': '2026-02-08T00:00:41.938435Z', 'uuid': 'c32bfbf5-9665-4ad1-837e-92fa882288a3', 'rank': 'STRATEGIST', 'username': 'StyNath', 'lastJoined': '2026-02-03T23:57:39.162000Z', 'daysLastJoined': '0.002', 'playtime': '136.42', 'wars': '9', 'graids': '23', 'lootruns': '1', 'raids': '56', 'totalLevel': '882', 'contentCompletion': '551', 'date_dt': datetime.datetime(2026, 2, 8, 0, 0, 41, 938435)}
# weak counter: 9
# {'date': '2026-03-08T00:00:23.653376Z', 'uuid': 'c32bfbf5-9665-4ad1-837e-92fa882288a3', 'rank': 'STRATEGIST', 'username': 'StyNath', 'lastJoined': '2026-02-25T21:56:01.849000Z', 'daysLastJoined': '0.003', 'playtime': '137.33', 'wars': '9', 'graids': '23', 'lootruns': '1', 'raids': '56', 'totalLevel': '882', 'contentCompletion': '551', 'date_dt': datetime.datetime(2026, 3, 8, 0, 0, 23, 653376)}
# 9
# weak counter: 5
# {'date': '2026-02-08T00:00:41.938435Z', 'uuid': 'f46a3aa1-ed18-48f4-bcf9-594e0ff19842', 'rank': 'STRATEGIST', 'username': 'WhiteNoise0113', 'lastJoined': '2026-02-24T23:15:42.837000Z', 'daysLastJoined': '0.031', 'playtime': '2872.58', 'wars': '4012', 'graids': '97', 'lootruns': '5', 'raids': '261', 'totalLevel': '9528', 'contentCompletion': '3904', 'date_dt': datetime.datetime(2026, 2, 8, 0, 0, 41, 938435)}
# weak counter: 9
# {'date': '2026-03-08T00:00:23.653376Z', 'uuid': 'f46a3aa1-ed18-48f4-bcf9-594e0ff19842', 'rank': 'STRATEGIST', 'username': 'WhiteNoise0113', 'lastJoined': '2026-02-25T19:23:52.135000Z', 'daysLastJoined': '0.109', 'playtime': '2872.75', 'wars': '4012', 'graids': '97', 'lootruns': '5', 'raids': '261', 'totalLevel': '9528', 'contentCompletion': '3904', 'date_dt': datetime.datetime(2026, 3, 8, 0, 0, 23, 653376)}
# CSV saved as ./dev_monthly_data.csv with only 4-week intervals

# %%
player_data = {}
weekly_data = {}
no_weekly_data = []
monthly_data = {}
no_monthly_data = []
def subtract_date_string(day1, day2):
    filter1 = datetime.strptime(day1, time_format)
    filter2 = datetime.strptime(day2, time_format)
    days_time = filter1 - filter2
    return round(abs(days_time.total_seconds()/60/60/24), 3)

with open(output_file, "r", newline="") as f:
    reader = csv.DictReader(f)
    for row in reader:
        uuid = row['uuid']
        if uuid not in player_data:
            player_data[uuid] = []
        if len(player_data[uuid]) >= 5:
            player_data[uuid] = player_data[uuid][-4:] + [row]
        else:
            player_data[uuid].append(row)


for player in player_data:
    #  player_data[player]
    
    dates = [day['date'] for day in player_data[player]]
    # if dates[-1]==formatted:
    # if player_data[player][-1]['username']=="StyNath":
    #         print(player_data[player][-1]['username'])
    #         print(dates)
    #         print(round(subtract_date_string(dates[-1], dates[-2]), 0))
    #         print(formatted)
    #         print(len(player_data[player]) > 1 and dates[-1]==formatted and round(subtract_date_string(dates[-1], dates[-2]), 0)==7)
    # formatted = "2026-03-08T00:00:23.653376Z"
    
    
    if len(player_data[player]) > 1 and dates[-1]==formatted and round(subtract_date_string(dates[-1], dates[-2]), 0)==7:
        # print(f"Got to weekly: {player_data[player][-1]['username']}")
        weekly_data[player] = {
            "date": formatted,
            "username": player_data[player][-1]['username'], 
            "uuid": player,
            "rank": player_data[player][-1]['rank'],
            "daysLastJoined": player_data[player][-1]["daysLastJoined"],
            "playtime": round(float(player_data[player][-1]['playtime']) -float(player_data[player][-2]['playtime']), 2),
            "wars":round(float(player_data[player][-1]['wars']) -float(player_data[player][-2]['wars']),2 ),
            "graids": round(float(player_data[player][-1]['graids']) -float(player_data[player][-2]['graids']), 2),
            "lootruns": round(float(player_data[player][-1]['lootruns']) -float(player_data[player][-2]['lootruns']), 2),
            "raids": round(float(player_data[player][-1]['raids']) -float(player_data[player][-2]['raids']), 2),
            "totalLevel":round(float(player_data[player][-1]['totalLevel']) -float(player_data[player][-2]['totalLevel']), 2),
            "contentCompletion":round(float(player_data[player][-1]['contentCompletion']) -float(player_data[player][-2]['contentCompletion']), 2),
            "lastJoined": player_data[player][-1]['lastJoined']
                               }
        # print(weekly_data)
    else:
        no_weekly_data.append(player)
    this_month = [round(subtract_date_string(formatted, d), 0)<=28 for d in dates]
    oldest_this_month = 0
    for i in this_month:
        if i:
            oldest_this_month += 1
    start_day = "2026-03-01T00:00:00.000000Z"
    # start_day = "2026-01-11T00:00:00.000000Z"
    # if "StyNath" ==player_data[player][-1]['username']:
    #     print(len(player_data[player]) > 2 and sum(this_month) > 1 and round(subtract_date_string(start_day, formatted),0)%28==0)
    #     print(round(subtract_date_string(start_day, formatted),0)%28==0)
    #     print(round(subtract_date_string(start_day, formatted),0))

    
    if len(player_data[player]) > 2 and round(subtract_date_string(dates[-oldest_this_month], formatted),0)==28 and round(subtract_date_string(start_day, formatted),0)%28==0:
        month_stats = {
            "date": formatted,
            "username": player_data[player][-1]['username'], 
            "uuid": player,
            "rank": player_data[player][-1]['rank'],
            "daysLastJoined": float(player_data[player][-1]["daysLastJoined"]),
            "playtime":round(float(player_data[player][-1]['playtime']) -float(player_data[player][-oldest_this_month]['playtime']), 2),
            "wars":round(float(player_data[player][-1]['wars']) -float(player_data[player][-oldest_this_month]['wars']), 2),
            "graids":round(float(player_data[player][-1]['graids']) -float(player_data[player][-oldest_this_month]['graids']), 2),
            "lootruns": round(float(player_data[player][-1]['lootruns']) -float(player_data[player][-oldest_this_month]['lootruns']), 2),
            "raids":round(float(player_data[player][-1]['raids']) -float(player_data[player][-oldest_this_month]['raids']), 2),
            "totalLevel":round(float(player_data[player][-1]['totalLevel']) -float(player_data[player][-oldest_this_month]['totalLevel']), 2),
            "contentCompletion":round(float(player_data[player][-1]['contentCompletion']) -float(player_data[player][-oldest_this_month]['contentCompletion']), 2),
            "lastJoined": player_data[player][-1]['lastJoined']
        }
        monthly_data[player] = month_stats
        # if player_data[player][-1]['username']=="StyNath":
        #     print(json.dumps(player_data[player], indent=2))
weekly_fieldnames = set()
for data in weekly_data.values():
    weekly_fieldnames.update(data.keys())
weekly_fieldnames = list(weekly_fieldnames)  # optional: sort for consistent order

# Similarly for monthly_data
monthly_fieldnames = set()
for data in monthly_data.values():
    monthly_fieldnames.update(data.keys())
monthly_fieldnames = list(monthly_fieldnames)

# Write CSV
fieldnames = [
    "date",
    "username",
    "uuid",
    "rank",
    "daysLastJoined",
    "playtime",
    "wars",
    "graids",
    "lootruns",
    "raids",
    "totalLevel",
    "contentCompletion",
    "lastJoined"
]
with open(weekly_csv_file, "a", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    if f.tell()==0:
        writer.writeheader()
    
    # Write each player's monthly data
    for player, data in weekly_data.items():
        writer.writerow(data)

# Write CSV
with open(monthly_csv_file, "a", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    if f.tell()==0:
        writer.writeheader()
    
    # Write each player's monthly data
    for player, data in monthly_data.items():
        writer.writerow(data)

# %%
# print(weekly_data)
for player in weekly_data:
    print(player)
    print(weekly_data[player])
    # if weekly_data[player]["playtime"] > 0:
    #     print(player)
    #     print(weekly_data[player])
# Out:
# f46a3aa1-ed18-48f4-bcf9-594e0ff19842
# {'date': '2026-03-08T00:00:23.653376Z', 'username': 'WhiteNoise0113', 'uuid': 'f46a3aa1-ed18-48f4-bcf9-594e0ff19842', 'rank': 'STRATEGIST', 'daysLastJoined': '0.109', 'playtime': 0.0, 'wars': 0.0, 'graids': 0.0, 'lootruns': 0.0, 'raids': 0.0, 'totalLevel': 0.0, 'contentCompletion': 0.0, 'lastJoined': '2026-02-25T19:23:52.135000Z'}
# c32bfbf5-9665-4ad1-837e-92fa882288a3
# {'date': '2026-03-08T00:00:23.653376Z', 'username': 'StyNath', 'uuid': 'c32bfbf5-9665-4ad1-837e-92fa882288a3', 'rank': 'STRATEGIST', 'daysLastJoined': '0.003', 'playtime': 0.5, 'wars': 0.0, 'graids': 0.0, 'lootruns': 0.0, 'raids': 0.0, 'totalLevel': 0.0, 'contentCompletion': 0.0, 'lastJoined': '2026-02-25T21:56:01.849000Z'}

# %%
for player in monthly_data:
    # if monthly_data[player]["playtime"] > 0:
        print(player)
        print(monthly_data[player])
# Out:
# c32bfbf5-9665-4ad1-837e-92fa882288a3
# {'date': '2026-03-08T00:00:23.653376Z', 'username': 'StyNath', 'uuid': 'c32bfbf5-9665-4ad1-837e-92fa882288a3', 'rank': 'STRATEGIST', 'daysLastJoin': '0.003', 'playtime': 0.91, 'wars': 0.0, 'graid': 0.0, 'lootruns': 0.0, 'raids': 0.0, 'totalLevel': 0.0, 'contentCompletion': 0.0}

# %%
print(json.dumps(weekly_data["c32bfbf5-9665-4ad1-837e-92fa882288a3"], indent=2))
# Out:
# {
#   "username": "StyNath",
#   "rank": "STRATEGIST",
#   "daysLastJoin": "0.839",
#   "playtime": 0.0,
#   "wars": 0.0,
#   "graid": 0.0,
#   "lootruns": 0.0,
#   "raids": 0.0,
#   "totalLevel": 0.0,
#   "contentCompletion": 0.0
# }

# %%
print(json.dumps(monthly_data["c32bfbf5-9665-4ad1-837e-92fa882288a3"], indent=2))
# Out:
# {
#   "username": "StyNath",
#   "rank": "STRATEGIST",
#   "daysLastJoin": "0.839",
#   "playtime": 0.41,
#   "wars": 0.0,
#   "graid": 0.0,
#   "lootruns": 0.0,
#   "raids": 0.0,
#   "totalLevel": 0.0,
#   "contentCompletion": 0.0
# }

# %%
import csv
from collections import defaultdict
import plotly.graph_objects as go

numeric_fields = ["playtime", "wars", "graids", "lootruns", "raids", "totalLevel", "contentCompletion"]

data = defaultdict(lambda: defaultdict(list))

# Read CSV
with open(dev_weekly_file) as f:
    reader = csv.DictReader(f)
    for row in reader:
        key = row["uuid"]
        timestamp = row["date"]
        username = row.get("username", key)
        for field in numeric_fields:
            if row.get(field):  # only add if value exists
                data[key][field].append({"timestamp": timestamp, "value": float(row[field]), "username": username})

fig = go.Figure()
traces = []
trace_info = []

# Add traces only if there is data
for key in data:
    for field in numeric_fields:
        if data[key][field]:  # skip empty fields
            trace = go.Scatter(
                x=[entry["timestamp"] for entry in data[key][field]],
                y=[entry["value"] for entry in data[key][field]],
                mode="lines+markers",
                name=f"{data[key][field][-1]['username']} - {field}",
                visible=False
            )
            fig.add_trace(trace)
            trace_info.append((key, field))

# Player dropdown
player_buttons = []
player_keys = list(data.keys())

for key in player_keys:
    visibility = [False] * len(fig.data)
    for j, (k, f) in enumerate(trace_info):
        if k == key:
            visibility[j] = True
    # Pick first non-empty field to get username
    first_field = next((f for f in numeric_fields if data[key][f]), None)
    username = data[key][first_field][-1]['username'] if first_field else key
    player_buttons.append(dict(
        label=username,
        method="update",
        args=[{"visible": visibility},
              {"title": f"Player: {username}"}]
    ))

# Field dropdown
field_buttons = []
for field in numeric_fields:
    visibility = [False] * len(fig.data)
    for j, (k, f) in enumerate(trace_info):
        if f == field:
            visibility[j] = True
    field_buttons.append(dict(
        label=field,
        method="update",
        args=[{"visible": visibility},
              {"title": f"Field: {field}"}]
    ))

fig.update_layout(
    updatemenus=[
        dict(active=0, buttons=player_buttons, x=0, y=1.1, xanchor='left', direction='down'),
        dict(active=0, buttons=field_buttons, x=0.3, y=1.1, xanchor='left', direction='down')
    ],
    title="Interactive Player Stats"
)

weekly_html_str = fig.to_html(
    include_plotlyjs="cdn",
    full_html=False
)

# %%
numeric_fields = ["playtime", "wars", "graids", "lootruns", "raids", "totalLevel", "contentCompletion"]

data = defaultdict(lambda: defaultdict(list))

# Read CSV
with open(dev_monthly_file) as f:
    reader = csv.DictReader(f)
    for row in reader:
        key = row["uuid"]
        timestamp = row["date"]
        username = row.get("username", key)
        for field in numeric_fields:
            if row.get(field):  # only add if value exists
                data[key][field].append({"timestamp": timestamp, "value": float(row[field]), "username": username})

fig = go.Figure()
traces = []
trace_info = []

# Add traces only if there is data
for key in data:
    for field in numeric_fields:
        if data[key][field]:  # skip empty fields
            trace = go.Scatter(
                x=[entry["timestamp"] for entry in data[key][field]],
                y=[entry["value"] for entry in data[key][field]],
                mode="lines+markers",
                name=f"{data[key][field][-1]['username']} - {field}",
                visible=False
            )
            fig.add_trace(trace)
            trace_info.append((key, field))

# Player dropdown
player_buttons = []
player_keys = list(data.keys())

for key in player_keys:
    visibility = [False] * len(fig.data)
    for j, (k, f) in enumerate(trace_info):
        if k == key:
            visibility[j] = True
    # Pick first non-empty field to get username
    first_field = next((f for f in numeric_fields if data[key][f]), None)
    username = data[key][first_field][-1]['username'] if first_field else key
    player_buttons.append(dict(
        label=username,
        method="update",
        args=[{"visible": visibility},
              {"title": f"Player: {username}"}]
    ))

# Field dropdown
field_buttons = []
for field in numeric_fields:
    visibility = [False] * len(fig.data)
    for j, (k, f) in enumerate(trace_info):
        if f == field:
            visibility[j] = True
    field_buttons.append(dict(
        label=field,
        method="update",
        args=[{"visible": visibility},
              {"title": f"Field: {field}"}]
    ))

fig.update_layout(
    updatemenus=[
        dict(active=0, buttons=player_buttons, x=0, y=1.1, xanchor='left', direction='down'),
        dict(active=0, buttons=field_buttons, x=0.3, y=1.1, xanchor='left', direction='down')
    ],
    title="Interactive Player Stats"
)

monthly_html_str = fig.to_html(
    include_plotlyjs="cdn",
    full_html=False
)

# %%
import csv
weekly_data = {}
rows = []

# Step 1: Read all rows
with open(dev_weekly_file, newline="", encoding="utf-8") as f:
    reader = csv.DictReader(f)
    for row in reader:
        rows.append(row)

# Step 2: Find latest date
latest_date = max(row["date"] for row in rows)

# Step 3: Build weekly_data from rows matching latest_date
for row in rows:
    if row["date"] == latest_date:
        player = row["uuid"]
        weekly_data[player] = {
            "date": row["date"],
            "username": row["username"],
            "uuid": player,
            "rank": row["rank"],
            "daysLastJoined": row["daysLastJoined"],
            "playtime": float(row["playtime"]),
            "wars": float(row["wars"]),
            "graids": float(row["graids"]),
            "lootruns": float(row["lootruns"]),
            "raids": float(row["raids"]),
            "totalLevel": float(row["totalLevel"]),
            "contentCompletion": float(row["contentCompletion"]),
            "lastJoined": row["lastJoined"]
        }
print(json.dumps(weekly_data, indent=2))
incognito = ['cff26bb4-bad0-4de2-8559-19d23e2d9d41']
# Out:
# {
#   "c32bfbf5-9665-4ad1-837e-92fa882288a3": {
#     "date": "2026-03-08T00:00:23.653376Z",
#     "username": "StyNath",
#     "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3",
#     "rank": "STRATEGIST",
#     "daysLastJoined": "0.003",
#     "playtime": 0.5,
#     "wars": 0.0,
#     "graids": 0.0,
#     "lootruns": 0.0,
#     "raids": 0.0,
#     "totalLevel": 0.0,
#     "contentCompletion": 0.0,
#     "lastJoined": "2026-02-25T21:56:01.849000Z"
#   },
#   "f46a3aa1-ed18-48f4-bcf9-594e0ff19842": {
#     "date": "2026-03-08T00:00:23.653376Z",
#     "username": "WhiteNoise0113",
#     "uuid": "f46a3aa1-ed18-48f4-bcf9-594e0ff19842",
#     "rank": "STRATEGIST",
#     "daysLastJoined": "0.109",
#     "playtime": 0.0,
#     "wars": 0.0,
#     "graids": 0.0,
#     "lootruns": 0.0,
#     "raids": 0.0,
#     "totalLevel": 0.0,
#     "contentCompletion": 0.0,
#     "lastJoined": "2026-02-25T19:23:52.135000Z"
#   }
# }

# %%
monthly_data = {}
rows = []

# Step 1: Read all rows
with open(dev_monthly_file, newline="", encoding="utf-8") as f:
    reader = csv.DictReader(f)
    for row in reader:
        rows.append(row)

# Step 2: Find latest date
latest_date = max(row["date"] for row in rows)

# Step 3: Build weekly_data from rows matching latest_date
for row in rows:
    if row["date"] == latest_date:
        player = row["uuid"]
        monthly_data[player] = {
            "date": row["date"],
            "username": row["username"],
            "uuid": player,
            "rank": row["rank"],
            "daysLastJoined": row["daysLastJoined"],
            "playtime": float(row["playtime"]),
            "wars": float(row["wars"]),
            "graids": float(row["graids"]),
            "lootruns": float(row["lootruns"]),
            "raids": float(row["raids"]),
            "totalLevel": float(row["totalLevel"]),
            "contentCompletion": float(row["contentCompletion"]),
            "lastJoined": row["lastJoined"]
        }
print(json.dumps(monthly_data, indent=2))
# Out:
# {
#   "c32bfbf5-9665-4ad1-837e-92fa882288a3": {
#     "date": "2026-03-08T00:00:23.653376Z",
#     "username": "StyNath",
#     "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3",
#     "rank": "STRATEGIST",
#     "daysLastJoined": "0.003",
#     "playtime": 0.910000000000025,
#     "wars": 0.0,
#     "graids": 0.0,
#     "lootruns": 0.0,
#     "raids": 0.0,
#     "totalLevel": 0.0,
#     "contentCompletion": 0.0,
#     "lastJoined": "2026-02-25T21:56:01.849000Z"
#   },
#   "f46a3aa1-ed18-48f4-bcf9-594e0ff19842": {
#     "date": "2026-03-08T00:00:23.653376Z",
#     "username": "WhiteNoise0113",
#     "uuid": "f46a3aa1-ed18-48f4-bcf9-594e0ff19842",
#     "rank": "STRATEGIST",
#     "daysLastJoined": "0.109",
#     "playtime": 0.17000000000007276,
#     "wars": 0.0,
#     "graids": 0.0,
#     "lootruns": 0.0,
#     "raids": 0.0,
#     "totalLevel": 0.0,
#     "contentCompletion": 0.0,
#     "lastJoined": "2026-02-25T19:23:52.135000Z"
#   }
# }

# %%
import html

def dict_to_html_table(pairs, value_label):
    rows = "\n".join(
        f"<tr><td>{html.escape(str(k))}</td><td>{html.escape(str(v))}</td></tr>"
        for k, v in pairs
    )
    
    return f"""
    <table border="1">
        <thead>
            <tr><th>username</th><th>{html.escape(str(value_label))}</th></tr>
        </thead>
        <tbody>
            {rows}
        </tbody>
    </table>
    """
def paired_tables_dropdown(weekly_pairs, monthly_pairs, value_label):
    weekly_rows = "\n".join(
        f"<tr><td>{html.escape(str(k))}</td><td>{html.escape(str(v))}</td></tr>"
        for k, v in weekly_pairs
    )

    monthly_rows = "\n".join(
        f"<tr><td>{html.escape(str(k))}</td><td>{html.escape(str(v))}</td></tr>"
        for k, v in monthly_pairs
    )

    return f"""
    <details style="margin-bottom: 20px;">
        <summary style="font-size: 18px; font-weight: bold; cursor: pointer;">
            {html.escape(str(value_label))}
        </summary>

        <div style="display: flex; gap: 30px; margin-top: 15px;">

            <div style="width: 50%;">
                <h3>Weekly</h3>
                <table border="1" style="border-collapse: collapse; width: 100%;">
                    <tr>
                        <th>Username</th>
                        <th>{html.escape(str(value_label))}</th>
                    </tr>
                    {weekly_rows}
                </table>
            </div>

            <div style="width: 50%;">
                <h3>Monthly</h3>
                <table border="1" style="border-collapse: collapse; width: 100%;">
                    <tr>
                        <th>Username</th>
                        <th>{html.escape(str(value_label))}</th>
                    </tr>
                    {monthly_rows}
                </table>
            </div>

        </div>
    </details>
    """

# %%
import html


def make_table(pairs, value_label):
    rows = "\n".join(
        f"<tr><td>{html.escape(str(k))}</td><td>{html.escape(str(round(v, 2)))}</td></tr>"
        for k, v in pairs
    )

    return f"""
    <table border="1" style="border-collapse: collapse; font-size: 14px;">
        <tr>
            <th>Username</th>
            <th>{html.escape(str(value_label))}</th>
        </tr>
        {rows}
    </table>
    """


def full_field_dropdown(field, asc_weekly, asc_monthly, desc_weekly, desc_monthly):
    return f"""
    <details style="margin-bottom: 30px;">
        <summary style="font-size: 20px; font-weight: bold; cursor: pointer;">
            {html.escape(field)}
        </summary>

        <div style="
            margin-top: 15px;
            display: flex;
            gap: 25px;
            flex-wrap: nowrap;
        ">

            <div>
                <h4>Top Weekly</h4>
                {make_table(asc_weekly, field)}
            </div>

            <div>
                <h4>Top Monthly</h4>
                {make_table(asc_monthly, field)}
            </div>

            <div>
                <h4>Lowest Weekly</h4>
                {make_table(desc_weekly, field)}
            </div>

            <div>
                <h4>Lowest Monthly</h4>
                {make_table(desc_monthly, field)}
            </div>

        </div>
    </details>
    """

# %%
numeric_fields = ["playtime", "wars", "graids", "lootruns", "raids", "totalLevel", "contentCompletion"]
# asc_weekly_tables = ""
# asc_monthly_tables = ""
# desc_weekly_tables = ""
# desc_monthly_tables = ""
all_tables_html = ""
# money_made_for_guild_weekly_tables = ""
# money_made_for_guild_weekly = sorted([(weekly_data[uuid]["username"], (3 * weekly_data[uuid]["graids"] + weekly_data[uuid]["wars"])/4) for uuid in weekly_data], key=lambda x: x[1], reverse=True)
# # money_made_for_guild_monthly_tables = ""
# money_made_for_guild_monthly = sorted([(monthly_data[uuid]["username"], (3 * monthly_data[uuid]["graids"] + monthly_data[uuid]["wars"])/4) for uuid in monthly_data], key=lambda x: x[1], reverse=True)
for field in numeric_fields:
    asc_weekly = sorted([(weekly_data[uuid]["username"], weekly_data[uuid][field]) for uuid in weekly_data], key=lambda x: x[1], reverse=True)
    asc_monthly = sorted([(monthly_data[uuid]["username"], monthly_data[uuid][field]) for uuid in monthly_data], key=lambda x: x[1], reverse=True)
    desc_weekly = sorted([(weekly_data[uuid]["username"], weekly_data[uuid][field]) for uuid in weekly_data], key=lambda x: x[1], reverse=False)
    desc_monthly = sorted([(monthly_data[uuid]["username"], monthly_data[uuid][field]) for uuid in monthly_data], key=lambda x: x[1], reverse=False)
    # asc_weekly_tables += dict_to_html_table(asc_weekly[:20], field)
    # asc_monthly_tables += dict_to_html_table(asc_monthly[:20], field)
    # desc_weekly_tables += dict_to_html_table(desc_weekly[:20], field)
    # desc_monthly_tables += dict_to_html_table(desc_monthly[:20], field)
    all_tables_html += full_field_dropdown(
        field,
        asc_weekly[:20],
        asc_monthly[:20],
        desc_weekly[:20],
        desc_monthly[:20]
    )

html_ = f"""
<html>
<head>
  <title>My Graph Page</title>
</head>
<body>
  <h1>Performance Rankings</h1>
  Warning icognito players: {"[member_stats[uuid]['username'] for uuid in incognito]"}
  {all_tables_html}
  <div style="display: flex; flex-direction: row">
    <h1 style="width: 50%">Weekly Graphs</h1>
    <h1>Monthly Graphs</h1>
  </div>
  <div style="display: flex; flex-direction: row">
    <div style="width: 50%">
      {weekly_html_str}
    </div>
    <div style="width: 50%">
      {monthly_html_str}
    </div>
  </div>
</body>
</html>
"""
with open("my_page.html", "w") as f:
    f.write(html_)

# %%
import csv
from datetime import datetime, timedelta
import subprocess

# venv_python = ".venv/bin/python"

# subprocess.run([venv_python, "script.py"])

# %%
start_day = "2025-10-09T08:38:37.034846Z"
for i in range(13):
    venv_python = ".venv/bin/python"
    
    subprocess.run([venv_python, "script.py", start_day], check=True)
    
    if i==12:
        break
    file_path = "weekly_data.csv"  # change this

    # --- Step 1: Read everything into memory ---
    with open(file_path, "r", newline="") as f:
        rows = list(csv.reader(f))

    # --- Step 2: Modify first column (subtract 7 days) ---
    for row in rows:
        if not row:
            continue
        if row[0] == "date":
            continue
        dt = datetime.fromisoformat(row[0].replace("Z", "+00:00"))
        new_dt = dt - timedelta(days=7)

        # Force identical formatting
        row[0] = new_dt.strftime("%Y-%m-%dT%H:%M:%S.%fZ")

    # --- Step 3: Write everything back ---
    with open(file_path, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerows(rows)

    
    

    file_path = "dataCollection.csv"  # change this

    # --- Step 1: Read everything into memory ---
    with open(file_path, "r", newline="") as f:
        rows = list(csv.reader(f))

    # --- Step 2: Modify first column (subtract 7 days) ---
    for row in rows:
        if not row:
            continue
        if row[0] == "date":
            continue
        dt = datetime.fromisoformat(row[0].replace("Z", "+00:00"))
        new_dt = dt - timedelta(days=7)

        # Force identical formatting
        row[0] = new_dt.strftime("%Y-%m-%dT%H:%M:%S.%fZ")

    # --- Step 3: Write everything back ---
    with open(file_path, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerows(rows)
    
    file_path = "monthly_data.csv"  # change this

    # --- Step 1: Read everything into memory ---
    with open(file_path, "r", newline="") as f:
        rows = list(csv.reader(f))

    # --- Step 2: Modify first column (subtract 7 days) ---
    for row in rows:
        if not row:
            continue
        if row[0] == "date":
            continue
        dt = datetime.fromisoformat(row[0].replace("Z", "+00:00"))
        new_dt = dt - timedelta(days=7)

        # Force identical formatting
        row[0] = new_dt.strftime("%Y-%m-%dT%H:%M:%S.%fZ")

    # --- Step 3: Write everything back ---
    with open(file_path, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerows(rows)
    dt = datetime.fromisoformat(start_day.replace("Z", "+00:00"))

    # Add 7 days
    new_dt = dt + timedelta(days=7)

    # Convert back to same format
    start_day = new_dt.strftime("%Y-%m-%dT%H:%M:%S.%fZ")
    print(f"{i+1}/8 complete")
# Out:
# oldest_this_month_div: 0.0
# start_day_to_today_formatted: 140.0
# 1/8 complete
# oldest_this_month_div: 7.0
# start_day_to_today_formatted: 133.0
# 2/8 complete
# oldest_this_month_div: 14.0
# start_day_to_today_formatted: 126.0
# 3/8 complete
# oldest_this_month_div: 21.0
# start_day_to_today_formatted: 119.0
# 4/8 complete
# oldest_this_month_div: 28.0
# start_day_to_today_formatted: 112.0
# 5/8 complete
# oldest_this_month_div: 28.0
# start_day_to_today_formatted: 105.0
# 6/8 complete
# oldest_this_month_div: 28.0
# start_day_to_today_formatted: 98.0
# 7/8 complete
# oldest_this_month_div: 28.0
# start_day_to_today_formatted: 91.0
# 8/8 complete
# oldest_this_month_div: 28.0
# start_day_to_today_formatted: 84.0
# 9/8 complete
# oldest_this_month_div: 28.0
# start_day_to_today_formatted: 77.0
# 10/8 complete
# oldest_this_month_div: 28.0
# start_day_to_today_formatted: 70.0
# 11/8 complete
# oldest_this_month_div: 28.0
# start_day_to_today_formatted: 63.0
# 12/8 complete
# oldest_this_month_div: 28.0
# start_day_to_today_formatted: 56.0
