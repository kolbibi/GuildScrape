# %%
from urllib.request import urlopen, Request
import json
import time
from datetime import datetime, timezone
from dotenv import load_dotenv
import os
load_dotenv()


# import os
# Out:
# True

# %%
guild_name = "Godly"
# player1 = "Krijer1?fullResult"
player1 = "CodeCrevette"
start_url = "https://api.wynncraft.com/v3/"
player_url = start_url + "player/"
guild_url = start_url + "guild/"
weekly_csv_file = "./weekly_data.csv"
monthly_csv_file = "./monthly_data.csv"
dev_weekly_file = "./dev_weekly_data.csv"
dev_monthly_file = "./dev_monthly_data.csv"
time_format = "%Y-%m-%dT%H:%M:%S.%fZ"

# %%
class Response:
    def __init__(self, text, status_code, headers):
        self.text = text
        self.status_code = status_code
        self.headers = headers
    def json(self):
        return json.loads(self.text)
class Requests():
    def __init__(self):
        self.headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                      "AppleWebKit/537.36 (KHTML, like Gecko) "
                      "Chrome/116.0.5845.97 Safari/537.36",
            "Authorization": f"Bearer {os.environ.get('API_TOKEN')}"
        }
    def get(self, url):
        req = Request(url, headers=self.headers)
        with urlopen(req) as response:
            data = response.read()
            encoding = response.info().get_content_charset("utf-8")
            text = data.decode(encoding)
            return Response(text, response.getcode(), dict(response.info()))
def subtract_date_string(day1, day2):
    filter1 = datetime.strptime(day1, time_format)
    filter2 = datetime.strptime(day2, time_format)
    days_time = filter1 - filter2
    return round(abs(days_time.total_seconds()/60/60/24), 3)
requests = Requests()

# %%
response = requests.get(player_url + "H1V")
print(json.dumps(response.json(), indent=2))
# Out:
# {
#   "username": "H1V",
#   "online": false,
#   "server": "EU14",
#   "activeCharacter": "b7e25e4c-2d57-48d4-9e38-822a99126ad0",
#   "nickname": null,
#   "uuid": "845eed02-175a-44b4-87a2-0228b1fbc3ee",
#   "rank": "Player",
#   "rankBadge": "nextgen/badges/rank_hero.svg",
#   "legacyRankColour": {
#     "main": "#AA00AA",
#     "sub": "#FF55FF"
#   },
#   "shortenedRank": null,
#   "supportRank": "hero",
#   "veteran": null,
#   "lastJoin": "2026-05-22T14:22:45.481000Z",
#   "ranking": {
#     "playerContent": 280,
#     "orphionSrPlayers": 885,
#     "orphionCompletion": 949,
#     "namelessSrPlayers": 1480,
#     "huntedContent": 1678,
#     "globalPlayerContent": 1980,
#     "woodcuttingLevel": 2225,
#     "combatSoloLevel": 2378,
#     "farmingLevel": 2402,
#     "namelessCompletion": 2609,
#     "fishingLevel": 2650,
#     "frumaCompletion": 2726,
#     "miningLevel": 2907,
#     "frumaSrPlayers": 2950,
#     "grootslangCompletion": 3091,
#     "grootslangSrPlayers": 3220,
#     "colossusSrPlayers": 3664,
#     "colossusCompletion": 4409,
#     "combatGlobalLevel": 6962,
#     "warsCompletion": 8869,
#     "totalSoloLevel": 11501,
#     "professionsSoloLevel": 12561,
#     "totalGlobalLevel": 30195,
#     "jewelingLevel": 36368,
#     "cookingLevel": 55590,
#     "weaponsmithingLevel": 110190,
#     "woodworkingLevel": 130445,
#     "professionsGlobalLevel": 201195,
#     "alchemismLevel": 1603529,
#     "scribingLevel": 1619270,
#     "tailoringLevel": 1620700,
#     "armouringLevel": 1634334
#   },
#   "previousRanking": {},
#   "guild": {
#     "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#     "name": "Godly",
#     "prefix": "grey",
#     "rank": "CHIEF",
#     "rankStars": "\u2605\u2605\u2605\u2605"
#   },
#   "guildHistory": [
#     "0dd24dcc-370c-4e27-a1b4-2dfa92e76667",
#     "194cfad7-4cca-4fde-8760-e42760f9c3d9",
#     "22bbeb0e-6043-407f-9385-0203c1e0bfad",
#     "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#     "f510a7e6-048c-4b19-98db-e16a1c1a60aa"
#   ],
#   "firstJoin": "2017-05-26T22:42:00.776000Z",
#   "playtime": 1370.0,
#   "globalData": {
#     "contentCompletion": 3662,
#     "wars": 30,
#     "totalLevel": 1405,
#     "mobsKilled": 301647,
#     "chestsFound": 6714,
#     "dungeons": {
#       "total": 414,
#       "list": {
#         "Decrepit Sewers": 34,
#         "Infested Pit": 33,
#         "Lost Sanctuary": 14,
#         "Underworld Crypt": 12,
#         "Ice Barrows": 17,
#         "Undergrowth Ruins": 13,
#         "Galleon's Graveyard": 9,
#         "Corrupted Lost Sanctuary": 15,
#         "Fallen Factory": 12,
#         "Corrupted Decrepit Sewers": 16,
#         "Corrupted Infested Pit": 16,
#         "Corrupted Underworld Crypt": 21,
#         "Corrupted Sand-Swept Tomb": 120,
#         "Corrupted Ice Barrows": 13,
#         "Corrupted Undergrowth Ruins": 14,
#         "Corrupted Galleon's Graveyard": 17,
#         "Eldritch Outlook": 20,
#         "Timelost Sanctum": 3,
#         "Sand-Swept Tomb": 15
#       }
#     },
#     "raids": {
#       "total": 703,
#       "list": {
#         "The Canyon Colossus": 124,
#         "Orphion's Nexus of Light": 161,
#         "The Nameless Anomaly": 239,
#         "Nest of the Grootslangs": 168,
#         "The Wartorn Palace": 11
#       }
#     },
#     "worldEvents": 84,
#     "lootruns": 7,
#     "caves": 512,
#     "completedQuests": 524,
#     "raidStats": {
#       "damageTaken": 78433279,
#       "damageDealt": 6305636243,
#       "healthHealed": 1079822688,
#       "deaths": 239,
#       "buffsTaken": 1954,
#       "gambitsUsed": 939
#     },
#     "pvp": {
#       "kills": 0,
#       "deaths": 0
#     },
#     "guildRaids": {
#       "total": 343,
#       "list": {
#         "The Canyon Colossus": 32,
#         "Orphion's Nexus of Light": 98,
#         "Nest of the Grootslangs": 73,
#         "The Nameless Anomaly": 138,
#         "The Wartorn Palace": 2
#       }
#     }
#   },
#   "featuredStats": {
#     "firstJoin": "2017-05-26T22:42:00.776000Z",
#     "playtime": 1370.0,
#     "globalData.totalLevel": 1405,
#     "globalData.mobsKilled": 301647,
#     "globalData.completedQuests": 524
#   },
#   "wallpaper": "home",
#   "avatar": "player",
#   "restrictions": {
#     "mainAccess": false,
#     "onlineStatus": false,
#     "guildHistoryAccess": false
#   }
# }

# %%
response = requests.get(player_url + "CodeCrevette")

# %%
print(json.dumps(response.json(), indent=2))
# Out:
# {
#   "username": "CodeCrevette",
#   "online": true,
#   "server": "NA21",
#   "activeCharacter": "895a7659-2261-4ef0-a588-9c3f1755c054",
#   "nickname": null,
#   "uuid": "c1d04519-cf18-4a40-9061-a0d72ec3fda2",
#   "rank": "Player",
#   "rankBadge": "nextgen/badges/rank_champion.svg",
#   "legacyRankColour": {
#     "main": "#ffff55",
#     "sub": "#ffaa00"
#   },
#   "shortenedRank": null,
#   "supportRank": "champion",
#   "veteran": null,
#   "lastJoin": "2026-05-21T20:56:54.864000Z",
#   "ranking": {
#     "ultimateIronmanContent": 189,
#     "craftsmanContent": 205,
#     "ironmanContent": 509,
#     "huicContent": 526,
#     "playerContent": 575,
#     "weaponsmithingLevel": 678,
#     "woodworkingLevel": 698,
#     "huichContent": 835,
#     "cookingLevel": 861,
#     "orphionSrPlayers": 921,
#     "scribingLevel": 947,
#     "alchemismLevel": 968,
#     "frumaSrPlayers": 1030,
#     "armouringLevel": 1047,
#     "totalSoloLevel": 1070,
#     "frumaCompletion": 1073,
#     "tailoringLevel": 1097,
#     "professionsSoloLevel": 1121,
#     "combatSoloLevel": 1186,
#     "orphionCompletion": 1220,
#     "jewelingLevel": 1234,
#     "namelessSrPlayers": 1673,
#     "professionsGlobalLevel": 2217,
#     "grootslangSrPlayers": 2650,
#     "totalGlobalLevel": 2851,
#     "grootslangCompletion": 2969,
#     "namelessCompletion": 3327,
#     "woodcuttingLevel": 3833,
#     "farmingLevel": 3940,
#     "fishingLevel": 4195,
#     "colossusSrPlayers": 4390,
#     "miningLevel": 4887,
#     "colossusCompletion": 6171,
#     "globalPlayerContent": 7058,
#     "combatGlobalLevel": 9879,
#     "warsCompletion": 11997
#   },
#   "previousRanking": {},
#   "guild": {
#     "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#     "name": "Godly",
#     "prefix": "grey",
#     "rank": "CHIEF",
#     "rankStars": "\u2605\u2605\u2605\u2605"
#   },
#   "guildHistory": [
#     "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#     "2f575d9b-5a6b-4df2-8b6a-8c0ba765e3da",
#     "373c8c68-b5be-4d12-834b-09634483967e"
#   ],
#   "firstJoin": "2026-01-11T22:55:08.663000Z",
#   "playtime": 1053.58,
#   "globalData": {
#     "contentCompletion": 2363,
#     "wars": 14,
#     "totalLevel": 2827,
#     "mobsKilled": 308264,
#     "chestsFound": 4517,
#     "dungeons": {
#       "total": 166,
#       "list": {
#         "Decrepit Sewers": 7,
#         "Infested Pit": 10,
#         "Timelost Sanctum": 3,
#         "Underworld Crypt": 8,
#         "Ice Barrows": 11,
#         "Undergrowth Ruins": 49,
#         "Sand-Swept Tomb": 5,
#         "Galleon's Graveyard": 5,
#         "Corrupted Decrepit Sewers": 16,
#         "Corrupted Infested Pit": 11,
#         "Corrupted Underworld Crypt": 7,
#         "Corrupted Ice Barrows": 7,
#         "Corrupted Undergrowth Ruins": 7,
#         "Corrupted Galleon's Graveyard": 6,
#         "Corrupted Lost Sanctuary": 6,
#         "Corrupted Sand-Swept Tomb": 6,
#         "Fallen Factory": 1,
#         "Eldritch Outlook": 1
#       }
#     },
#     "raids": {
#       "total": 604,
#       "list": {
#         "The Canyon Colossus": 81,
#         "Orphion's Nexus of Light": 136,
#         "The Nameless Anomaly": 178,
#         "Nest of the Grootslangs": 173,
#         "The Wartorn Palace": 36
#       }
#     },
#     "worldEvents": 72,
#     "lootruns": 7,
#     "caves": 285,
#     "completedQuests": 299,
#     "raidStats": {
#       "damageTaken": 53635132,
#       "damageDealt": 8935276168,
#       "healthHealed": 17538019,
#       "deaths": 332,
#       "buffsTaken": 1674,
#       "gambitsUsed": 1682
#     },
#     "pvp": {
#       "kills": 0,
#       "deaths": 0
#     },
#     "guildRaids": {
#       "total": 334,
#       "list": {
#         "The Canyon Colossus": 45,
#         "Orphion's Nexus of Light": 70,
#         "Nest of the Grootslangs": 86,
#         "The Nameless Anomaly": 112,
#         "The Wartorn Palace": 21
#       }
#     }
#   },
#   "featuredStats": {
#     "firstJoin": "2026-01-11T22:55:08.663000Z",
#     "playtime": 1053.58,
#     "globalData.totalLevel": 2827,
#     "globalData.mobsKilled": 308264,
#     "globalData.completedQuests": 299
#   },
#   "wallpaper": "home",
#   "avatar": "player",
#   "restrictions": {
#     "mainAccess": false,
#     "onlineStatus": false,
#     "guildHistoryAccess": false
#   }
# }

# %%
player1Req = requests.get(player_url + player1)
# player2Req = requests.get(player_url + player2)

# %%
player1Data = player1Req.json()
print(json.dumps(player1Data, indent=2))
# Out:
# {
#   "username": "Krijer1",
#   "online": true,
#   "server": "EU25",
#   "activeCharacter": "a1945914-e28a-4d75-b5a4-2e1a35d0030f",
#   "nickname": null,
#   "uuid": "4a82c3ac-be5d-4115-a822-f2a9c7bdb096",
#   "rank": "Player",
#   "rankBadge": "nextgen/badges/rank_hero.svg",
#   "legacyRankColour": {
#     "main": "#AA00AA",
#     "sub": "#FF55FF"
#   },
#   "shortenedRank": null,
#   "supportRank": "hero",
#   "veteran": null,
#   "lastJoin": "2026-02-25T20:26:25.749000Z",
#   "guild": {
#     "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#     "name": "Godly",
#     "prefix": "grey",
#     "rank": "CHIEF",
#     "rankStars": "\u2605\u2605\u2605\u2605"
#   },
#   "ranking": {
#     "cookingLevel": 2249,
#     "farmingLevel": 3196,
#     "fishingLevel": 3369,
#     "jewelingLevel": 3423,
#     "namelessSrPlayers": 3641,
#     "warsCompletion": 3817,
#     "totalSoloLevel": 4776,
#     "professionsSoloLevel": 4828,
#     "miningLevel": 4946,
#     "tailoringLevel": 5139,
#     "armouringLevel": 6476,
#     "guildRaids": 6597,
#     "playerContent": 6621,
#     "namelessCompletion": 6876,
#     "grootslangSrPlayers": 7089,
#     "grootslangCompletion": 7094,
#     "totalGlobalLevel": 8180,
#     "colossusSrPlayers": 8935,
#     "combatGlobalLevel": 8964,
#     "professionsGlobalLevel": 9370,
#     "orphionSrPlayers": 10527,
#     "scribingLevel": 11253,
#     "globalPlayerContent": 11366,
#     "orphionCompletion": 12465,
#     "colossusCompletion": 12851,
#     "woodcuttingLevel": 15327,
#     "combatSoloLevel": 18893,
#     "weaponsmithingLevel": 45936,
#     "woodworkingLevel": 105851,
#     "alchemismLevel": 2325100
#   },
#   "previousRanking": {},
#   "firstJoin": "2018-03-07T16:26:49.359000Z",
#   "playtime": 583.08,
#   "globalData": {
#     "contentCompletion": 1745,
#     "wars": 165,
#     "totalLevel": 3363,
#     "mobsKilled": 226501,
#     "chestsFound": 2610,
#     "dungeons": {
#       "total": 167,
#       "list": {
#         "Decrepit Sewers": 38,
#         "Infested Pit": 16,
#         "Underworld Crypt": 10,
#         "Sand-Swept Tomb": 18,
#         "Ice Barrows": 14,
#         "Undergrowth Ruins": 12,
#         "Lost Sanctuary": 2,
#         "Galleon's Graveyard": 5,
#         "Corrupted Decrepit Sewers": 10,
#         "Corrupted Lost Sanctuary": 7,
#         "Corrupted Infested Pit": 7,
#         "Corrupted Underworld Crypt": 6,
#         "Corrupted Sand-Swept Tomb": 6,
#         "Corrupted Ice Barrows": 6,
#         "Corrupted Undergrowth Ruins": 2,
#         "Eldritch Outlook": 2,
#         "Fallen Factory": 3,
#         "Corrupted Galleon's Graveyard": 2,
#         "Timelost Sanctum": 1
#       }
#     },
#     "raids": {
#       "total": 147,
#       "list": {
#         "The Canyon Colossus": 20,
#         "Orphion's Nexus of Light": 10,
#         "The Nameless Anomaly": 57,
#         "Nest of the Grootslangs": 60
#       }
#     },
#     "worldEvents": 25,
#     "lootruns": 5,
#     "caves": 167,
#     "completedQuests": 262,
#     "pvp": {
#       "kills": 0,
#       "deaths": 0
#     },
#     "guildRaids": {
#       "total": 22,
#       "list": {
#         "The Canyon Colossus": 6,
#         "Orphion's Nexus of Light": 0,
#         "Nest of the Grootslangs": 2,
#         "The Nameless Anomaly": 14
#       }
#     }
#   },
#   "featuredStats": {
#     "firstJoin": "2018-03-07T16:26:49.359000Z",
#     "playtime": 583.08,
#     "globalData.totalLevel": 3363,
#     "globalData.mobsKilled": 226501,
#     "globalData.completedQuests": 262
#   },
#   "wallpaper": "home",
#   "avatar": "player",
#   "restrictions": {
#     "mainAccess": false,
#     "onlineStatus": false
#   }
# }

# %%
#Player info
# print(json.dumps(response.json(), indent=2))
# print(response.json()['playtime'])
# print(json.dumps(player1Data, indent=2))
player1time = player1Data["playtime"]
print(player1time)
# Out:
# 583.08

# %%
guild_req = requests.get(guild_url + guild_name)

# %%
print(json.dumps(guild_req.json(), indent=2))
# Out:
# {
#   "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#   "name": "Godly",
#   "prefix": "grey",
#   "level": 77,
#   "xpPercent": 26,
#   "territories": 0,
#   "wars": 1808,
#   "raids": 2374,
#   "created": "2025-08-20T06:59:13.342000Z",
#   "members": {
#     "total": 84,
#     "owner": {
#       "Nqn": {
#         "uuid": "a8e5c7c3-444f-4436-b69f-a8db58cdf40d",
#         "legacyName": "Nqn",
#         "online": false,
#         "lastJoin": "2026-05-23T11:52:30.789000Z",
#         "server": null,
#         "contributed": 5597029384,
#         "contributionRank": 1,
#         "joined": "2025-08-20T06:59:13.342000Z",
#         "weekly": {
#           "completed": true,
#           "streak": 19
#         },
#         "globalData": {
#           "contentCompletion": 2032,
#           "wars": 416,
#           "totalLevel": 2270,
#           "mobsKilled": 1670741,
#           "chestsFound": 9816,
#           "dungeons": {
#             "total": 236,
#             "list": {
#               "Decrepit Sewers": 43,
#               "Sand-Swept Tomb": 4,
#               "Ice Barrows": 7,
#               "Eldritch Outlook": 10,
#               "Corrupted Galleon's Graveyard": 24,
#               "Corrupted Decrepit Sewers": 24,
#               "Corrupted Infested Pit": 21,
#               "Corrupted Lost Sanctuary": 19,
#               "Corrupted Underworld Crypt": 20,
#               "Corrupted Sand-Swept Tomb": 24,
#               "Corrupted Ice Barrows": 18,
#               "Corrupted Undergrowth Ruins": 18,
#               "Underworld Crypt": 1,
#               "Infested Pit": 2,
#               "Timelost Sanctum": 1
#             }
#           },
#           "raids": {
#             "total": 1134,
#             "list": {
#               "The Canyon Colossus": 208,
#               "Orphion's Nexus of Light": 132,
#               "The Nameless Anomaly": 467,
#               "Nest of the Grootslangs": 218,
#               "The Wartorn Palace": 109
#             }
#           },
#           "worldEvents": 26,
#           "lootruns": 5,
#           "caves": 137,
#           "completedQuests": 122,
#           "raidStats": {
#             "damageTaken": 93214150,
#             "damageDealt": 18376622864,
#             "healthHealed": 131567855,
#             "deaths": 396,
#             "buffsTaken": 3099,
#             "gambitsUsed": 3169
#           },
#           "pvp": {
#             "kills": 0,
#             "deaths": 0
#           },
#           "guildRaids": {
#             "total": 321,
#             "list": {
#               "The Canyon Colossus": 57,
#               "Orphion's Nexus of Light": 37,
#               "Nest of the Grootslangs": 81,
#               "The Nameless Anomaly": 117,
#               "The Wartorn Palace": 29
#             }
#           },
#           "playtime": 1304.75
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       }
#     },
#     "chief": {
#       "SolaR8735": {
#         "uuid": "4fb7c4a3-a84e-431c-9d93-649f6391f7eb",
#         "legacyName": "SolaR8735",
#         "online": false,
#         "lastJoin": "2026-05-23T08:11:42.446000Z",
#         "server": null,
#         "contributed": 2607181067,
#         "contributionRank": 2,
#         "joined": "2026-02-26T06:41:54.658000Z",
#         "weekly": {
#           "completed": true,
#           "streak": 12
#         },
#         "globalData": {
#           "contentCompletion": 851,
#           "wars": 73,
#           "totalLevel": 634,
#           "mobsKilled": 232821,
#           "chestsFound": 6227,
#           "dungeons": {
#             "total": 97,
#             "list": {
#               "Decrepit Sewers": 11,
#               "Infested Pit": 10,
#               "Timelost Sanctum": 7,
#               "Underworld Crypt": 3,
#               "Sand-Swept Tomb": 3,
#               "Ice Barrows": 11,
#               "Undergrowth Ruins": 17,
#               "Galleon's Graveyard": 11,
#               "Corrupted Decrepit Sewers": 10,
#               "Corrupted Infested Pit": 2,
#               "Corrupted Lost Sanctuary": 2,
#               "Corrupted Underworld Crypt": 1,
#               "Corrupted Sand-Swept Tomb": 1,
#               "Corrupted Ice Barrows": 1,
#               "Corrupted Undergrowth Ruins": 1,
#               "Corrupted Galleon's Graveyard": 3,
#               "Eldritch Outlook": 3
#             }
#           },
#           "raids": {
#             "total": 608,
#             "list": {
#               "The Canyon Colossus": 138,
#               "Orphion's Nexus of Light": 111,
#               "The Nameless Anomaly": 140,
#               "Nest of the Grootslangs": 184,
#               "The Wartorn Palace": 35
#             }
#           },
#           "worldEvents": 31,
#           "lootruns": 5,
#           "caves": 121,
#           "completedQuests": 64,
#           "raidStats": {
#             "damageTaken": 98746725,
#             "damageDealt": 12600840657,
#             "healthHealed": 6771184093,
#             "deaths": 75,
#             "buffsTaken": 1676,
#             "gambitsUsed": 1509
#           },
#           "pvp": {
#             "kills": 0,
#             "deaths": 0
#           },
#           "guildRaids": {
#             "total": 319,
#             "list": {
#               "The Canyon Colossus": 62,
#               "Orphion's Nexus of Light": 65,
#               "Nest of the Grootslangs": 81,
#               "The Nameless Anomaly": 95,
#               "The Wartorn Palace": 16
#             }
#           },
#           "playtime": 777.25
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       },
#       "_N8": {
#         "uuid": "5652732f-e36b-4ca4-87ca-59f9c6dc3ba1",
#         "legacyName": "_N8",
#         "online": false,
#         "lastJoin": "2026-05-16T06:36:26.939000Z",
#         "server": null,
#         "contributed": 2103181423,
#         "contributionRank": 3,
#         "joined": "2025-08-20T06:59:30.170000Z",
#         "weekly": {
#           "completed": false,
#           "streak": 0
#         },
#         "globalData": {
#           "contentCompletion": 1878,
#           "wars": 369,
#           "totalLevel": 1082,
#           "mobsKilled": 291352,
#           "chestsFound": 4104,
#           "dungeons": {
#             "total": 132,
#             "list": {
#               "Skeleton": 3,
#               "Spider": 1,
#               "Animal": 1,
#               "Decrepit Sewers": 16,
#               "Sand-Swept Tomb": 1,
#               "Ice Barrows": 5,
#               "Underworld Crypt": 1,
#               "Timelost Sanctum": 1,
#               "Corrupted Infested Pit": 13,
#               "Corrupted Sand-Swept Tomb": 16,
#               "Corrupted Decrepit Sewers": 15,
#               "Corrupted Lost Sanctuary": 12,
#               "Corrupted Underworld Crypt": 11,
#               "Corrupted Ice Barrows": 13,
#               "Corrupted Undergrowth Ruins": 12,
#               "Corrupted Galleon's Graveyard": 10,
#               "Eldritch Outlook": 1
#             }
#           },
#           "raids": {
#             "total": 89,
#             "list": {
#               "Orphion's Nexus of Light": 42,
#               "The Nameless Anomaly": 18,
#               "Nest of the Grootslangs": 29
#             }
#           },
#           "worldEvents": 18,
#           "lootruns": 2,
#           "caves": 109,
#           "completedQuests": 80,
#           "raidStats": {
#             "damageTaken": 7384063,
#             "damageDealt": 337924672,
#             "healthHealed": 3400833,
#             "deaths": 67,
#             "buffsTaken": 248,
#             "gambitsUsed": 6
#           },
#           "pvp": {
#             "kills": 127,
#             "deaths": 185
#           },
#           "guildRaids": {
#             "total": 15,
#             "list": {
#               "The Canyon Colossus": 0,
#               "Orphion's Nexus of Light": 5,
#               "Nest of the Grootslangs": 7,
#               "The Nameless Anomaly": 3,
#               "The Wartorn Palace": 0
#             }
#           },
#           "playtime": 766.08
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       },
#       "GigaFanDeJul": {
#         "uuid": "0a19dd60-254e-4c48-9d76-1b57a2f12c7f",
#         "legacyName": "GigaFanDeJul",
#         "online": false,
#         "lastJoin": "2026-05-16T23:06:54.046000Z",
#         "server": null,
#         "contributed": 1088150560,
#         "contributionRank": 4,
#         "joined": "2026-01-17T14:55:37.482000Z",
#         "weekly": {
#           "completed": false,
#           "streak": 0
#         },
#         "globalData": {
#           "contentCompletion": 1319,
#           "wars": 183,
#           "totalLevel": 1755,
#           "mobsKilled": 266295,
#           "chestsFound": 3542,
#           "dungeons": {
#             "total": 114,
#             "list": {
#               "Skeleton": 2,
#               "Spider": 2,
#               "Zombie": 1,
#               "Animal": 5,
#               "Silverfish": 2,
#               "Infested Pit": 7,
#               "Decrepit Sewers": 29,
#               "Lost Sanctuary": 1,
#               "Underworld Crypt": 3,
#               "Sand-Swept Tomb": 8,
#               "Ice Barrows": 9,
#               "Corrupted Decrepit Sewers": 5,
#               "Corrupted Infested Pit": 5,
#               "Eldritch Outlook": 6,
#               "Corrupted Lost Sanctuary": 7,
#               "Corrupted Underworld Crypt": 4,
#               "Corrupted Sand-Swept Tomb": 4,
#               "Corrupted Ice Barrows": 3,
#               "Corrupted Undergrowth Ruins": 3,
#               "Corrupted Galleon's Graveyard": 8
#             }
#           },
#           "raids": {
#             "total": 222,
#             "list": {
#               "The Canyon Colossus": 60,
#               "Orphion's Nexus of Light": 32,
#               "The Nameless Anomaly": 54,
#               "Nest of the Grootslangs": 58,
#               "The Wartorn Palace": 18
#             }
#           },
#           "worldEvents": 32,
#           "lootruns": 1,
#           "caves": 80,
#           "completedQuests": 116,
#           "raidStats": {
#             "damageTaken": 13440441,
#             "damageDealt": 4237404362,
#             "healthHealed": 7620087,
#             "deaths": 96,
#             "buffsTaken": 619,
#             "gambitsUsed": 446
#           },
#           "pvp": {
#             "kills": 0,
#             "deaths": 0
#           },
#           "guildRaids": {
#             "total": 107,
#             "list": {
#               "The Canyon Colossus": 4,
#               "Orphion's Nexus of Light": 14,
#               "Nest of the Grootslangs": 41,
#               "The Nameless Anomaly": 48,
#               "The Wartorn Palace": 0
#             }
#           },
#           "playtime": 789.0
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       },
#       "H1V": {
#         "uuid": "845eed02-175a-44b4-87a2-0228b1fbc3ee",
#         "legacyName": "H1V",
#         "online": false,
#         "lastJoin": "2026-05-22T14:22:45.481000Z",
#         "server": null,
#         "contributed": 701104385,
#         "contributionRank": 5,
#         "joined": "2026-01-19T01:16:08.956000Z",
#         "weekly": {
#           "completed": true,
#           "streak": 14
#         },
#         "globalData": {
#           "contentCompletion": 3662,
#           "wars": 30,
#           "totalLevel": 1405,
#           "mobsKilled": 301647,
#           "chestsFound": 6714,
#           "dungeons": {
#             "total": 414,
#             "list": {
#               "Decrepit Sewers": 34,
#               "Infested Pit": 33,
#               "Lost Sanctuary": 14,
#               "Underworld Crypt": 12,
#               "Ice Barrows": 17,
#               "Undergrowth Ruins": 13,
#               "Galleon's Graveyard": 9,
#               "Corrupted Lost Sanctuary": 15,
#               "Fallen Factory": 12,
#               "Corrupted Decrepit Sewers": 16,
#               "Corrupted Infested Pit": 16,
#               "Corrupted Underworld Crypt": 21,
#               "Corrupted Sand-Swept Tomb": 120,
#               "Corrupted Ice Barrows": 13,
#               "Corrupted Undergrowth Ruins": 14,
#               "Corrupted Galleon's Graveyard": 17,
#               "Eldritch Outlook": 20,
#               "Timelost Sanctum": 3,
#               "Sand-Swept Tomb": 15
#             }
#           },
#           "raids": {
#             "total": 703,
#             "list": {
#               "The Canyon Colossus": 124,
#               "Orphion's Nexus of Light": 161,
#               "The Nameless Anomaly": 239,
#               "Nest of the Grootslangs": 168,
#               "The Wartorn Palace": 11
#             }
#           },
#           "worldEvents": 84,
#           "lootruns": 7,
#           "caves": 512,
#           "completedQuests": 524,
#           "raidStats": {
#             "damageTaken": 78433279,
#             "damageDealt": 6305636243,
#             "healthHealed": 1079822688,
#             "deaths": 239,
#             "buffsTaken": 1954,
#             "gambitsUsed": 939
#           },
#           "pvp": {
#             "kills": 0,
#             "deaths": 0
#           },
#           "guildRaids": {
#             "total": 219,
#             "list": {
#               "The Canyon Colossus": 32,
#               "Orphion's Nexus of Light": 60,
#               "Nest of the Grootslangs": 39,
#               "The Nameless Anomaly": 86,
#               "The Wartorn Palace": 2
#             }
#           },
#           "playtime": 1370.0
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       },
#       "Krijer1": {
#         "uuid": "4a82c3ac-be5d-4115-a822-f2a9c7bdb096",
#         "legacyName": "Krijer1",
#         "online": false,
#         "lastJoin": "2026-05-23T10:52:06.941000Z",
#         "server": null,
#         "contributed": 487302865,
#         "contributionRank": 6,
#         "joined": "2026-01-16T18:40:55.478000Z",
#         "weekly": {
#           "completed": true,
#           "streak": 18
#         },
#         "globalData": {
#           "contentCompletion": 2122,
#           "wars": 222,
#           "totalLevel": 1919,
#           "mobsKilled": 325937,
#           "chestsFound": 3899,
#           "dungeons": {
#             "total": 175,
#             "list": {
#               "Decrepit Sewers": 45,
#               "Infested Pit": 17,
#               "Underworld Crypt": 10,
#               "Sand-Swept Tomb": 18,
#               "Ice Barrows": 14,
#               "Undergrowth Ruins": 12,
#               "Lost Sanctuary": 2,
#               "Galleon's Graveyard": 5,
#               "Corrupted Decrepit Sewers": 10,
#               "Corrupted Lost Sanctuary": 7,
#               "Corrupted Infested Pit": 7,
#               "Corrupted Underworld Crypt": 6,
#               "Corrupted Sand-Swept Tomb": 6,
#               "Corrupted Ice Barrows": 6,
#               "Corrupted Undergrowth Ruins": 2,
#               "Eldritch Outlook": 2,
#               "Fallen Factory": 3,
#               "Corrupted Galleon's Graveyard": 2,
#               "Timelost Sanctum": 1
#             }
#           },
#           "raids": {
#             "total": 312,
#             "list": {
#               "The Canyon Colossus": 67,
#               "Orphion's Nexus of Light": 13,
#               "The Nameless Anomaly": 105,
#               "Nest of the Grootslangs": 105,
#               "The Wartorn Palace": 22
#             }
#           },
#           "worldEvents": 48,
#           "lootruns": 7,
#           "caves": 210,
#           "completedQuests": 273,
#           "raidStats": {
#             "damageTaken": 49646290,
#             "damageDealt": 4311341200,
#             "healthHealed": 4094942520,
#             "deaths": 32,
#             "buffsTaken": 787,
#             "gambitsUsed": 618
#           },
#           "pvp": {
#             "kills": 0,
#             "deaths": 0
#           },
#           "guildRaids": {
#             "total": 111,
#             "list": {
#               "The Canyon Colossus": 31,
#               "Orphion's Nexus of Light": 3,
#               "Nest of the Grootslangs": 40,
#               "The Nameless Anomaly": 33,
#               "The Wartorn Palace": 4
#             }
#           },
#           "playtime": 830.42
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       },
#       "CodeCrevette": {
#         "uuid": "c1d04519-cf18-4a40-9061-a0d72ec3fda2",
#         "legacyName": "CodeCrevette",
#         "online": false,
#         "lastJoin": "2026-05-23T04:44:37.953000Z",
#         "server": null,
#         "contributed": 404045857,
#         "contributionRank": 9,
#         "joined": "2026-04-20T23:53:02.804000Z",
#         "weekly": {
#           "completed": true,
#           "streak": 5
#         },
#         "globalData": {
#           "contentCompletion": 2551,
#           "wars": 14,
#           "totalLevel": 3361,
#           "mobsKilled": 311262,
#           "chestsFound": 4667,
#           "dungeons": {
#             "total": 170,
#             "list": {
#               "Decrepit Sewers": 10,
#               "Infested Pit": 11,
#               "Timelost Sanctum": 3,
#               "Underworld Crypt": 8,
#               "Ice Barrows": 11,
#               "Undergrowth Ruins": 49,
#               "Sand-Swept Tomb": 5,
#               "Galleon's Graveyard": 5,
#               "Corrupted Decrepit Sewers": 16,
#               "Corrupted Infested Pit": 11,
#               "Corrupted Underworld Crypt": 7,
#               "Corrupted Ice Barrows": 7,
#               "Corrupted Undergrowth Ruins": 7,
#               "Corrupted Galleon's Graveyard": 6,
#               "Corrupted Lost Sanctuary": 6,
#               "Corrupted Sand-Swept Tomb": 6,
#               "Fallen Factory": 1,
#               "Eldritch Outlook": 1
#             }
#           },
#           "raids": {
#             "total": 611,
#             "list": {
#               "The Canyon Colossus": 81,
#               "Orphion's Nexus of Light": 137,
#               "The Nameless Anomaly": 183,
#               "Nest of the Grootslangs": 173,
#               "The Wartorn Palace": 37
#             }
#           },
#           "worldEvents": 74,
#           "lootruns": 7,
#           "caves": 314,
#           "completedQuests": 332,
#           "raidStats": {
#             "damageTaken": 56069236,
#             "damageDealt": 9008421989,
#             "healthHealed": 21464924,
#             "deaths": 332,
#             "buffsTaken": 1695,
#             "gambitsUsed": 1703
#           },
#           "pvp": {
#             "kills": 0,
#             "deaths": 0
#           },
#           "guildRaids": {
#             "total": 330,
#             "list": {
#               "The Canyon Colossus": 45,
#               "Orphion's Nexus of Light": 71,
#               "Nest of the Grootslangs": 85,
#               "The Nameless Anomaly": 107,
#               "The Wartorn Palace": 22
#             }
#           },
#           "playtime": 1066.08
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       },
#       "Shivnitzl19": {
#         "uuid": "bd5c1697-4d42-41dd-a4f2-2c8a3a669104",
#         "legacyName": "Shivnitzl19",
#         "online": false,
#         "lastJoin": "2026-05-22T11:57:30.067000Z",
#         "server": null,
#         "contributed": 134955328,
#         "contributionRank": 19,
#         "joined": "2025-08-20T11:17:53.604000Z",
#         "weekly": {
#           "completed": true,
#           "streak": 2
#         },
#         "globalData": {
#           "contentCompletion": 5186,
#           "wars": 37,
#           "totalLevel": 3545,
#           "mobsKilled": 781078,
#           "chestsFound": 18130,
#           "dungeons": {
#             "total": 1545,
#             "list": {
#               "Decrepit Sewers": 44,
#               "Underworld Crypt": 44,
#               "Ice Barrows": 43,
#               "Undergrowth Ruins": 34,
#               "Galleon's Graveyard": 22,
#               "Corrupted Sand-Swept Tomb": 395,
#               "Corrupted Lost Sanctuary": 90,
#               "Corrupted Undergrowth Ruins": 251,
#               "Eldritch Outlook": 82,
#               "Corrupted Ice Barrows": 104,
#               "Corrupted Underworld Crypt": 103,
#               "Corrupted Infested Pit": 87,
#               "Corrupted Decrepit Sewers": 92,
#               "Infested Pit": 30,
#               "Sand-Swept Tomb": 25,
#               "Corrupted Galleon's Graveyard": 67,
#               "Fallen Factory": 24,
#               "Lost Sanctuary": 4,
#               "Timelost Sanctum": 4
#             }
#           },
#           "raids": {
#             "total": 497,
#             "list": {
#               "The Canyon Colossus": 121,
#               "Orphion's Nexus of Light": 260,
#               "The Nameless Anomaly": 28,
#               "Nest of the Grootslangs": 88
#             }
#           },
#           "worldEvents": 70,
#           "lootruns": 5,
#           "caves": 396,
#           "completedQuests": 970,
#           "raidStats": {
#             "damageTaken": 4246098,
#             "damageDealt": 637953206,
#             "healthHealed": 4310476,
#             "deaths": 27,
#             "buffsTaken": 185,
#             "gambitsUsed": 24
#           },
#           "pvp": {
#             "kills": 0,
#             "deaths": 0
#           },
#           "guildRaids": {
#             "total": 29,
#             "list": {
#               "The Canyon Colossus": 4,
#               "Orphion's Nexus of Light": 3,
#               "Nest of the Grootslangs": 11,
#               "The Nameless Anomaly": 11,
#               "The Wartorn Palace": 0
#             }
#           },
#           "playtime": 3809.58
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       },
#       "ewenfi": {
#         "uuid": "89cdeb83-0958-4563-a606-0a460e13abfa",
#         "legacyName": "ewenfi",
#         "online": false,
#         "lastJoin": "2026-05-04T15:48:40.553000Z",
#         "server": null,
#         "contributed": 60744728,
#         "contributionRank": 32,
#         "joined": "2026-01-17T14:57:25.432000Z",
#         "weekly": {
#           "completed": false,
#           "streak": 0
#         },
#         "globalData": {
#           "contentCompletion": 2051,
#           "wars": 71,
#           "totalLevel": 904,
#           "mobsKilled": 327105,
#           "chestsFound": 10775,
#           "dungeons": {
#             "total": 426,
#             "list": {
#               "Skeleton": 39,
#               "Spider": 34,
#               "Animal": 26,
#               "Zombie": 16,
#               "Silverfish": 12,
#               "Jungle": 6,
#               "Ice Barrows": 14,
#               "Lost Sanctuary": 4,
#               "Undergrowth Ruins": 4,
#               "Decrepit Sewers": 12,
#               "Underworld Crypt": 3,
#               "Fallen Factory": 8,
#               "Corrupted Lost Sanctuary": 37,
#               "Corrupted Sand-Swept Tomb": 53,
#               "Infested Pit": 26,
#               "Sand-Swept Tomb": 20,
#               "Corrupted Infested Pit": 22,
#               "Corrupted Decrepit Sewers": 21,
#               "Corrupted Underworld Crypt": 20,
#               "Corrupted Ice Barrows": 17,
#               "Corrupted Undergrowth Ruins": 16,
#               "Eldritch Outlook": 2,
#               "Corrupted Galleon's Graveyard": 9,
#               "Galleon's Graveyard": 5
#             }
#           },
#           "raids": {
#             "total": 427,
#             "list": {
#               "The Canyon Colossus": 195,
#               "Orphion's Nexus of Light": 79,
#               "The Nameless Anomaly": 66,
#               "Nest of the Grootslangs": 67,
#               "The Wartorn Palace": 20
#             }
#           },
#           "worldEvents": 19,
#           "lootruns": 2,
#           "caves": 132,
#           "completedQuests": 320,
#           "raidStats": {
#             "damageTaken": 25983483,
#             "damageDealt": 3157564149,
#             "healthHealed": 90159330,
#             "deaths": 153,
#             "buffsTaken": 1046,
#             "gambitsUsed": 898
#           },
#           "pvp": {
#             "kills": 0,
#             "deaths": 0
#           },
#           "guildRaids": {
#             "total": 99,
#             "list": {
#               "The Canyon Colossus": 2,
#               "Orphion's Nexus of Light": 12,
#               "Nest of the Grootslangs": 41,
#               "The Nameless Anomaly": 44,
#               "The Wartorn Palace": 0
#             }
#           },
#           "playtime": 1006.83
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       },
#       "KirouXD": {
#         "uuid": "4470c807-1394-4930-937d-1680d508d22d",
#         "legacyName": "KirouXD",
#         "online": false,
#         "lastJoin": "2026-03-08T15:19:03.061000Z",
#         "server": null,
#         "contributed": 18336630,
#         "contributionRank": 49,
#         "joined": "2026-01-17T14:36:32.901000Z",
#         "weekly": {
#           "completed": false,
#           "streak": 6
#         },
#         "globalData": {
#           "contentCompletion": 659,
#           "wars": 92,
#           "totalLevel": 1015,
#           "mobsKilled": 147708,
#           "chestsFound": 4104,
#           "dungeons": {
#             "total": 65,
#             "list": {
#               "Decrepit Sewers": 14,
#               "Sand-Swept Tomb": 3,
#               "Ice Barrows": 8,
#               "Corrupted Decrepit Sewers": 4,
#               "Corrupted Infested Pit": 3,
#               "Corrupted Lost Sanctuary": 7,
#               "Corrupted Underworld Crypt": 4,
#               "Corrupted Sand-Swept Tomb": 3,
#               "Corrupted Ice Barrows": 8,
#               "Corrupted Undergrowth Ruins": 3,
#               "Corrupted Galleon's Graveyard": 8
#             }
#           },
#           "raids": {
#             "total": 188,
#             "list": {
#               "The Canyon Colossus": 33,
#               "Orphion's Nexus of Light": 53,
#               "The Nameless Anomaly": 72,
#               "Nest of the Grootslangs": 30
#             }
#           },
#           "worldEvents": 7,
#           "lootruns": 3,
#           "caves": 36,
#           "completedQuests": 48,
#           "raidStats": {
#             "damageTaken": 20693577,
#             "damageDealt": 1767531856,
#             "healthHealed": 72293908,
#             "deaths": 42,
#             "buffsTaken": 507,
#             "gambitsUsed": 418
#           },
#           "pvp": {
#             "kills": 0,
#             "deaths": 0
#           },
#           "guildRaids": {
#             "total": 61,
#             "list": {
#               "The Canyon Colossus": 2,
#               "Orphion's Nexus of Light": 17,
#               "Nest of the Grootslangs": 25,
#               "The Nameless Anomaly": 17,
#               "The Wartorn Palace": 0
#             }
#           },
#           "playtime": 395.17
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       },
#       "Chevacchi": {
#         "uuid": "eb33d516-a34b-4050-bd2c-69a24bf0bd75",
#         "legacyName": "Chevacchi",
#         "online": false,
#         "lastJoin": "2026-05-08T04:57:17.623000Z",
#         "server": null,
#         "contributed": 35,
#         "contributionRank": 80,
#         "joined": "2026-04-15T22:59:32.906000Z",
#         "weekly": {
#           "completed": false,
#           "streak": 0
#         },
#         "globalData": {
#           "contentCompletion": 830,
#           "wars": 844,
#           "totalLevel": 521,
#           "mobsKilled": 107165,
#           "chestsFound": 8,
#           "dungeons": {
#             "total": 1,
#             "list": {
#               "Eldritch Outlook": 1
#             }
#           },
#           "raids": {
#             "total": 53,
#             "list": {
#               "The Nameless Anomaly": 17,
#               "Nest of the Grootslangs": 16,
#               "The Canyon Colossus": 16,
#               "Orphion's Nexus of Light": 4
#             }
#           },
#           "worldEvents": 1,
#           "lootruns": 0,
#           "caves": 0,
#           "completedQuests": 19,
#           "raidStats": {
#             "damageTaken": 3565471,
#             "damageDealt": 603189563,
#             "healthHealed": 70695031,
#             "deaths": 60,
#             "buffsTaken": 159,
#             "gambitsUsed": 65
#           },
#           "pvp": {
#             "kills": 0,
#             "deaths": 0
#           },
#           "guildRaids": {
#             "total": 32,
#             "list": {
#               "The Canyon Colossus": 9,
#               "Orphion's Nexus of Light": 3,
#               "Nest of the Grootslangs": 5,
#               "The Nameless Anomaly": 15,
#               "The Wartorn Palace": 0
#             }
#           },
#           "playtime": 559.67
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       },
#       "happyguy18": {
#         "uuid": "e36e1abc-7682-4b65-a8d1-7222424ee59a",
#         "legacyName": "happyguy18",
#         "online": false,
#         "lastJoin": "2026-04-19T06:35:33.272000Z",
#         "server": null,
#         "contributed": 0,
#         "contributionRank": 81,
#         "joined": "2026-04-05T05:31:19.548000Z",
#         "weekly": {
#           "completed": false,
#           "streak": 1
#         },
#         "globalData": {
#           "contentCompletion": 781,
#           "wars": 166,
#           "totalLevel": 1228,
#           "mobsKilled": 77553,
#           "chestsFound": 480,
#           "dungeons": {
#             "total": 47,
#             "list": {
#               "Decrepit Sewers": 6,
#               "Underworld Crypt": 4,
#               "Timelost Sanctum": 1,
#               "Corrupted Infested Pit": 2,
#               "Corrupted Lost Sanctuary": 4,
#               "Corrupted Underworld Crypt": 2,
#               "Corrupted Decrepit Sewers": 1,
#               "Corrupted Sand-Swept Tomb": 1,
#               "Corrupted Ice Barrows": 1,
#               "Corrupted Galleon's Graveyard": 1,
#               "Corrupted Undergrowth Ruins": 1,
#               "Sand-Swept Tomb": 2,
#               "Ice Barrows": 7,
#               "Undergrowth Ruins": 8,
#               "Galleon's Graveyard": 2,
#               "Infested Pit": 4
#             }
#           },
#           "raids": {
#             "total": 72,
#             "list": {
#               "The Canyon Colossus": 11,
#               "Orphion's Nexus of Light": 5,
#               "The Nameless Anomaly": 25,
#               "Nest of the Grootslangs": 31
#             }
#           },
#           "worldEvents": 9,
#           "lootruns": 1,
#           "caves": 42,
#           "completedQuests": 78,
#           "raidStats": {
#             "damageTaken": 5009373,
#             "damageDealt": 630485111,
#             "healthHealed": 2481760,
#             "deaths": 38,
#             "buffsTaken": 212,
#             "gambitsUsed": 86
#           },
#           "pvp": {
#             "kills": 0,
#             "deaths": 0
#           },
#           "guildRaids": {
#             "total": 14,
#             "list": {
#               "The Canyon Colossus": 0,
#               "Orphion's Nexus of Light": 1,
#               "Nest of the Grootslangs": 4,
#               "The Nameless Anomaly": 9,
#               "The Wartorn Palace": 0
#             }
#           },
#           "playtime": 290.92
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       }
#     },
#     "strategist": {
#       "_Snoopers_": {
#         "uuid": "130612b6-1d46-49c7-b06e-3200959254c7",
#         "legacyName": "_Snoopers_",
#         "online": false,
#         "lastJoin": "2026-05-18T02:54:10.491000Z",
#         "server": null,
#         "contributed": 193299111,
#         "contributionRank": 11,
#         "joined": "2026-01-16T19:11:52.855000Z",
#         "weekly": {
#           "completed": false,
#           "streak": 0
#         },
#         "globalData": {
#           "contentCompletion": 1536,
#           "wars": 38,
#           "totalLevel": 521,
#           "mobsKilled": 88258,
#           "chestsFound": 1730,
#           "dungeons": {
#             "total": 52,
#             "list": {
#               "Decrepit Sewers": 4,
#               "Infested Pit": 8,
#               "Underworld Crypt": 6,
#               "Timelost Sanctum": 1,
#               "Sand-Swept Tomb": 5,
#               "Ice Barrows": 5,
#               "Undergrowth Ruins": 2,
#               "Galleon's Graveyard": 2,
#               "Corrupted Lost Sanctuary": 1,
#               "Corrupted Underworld Crypt": 6,
#               "Corrupted Decrepit Sewers": 1,
#               "Corrupted Infested Pit": 1,
#               "Fallen Factory": 4,
#               "Eldritch Outlook": 2,
#               "Corrupted Galleon's Graveyard": 4
#             }
#           },
#           "raids": {
#             "total": 144,
#             "list": {
#               "The Canyon Colossus": 36,
#               "Orphion's Nexus of Light": 38,
#               "The Nameless Anomaly": 40,
#               "Nest of the Grootslangs": 30
#             }
#           },
#           "worldEvents": 58,
#           "lootruns": 5,
#           "caves": 239,
#           "completedQuests": 137,
#           "raidStats": {
#             "damageTaken": 13067457,
#             "damageDealt": 1148811747,
#             "healthHealed": 6871210,
#             "deaths": 106,
#             "buffsTaken": 399,
#             "gambitsUsed": 159
#           },
#           "pvp": {
#             "kills": 0,
#             "deaths": 0
#           },
#           "guildRaids": {
#             "total": 78,
#             "list": {
#               "The Canyon Colossus": 20,
#               "Orphion's Nexus of Light": 25,
#               "Nest of the Grootslangs": 14,
#               "The Nameless Anomaly": 19,
#               "The Wartorn Palace": 0
#             }
#           },
#           "playtime": 327.92
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       },
#       "FlamePootis": {
#         "uuid": "8c0c0855-a6e0-49aa-9b4d-ceb0e040d9cb",
#         "legacyName": "FlamePootis",
#         "online": false,
#         "lastJoin": "2026-05-23T03:37:56.094000Z",
#         "server": null,
#         "contributed": 103620309,
#         "contributionRank": 24,
#         "joined": "2026-03-02T01:43:36.600000Z",
#         "weekly": {
#           "completed": true,
#           "streak": 11
#         },
#         "globalData": {
#           "contentCompletion": 934,
#           "wars": 1,
#           "totalLevel": 288,
#           "mobsKilled": 78792,
#           "chestsFound": 1018,
#           "dungeons": {
#             "total": 75,
#             "list": {
#               "Infested Pit": 4,
#               "Timelost Sanctum": 2,
#               "Underworld Crypt": 11,
#               "Sand-Swept Tomb": 4,
#               "Ice Barrows": 8,
#               "Undergrowth Ruins": 16,
#               "Galleon's Graveyard": 5,
#               "Corrupted Decrepit Sewers": 8,
#               "Corrupted Infested Pit": 2,
#               "Corrupted Lost Sanctuary": 1,
#               "Corrupted Underworld Crypt": 1,
#               "Corrupted Sand-Swept Tomb": 1,
#               "Corrupted Ice Barrows": 1,
#               "Corrupted Undergrowth Ruins": 1,
#               "Fallen Factory": 1,
#               "Eldritch Outlook": 1,
#               "Decrepit Sewers": 8
#             }
#           },
#           "raids": {
#             "total": 151,
#             "list": {
#               "The Canyon Colossus": 18,
#               "Orphion's Nexus of Light": 34,
#               "The Nameless Anomaly": 35,
#               "Nest of the Grootslangs": 60,
#               "The Wartorn Palace": 4
#             }
#           },
#           "worldEvents": 17,
#           "lootruns": 6,
#           "caves": 147,
#           "completedQuests": 85,
#           "raidStats": {
#             "damageTaken": 11722300,
#             "damageDealt": 1693752368,
#             "healthHealed": 9985132,
#             "deaths": 28,
#             "buffsTaken": 413,
#             "gambitsUsed": 248
#           },
#           "pvp": {
#             "kills": 0,
#             "deaths": 0
#           },
#           "guildRaids": {
#             "total": 78,
#             "list": {
#               "The Canyon Colossus": 14,
#               "Orphion's Nexus of Light": 15,
#               "Nest of the Grootslangs": 23,
#               "The Nameless Anomaly": 23,
#               "The Wartorn Palace": 3
#             }
#           },
#           "playtime": 221.42
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       },
#       "ddxWeCraft": {
#         "uuid": "d680883b-e7b2-4bfc-bad7-79372d97c60d",
#         "legacyName": "ddxWeCraft",
#         "online": false,
#         "lastJoin": "2026-05-22T04:21:19.915000Z",
#         "server": null,
#         "contributed": 63722174,
#         "contributionRank": 31,
#         "joined": "2026-05-09T01:27:30.350000Z",
#         "weekly": {
#           "completed": false,
#           "streak": 1
#         },
#         "globalData": {
#           "contentCompletion": 1985,
#           "wars": 43,
#           "totalLevel": 1244,
#           "mobsKilled": 270398,
#           "chestsFound": 7535,
#           "dungeons": {
#             "total": 171,
#             "list": {
#               "Decrepit Sewers": 17,
#               "Infested Pit": 6,
#               "Underworld Crypt": 8,
#               "Timelost Sanctum": 1,
#               "Sand-Swept Tomb": 6,
#               "Ice Barrows": 7,
#               "Undergrowth Ruins": 12,
#               "Galleon's Graveyard": 12,
#               "Corrupted Decrepit Sewers": 18,
#               "Corrupted Infested Pit": 21,
#               "Corrupted Galleon's Graveyard": 13,
#               "Corrupted Undergrowth Ruins": 6,
#               "Corrupted Ice Barrows": 8,
#               "Corrupted Sand-Swept Tomb": 8,
#               "Corrupted Underworld Crypt": 12,
#               "Corrupted Lost Sanctuary": 15,
#               "Eldritch Outlook": 1
#             }
#           },
#           "raids": {
#             "total": 668,
#             "list": {
#               "The Canyon Colossus": 125,
#               "Orphion's Nexus of Light": 91,
#               "The Nameless Anomaly": 204,
#               "Nest of the Grootslangs": 160,
#               "The Wartorn Palace": 88
#             }
#           },
#           "worldEvents": 25,
#           "lootruns": 7,
#           "caves": 231,
#           "completedQuests": 140,
#           "raidStats": {
#             "damageTaken": 84199487,
#             "damageDealt": 4607821318,
#             "healthHealed": 295974959,
#             "deaths": 166,
#             "buffsTaken": 1723,
#             "gambitsUsed": 1630
#           },
#           "pvp": {
#             "kills": 0,
#             "deaths": 0
#           },
#           "guildRaids": {
#             "total": 224,
#             "list": {
#               "The Canyon Colossus": 37,
#               "Orphion's Nexus of Light": 40,
#               "Nest of the Grootslangs": 70,
#               "The Nameless Anomaly": 75,
#               "The Wartorn Palace": 2
#             }
#           },
#           "playtime": 907.67
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       },
#       "JP_GOD_Divzer": {
#         "uuid": "9731aa53-56d8-43e2-99d1-86e5e2efd7de",
#         "legacyName": "JP_GOD_Divzer",
#         "online": false,
#         "lastJoin": "2026-05-22T06:08:15.263000Z",
#         "server": null,
#         "contributed": 48949924,
#         "contributionRank": 35,
#         "joined": "2026-02-03T13:25:48.520000Z",
#         "weekly": {
#           "completed": false,
#           "streak": 0
#         },
#         "globalData": {
#           "contentCompletion": 903,
#           "wars": 0,
#           "totalLevel": 476,
#           "mobsKilled": 142065,
#           "chestsFound": 2229,
#           "dungeons": {
#             "total": 67,
#             "list": {
#               "Decrepit Sewers": 4,
#               "Infested Pit": 4,
#               "Underworld Crypt": 7,
#               "Timelost Sanctum": 6,
#               "Sand-Swept Tomb": 8,
#               "Ice Barrows": 11,
#               "Undergrowth Ruins": 4,
#               "Corrupted Decrepit Sewers": 5,
#               "Corrupted Infested Pit": 3,
#               "Corrupted Lost Sanctuary": 3,
#               "Corrupted Ice Barrows": 4,
#               "Eldritch Outlook": 1,
#               "Corrupted Underworld Crypt": 2,
#               "Corrupted Sand-Swept Tomb": 1,
#               "Corrupted Undergrowth Ruins": 1,
#               "Fallen Factory": 3
#             }
#           },
#           "raids": {
#             "total": 232,
#             "list": {
#               "The Canyon Colossus": 61,
#               "Orphion's Nexus of Light": 31,
#               "The Nameless Anomaly": 67,
#               "Nest of the Grootslangs": 70,
#               "The Wartorn Palace": 3
#             }
#           },
#           "worldEvents": 12,
#           "lootruns": 3,
#           "caves": 61,
#           "completedQuests": 53,
#           "raidStats": {
#             "damageTaken": 14667532,
#             "damageDealt": 2510110472,
#             "healthHealed": 9164690,
#             "deaths": 250,
#             "buffsTaken": 574,
#             "gambitsUsed": 463
#           },
#           "pvp": {
#             "kills": 0,
#             "deaths": 0
#           },
#           "guildRaids": {
#             "total": 11,
#             "list": {
#               "The Canyon Colossus": 4,
#               "Orphion's Nexus of Light": 0,
#               "Nest of the Grootslangs": 1,
#               "The Nameless Anomaly": 6,
#               "The Wartorn Palace": 0
#             }
#           },
#           "playtime": 412.83
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       },
#       "LaserX": {
#         "uuid": "a8ff0b79-9511-47b7-8705-b657eba980aa",
#         "legacyName": "LaserX",
#         "online": false,
#         "lastJoin": "2026-05-02T17:15:58.193000Z",
#         "server": null,
#         "contributed": 32317907,
#         "contributionRank": 39,
#         "joined": "2026-01-17T16:58:35.099000Z",
#         "weekly": {
#           "completed": false,
#           "streak": 2
#         },
#         "globalData": {
#           "contentCompletion": 2284,
#           "wars": 73,
#           "totalLevel": 958,
#           "mobsKilled": 477222,
#           "chestsFound": 11855,
#           "dungeons": {
#             "total": 135,
#             "list": {
#               "Decrepit Sewers": 28,
#               "Infested Pit": 6,
#               "Underworld Crypt": 13,
#               "Lost Sanctuary": 3,
#               "Sand-Swept Tomb": 12,
#               "Ice Barrows": 14,
#               "Undergrowth Ruins": 8,
#               "Galleon's Graveyard": 3,
#               "Corrupted Decrepit Sewers": 6,
#               "Corrupted Infested Pit": 3,
#               "Corrupted Undergrowth Ruins": 6,
#               "Corrupted Underworld Crypt": 5,
#               "Eldritch Outlook": 2,
#               "Corrupted Sand-Swept Tomb": 10,
#               "Corrupted Lost Sanctuary": 5,
#               "Corrupted Ice Barrows": 2,
#               "Corrupted Galleon's Graveyard": 4,
#               "Fallen Factory": 4,
#               "Timelost Sanctum": 1
#             }
#           },
#           "raids": {
#             "total": 297,
#             "list": {
#               "Nest of the Grootslangs": 238,
#               "The Canyon Colossus": 14,
#               "Orphion's Nexus of Light": 12,
#               "The Nameless Anomaly": 17,
#               "The Wartorn Palace": 16
#             }
#           },
#           "worldEvents": 36,
#           "lootruns": 6,
#           "caves": 251,
#           "completedQuests": 246,
#           "raidStats": {
#             "damageTaken": 26646354,
#             "damageDealt": 2650656112,
#             "healthHealed": 1451728946,
#             "deaths": 71,
#             "buffsTaken": 826,
#             "gambitsUsed": 703
#           },
#           "pvp": {
#             "kills": 0,
#             "deaths": 0
#           },
#           "guildRaids": {
#             "total": 47,
#             "list": {
#               "The Canyon Colossus": 2,
#               "Orphion's Nexus of Light": 11,
#               "Nest of the Grootslangs": 31,
#               "The Nameless Anomaly": 3,
#               "The Wartorn Palace": 0
#             }
#           },
#           "playtime": 821.5
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       },
#       "WhiteNoise0113": {
#         "uuid": "f46a3aa1-ed18-48f4-bcf9-594e0ff19842",
#         "legacyName": "WhiteNoise0113",
#         "online": false,
#         "lastJoin": "2026-05-10T03:26:11.116000Z",
#         "server": null,
#         "contributed": 20412697,
#         "contributionRank": 47,
#         "joined": "2026-02-10T14:20:22.052000Z",
#         "weekly": {
#           "completed": false,
#           "streak": 0
#         },
#         "globalData": {
#           "contentCompletion": 3977,
#           "wars": 4040,
#           "totalLevel": 2779,
#           "mobsKilled": 970758,
#           "chestsFound": 34578,
#           "dungeons": {
#             "total": 541,
#             "list": {
#               "Decrepit Sewers": 72,
#               "Infested Pit": 28,
#               "Underworld Crypt": 35,
#               "Sand-Swept Tomb": 33,
#               "Corrupted Decrepit Sewers": 52,
#               "Corrupted Infested Pit": 46,
#               "Corrupted Lost Sanctuary": 46,
#               "Corrupted Underworld Crypt": 33,
#               "Corrupted Sand-Swept Tomb": 25,
#               "Corrupted Undergrowth Ruins": 38,
#               "Corrupted Ice Barrows": 21,
#               "Eldritch Outlook": 16,
#               "Ice Barrows": 18,
#               "Corrupted Galleon's Graveyard": 9,
#               "Undergrowth Ruins": 30,
#               "Fallen Factory": 10,
#               "Galleon's Graveyard": 23,
#               "Skeleton": 4,
#               "Spider": 1,
#               "Timelost Sanctum": 1
#             }
#           },
#           "raids": {
#             "total": 261,
#             "list": {
#               "The Canyon Colossus": 64,
#               "The Nameless Anomaly": 40,
#               "Nest of the Grootslangs": 147,
#               "Orphion's Nexus of Light": 10
#             }
#           },
#           "worldEvents": 50,
#           "lootruns": 5,
#           "caves": 446,
#           "completedQuests": 448,
#           "raidStats": {
#             "damageTaken": 38858541,
#             "damageDealt": 1340518114,
#             "healthHealed": 514520132,
#             "deaths": 86,
#             "buffsTaken": 563,
#             "gambitsUsed": 456
#           },
#           "pvp": {
#             "kills": 0,
#             "deaths": 0
#           },
#           "guildRaids": {
#             "total": 1,
#             "list": {
#               "The Canyon Colossus": 0,
#               "Orphion's Nexus of Light": 0,
#               "Nest of the Grootslangs": 0,
#               "The Nameless Anomaly": 1,
#               "The Wartorn Palace": 0
#             }
#           },
#           "playtime": 2801.17
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       },
#       "StyNath": {
#         "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3",
#         "legacyName": "StyNath",
#         "online": false,
#         "lastJoin": "2026-04-23T20:09:18.938000Z",
#         "server": null,
#         "contributed": 17828015,
#         "contributionRank": 50,
#         "joined": "2026-01-17T22:49:33.209000Z",
#         "weekly": {
#           "completed": false,
#           "streak": 0
#         },
#         "globalData": {
#           "contentCompletion": 822,
#           "wars": 11,
#           "totalLevel": 386,
#           "mobsKilled": 61846,
#           "chestsFound": 1738,
#           "dungeons": {
#             "total": 18,
#             "list": {
#               "Underworld Crypt": 4,
#               "Timelost Sanctum": 1,
#               "Infested Pit": 1,
#               "Sand-Swept Tomb": 1,
#               "Undergrowth Ruins": 1,
#               "Ice Barrows": 1,
#               "Eldritch Outlook": 1,
#               "Corrupted Decrepit Sewers": 2,
#               "Corrupted Infested Pit": 1,
#               "Corrupted Lost Sanctuary": 1,
#               "Corrupted Sand-Swept Tomb": 1,
#               "Corrupted Ice Barrows": 1,
#               "Corrupted Undergrowth Ruins": 1,
#               "Corrupted Galleon's Graveyard": 1
#             }
#           },
#           "raids": {
#             "total": 83,
#             "list": {
#               "Orphion's Nexus of Light": 33,
# ...
#               "Timelost Sanctum": 1,
#               "Sand-Swept Tomb": 5,
#               "Ice Barrows": 7,
#               "Undergrowth Ruins": 3
#             }
#           },
#           "raids": {
#             "total": 3,
#             "list": {
#               "Nest of the Grootslangs": 3
#             }
#           },
#           "worldEvents": 5,
#           "lootruns": 0,
#           "caves": 52,
#           "completedQuests": 38,
#           "raidStats": {
#             "damageTaken": 45613,
#             "damageDealt": 4522470,
#             "healthHealed": 39558,
#             "deaths": 0,
#             "buffsTaken": 9,
#             "gambitsUsed": 0
#           },
#           "pvp": {
#             "kills": 0,
#             "deaths": 0
#           },
#           "guildRaids": {
#             "total": 3,
#             "list": {
#               "The Canyon Colossus": 0,
#               "Orphion's Nexus of Light": 0,
#               "Nest of the Grootslangs": 3,
#               "The Nameless Anomaly": 0,
#               "The Wartorn Palace": 0
#             }
#           },
#           "playtime": 53.5
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       },
#       "_Saddest": {
#         "uuid": "3f0f27aa-67bb-475d-b6a8-c7dc5ed3395f",
#         "legacyName": "_Saddest",
#         "online": false,
#         "lastJoin": "2026-05-19T02:25:00.725000Z",
#         "server": null,
#         "contributed": 3151028,
#         "contributionRank": 68,
#         "joined": "2026-05-04T22:00:34.772000Z",
#         "weekly": {
#           "completed": true,
#           "streak": 2
#         },
#         "globalData": {
#           "contentCompletion": 1179,
#           "wars": 9,
#           "totalLevel": 739,
#           "mobsKilled": 81414,
#           "chestsFound": 1134,
#           "dungeons": {
#             "total": 81,
#             "list": {
#               "Decrepit Sewers": 21,
#               "Infested Pit": 23,
#               "Timelost Sanctum": 4,
#               "Sand-Swept Tomb": 5,
#               "Ice Barrows": 8,
#               "Undergrowth Ruins": 14,
#               "Underworld Crypt": 5,
#               "Galleon's Graveyard": 1
#             }
#           },
#           "raids": {
#             "total": 10,
#             "list": {
#               "Nest of the Grootslangs": 10
#             }
#           },
#           "worldEvents": 22,
#           "lootruns": 0,
#           "caves": 173,
#           "completedQuests": 173,
#           "raidStats": {
#             "damageTaken": 320646,
#             "damageDealt": 18214816,
#             "healthHealed": 2573412,
#             "deaths": 2,
#             "buffsTaken": 30,
#             "gambitsUsed": 0
#           },
#           "pvp": {
#             "kills": 0,
#             "deaths": 0
#           },
#           "guildRaids": {
#             "total": 2,
#             "list": {
#               "The Canyon Colossus": 0,
#               "Orphion's Nexus of Light": 0,
#               "Nest of the Grootslangs": 2,
#               "The Nameless Anomaly": 0,
#               "The Wartorn Palace": 0
#             }
#           },
#           "playtime": 443.92
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       },
#       "Mystic757": {
#         "uuid": "e295d517-ab78-43af-9e87-1b38581bcbb9",
#         "legacyName": "Mystic757",
#         "online": false,
#         "lastJoin": "2026-05-13T10:21:57.199000Z",
#         "server": null,
#         "contributed": 1091996,
#         "contributionRank": 70,
#         "joined": "2026-05-01T21:06:20.598000Z",
#         "weekly": {
#           "completed": false,
#           "streak": 0
#         },
#         "globalData": {
#           "contentCompletion": 459,
#           "wars": 0,
#           "totalLevel": 225,
#           "mobsKilled": 14117,
#           "chestsFound": 248,
#           "dungeons": {
#             "total": 24,
#             "list": {
#               "Decrepit Sewers": 5,
#               "Underworld Crypt": 3,
#               "Sand-Swept Tomb": 4,
#               "Ice Barrows": 1,
#               "Infested Pit": 7,
#               "Timelost Sanctum": 2,
#               "Undergrowth Ruins": 1,
#               "Corrupted Decrepit Sewers": 1
#             }
#           },
#           "raids": {
#             "total": 7,
#             "list": {
#               "Nest of the Grootslangs": 7
#             }
#           },
#           "worldEvents": 9,
#           "lootruns": 0,
#           "caves": 42,
#           "completedQuests": 66,
#           "raidStats": {
#             "damageTaken": 257057,
#             "damageDealt": 5704556,
#             "healthHealed": 135427,
#             "deaths": 4,
#             "buffsTaken": 20,
#             "gambitsUsed": 2
#           },
#           "pvp": {
#             "kills": 0,
#             "deaths": 0
#           },
#           "guildRaids": {
#             "total": 0,
#             "list": {
#               "The Canyon Colossus": 0,
#               "Orphion's Nexus of Light": 0,
#               "Nest of the Grootslangs": 0,
#               "The Nameless Anomaly": 0,
#               "The Wartorn Palace": 0
#             }
#           },
#           "playtime": 80.0
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       },
#       "TinyTurtle32011": {
#         "uuid": "51df6ec9-cc55-4728-864a-868f14c452a8",
#         "legacyName": "TinyTurtle32011",
#         "online": false,
#         "lastJoin": "2026-05-05T00:01:51.992000Z",
#         "server": null,
#         "contributed": 105083,
#         "contributionRank": 75,
#         "joined": "2026-04-29T07:04:57.616000Z",
#         "weekly": {
#           "completed": false,
#           "streak": 0
#         },
#         "globalData": {
#           "contentCompletion": 166,
#           "wars": 0,
#           "totalLevel": 78,
#           "mobsKilled": 4856,
#           "chestsFound": 104,
#           "dungeons": {
#             "total": 40,
#             "list": {
#               "Infested Pit": 4,
#               "Underworld Crypt": 8,
#               "Timelost Sanctum": 2,
#               "Sand-Swept Tomb": 11,
#               "Decrepit Sewers": 1,
#               "Ice Barrows": 5,
#               "Undergrowth Ruins": 7,
#               "Galleon's Graveyard": 2
#             }
#           },
#           "raids": {
#             "total": 9,
#             "list": {
#               "Nest of the Grootslangs": 9
#             }
#           },
#           "worldEvents": 7,
#           "lootruns": 0,
#           "caves": 4,
#           "completedQuests": 2,
#           "raidStats": {
#             "damageTaken": 181619,
#             "damageDealt": 10476944,
#             "healthHealed": 147638,
#             "deaths": 5,
#             "buffsTaken": 27,
#             "gambitsUsed": 0
#           },
#           "pvp": {
#             "kills": 0,
#             "deaths": 0
#           },
#           "guildRaids": {
#             "total": 0,
#             "list": {
#               "The Canyon Colossus": 0,
#               "Orphion's Nexus of Light": 0,
#               "Nest of the Grootslangs": 0,
#               "The Nameless Anomaly": 0,
#               "The Wartorn Palace": 0
#             }
#           },
#           "playtime": 33.83
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       },
#       "Szkraft220": {
#         "uuid": "a8fed6f5-e05e-407d-be10-9f742c3853e5",
#         "legacyName": "Szkraft220",
#         "online": false,
#         "lastJoin": "2026-05-16T16:46:26.854000Z",
#         "server": null,
#         "contributed": 38165,
#         "contributionRank": 76,
#         "joined": "2026-05-08T19:58:19.117000Z",
#         "weekly": {
#           "completed": false,
#           "streak": 1
#         },
#         "globalData": {
#           "contentCompletion": 668,
#           "wars": 0,
#           "totalLevel": 728,
#           "mobsKilled": 62247,
#           "chestsFound": 2286,
#           "dungeons": {
#             "total": 66,
#             "list": {
#               "Decrepit Sewers": 19,
#               "Infested Pit": 9,
#               "Underworld Crypt": 4,
#               "Timelost Sanctum": 5,
#               "Sand-Swept Tomb": 6,
#               "Ice Barrows": 9,
#               "Undergrowth Ruins": 9,
#               "Galleon's Graveyard": 4,
#               "Corrupted Decrepit Sewers": 1
#             }
#           },
#           "raids": {
#             "total": 10,
#             "list": {
#               "Nest of the Grootslangs": 10
#             }
#           },
#           "worldEvents": 21,
#           "lootruns": 0,
#           "caves": 84,
#           "completedQuests": 116,
#           "raidStats": {
#             "damageTaken": 436603,
#             "damageDealt": 9205571,
#             "healthHealed": 11237411,
#             "deaths": 5,
#             "buffsTaken": 30,
#             "gambitsUsed": 0
#           },
#           "pvp": {
#             "kills": 0,
#             "deaths": 0
#           },
#           "guildRaids": {
#             "total": 0,
#             "list": {
#               "The Canyon Colossus": 0,
#               "Orphion's Nexus of Light": 0,
#               "Nest of the Grootslangs": 0,
#               "The Nameless Anomaly": 0,
#               "The Wartorn Palace": 0
#             }
#           },
#           "playtime": 371.67
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       },
#       "ellio_f": {
#         "uuid": "16e852c9-0ec0-4de7-8615-fbf4d9f9698b",
#         "legacyName": "ellio_f",
#         "online": false,
#         "lastJoin": "2026-05-23T08:57:15.051000Z",
#         "server": null,
#         "contributed": 1860,
#         "contributionRank": 78,
#         "joined": "2026-05-22T06:58:50.614000Z",
#         "weekly": {
#           "completed": false,
#           "streak": 0
#         },
#         "globalData": {
#           "contentCompletion": 40,
#           "wars": 0,
#           "totalLevel": 29,
#           "mobsKilled": 1136,
#           "chestsFound": 39,
#           "dungeons": {
#             "total": 3,
#             "list": {
#               "Decrepit Sewers": 1,
#               "Infested Pit": 2
#             }
#           },
#           "raids": {
#             "total": 0,
#             "list": {}
#           },
#           "worldEvents": 1,
#           "lootruns": 0,
#           "caves": 3,
#           "completedQuests": 1,
#           "raidStats": null,
#           "pvp": {
#             "kills": 0,
#             "deaths": 0
#           },
#           "guildRaids": {
#             "total": 0,
#             "list": {
#               "The Canyon Colossus": 0,
#               "Orphion's Nexus of Light": 0,
#               "Nest of the Grootslangs": 0,
#               "The Nameless Anomaly": 0,
#               "The Wartorn Palace": 0
#             }
#           },
#           "playtime": 5.17
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       },
#       "bludiamond5": {
#         "uuid": "3e3d018b-142d-499d-847b-dcf6f2be7951",
#         "legacyName": "bludiamond5",
#         "online": false,
#         "lastJoin": "2026-05-23T03:58:40.326000Z",
#         "server": null,
#         "contributed": 0,
#         "contributionRank": 83,
#         "joined": "2026-05-07T23:29:19.640000Z",
#         "weekly": {
#           "completed": false,
#           "streak": 1
#         },
#         "globalData": {
#           "contentCompletion": 1491,
#           "wars": 0,
#           "totalLevel": 859,
#           "mobsKilled": 226496,
#           "chestsFound": 3056,
#           "dungeons": {
#             "total": 83,
#             "list": {
#               "Animal": 6,
#               "Skeleton": 12,
#               "Spider": 9,
#               "Zombie": 6,
#               "Silverfish": 8,
#               "Jungle": 2,
#               "Decrepit Sewers": 12,
#               "Infested Pit": 7,
#               "Underworld Crypt": 8,
#               "Sand-Swept Tomb": 4,
#               "Undergrowth Ruins": 1,
#               "Corrupted Infested Pit": 2,
#               "Corrupted Sand-Swept Tomb": 2,
#               "Timelost Sanctum": 2,
#               "Ice Barrows": 2
#             }
#           },
#           "raids": {
#             "total": 82,
#             "list": {
#               "The Canyon Colossus": 34,
#               "Nest of the Grootslangs": 48
#             }
#           },
#           "worldEvents": 11,
#           "lootruns": 3,
#           "caves": 119,
#           "completedQuests": 216,
#           "raidStats": {
#             "damageTaken": 7248231,
#             "damageDealt": 540762374,
#             "healthHealed": 133380323,
#             "deaths": 20,
#             "buffsTaken": 215,
#             "gambitsUsed": 185
#           },
#           "pvp": {
#             "kills": 41,
#             "deaths": 45
#           },
#           "guildRaids": {
#             "total": 0,
#             "list": {
#               "The Canyon Colossus": 0,
#               "Orphion's Nexus of Light": 0,
#               "Nest of the Grootslangs": 0,
#               "The Nameless Anomaly": 0,
#               "The Wartorn Palace": 0
#             }
#           },
#           "playtime": 543.0
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       },
#       "gekkiedemafste2": {
#         "uuid": "b547f21e-6699-478a-b704-3b0094b1d396",
#         "legacyName": "gekkiedemafste2",
#         "online": false,
#         "lastJoin": "2026-05-21T20:28:09.085000Z",
#         "server": null,
#         "contributed": 0,
#         "contributionRank": 84,
#         "joined": "2026-05-21T20:07:04.258000Z",
#         "weekly": {
#           "completed": false,
#           "streak": 0
#         },
#         "globalData": {
#           "contentCompletion": 601,
#           "wars": 0,
#           "totalLevel": 488,
#           "mobsKilled": 24540,
#           "chestsFound": 398,
#           "dungeons": {
#             "total": 56,
#             "list": {
#               "Decrepit Sewers": 9,
#               "Infested Pit": 15,
#               "Underworld Crypt": 9,
#               "Timelost Sanctum": 6,
#               "Sand-Swept Tomb": 5,
#               "Ice Barrows": 5,
#               "Undergrowth Ruins": 7
#             }
#           },
#           "raids": {
#             "total": 10,
#             "list": {
#               "Nest of the Grootslangs": 10
#             }
#           },
#           "worldEvents": 8,
#           "lootruns": 0,
#           "caves": 39,
#           "completedQuests": 63,
#           "raidStats": {
#             "damageTaken": 407905,
#             "damageDealt": 11230969,
#             "healthHealed": 1965127,
#             "deaths": 8,
#             "buffsTaken": 32,
#             "gambitsUsed": 0
#           },
#           "pvp": {
#             "kills": 0,
#             "deaths": 0
#           },
#           "guildRaids": {
#             "total": 0,
#             "list": {
#               "The Canyon Colossus": 0,
#               "Orphion's Nexus of Light": 0,
#               "Nest of the Grootslangs": 0,
#               "The Nameless Anomaly": 0,
#               "The Wartorn Palace": 0
#             }
#           },
#           "playtime": 76.83
#         },
#         "restrictions": {
#           "online_status": false,
#           "main_access": false,
#           "weekly_access": false
#         }
#       }
#     }
#   },
#   "online": 4,
#   "banner": {
#     "base": "BLACK",
#     "tier": 5,
#     "structure": "tier5",
#     "layers": [
#       {
#         "colour": "SILVER",
#         "pattern": "FLOWER"
#       },
#       {
#         "colour": "BLACK",
#         "pattern": "SKULL"
#       },
#       {
#         "colour": "GRAY",
#         "pattern": "RHOMBUS_MIDDLE"
#       },
#       {
#         "colour": "BLACK",
#         "pattern": "CIRCLE_MIDDLE"
#       },
#       {
#         "colour": "BLACK",
#         "pattern": "TRIANGLE_TOP"
#       }
#     ]
#   },
#   "seasonRanks": {
#     "29": {
#       "rating": 583666,
#       "finalTerritories": 2
#     },
#     "30": {
#       "rating": 252250,
#       "finalTerritories": 0
#     }
#   },
#   "ranking": {
#     "frumaSrGuilds": 40,
#     "orphionSrGuilds": 42,
#     "namelessSrGuilds": 46,
#     "grootslangSrGuilds": 65,
#     "guildTotalRaids": 68,
#     "colossusSrGuilds": 75
#   }
# }

# %%
guild_data = guild_req.json()
# print(guild_data["members"])
all_members = []
guild_break_username = {}
guild_break_down = {}
for key in guild_data['members'].keys():
    if key =="total":
        continue
    guild_break_down[key] = []
    guild_break_username[key] = []
    for member in guild_data['members'][key]:
        guild_break_username[key].append(member)
        guild_break_down[key].append(guild_data['members'][key][member]['uuid'])
        all_members.append(guild_data['members'][key][member]['uuid'])

# %%
print(json.dumps(guild_data['members'], indent=2))
# Out:
# {
#   "total": 79,
#   "owner": {
#     "Nqn": {
#       "uuid": "a8e5c7c3-444f-4436-b69f-a8db58cdf40d",
#       "online": true,
#       "server": "NA30",
#       "contributed": 4293174513,
#       "contributionRank": 2,
#       "joined": "2025-08-20T06:59:13.342000Z",
#       "guildRaids": {
#         "total": 67,
#         "list": {
#           "The Canyon Colossus": 8,
#           "Orphion's Nexus of Light": 6,
#           "Nest of the Grootslangs": 9,
#           "The Nameless Anomaly": 44
#         }
#       }
#     }
#   },
#   "chief": {
#     "Tisumi": {
#       "uuid": "91be9a75-7398-47e0-8c4d-f79df2fc035f",
#       "online": false,
#       "server": null,
#       "contributed": 11268140438,
#       "contributionRank": 1,
#       "joined": "2025-09-27T06:58:29.986000Z",
#       "guildRaids": {
#         "total": 173,
#         "list": {
#           "The Canyon Colossus": 45,
#           "Orphion's Nexus of Light": 6,
#           "Nest of the Grootslangs": 23,
#           "The Nameless Anomaly": 99
#         }
#       }
#     },
#     "_N8": {
#       "uuid": "5652732f-e36b-4ca4-87ca-59f9c6dc3ba1",
#       "online": false,
#       "server": null,
#       "contributed": 2062281051,
#       "contributionRank": 3,
#       "joined": "2025-08-20T06:59:30.170000Z",
#       "guildRaids": {
#         "total": 8,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 1,
#           "Nest of the Grootslangs": 5,
#           "The Nameless Anomaly": 2
#         }
#       }
#     },
#     "GigaFanDeJul": {
#       "uuid": "0a19dd60-254e-4c48-9d76-1b57a2f12c7f",
#       "online": true,
#       "server": "EU34",
#       "contributed": 1088150560,
#       "contributionRank": 4,
#       "joined": "2026-01-17T14:55:37.482000Z",
#       "guildRaids": {
#         "total": 107,
#         "list": {
#           "The Canyon Colossus": 4,
#           "Orphion's Nexus of Light": 14,
#           "Nest of the Grootslangs": 41,
#           "The Nameless Anomaly": 48
#         }
#       }
#     },
#     "clohi": {
#       "uuid": "1b6568dd-4e58-442f-918f-90926f58de0c",
#       "online": true,
#       "server": "NA2",
#       "contributed": 755043873,
#       "contributionRank": 5,
#       "joined": "2026-02-07T19:57:11.309000Z",
#       "guildRaids": {
#         "total": 37,
#         "list": {
#           "The Canyon Colossus": 28,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 9
#         }
#       }
#     },
#     "Krijer1": {
#       "uuid": "4a82c3ac-be5d-4115-a822-f2a9c7bdb096",
#       "online": true,
#       "server": "NA30",
#       "contributed": 209909291,
#       "contributionRank": 6,
#       "joined": "2026-01-16T18:40:55.478000Z",
#       "guildRaids": {
#         "total": 34,
#         "list": {
#           "The Canyon Colossus": 10,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 10,
#           "The Nameless Anomaly": 14
#         }
#       }
#     },
#     "Shivnitzl19": {
#       "uuid": "bd5c1697-4d42-41dd-a4f2-2c8a3a669104",
#       "online": false,
#       "server": null,
#       "contributed": 87695894,
#       "contributionRank": 9,
#       "joined": "2025-08-20T11:17:53.604000Z",
#       "guildRaids": {
#         "total": 19,
#         "list": {
#           "The Canyon Colossus": 1,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 10,
#           "The Nameless Anomaly": 8
#         }
#       }
#     },
#     "Xentell": {
#       "uuid": "1a3f6b2a-993b-49ed-8542-7584081864b6",
#       "online": false,
#       "server": null,
#       "contributed": 30281450,
#       "contributionRank": 17,
#       "joined": "2025-11-12T15:27:54.940000Z",
#       "guildRaids": {
#         "total": 9,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 1,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 8
#         }
#       }
#     },
#     "ewenfi": {
#       "uuid": "89cdeb83-0958-4563-a606-0a460e13abfa",
#       "online": false,
#       "server": null,
#       "contributed": 27088434,
#       "contributionRank": 22,
#       "joined": "2026-01-17T14:57:25.432000Z",
#       "guildRaids": {
#         "total": 93,
#         "list": {
#           "The Canyon Colossus": 2,
#           "Orphion's Nexus of Light": 12,
#           "Nest of the Grootslangs": 35,
#           "The Nameless Anomaly": 44
#         }
#       }
#     },
#     "H1V": {
#       "uuid": "845eed02-175a-44b4-87a2-0228b1fbc3ee",
#       "online": false,
#       "server": null,
#       "contributed": 26185368,
#       "contributionRank": 24,
#       "joined": "2026-01-19T01:16:08.956000Z",
#       "guildRaids": {
#         "total": 159,
#         "list": {
#           "The Canyon Colossus": 11,
#           "Orphion's Nexus of Light": 39,
#           "Nest of the Grootslangs": 47,
#           "The Nameless Anomaly": 62
#         }
#       }
#     },
#     "KirouXD": {
#       "uuid": "4470c807-1394-4930-937d-1680d508d22d",
#       "online": false,
#       "server": null,
#       "contributed": 18336069,
#       "contributionRank": 31,
#       "joined": "2026-01-17T14:36:32.901000Z",
#       "guildRaids": {
#         "total": 61,
#         "list": {
#           "The Canyon Colossus": 2,
#           "Orphion's Nexus of Light": 17,
#           "Nest of the Grootslangs": 25,
#           "The Nameless Anomaly": 17
#         }
#       }
#     },
#     "Chevacchi": {
#       "uuid": "eb33d516-a34b-4050-bd2c-69a24bf0bd75",
#       "online": false,
#       "server": null,
#       "contributed": 7633378,
#       "contributionRank": 43,
#       "joined": "2026-02-16T00:35:06.942000Z",
#       "guildRaids": {
#         "total": 14,
#         "list": {
#           "The Canyon Colossus": 7,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 7
#         }
#       }
#     }
#   },
#   "strategist": {
#     "_Snoopers_": {
#       "uuid": "130612b6-1d46-49c7-b06e-3200959254c7",
#       "online": false,
#       "server": null,
#       "contributed": 105235318,
#       "contributionRank": 8,
#       "joined": "2026-01-16T19:11:52.855000Z",
#       "guildRaids": {
#         "total": 33,
#         "list": {
#           "The Canyon Colossus": 14,
#           "Orphion's Nexus of Light": 1,
#           "Nest of the Grootslangs": 12,
#           "The Nameless Anomaly": 6
#         }
#       }
#     },
#     "LaserX": {
#       "uuid": "a8ff0b79-9511-47b7-8705-b657eba980aa",
#       "online": false,
#       "server": null,
#       "contributed": 24076709,
#       "contributionRank": 26,
#       "joined": "2026-01-17T16:58:35.099000Z",
#       "guildRaids": {
#         "total": 41,
#         "list": {
#           "The Canyon Colossus": 2,
#           "Orphion's Nexus of Light": 11,
#           "Nest of the Grootslangs": 25,
#           "The Nameless Anomaly": 3
#         }
#       }
#     },
#     "WhiteNoise0113": {
#       "uuid": "f46a3aa1-ed18-48f4-bcf9-594e0ff19842",
#       "online": true,
#       "server": "NA2",
#       "contributed": 20412697,
#       "contributionRank": 30,
#       "joined": "2026-02-10T14:20:22.052000Z",
#       "guildRaids": {
#         "total": 97,
#         "list": {
#           "The Canyon Colossus": 33,
#           "Orphion's Nexus of Light": 8,
#           "Nest of the Grootslangs": 35,
#           "The Nameless Anomaly": 21
#         }
#       }
#     },
#     "StyNath": {
#       "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3",
#       "online": false,
#       "server": null,
#       "contributed": 3559271,
#       "contributionRank": 49,
#       "joined": "2026-01-17T22:49:33.209000Z",
#       "guildRaids": {
#         "total": 24,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 2,
#           "Nest of the Grootslangs": 19,
#           "The Nameless Anomaly": 3
#         }
#       }
#     },
#     "kcsato": {
#       "uuid": "ce2fc852-9b0e-41d2-a323-603be70f5b69",
#       "online": false,
#       "server": null,
#       "contributed": 1507251,
#       "contributionRank": 55,
#       "joined": "2026-01-17T14:36:37.544000Z",
#       "guildRaids": {
#         "total": 10,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 3,
#           "Nest of the Grootslangs": 4,
#           "The Nameless Anomaly": 3
#         }
#       }
#     },
#     "imNaphy": {
#       "uuid": "9604c081-52b1-4224-8107-b00885644c84",
#       "online": false,
#       "server": null,
#       "contributed": 509741,
#       "contributionRank": 63,
#       "joined": "2025-08-20T12:35:13.228000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "FireGamingDK": {
#       "uuid": "96512a2a-4200-463e-8974-27a4c81947cd",
#       "online": false,
#       "server": null,
#       "contributed": 221976,
#       "contributionRank": 67,
#       "joined": "2026-01-16T18:41:23.015000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "Lliseron": {
#       "uuid": "fdaac6c6-88b2-437a-b923-44d14d0841f6",
#       "online": false,
#       "server": null,
#       "contributed": 0,
#       "contributionRank": 79,
#       "joined": "2026-02-28T19:04:03.857000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     }
#   },
#   "captain": {
#     "xEagless": {
#       "uuid": "a27ae078-8209-4c2e-85ea-57de6168cc9b",
#       "online": false,
#       "server": null,
#       "contributed": 129392767,
#       "contributionRank": 7,
#       "joined": "2026-01-17T18:00:19.960000Z",
#       "guildRaids": {
#         "total": 24,
#         "list": {
#           "The Canyon Colossus": 7,
#           "Orphion's Nexus of Light": 1,
#           "Nest of the Grootslangs": 6,
#           "The Nameless Anomaly": 10
#         }
#       }
#     },
#     "WynnDestroyer": {
#       "uuid": "81c0cf7a-43f9-4aaf-8783-4953970e394d",
#       "online": false,
#       "server": null,
#       "contributed": 78064043,
#       "contributionRank": 10,
#       "joined": "2026-01-03T10:54:17.217000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "cresseliah": {
#       "uuid": "b7d4a9f2-73ba-47b6-bc7c-d8db98ad6a2e",
#       "online": false,
#       "server": null,
#       "contributed": 77877190,
#       "contributionRank": 11,
#       "joined": "2026-02-20T06:58:27.525000Z",
#       "guildRaids": {
#         "total": 3,
#         "list": {
#           "The Canyon Colossus": 2,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 1
#         }
#       }
#     },
#     "MoondustPeachy": {
#       "uuid": "06793d89-e8ea-4ec2-aa55-4c5f03b93026",
#       "online": false,
#       "server": null,
#       "contributed": 59689710,
#       "contributionRank": 12,
#       "joined": "2026-02-13T22:21:27.329000Z",
#       "guildRaids": {
#         "total": 24,
#         "list": {
#           "The Canyon Colossus": 10,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 4,
#           "The Nameless Anomaly": 10
#         }
#       }
#     },
#     "ddxWeCraft": {
#       "uuid": "d680883b-e7b2-4bfc-bad7-79372d97c60d",
#       "online": false,
#       "server": null,
#       "contributed": 39697659,
#       "contributionRank": 14,
#       "joined": "2026-02-18T21:33:06.478000Z",
#       "guildRaids": {
#         "total": 17,
#         "list": {
#           "The Canyon Colossus": 10,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 1,
#           "The Nameless Anomaly": 6
#         }
#       }
#     },
#     "Riku_56rr": {
#       "uuid": "9731aa53-56d8-43e2-99d1-86e5e2efd7de",
#       "online": true,
#       "server": "NA30",
#       "contributed": 39233706,
#       "contributionRank": 15,
#       "joined": "2026-02-03T13:25:48.520000Z",
#       "guildRaids": {
#         "total": 3,
#         "list": {
#           "The Canyon Colossus": 3,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "BlueSkyMoose": {
#       "uuid": "b3be31d6-e441-4299-a342-685898f35f30",
#       "online": false,
#       "server": null,
#       "contributed": 34700583,
#       "contributionRank": 16,
#       "joined": "2026-02-13T03:36:59.937000Z",
#       "guildRaids": {
#         "total": 64,
#         "list": {
#           "The Canyon Colossus": 17,
#           "Orphion's Nexus of Light": 4,
#           "Nest of the Grootslangs": 1,
#           "The Nameless Anomaly": 42
#         }
#       }
#     },
#     "jeff1234567842": {
#       "uuid": "c77bcc5e-ad22-478d-a70e-fa3a255f2f86",
#       "online": true,
#       "server": "NA30",
#       "contributed": 26653593,
#       "contributionRank": 23,
#       "joined": "2026-02-01T03:33:39.394000Z",
#       "guildRaids": {
#         "total": 23,
#         "list": {
#           "The Canyon Colossus": 1,
#           "Orphion's Nexus of Light": 1,
#           "Nest of the Grootslangs": 2,
#           "The Nameless Anomaly": 19
#         }
#       }
#     },
#     "kanyo0904": {
#       "uuid": "ae32ae54-c15c-4c6d-ab46-3bdcec6e2e7f",
#       "online": false,
#       "server": null,
#       "contributed": 21727159,
#       "contributionRank": 28,
#       "joined": "2026-01-28T08:18:54.212000Z",
#       "guildRaids": {
#         "total": 1,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 1
#         }
#       }
#     },
#     "YBN": {
#       "uuid": "3ed556ef-70ef-4d27-8bae-c2cff73f9b20",
#       "online": false,
#       "server": null,
#       "contributed": 21033900,
#       "contributionRank": 29,
#       "joined": "2026-02-11T07:18:34.778000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "Gurlic": {
#       "uuid": "bf6fd3d8-f0b2-4831-9dc2-77db02b015d7",
#       "online": false,
#       "server": null,
#       "contributed": 17752217,
#       "contributionRank": 32,
#       "joined": "2026-01-30T10:39:02.737000Z",
#       "guildRaids": {
#         "total": 4,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 2,
#           "The Nameless Anomaly": 2
#         }
#       }
#     },
#     "wrggg": {
#       "uuid": "2ad7fd38-792d-4862-ba2a-b7e1c1723b18",
#       "online": false,
#       "server": null,
#       "contributed": 13273891,
#       "contributionRank": 37,
#       "joined": "2026-02-10T12:55:21.967000Z",
#       "guildRaids": {
#         "total": 192,
#         "list": {
#           "The Canyon Colossus": 7,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 100,
#           "The Nameless Anomaly": 85
#         }
#       }
#     },
#     "parrandeno": {
#       "uuid": "065f7a4a-e15a-4bbf-ab2f-b55051e0b6de",
#       "online": false,
#       "server": null,
#       "contributed": 12939677,
#       "contributionRank": 38,
#       "joined": "2026-01-31T01:31:02.265000Z",
#       "guildRaids": {
#         "total": 4,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 4
#         }
#       }
#     },
#     "EdouardpheoIII": {
#       "uuid": "b0135e82-95b5-432b-a008-d7a8d6829e07",
#       "online": false,
#       "server": null,
#       "contributed": 5220747,
#       "contributionRank": 48,
#       "joined": "2026-01-17T15:33:41.365000Z",
#       "guildRaids": {
#         "total": 15,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 15,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "Ecmz": {
#       "uuid": "cff26bb4-bad0-4de2-8559-19d23e2d9d41",
#       "online": false,
#       "server": null,
#       "contributed": 2636625,
#       "contributionRank": 51,
#       "joined": "2026-02-13T07:46:17.033000Z",
#       "guildRaids": {
#         "total": 1,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 1
#         }
#       }
#     },
#     "Liciela": {
#       "uuid": "823ee888-e114-4ca9-9781-7086b5430a54",
#       "online": false,
#       "server": null,
#       "contributed": 1620644,
#       "contributionRank": 54,
#       "joined": "2026-02-03T15:51:05.744000Z",
#       "guildRaids": {
#         "total": 7,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 3,
#           "The Nameless Anomaly": 4
#         }
#       }
#     },
#     "Megawati": {
#       "uuid": "9ce7b212-c818-41cf-bd2a-9a2ad4f0e5df",
#       "online": false,
#       "server": null,
#       "contributed": 1329288,
#       "contributionRank": 56,
#       "joined": "2026-01-18T10:28:12.188000Z",
#       "guildRaids": {
#         "total": 3,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 1,
#           "The Nameless Anomaly": 2
#         }
#       }
#     },
#     "gauvinsteven": {
#       "uuid": "d0344f4e-a5fb-48ee-9359-1c82fb2320aa",
#       "online": true,
#       "server": "EU14",
#       "contributed": 1187010,
#       "contributionRank": 57,
#       "joined": "2026-01-18T15:22:11.811000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "MelinoeNemesis": {
#       "uuid": "9c413f4a-9e5f-46e9-8b89-abdd46f3f74b",
#       "online": false,
#       "server": null,
#       "contributed": 653536,
#       "contributionRank": 61,
#       "joined": "2026-01-17T11:13:30.901000Z",
#       "guildRaids": {
#         "total": 13,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 13,
#           "The Nameless Anomaly": 0
#         }
#       }
#     }
#   },
#   "recruiter": {
#     "jayandjef": {
#       "uuid": "c837e8b4-4e0a-41c4-b397-7b02f8f35f2a",
#       "online": false,
#       "server": null,
#       "contributed": 30196248,
#       "contributionRank": 18,
#       "joined": "2026-01-24T21:07:00.006000Z",
#       "guildRaids": {
#         "total": 35,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 3,
#           "Nest of the Grootslangs": 26,
#           "The Nameless Anomaly": 6
#         }
#       }
#     },
#     "roll_54": {
#       "uuid": "04be2792-d567-4c0a-aa1d-67242dbcf0a8",
#       "online": false,
#       "server": null,
#       "contributed": 28857367,
#       "contributionRank": 20,
#       "joined": "2026-01-13T12:46:46.051000Z",
#       "guildRaids": {
#         "total": 2,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 2
#         }
#       }
#     },
#     "AmasoXd": {
#       "uuid": "423997a0-9626-479c-97e5-d3517b93083c",
#       "online": false,
#       "server": null,
#       "contributed": 17547352,
#       "contributionRank": 33,
#       "joined": "2026-02-01T06:53:43.371000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "Aqimcrafty": {
#       "uuid": "3823b995-b8fa-49f5-8c68-6d1a66bdf215",
#       "online": false,
#       "server": null,
#       "contributed": 17489352,
#       "contributionRank": 34,
#       "joined": "2026-02-03T15:54:49.846000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "evbubba": {
#       "uuid": "1af5a66a-9337-4e66-a69b-35d825f4a62b",
#       "online": false,
#       "server": null,
#       "contributed": 13772282,
#       "contributionRank": 36,
#       "joined": "2026-01-17T22:47:38.178000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "squirley": {
#       "uuid": "b9112e4d-7141-4922-9fca-47430268445e",
#       "online": false,
#       "server": null,
#       "contributed": 11288654,
#       "contributionRank": 39,
#       "joined": "2026-01-29T07:00:26.907000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "Thund3rMC": {
#       "uuid": "0254668f-5453-408d-aa18-d44d8619c215",
#       "online": false,
#       "server": null,
#       "contributed": 7270574,
#       "contributionRank": 44,
#       "joined": "2026-01-29T18:40:14.004000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "JJCourts": {
#       "uuid": "0cea76a6-b7a3-4537-8b64-f98ab836a1e2",
#       "online": false,
#       "server": null,
#       "contributed": 2987518,
#       "contributionRank": 50,
#       "joined": "2026-01-08T18:39:54.463000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "AlleNupY": {
#       "uuid": "ec784aab-d88e-40df-a5ab-c6a26fc9c671",
#       "online": false,
#       "server": null,
#       "contributed": 1126098,
#       "contributionRank": 58,
#       "joined": "2026-02-03T13:49:15.749000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "Zytiv": {
#       "uuid": "5e3c6983-b267-49be-b6f8-7eedb09fddb4",
#       "online": false,
#       "server": null,
#       "contributed": 787108,
#       "contributionRank": 60,
#       "joined": "2026-01-23T02:13:31.299000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "Firetornado2312": {
#       "uuid": "4c0e0ac7-49e1-4590-b4d6-8fe2f1ca1e26",
#       "online": false,
#       "server": null,
#       "contributed": 625522,
#       "contributionRank": 62,
#       "joined": "2026-01-25T00:45:32.978000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "White_plague": {
#       "uuid": "6f327520-de36-4695-b8f1-f67558d0d4fc",
#       "online": false,
#       "server": null,
#       "contributed": 265636,
#       "contributionRank": 65,
#       "joined": "2026-02-13T09:52:38.716000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "vamqir": {
#       "uuid": "85017f3e-4643-454b-a315-f158dd3971dd",
#       "online": false,
#       "server": null,
#       "contributed": 255846,
#       "contributionRank": 66,
#       "joined": "2026-02-04T06:26:27.618000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "VenonatGX": {
#       "uuid": "9867e87a-e526-4da0-8945-e91f339409cc",
#       "online": false,
#       "server": null,
#       "contributed": 159340,
#       "contributionRank": 69,
#       "joined": "2026-01-26T08:59:32.851000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "djderpcat": {
#       "uuid": "eb1d2b6f-cd58-4cc8-b389-05bbfa831a3e",
#       "online": false,
#       "server": null,
#       "contributed": 23307,
#       "contributionRank": 70,
#       "joined": "2026-01-31T07:22:05.532000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "S6kuna": {
#       "uuid": "d3abfd17-2a07-45b1-a5b0-9b76800b53f4",
#       "online": false,
#       "server": null,
#       "contributed": 6976,
#       "contributionRank": 71,
#       "joined": "2026-02-03T15:57:33.408000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "SoupSkids": {
#       "uuid": "4ee827d7-5300-4f49-a5ba-3945e454460a",
#       "online": false,
#       "server": null,
#       "contributed": 0,
#       "contributionRank": 74,
#       "joined": "2025-10-28T15:42:04.073000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     }
#   },
#   "recruit": {
#     "ZicZac": {
#       "uuid": "fff311d0-b571-4b80-baa2-43adfe981448",
#       "online": false,
#       "server": null,
#       "contributed": 47193601,
#       "contributionRank": 13,
#       "joined": "2026-02-19T19:53:08.815000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "notBirdblade": {
#       "uuid": "283536d3-5e6f-4c8d-a23b-9fa8a8b50f18",
#       "online": true,
#       "server": "NA2",
#       "contributed": 30108135,
#       "contributionRank": 19,
#       "joined": "2026-02-21T23:55:37.648000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "Feather_Storm": {
#       "uuid": "6582d74d-9b97-435e-9781-66cf2aedb17a",
#       "online": false,
#       "server": null,
#       "contributed": 28145462,
#       "contributionRank": 21,
#       "joined": "2026-02-21T00:07:34.033000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "SewageFarts": {
#       "uuid": "b22cfe82-4f5d-4b43-b63f-8e33bf3d7835",
#       "online": false,
#       "server": null,
#       "contributed": 24285829,
#       "contributionRank": 25,
#       "joined": "2026-02-14T00:43:18.689000Z",
#       "guildRaids": {
#         "total": 1,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 1
#         }
#       }
#     },
#     "iParadox1122": {
#       "uuid": "bd589667-31d5-4f6c-95b8-04ddad4b241f",
#       "online": false,
#       "server": null,
#       "contributed": 22608037,
#       "contributionRank": 27,
#       "joined": "2026-02-11T14:51:47.432000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "Bluvey": {
#       "uuid": "e781dac3-37b9-48e8-b588-dc8b5a1e0200",
#       "online": true,
#       "server": "NA2",
#       "contributed": 14005385,
#       "contributionRank": 35,
#       "joined": "2026-02-22T03:04:42.171000Z",
#       "guildRaids": {
#         "total": 10,
#         "list": {
#           "The Canyon Colossus": 10,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "CodeCrevette": {
#       "uuid": "c1d04519-cf18-4a40-9061-a0d72ec3fda2",
#       "online": false,
#       "server": null,
#       "contributed": 10163608,
#       "contributionRank": 40,
#       "joined": "2026-02-26T07:00:38.718000Z",
#       "guildRaids": {
#         "total": 14,
#         "list": {
#           "The Canyon Colossus": 6,
#           "Orphion's Nexus of Light": 2,
#           "Nest of the Grootslangs": 1,
#           "The Nameless Anomaly": 5
#         }
#       }
#     },
#     "_Hammie_": {
#       "uuid": "2adb411c-37e2-491c-8afd-9a38fc4fdf06",
#       "online": false,
#       "server": null,
#       "contributed": 8974930,
#       "contributionRank": 41,
#       "joined": "2026-02-06T21:37:14.461000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "Ryuuchen": {
#       "uuid": "4bfb9baf-7347-43c8-9c4d-5c55b27c780e",
#       "online": false,
#       "server": null,
#       "contributed": 8652184,
#       "contributionRank": 42,
#       "joined": "2026-01-31T01:12:04.876000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "Pogo_Duck": {
#       "uuid": "f2fb427f-1ccc-495f-90f1-d40ad5de42f9",
#       "online": false,
#       "server": null,
#       "contributed": 7244970,
#       "contributionRank": 45,
#       "joined": "2026-02-24T23:40:27.364000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "Kanaefx": {
#       "uuid": "1b6b5470-e8d6-48c8-a553-5bb52395a662",
#       "online": false,
#       "server": null,
#       "contributed": 6705817,
#       "contributionRank": 46,
#       "joined": "2026-02-03T05:50:22.212000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "SolaR8735": {
#       "uuid": "4fb7c4a3-a84e-431c-9d93-649f6391f7eb",
#       "online": true,
#       "server": "NA15",
#       "contributed": 6255815,
#       "contributionRank": 47,
#       "joined": "2026-02-26T06:41:54.658000Z",
#       "guildRaids": {
#         "total": 9,
#         "list": {
#           "The Canyon Colossus": 3,
#           "Orphion's Nexus of Light": 1,
#           "Nest of the Grootslangs": 1,
#           "The Nameless Anomaly": 4
#         }
#       }
#     },
#     "Arctifire": {
#       "uuid": "4f7fad4a-c959-468f-8708-dd68f28e945b",
#       "online": false,
#       "server": null,
#       "contributed": 2382452,
#       "contributionRank": 52,
#       "joined": "2026-02-27T19:10:31.309000Z",
#       "guildRaids": {
#         "total": 4,
#         "list": {
#           "The Canyon Colossus": 2,
#           "Orphion's Nexus of Light": 1,
#           "Nest of the Grootslangs": 1,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "Endyre": {
#       "uuid": "502073b4-06bc-4f30-8a4f-115e6c9e35af",
#       "online": false,
#       "server": null,
#       "contributed": 1844442,
#       "contributionRank": 53,
#       "joined": "2026-02-20T03:17:25.645000Z",
#       "guildRaids": {
#         "total": 14,
#         "list": {
#           "The Canyon Colossus": 1,
#           "Orphion's Nexus of Light": 1,
#           "Nest of the Grootslangs": 12,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "nawe69": {
#       "uuid": "3ee651c0-59d3-452d-a98d-214d717bef83",
#       "online": false,
#       "server": null,
#       "contributed": 855964,
#       "contributionRank": 59,
#       "joined": "2026-02-11T11:52:18.106000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "aIfaa": {
#       "uuid": "511c4018-f6ca-4ccb-a698-9b64b07c6ad3",
#       "online": false,
#       "server": null,
#       "contributed": 409244,
#       "contributionRank": 64,
#       "joined": "2026-02-22T21:11:42.877000Z",
#       "guildRaids": {
#         "total": 1,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 1,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "erik_9453": {
#       "uuid": "1ebcb3ff-2695-4a54-b482-a22081cb024a",
#       "online": false,
#       "server": null,
#       "contributed": 221688,
#       "contributionRank": 68,
#       "joined": "2026-02-04T06:29:18.410000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "TheKzR": {
#       "uuid": "31cc44b4-4c2d-4d88-8e41-f4a4b0337346",
#       "online": false,
#       "server": null,
#       "contributed": 491,
#       "contributionRank": 72,
#       "joined": "2026-02-22T22:39:44.498000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "GrayR0ot": {
#       "uuid": "a4fa7dd2-7cd7-4626-b9f6-3284fc16557a",
#       "online": false,
#       "server": null,
#       "contributed": 365,
#       "contributionRank": 73,
#       "joined": "2026-02-14T11:49:09.064000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "Budiono": {
#       "uuid": "02115748-53c2-4a43-afd7-5412d8e01f8a",
#       "online": false,
#       "server": null,
#       "contributed": 0,
#       "contributionRank": 75,
#       "joined": "2026-02-03T13:37:48.695000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "cheeseball01": {
#       "uuid": "94591244-b96c-4675-99fc-b4e9abfac6de",
#       "online": false,
#       "server": null,
#       "contributed": 0,
#       "contributionRank": 76,
#       "joined": "2026-02-15T20:30:48.258000Z",
#       "guildRaids": {
#         "total": 71,
#         "list": {
#           "The Canyon Colossus": 7,
#           "Orphion's Nexus of Light": 15,
#           "Nest of the Grootslangs": 35,
#           "The Nameless Anomaly": 14
#         }
#       }
#     },
#     "skrybs": {
#       "uuid": "1285f316-0b50-4d36-ae61-a02ed620c8ff",
#       "online": false,
#       "server": null,
#       "contributed": 0,
#       "contributionRank": 77,
#       "joined": "2026-02-21T21:33:09.719000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     },
#     "Laborious": {
#       "uuid": "4489c7f5-9d5a-4b32-b0a3-e2dd9ae619ab",
#       "online": false,
#       "server": null,
#       "contributed": 0,
#       "contributionRank": 78,
#       "joined": "2026-02-22T05:07:24.051000Z",
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0
#         }
#       }
#     }
#   }
# }

# %%
# print(json.dumps(guild_data['members'], indent=2))
now_utc = datetime.now(timezone.utc)
formatted = now_utc.strftime(time_format)
for rank in guild_data['members']:
    if rank != "total":
        for player in guild_data['members'][rank]:
            if rank == "recruit" and subtract_date_string(guild_data['members'][rank][player]['joined'], formatted) > 7: #not in ['recruit', "recruiter", "owner", 'captain', 'total']:
                # print(rank)
                print(f"{rank}: {player}: Join Date {guild_data['members'][rank][player]['joined']} : Contribution Rank {guild_data['members'][rank][player]['contributionRank']}")
# Out:
# recruit: Couteau: Join Date 2026-03-16T19:58:09.067000Z : Contribution Rank 12
# recruit: Feather_Storm: Join Date 2026-02-21T00:07:34.033000Z : Contribution Rank 23
# recruit: Ryuuchen: Join Date 2026-01-31T01:12:04.876000Z : Contribution Rank 48
# recruit: Slickx_: Join Date 2026-04-12T10:09:32.886000Z : Contribution Rank 50
# recruit: skrybs: Join Date 2026-02-21T21:33:09.719000Z : Contribution Rank 51
# recruit: RealArmis: Join Date 2026-03-19T07:11:49.534000Z : Contribution Rank 53
# recruit: reparody: Join Date 2026-03-23T00:02:39.387000Z : Contribution Rank 55
# recruit: Gunther_v: Join Date 2026-03-24T05:47:23.935000Z : Contribution Rank 61
# recruit: MaanBoys: Join Date 2026-04-07T22:57:08.867000Z : Contribution Rank 62
# recruit: TheKzR: Join Date 2026-02-22T22:39:44.498000Z : Contribution Rank 68
# recruit: Ahmedboss891: Join Date 2026-04-09T01:35:12.917000Z : Contribution Rank 72
# recruit: Laborious: Join Date 2026-02-22T05:07:24.051000Z : Contribution Rank 74
# recruit: 8uc: Join Date 2026-03-22T05:05:38.850000Z : Contribution Rank 75
# recruit: vSlqm: Join Date 2026-03-30T23:40:30.029000Z : Contribution Rank 76
# recruit: IcyIce7: Join Date 2026-04-07T22:10:15.487000Z : Contribution Rank 83

# %%
# print(json.dumps(guild_break_username, indent=2))
for key in guild_break_down.keys():
    print(f"There are {len(guild_break_down[key])} {key}'s")
# print(f"And {len(all_members)} total members")
# print(guild_break_down)
# Out:
# There are 1 owner's
# There are 11 chief's
# There are 8 strategist's
# There are 19 captain's
# There are 17 recruiter's
# There are 23 recruit's

# %%
print(json.dumps(guild_break_down, indent=2))
# Out:
# {
#   "owner": [
#     "a8e5c7c3-444f-4436-b69f-a8db58cdf40d"
#   ],
#   "chief": [
#     "91be9a75-7398-47e0-8c4d-f79df2fc035f",
#     "5652732f-e36b-4ca4-87ca-59f9c6dc3ba1",
#     "0a19dd60-254e-4c48-9d76-1b57a2f12c7f",
#     "4a82c3ac-be5d-4115-a822-f2a9c7bdb096",
#     "bd5c1697-4d42-41dd-a4f2-2c8a3a669104",
#     "1a3f6b2a-993b-49ed-8542-7584081864b6",
#     "845eed02-175a-44b4-87a2-0228b1fbc3ee",
#     "89cdeb83-0958-4563-a606-0a460e13abfa",
#     "4470c807-1394-4930-937d-1680d508d22d",
#     "eb33d516-a34b-4050-bd2c-69a24bf0bd75"
#   ],
#   "strategist": [
#     "1b6568dd-4e58-442f-918f-90926f58de0c",
#     "130612b6-1d46-49c7-b06e-3200959254c7",
#     "a8ff0b79-9511-47b7-8705-b657eba980aa",
#     "f46a3aa1-ed18-48f4-bcf9-594e0ff19842",
#     "c32bfbf5-9665-4ad1-837e-92fa882288a3",
#     "ce2fc852-9b0e-41d2-a323-603be70f5b69",
#     "9604c081-52b1-4224-8107-b00885644c84",
#     "96512a2a-4200-463e-8974-27a4c81947cd"
#   ],
#   "captain": [
#     "a27ae078-8209-4c2e-85ea-57de6168cc9b",
#     "81c0cf7a-43f9-4aaf-8783-4953970e394d",
#     "b3be31d6-e441-4299-a342-685898f35f30",
#     "06793d89-e8ea-4ec2-aa55-4c5f03b93026",
#     "ae32ae54-c15c-4c6d-ab46-3bdcec6e2e7f",
#     "3ed556ef-70ef-4d27-8bae-c2cff73f9b20",
#     "bf6fd3d8-f0b2-4831-9dc2-77db02b015d7",
#     "d680883b-e7b2-4bfc-bad7-79372d97c60d",
#     "2ad7fd38-792d-4862-ba2a-b7e1c1723b18",
#     "065f7a4a-e15a-4bbf-ab2f-b55051e0b6de",
#     "cff26bb4-bad0-4de2-8559-19d23e2d9d41",
#     "823ee888-e114-4ca9-9781-7086b5430a54",
#     "9ce7b212-c818-41cf-bd2a-9a2ad4f0e5df",
#     "b7d4a9f2-73ba-47b6-bc7c-d8db98ad6a2e",
#     "d0344f4e-a5fb-48ee-9359-1c82fb2320aa",
#     "9c413f4a-9e5f-46e9-8b89-abdd46f3f74b",
#     "b0135e82-95b5-432b-a008-d7a8d6829e07"
#   ],
#   "recruiter": [
#     "9731aa53-56d8-43e2-99d1-86e5e2efd7de",
#     "c837e8b4-4e0a-41c4-b397-7b02f8f35f2a",
#     "04be2792-d567-4c0a-aa1d-67242dbcf0a8",
#     "c77bcc5e-ad22-478d-a70e-fa3a255f2f86",
#     "423997a0-9626-479c-97e5-d3517b93083c",
#     "3823b995-b8fa-49f5-8c68-6d1a66bdf215",
#     "1af5a66a-9337-4e66-a69b-35d825f4a62b",
#     "b9112e4d-7141-4922-9fca-47430268445e",
#     "0254668f-5453-408d-aa18-d44d8619c215",
#     "0cea76a6-b7a3-4537-8b64-f98ab836a1e2",
#     "ec784aab-d88e-40df-a5ab-c6a26fc9c671",
#     "5e3c6983-b267-49be-b6f8-7eedb09fddb4",
#     "4c0e0ac7-49e1-4590-b4d6-8fe2f1ca1e26",
#     "aed8039a-4d4e-40e9-ab22-d1ec544ba155",
#     "467ed4aa-50fe-45b3-8705-b65d2a713a8c",
#     "6f327520-de36-4695-b8f1-f67558d0d4fc",
#     "85017f3e-4643-454b-a315-f158dd3971dd",
#     "d99b449a-7b7b-4561-a646-459bf8ab0825",
#     "cfc0ef1a-1951-4343-9adb-7ceb949b06c0",
#     "9867e87a-e526-4da0-8945-e91f339409cc",
#     "eb1d2b6f-cd58-4cc8-b389-05bbfa831a3e",
#     "d3abfd17-2a07-45b1-a5b0-9b76800b53f4",
#     "4ee827d7-5300-4f49-a5ba-3945e454460a"
#   ],
#   "recruit": [
#     "6582d74d-9b97-435e-9781-66cf2aedb17a",
#     "283536d3-5e6f-4c8d-a23b-9fa8a8b50f18",
#     "b22cfe82-4f5d-4b43-b63f-8e33bf3d7835",
#     "fff311d0-b571-4b80-baa2-43adfe981448",
#     "bd589667-31d5-4f6c-95b8-04ddad4b241f",
#     "4bfb9baf-7347-43c8-9c4d-5c55b27c780e",
#     "1b6b5470-e8d6-48c8-a553-5bb52395a662",
#     "2adb411c-37e2-491c-8afd-9a38fc4fdf06",
#     "502073b4-06bc-4f30-8a4f-115e6c9e35af",
#     "3ee651c0-59d3-452d-a98d-214d717bef83",
#     "733e86a2-b926-4257-9658-81a990d2ac0a",
#     "511c4018-f6ca-4ccb-a698-9b64b07c6ad3",
#     "1ebcb3ff-2695-4a54-b482-a22081cb024a",
#     "31cc44b4-4c2d-4d88-8e41-f4a4b0337346",
#     "a4fa7dd2-7cd7-4626-b9f6-3284fc16557a",
#     "02115748-53c2-4a43-afd7-5412d8e01f8a",
#     "94591244-b96c-4675-99fc-b4e9abfac6de",
#     "1285f316-0b50-4d36-ae61-a02ed620c8ff",
#     "e781dac3-37b9-48e8-b588-dc8b5a1e0200",
#     "4489c7f5-9d5a-4b32-b0a3-e2dd9ae619ab",
#     "f2fb427f-1ccc-495f-90f1-d40ad5de42f9"
#   ]
# }

# %%
member_stats = {}
for member in all_members:
    member_data = json.loads(json.dumps(requests.get(player_url + member).json(), default=str))
    
    member_stats[member.lower()] = member_data
    time.sleep(2)
    # print(json.dumps(member_data, indent=2))
    # break

# %%
print(json.dumps(member_stats, indent=2))
# Out:
# {
#   "a8e5c7c3-444f-4436-b69f-a8db58cdf40d": {
#     "username": "Nqn",
#     "online": false,
#     "server": "NA46",
#     "activeCharacter": "429af94a-691d-4f94-b70c-eb944c20b210",
#     "nickname": null,
#     "uuid": "a8e5c7c3-444f-4436-b69f-a8db58cdf40d",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_champion.svg",
#     "legacyRankColour": {
#       "main": "#ffff55",
#       "sub": "#ffaa00"
#     },
#     "shortenedRank": null,
#     "supportRank": "champion",
#     "veteran": null,
#     "lastJoin": "2026-05-03T21:47:01.317000Z",
#     "ranking": {
#       "woodworkingLevel": 512,
#       "weaponsmithingLevel": 549,
#       "frumaSrPlayers": 592,
#       "frumaCompletion": 606,
#       "namelessSrPlayers": 666,
#       "scribingLevel": 703,
#       "tailoringLevel": 762,
#       "armouringLevel": 799,
#       "jewelingLevel": 842,
#       "professionsSoloLevel": 863,
#       "totalSoloLevel": 892,
#       "alchemismLevel": 1015,
#       "cookingLevel": 1023,
#       "combatSoloLevel": 1086,
#       "orphionSrPlayers": 1300,
#       "namelessCompletion": 1478,
#       "orphionCompletion": 1667,
#       "colossusSrPlayers": 2129,
#       "woodcuttingLevel": 2177,
#       "warsCompletion": 2220,
#       "grootslangSrPlayers": 2375,
#       "farmingLevel": 2376,
#       "fishingLevel": 2666,
#       "grootslangCompletion": 2736,
#       "colossusCompletion": 3083,
#       "miningLevel": 3492,
#       "combatGlobalLevel": 6780,
#       "totalGlobalLevel": 8095,
#       "globalPlayerContent": 11219,
#       "professionsGlobalLevel": 11737,
#       "playerContent": 31291
#     },
#     "previousRanking": {},
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "OWNER",
#       "rankStars": "\u2605\u2605\u2605\u2605\u2605"
#     },
#     "guildHistory": [
#       "25a677eb-5511-47aa-9351-ffb2d18a39ca"
#     ],
#     "firstJoin": "2022-10-27T09:09:48.757000Z",
#     "playtime": 1145.83,
#     "globalData": {
#       "contentCompletion": 1870,
#       "wars": 416,
#       "totalLevel": 2199,
#       "mobsKilled": 1433605,
#       "chestsFound": 9277,
#       "dungeons": {
#         "total": 227,
#         "list": {
#           "Decrepit Sewers": 43,
#           "Sand-Swept Tomb": 4,
#           "Ice Barrows": 7,
#           "Eldritch Outlook": 9,
#           "Corrupted Galleon's Graveyard": 23,
#           "Corrupted Decrepit Sewers": 23,
#           "Corrupted Infested Pit": 20,
#           "Corrupted Lost Sanctuary": 18,
#           "Corrupted Underworld Crypt": 19,
#           "Corrupted Sand-Swept Tomb": 23,
#           "Corrupted Ice Barrows": 17,
#           "Corrupted Undergrowth Ruins": 17,
#           "Underworld Crypt": 1,
#           "Infested Pit": 2,
#           "Timelost Sanctum": 1
#         }
#       },
#       "raids": {
#         "total": 921,
#         "list": {
#           "The Canyon Colossus": 177,
#           "Orphion's Nexus of Light": 103,
#           "The Nameless Anomaly": 424,
#           "Nest of the Grootslangs": 178,
#           "The Wartorn Palace": 39
#         }
#       },
#       "worldEvents": 15,
#       "lootruns": 5,
#       "caves": 135,
#       "completedQuests": 120,
#       "raidStats": {
#         "damageTaken": 78166044,
#         "damageDealt": 10713773042,
#         "healthHealed": 123357617,
#         "deaths": 361,
#         "buffsTaken": 2559,
#         "gambitsUsed": 2528
#       },
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 189,
#         "list": {
#           "The Canyon Colossus": 34,
#           "Orphion's Nexus of Light": 18,
#           "Nest of the Grootslangs": 47,
#           "The Nameless Anomaly": 90,
#           "The Wartorn Palace": 0
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2022-10-27T09:09:48.757000Z",
#       "playtime": 1145.83,
#       "globalData.totalLevel": 2199,
#       "globalData.mobsKilled": 1433605,
#       "globalData.completedQuests": 120
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false,
#       "guildHistoryAccess": false
#     }
#   },
#   "5652732f-e36b-4ca4-87ca-59f9c6dc3ba1": {
#     "username": "_N8",
#     "online": false,
#     "server": "NA27",
#     "activeCharacter": "10fc2d31-93c1-4870-b833-711845ad3f13",
#     "nickname": null,
#     "uuid": "5652732f-e36b-4ca4-87ca-59f9c6dc3ba1",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_hero.svg",
#     "legacyRankColour": {
#       "main": "#AA00AA",
#       "sub": "#FF55FF"
#     },
#     "shortenedRank": null,
#     "supportRank": "hero",
#     "veteran": null,
#     "lastJoin": "2026-04-29T07:17:23.380000Z",
#     "ranking": {
#       "warsCompletion": 2379,
#       "combatSoloLevel": 3843,
#       "woodcuttingLevel": 4600,
#       "orphionSrPlayers": 4700,
#       "orphionCompletion": 5065,
#       "fishingLevel": 6357,
#       "combatGlobalLevel": 7176,
#       "miningLevel": 7520,
#       "namelessSrPlayers": 9785,
#       "globalPlayerContent": 11305,
#       "namelessCompletion": 13886,
#       "grootslangCompletion": 17094,
#       "grootslangSrPlayers": 17239,
#       "totalSoloLevel": 20093,
#       "professionsSoloLevel": 23546,
#       "playerContent": 23607,
#       "farmingLevel": 42559,
#       "totalGlobalLevel": 67359,
#       "professionsGlobalLevel": 605438,
#       "alchemismLevel": 2146027,
#       "scribingLevel": 2156128,
#       "tailoringLevel": 2157244,
#       "jewelingLevel": 2158917,
#       "armouringLevel": 2166250,
#       "cookingLevel": 2174669,
#       "weaponsmithingLevel": 2341546,
#       "woodworkingLevel": 2350920
#     },
#     "previousRanking": {},
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "CHIEF",
#       "rankStars": "\u2605\u2605\u2605\u2605"
#     },
#     "guildHistory": [
#       "25a677eb-5511-47aa-9351-ffb2d18a39ca"
#     ],
#     "firstJoin": "2014-09-04T02:43:52.467000Z",
#     "playtime": 762.0,
#     "globalData": {
#       "contentCompletion": 1864,
#       "wars": 369,
#       "totalLevel": 1081,
#       "mobsKilled": 291170,
#       "chestsFound": 4097,
#       "dungeons": {
#         "total": 132,
#         "list": {
#           "Skeleton": 3,
#           "Spider": 1,
#           "Animal": 1,
#           "Decrepit Sewers": 16,
#           "Sand-Swept Tomb": 1,
#           "Ice Barrows": 5,
#           "Underworld Crypt": 1,
#           "Timelost Sanctum": 1,
#           "Corrupted Infested Pit": 13,
#           "Corrupted Sand-Swept Tomb": 16,
#           "Corrupted Decrepit Sewers": 15,
#           "Corrupted Lost Sanctuary": 12,
#           "Corrupted Underworld Crypt": 11,
#           "Corrupted Ice Barrows": 13,
#           "Corrupted Undergrowth Ruins": 12,
#           "Corrupted Galleon's Graveyard": 10,
#           "Eldritch Outlook": 1
#         }
#       },
#       "raids": {
#         "total": 85,
#         "list": {
#           "Orphion's Nexus of Light": 39,
#           "The Nameless Anomaly": 18,
#           "Nest of the Grootslangs": 28
#         }
#       },
#       "worldEvents": 18,
#       "lootruns": 2,
#       "caves": 109,
#       "completedQuests": 79,
#       "raidStats": {
#         "damageTaken": 7267404,
#         "damageDealt": 331191746,
#         "healthHealed": 3344173,
#         "deaths": 66,
#         "buffsTaken": 236,
#         "gambitsUsed": 6
#       },
#       "pvp": {
#         "kills": 127,
#         "deaths": 185
#       },
#       "guildRaids": {
#         "total": 13,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 4,
#           "Nest of the Grootslangs": 6,
#           "The Nameless Anomaly": 3,
#           "The Wartorn Palace": 0
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2014-09-04T02:43:52.467000Z",
#       "playtime": 762.0,
#       "globalData.totalLevel": 1081,
#       "globalData.mobsKilled": 291170,
#       "globalData.completedQuests": 79
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false,
#       "guildHistoryAccess": false
#     }
#   },
#   "4fb7c4a3-a84e-431c-9d93-649f6391f7eb": {
#     "username": "SolaR8735",
#     "online": true,
#     "server": "NA27",
#     "activeCharacter": "edbce027-32a1-42c0-8507-7f4093a3aa58",
#     "nickname": null,
#     "uuid": "4fb7c4a3-a84e-431c-9d93-649f6391f7eb",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_champion.svg",
#     "legacyRankColour": {
#       "main": "#ffff55",
#       "sub": "#ffaa00"
#     },
#     "shortenedRank": null,
#     "supportRank": "champion",
#     "veteran": null,
#     "lastJoin": "2026-05-04T05:24:09.350000Z",
#     "ranking": {
#       "orphionSrPlayers": 1712,
#       "orphionCompletion": 2215,
#       "namelessSrPlayers": 2725,
#       "frumaSrPlayers": 3279,
#       "frumaCompletion": 3372,
#       "colossusSrPlayers": 3511,
#       "grootslangSrPlayers": 4146,
#       "grootslangCompletion": 4601,
#       "combatSoloLevel": 4823,
#       "namelessCompletion": 4974,
#       "colossusCompletion": 5038,
#       "playerContent": 11719,
#       "warsCompletion": 18272,
#       "globalPlayerContent": 43157,
#       "combatGlobalLevel": 59804,
#       "cookingLevel": 91679,
#       "armouringLevel": 145381,
#       "totalSoloLevel": 145682,
#       "farmingLevel": 165909,
#       "miningLevel": 208664,
#       "professionsSoloLevel": 324335,
#       "woodcuttingLevel": 752405,
#       "totalGlobalLevel": 1052889,
#       "alchemismLevel": 2225369,
#       "scribingLevel": 2234674,
#       "tailoringLevel": 2235741,
#       "jewelingLevel": 2237252,
#       "weaponsmithingLevel": 2405878,
#       "woodworkingLevel": 2414647,
#       "fishingLevel": 2543916,
#       "professionsGlobalLevel": 3000000
#     },
#     "previousRanking": {},
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "CHIEF",
#       "rankStars": "\u2605\u2605\u2605\u2605"
#     },
#     "guildHistory": [
#       "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "373c8c68-b5be-4d12-834b-09634483967e"
#     ],
#     "firstJoin": "2026-01-11T23:39:34.639000Z",
#     "playtime": 625.25,
#     "globalData": {
#       "contentCompletion": 844,
#       "wars": 4,
#       "totalLevel": 297,
#       "mobsKilled": 200855,
#       "chestsFound": 5845,
#       "dungeons": {
#         "total": 96,
#         "list": {
#           "Decrepit Sewers": 11,
#           "Infested Pit": 10,
#           "Timelost Sanctum": 7,
#           "Underworld Crypt": 3,
#           "Sand-Swept Tomb": 3,
#           "Ice Barrows": 11,
#           "Undergrowth Ruins": 17,
#           "Galleon's Graveyard": 11,
#           "Corrupted Decrepit Sewers": 10,
#           "Corrupted Infested Pit": 2,
#           "Corrupted Lost Sanctuary": 2,
#           "Corrupted Underworld Crypt": 1,
#           "Corrupted Sand-Swept Tomb": 1,
#           "Corrupted Ice Barrows": 1,
#           "Corrupted Undergrowth Ruins": 1,
#           "Corrupted Galleon's Graveyard": 3,
#           "Eldritch Outlook": 2
#         }
#       },
#       "raids": {
#         "total": 414,
#         "list": {
#           "The Canyon Colossus": 105,
#           "Orphion's Nexus of Light": 85,
#           "The Nameless Anomaly": 102,
#           "Nest of the Grootslangs": 118,
#           "The Wartorn Palace": 4
#         }
#       },
#       "worldEvents": 27,
#       "lootruns": 5,
#       "caves": 121,
#       "completedQuests": 64,
#       "raidStats": {
#         "damageTaken": 68826449,
#         "damageDealt": 5440068176,
#         "healthHealed": 5901636339,
#         "deaths": 57,
#         "buffsTaken": 1165,
#         "gambitsUsed": 1026
#       },
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 166,
#         "list": {
#           "The Canyon Colossus": 36,
#           "Orphion's Nexus of Light": 40,
#           "Nest of the Grootslangs": 29,
#           "The Nameless Anomaly": 59,
#           "The Wartorn Palace": 2
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2026-01-11T23:39:34.639000Z",
#       "playtime": 625.25,
#       "globalData.totalLevel": 297,
#       "globalData.mobsKilled": 200855,
#       "globalData.completedQuests": 64
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false,
#       "guildHistoryAccess": false
#     }
#   },
#   "0a19dd60-254e-4c48-9d76-1b57a2f12c7f": {
#     "username": "GigaFanDeJul",
#     "online": false,
#     "server": "EU53",
#     "activeCharacter": "61fd827d-a222-4c23-bd3d-e53481174b40",
#     "nickname": null,
#     "uuid": "0a19dd60-254e-4c48-9d76-1b57a2f12c7f",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_champion.svg",
#     "legacyRankColour": {
#       "main": "#ffff55",
#       "sub": "#ffaa00"
#     },
#     "shortenedRank": null,
#     "supportRank": "champion",
#     "veteran": false,
#     "lastJoin": "2026-05-02T21:50:39.995000Z",
#     "ranking": {
#       "weaponsmithingLevel": 884,
#       "cookingLevel": 978,
#       "alchemismLevel": 1281,
#       "frumaCompletion": 1295,
#       "frumaSrPlayers": 1311,
#       "scribingLevel": 1341,
#       "combatSoloLevel": 1500,
#       "armouringLevel": 1573,
#       "miningLevel": 1716,
#       "jewelingLevel": 1852,
#       "totalSoloLevel": 2977,
#       "woodcuttingLevel": 2989,
#       "professionsSoloLevel": 3041,
#       "warsCompletion": 3630,
#       "fishingLevel": 3639,
#       "namelessSrPlayers": 4726,
#       "orphionSrPlayers": 4856,
#       "colossusSrPlayers": 5625,
#       "orphionCompletion": 6099,
#       "colossusCompletion": 7587,
#       "namelessCompletion": 7792,
#       "grootslangSrPlayers": 7796,
#       "grootslangCompletion": 9209,
#       "totalGlobalLevel": 16806,
#       "professionsGlobalLevel": 18332,
#       "playerContent": 19210,
#       "globalPlayerContent": 21447,
#       "combatGlobalLevel": 21744,
#       "woodworkingLevel": 33257,
#       "farmingLevel": 42907,
#       "tailoringLevel": 3000000
#     },
#     "previousRanking": {},
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "CHIEF",
#       "rankStars": "\u2605\u2605\u2605\u2605"
#     },
#     "guildHistory": [
#       "25a677eb-5511-47aa-9351-ffb2d18a39ca"
#     ],
#     "firstJoin": "2014-07-20T19:12:41.277000Z",
#     "playtime": 783.08,
#     "globalData": {
#       "contentCompletion": 1319,
#       "wars": 182,
#       "totalLevel": 1754,
#       "mobsKilled": 266284,
#       "chestsFound": 3541,
#       "dungeons": {
#         "total": 114,
#         "list": {
#           "Skeleton": 2,
#           "Spider": 2,
#           "Zombie": 1,
#           "Animal": 5,
#           "Silverfish": 2,
#           "Infested Pit": 7,
#           "Decrepit Sewers": 29,
#           "Lost Sanctuary": 1,
#           "Underworld Crypt": 3,
#           "Sand-Swept Tomb": 8,
#           "Ice Barrows": 9,
#           "Corrupted Decrepit Sewers": 5,
#           "Corrupted Infested Pit": 5,
#           "Eldritch Outlook": 6,
#           "Corrupted Lost Sanctuary": 7,
#           "Corrupted Underworld Crypt": 4,
#           "Corrupted Sand-Swept Tomb": 4,
#           "Corrupted Ice Barrows": 3,
#           "Corrupted Undergrowth Ruins": 3,
#           "Corrupted Galleon's Graveyard": 8
#         }
#       },
#       "raids": {
#         "total": 222,
#         "list": {
#           "The Canyon Colossus": 60,
#           "Orphion's Nexus of Light": 32,
#           "The Nameless Anomaly": 54,
#           "Nest of the Grootslangs": 58,
#           "The Wartorn Palace": 18
#         }
#       },
#       "worldEvents": 32,
#       "lootruns": 1,
#       "caves": 80,
#       "completedQuests": 116,
#       "raidStats": {
#         "damageTaken": 13440441,
#         "damageDealt": 4237404362,
#         "healthHealed": 7620087,
#         "deaths": 96,
#         "buffsTaken": 619,
#         "gambitsUsed": 446
#       },
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 107,
#         "list": {
#           "The Canyon Colossus": 4,
#           "Orphion's Nexus of Light": 14,
#           "Nest of the Grootslangs": 41,
#           "The Nameless Anomaly": 48,
#           "The Wartorn Palace": 0
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2014-07-20T19:12:41.277000Z",
#       "playtime": 783.08,
#       "globalData.totalLevel": 1754,
#       "globalData.mobsKilled": 266284,
#       "globalData.completedQuests": 116
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false,
#       "guildHistoryAccess": false
#     }
#   },
#   "845eed02-175a-44b4-87a2-0228b1fbc3ee": {
#     "username": "H1V",
#     "online": false,
#     "server": "NA15",
#     "activeCharacter": "676765dc-98cb-4a69-9f79-a9aa3d7552ed",
#     "nickname": null,
#     "uuid": "845eed02-175a-44b4-87a2-0228b1fbc3ee",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_hero.svg",
#     "legacyRankColour": {
#       "main": "#AA00AA",
#       "sub": "#FF55FF"
#     },
#     "shortenedRank": null,
#     "supportRank": "hero",
#     "veteran": null,
#     "lastJoin": "2026-05-04T05:19:12.738000Z",
#     "ranking": {
#       "playerContent": 208,
#       "orphionSrPlayers": 1012,
#       "orphionCompletion": 1121,
#       "namelessSrPlayers": 1492,
#       "huntedContent": 1639,
#       "combatSoloLevel": 1798,
#       "globalPlayerContent": 1870,
#       "frumaCompletion": 2005,
#       "woodcuttingLevel": 2184,
#       "frumaSrPlayers": 2197,
#       "farmingLevel": 2371,
#       "fishingLevel": 2621,
#       "namelessCompletion": 2688,
#       "miningLevel": 2846,
#       "grootslangCompletion": 3431,
#       "grootslangSrPlayers": 3480,
#       "colossusSrPlayers": 3774,
#       "colossusCompletion": 4565,
#       "combatGlobalLevel": 6828,
#       "warsCompletion": 8867,
#       "totalSoloLevel": 11337,
#       "professionsSoloLevel": 12406,
#       "totalGlobalLevel": 31775,
#       "jewelingLevel": 36057,
#       "cookingLevel": 54983,
#       "weaponsmithingLevel": 109665,
#       "woodworkingLevel": 129697,
#       "professionsGlobalLevel": 206392,
#       "alchemismLevel": 1591467,
#       "scribingLevel": 1607123,
#       "tailoringLevel": 1608729,
#       "armouringLevel": 1622292
#     },
#     "previousRanking": {},
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "CHIEF",
#       "rankStars": "\u2605\u2605\u2605\u2605"
#     },
#     "guildHistory": [
#       "0dd24dcc-370c-4e27-a1b4-2dfa92e76667",
#       "194cfad7-4cca-4fde-8760-e42760f9c3d9",
#       "22bbeb0e-6043-407f-9385-0203c1e0bfad",
#       "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "f510a7e6-048c-4b19-98db-e16a1c1a60aa"
#     ],
#     "firstJoin": "2017-05-26T22:42:00.776000Z",
#     "playtime": 1342.75,
#     "globalData": {
#       "contentCompletion": 3661,
#       "wars": 29,
#       "totalLevel": 1403,
#       "mobsKilled": 290854,
#       "chestsFound": 6651,
#       "dungeons": {
#         "total": 406,
#         "list": {
#           "Decrepit Sewers": 34,
#           "Infested Pit": 33,
#           "Lost Sanctuary": 14,
#           "Underworld Crypt": 12,
#           "Ice Barrows": 17,
#           "Undergrowth Ruins": 13,
#           "Galleon's Graveyard": 9,
#           "Corrupted Lost Sanctuary": 14,
#           "Fallen Factory": 12,
#           "Corrupted Decrepit Sewers": 15,
#           "Corrupted Infested Pit": 15,
#           "Corrupted Underworld Crypt": 20,
#           "Corrupted Sand-Swept Tomb": 119,
#           "Corrupted Ice Barrows": 12,
#           "Corrupted Undergrowth Ruins": 13,
#           "Corrupted Galleon's Graveyard": 16,
#           "Eldritch Outlook": 20,
#           "Timelost Sanctum": 3,
#           "Sand-Swept Tomb": 15
#         }
#       },
#       "raids": {
#         "total": 639,
#         "list": {
#           "The Canyon Colossus": 116,
#           "Orphion's Nexus of Light": 140,
#           "The Nameless Anomaly": 223,
#           "Nest of the Grootslangs": 150,
#           "The Wartorn Palace": 10
#         }
#       },
#       "worldEvents": 84,
#       "lootruns": 7,
#       "caves": 512,
#       "completedQuests": 524,
#       "raidStats": {
#         "damageTaken": 71975690,
#         "damageDealt": 5202865370,
#         "healthHealed": 1013094526,
#         "deaths": 215,
#         "buffsTaken": 1765,
#         "gambitsUsed": 882
#       },
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 285,
#         "list": {
#           "The Canyon Colossus": 25,
#           "Orphion's Nexus of Light": 80,
#           "Nest of the Grootslangs": 57,
#           "The Nameless Anomaly": 122,
#           "The Wartorn Palace": 1
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2017-05-26T22:42:00.776000Z",
#       "playtime": 1342.75,
#       "globalData.totalLevel": 1403,
#       "globalData.mobsKilled": 290854,
#       "globalData.completedQuests": 524
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false,
#       "guildHistoryAccess": false
#     }
#   },
#   "4a82c3ac-be5d-4115-a822-f2a9c7bdb096": {
#     "username": "Krijer1",
#     "online": false,
#     "server": "EU44",
#     "activeCharacter": "a1945914-e28a-4d75-b5a4-2e1a35d0030f",
#     "nickname": null,
#     "uuid": "4a82c3ac-be5d-4115-a822-f2a9c7bdb096",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_champion.svg",
#     "legacyRankColour": {
#       "main": "#ffff55",
#       "sub": "#ffaa00"
#     },
#     "shortenedRank": null,
#     "supportRank": "champion",
#     "veteran": null,
#     "lastJoin": "2026-05-03T15:54:47.635000Z",
#     "ranking": {
#       "cookingLevel": 303,
#       "scribingLevel": 753,
#       "armouringLevel": 902,
#       "tailoringLevel": 961,
#       "jewelingLevel": 1046,
#       "huntedContent": 1275,
#       "farmingLevel": 1788,
#       "fishingLevel": 1918,
#       "totalSoloLevel": 2486,
#       "professionsSoloLevel": 2501,
#       "miningLevel": 2630,
#       "namelessSrPlayers": 2814,
#       "weaponsmithingLevel": 2946,
#       "warsCompletion": 3588,
#       "namelessCompletion": 4976,
#       "woodcuttingLevel": 5062,
#       "grootslangSrPlayers": 5359,
#       "grootslangCompletion": 5416,
#       "colossusSrPlayers": 5500,
#       "playerContent": 6027,
#       "colossusCompletion": 7487,
#       "combatGlobalLevel": 8146,
#       "globalPlayerContent": 9519,
#       "orphionSrPlayers": 11644,
#       "combatSoloLevel": 12365,
#       "totalGlobalLevel": 12963,
#       "orphionCompletion": 13124,
#       "professionsGlobalLevel": 20923,
#       "alchemismLevel": 28812,
#       "woodworkingLevel": 103657
#     },
#     "previousRanking": {},
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "CHIEF",
#       "rankStars": "\u2605\u2605\u2605\u2605"
#     },
#     "guildHistory": [
#       "25a677eb-5511-47aa-9351-ffb2d18a39ca"
#     ],
#     "firstJoin": "2018-03-07T16:26:49.359000Z",
#     "playtime": 784.33,
#     "globalData": {
#       "contentCompletion": 2024,
#       "wars": 186,
#       "totalLevel": 1908,
#       "mobsKilled": 318258,
#       "chestsFound": 3762,
#       "dungeons": {
#         "total": 174,
#         "list": {
#           "Decrepit Sewers": 45,
#           "Infested Pit": 16,
#           "Underworld Crypt": 10,
#           "Sand-Swept Tomb": 18,
#           "Ice Barrows": 14,
#           "Undergrowth Ruins": 12,
#           "Lost Sanctuary": 2,
#           "Galleon's Graveyard": 5,
#           "Corrupted Decrepit Sewers": 10,
#           "Corrupted Lost Sanctuary": 7,
#           "Corrupted Infested Pit": 7,
#           "Corrupted Underworld Crypt": 6,
#           "Corrupted Sand-Swept Tomb": 6,
#           "Corrupted Ice Barrows": 6,
#           "Corrupted Undergrowth Ruins": 2,
#           "Eldritch Outlook": 2,
#           "Fallen Factory": 3,
#           "Corrupted Galleon's Graveyard": 2,
#           "Timelost Sanctum": 1
#         }
#       },
#       "raids": {
#         "total": 275,
#         "list": {
#           "The Canyon Colossus": 61,
#           "Orphion's Nexus of Light": 12,
#           "The Nameless Anomaly": 102,
#           "Nest of the Grootslangs": 100
#         }
#       },
#       "worldEvents": 37,
#       "lootruns": 6,
#       "caves": 200,
#       "completedQuests": 261,
#       "raidStats": {
#         "damageTaken": 43662324,
#         "damageDealt": 2940966204,
#         "healthHealed": 3425807635,
#         "deaths": 26,
#         "buffsTaken": 701,
#         "gambitsUsed": 529
#       },
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 99,
#         "list": {
#           "The Canyon Colossus": 29,
#           "Orphion's Nexus of Light": 2,
#           "Nest of the Grootslangs": 37,
#           "The Nameless Anomaly": 31,
#           "The Wartorn Palace": 0
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2018-03-07T16:26:49.359000Z",
#       "playtime": 784.33,
#       "globalData.totalLevel": 1908,
#       "globalData.mobsKilled": 318258,
#       "globalData.completedQuests": 261
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false,
#       "guildHistoryAccess": false
#     }
#   },
#   "c1d04519-cf18-4a40-9061-a0d72ec3fda2": {
#     "username": "CodeCrevette",
#     "online": true,
#     "server": "NA1",
#     "activeCharacter": "457587dc-a6ed-4f61-8396-9e7937906773",
#     "nickname": null,
#     "uuid": "c1d04519-cf18-4a40-9061-a0d72ec3fda2",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_champion.svg",
#     "legacyRankColour": {
#       "main": "#ffff55",
#       "sub": "#ffaa00"
#     },
#     "shortenedRank": null,
#     "supportRank": "champion",
#     "veteran": null,
#     "lastJoin": "2026-05-04T05:06:48.499000Z",
#     "ranking": {
#       "playerContent": 501,
#       "huicContent": 516,
#       "ultimateIronmanContent": 637,
#       "weaponsmithingLevel": 662,
#       "woodworkingLevel": 673,
#       "huichContent": 820,
#       "cookingLevel": 835,
#       "scribingLevel": 923,
#       "alchemismLevel": 967,
#       "craftsmanContent": 975,
#       "armouringLevel": 1034,
#       "tailoringLevel": 1037,
#       "totalSoloLevel": 1044,
#       "professionsSoloLevel": 1101,
#       "orphionSrPlayers": 1109,
#       "jewelingLevel": 1195,
#       "combatSoloLevel": 1264,
#       "orphionCompletion": 1461,
#       "ironmanContent": 1617,
#       "namelessSrPlayers": 1822,
#       "frumaSrPlayers": 1915,
#       "frumaCompletion": 1978,
#       "grootslangSrPlayers": 3288,
#       "namelessCompletion": 3637,
#       "grootslangCompletion": 3641,
#       "woodcuttingLevel": 3767,
#       "farmingLevel": 3873,
#       "fishingLevel": 4138,
#       "miningLevel": 4821,
#       "colossusSrPlayers": 5063,
#       "professionsGlobalLevel": 7095,
#       "colossusCompletion": 7117,
#       "totalGlobalLevel": 11139,
#       "warsCompletion": 11828,
#       "globalPlayerContent": 12689,
#       "combatGlobalLevel": 47510
#     },
#     "previousRanking": {},
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "CHIEF",
#       "rankStars": "\u2605\u2605\u2605\u2605"
#     },
#     "guildHistory": [
#       "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "2f575d9b-5a6b-4df2-8b6a-8c0ba765e3da",
#       "373c8c68-b5be-4d12-834b-09634483967e"
#     ],
#     "firstJoin": "2026-01-11T22:55:08.663000Z",
#     "playtime": 891.5,
#     "globalData": {
#       "contentCompletion": 1761,
#       "wars": 14,
#       "totalLevel": 2002,
#       "mobsKilled": 254782,
#       "chestsFound": 4031,
#       "dungeons": {
#         "total": 144,
#         "list": {
#           "Decrepit Sewers": 7,
#           "Infested Pit": 10,
#           "Timelost Sanctum": 3,
#           "Underworld Crypt": 6,
#           "Ice Barrows": 11,
#           "Undergrowth Ruins": 38,
#           "Sand-Swept Tomb": 4,
#           "Galleon's Graveyard": 5,
#           "Corrupted Decrepit Sewers": 12,
#           "Corrupted Infested Pit": 7,
#           "Corrupted Underworld Crypt": 7,
#           "Corrupted Ice Barrows": 7,
#           "Corrupted Undergrowth Ruins": 7,
#           "Corrupted Galleon's Graveyard": 6,
#           "Corrupted Lost Sanctuary": 6,
#           "Corrupted Sand-Swept Tomb": 6,
#           "Fallen Factory": 1,
#           "Eldritch Outlook": 1
#         }
#       },
#       "raids": {
#         "total": 486,
#         "list": {
#           "The Canyon Colossus": 65,
#           "Orphion's Nexus of Light": 114,
#           "The Nameless Anomaly": 155,
#           "Nest of the Grootslangs": 142,
#           "The Wartorn Palace": 10
#         }
#       },
#       "worldEvents": 68,
#       "lootruns": 7,
#       "caves": 243,
#       "completedQuests": 266,
#       "raidStats": {
#         "damageTaken": 42210774,
#         "damageDealt": 6800512718,
#         "healthHealed": 12101429,
#         "deaths": 216,
#         "buffsTaken": 1355,
#         "gambitsUsed": 1328
#       },
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 236,
#         "list": {
#           "The Canyon Colossus": 33,
#           "Orphion's Nexus of Light": 51,
#           "Nest of the Grootslangs": 58,
#           "The Nameless Anomaly": 92,
#           "The Wartorn Palace": 2
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2026-01-11T22:55:08.663000Z",
#       "playtime": 891.5,
#       "globalData.totalLevel": 2002,
#       "globalData.mobsKilled": 254782,
#       "globalData.completedQuests": 266
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false,
#       "guildHistoryAccess": false
#     }
#   },
#   "bd5c1697-4d42-41dd-a4f2-2c8a3a669104": {
#     "username": "Shivnitzl19",
#     "online": false,
#     "server": "NA37",
#     "activeCharacter": "9320f34b-3e61-4a7a-a45b-ca9b9733006c",
#     "nickname": null,
#     "uuid": "bd5c1697-4d42-41dd-a4f2-2c8a3a669104",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_champion.svg",
#     "legacyRankColour": {
#       "main": "#ffff55",
#       "sub": "#ffaa00"
#     },
#     "shortenedRank": null,
#     "supportRank": "champion",
#     "veteran": null,
#     "lastJoin": "2026-05-01T11:59:20.669000Z",
#     "ranking": {
#       "orphionCompletion": 461,
#       "globalPlayerContent": 544,
#       "combatGlobalLevel": 711,
#       "weaponsmithingLevel": 792,
#       "cookingLevel": 878,
#       "totalGlobalLevel": 917,
#       "professionsSoloLevel": 1136,
#       "alchemismLevel": 1166,
#       "woodworkingLevel": 1174,
#       "totalSoloLevel": 1175,
#       "playerContent": 1303,
#       "scribingLevel": 1406,
#       "tailoringLevel": 1431,
#       "armouringLevel": 1557,
#       "fishingLevel": 1730,
#       "jewelingLevel": 1795,
#       "woodcuttingLevel": 1992,
#       "farmingLevel": 2010,
#       "professionsGlobalLevel": 2574,
#       "miningLevel": 2842,
#       "colossusCompletion": 4495,
#       "grootslangCompletion": 6520,
#       "warsCompletion": 7960,
#       "namelessSrPlayers": 8806,
#       "namelessCompletion": 11640,
#       "orphionSrPlayers": 13184,
#       "colossusSrPlayers": 16235,
#       "combatSoloLevel": 17991,
#       "grootslangSrPlayers": 27274
#     },
#     "previousRanking": {},
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "CHIEF",
#       "rankStars": "\u2605\u2605\u2605\u2605"
#     },
#     "guildHistory": [
#       "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "a22c51f6-3b96-4d74-aa0b-b39c58f1ccf7"
#     ],
#     "firstJoin": "2016-04-15T19:23:37.474000Z",
#     "playtime": 3799.0,
#     "globalData": {
#       "contentCompletion": 5181,
#       "wars": 37,
#       "totalLevel": 3541,
#       "mobsKilled": 778068,
#       "chestsFound": 18020,
#       "dungeons": {
#         "total": 1537,
#         "list": {
#           "Decrepit Sewers": 44,
#           "Underworld Crypt": 44,
#           "Ice Barrows": 43,
#           "Undergrowth Ruins": 34,
#           "Galleon's Graveyard": 22,
#           "Corrupted Sand-Swept Tomb": 394,
#           "Corrupted Lost Sanctuary": 89,
#           "Corrupted Undergrowth Ruins": 250,
#           "Eldritch Outlook": 82,
#           "Corrupted Ice Barrows": 103,
#           "Corrupted Underworld Crypt": 102,
#           "Corrupted Infested Pit": 86,
#           "Corrupted Decrepit Sewers": 91,
#           "Infested Pit": 30,
#           "Sand-Swept Tomb": 25,
#           "Corrupted Galleon's Graveyard": 66,
#           "Fallen Factory": 24,
#           "Lost Sanctuary": 4,
#           "Timelost Sanctum": 4
#         }
#       },
#       "raids": {
#         "total": 483,
#         "list": {
#           "The Canyon Colossus": 118,
#           "Orphion's Nexus of Light": 257,
#           "The Nameless Anomaly": 26,
#           "Nest of the Grootslangs": 82
#         }
#       },
#       "worldEvents": 70,
#       "lootruns": 5,
#       "caves": 396,
#       "completedQuests": 969,
#       "raidStats": {
#         "damageTaken": 3701829,
#         "damageDealt": 481571493,
#         "healthHealed": 4263208,
#         "deaths": 23,
#         "buffsTaken": 144,
#         "gambitsUsed": 24
#       },
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 22,
#         "list": {
#           "The Canyon Colossus": 1,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 10,
#           "The Nameless Anomaly": 11,
#           "The Wartorn Palace": 0
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2016-04-15T19:23:37.474000Z",
#       "playtime": 3799.0,
#       "globalData.totalLevel": 3541,
#       "globalData.mobsKilled": 778068,
#       "globalData.completedQuests": 969
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false,
#       "guildHistoryAccess": false
#     }
#   },
#   "89cdeb83-0958-4563-a606-0a460e13abfa": {
#     "username": "ewenfi",
#     "online": false,
#     "server": "NA23",
#     "activeCharacter": "15f2f73d-0da8-43d8-b35e-3bddca2c3b71",
#     "nickname": null,
#     "uuid": "89cdeb83-0958-4563-a606-0a460e13abfa",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_vipplus.svg",
#     "legacyRankColour": {
#       "main": "#55ffff",
#       "sub": "#00aaaa"
#     },
#     "shortenedRank": null,
#     "supportRank": "vipplus",
#     "veteran": null,
#     "lastJoin": "2026-05-03T09:23:09.422000Z",
#     "ranking": {
#       "combatSoloLevel": 1005,
#       "frumaSrPlayers": 1061,
#       "frumaCompletion": 1134,
#       "orphionSrPlayers": 1926,
#       "orphionCompletion": 2335,
#       "colossusSrPlayers": 2673,
#       "colossusCompletion": 2786,
#       "namelessSrPlayers": 3930,
#       "warsCompletion": 5936,
#       "namelessCompletion": 6816,
#       "grootslangSrPlayers": 6953,
#       "grootslangCompletion": 7966,
#       "combatGlobalLevel": 8911,
#       "globalPlayerContent": 9258,
#       "playerContent": 28289,
#       "miningLevel": 66645,
#       "totalSoloLevel": 79313,
#       "cookingLevel": 90661,
#       "armouringLevel": 110915,
#       "woodcuttingLevel": 111840,
#       "tailoringLevel": 117800,
#       "weaponsmithingLevel": 122421,
#       "totalGlobalLevel": 125580,
#       "woodworkingLevel": 131542,
#       "professionsSoloLevel": 134288,
#       "farmingLevel": 139558,
#       "fishingLevel": 281406,
#       "professionsGlobalLevel": 1145227,
#       "alchemismLevel": 1525730,
#       "scribingLevel": 1542062,
#       "jewelingLevel": 1546320
#     },
#     "previousRanking": {},
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "CHIEF",
#       "rankStars": "\u2605\u2605\u2605\u2605"
#     },
#     "guildHistory": [
#       "25a677eb-5511-47aa-9351-ffb2d18a39ca"
#     ],
#     "firstJoin": "2014-10-20T17:11:28.515000Z",
#     "playtime": 1006.67,
#     "globalData": {
#       "contentCompletion": 2051,
#       "wars": 71,
#       "totalLevel": 896,
#       "mobsKilled": 327102,
#       "chestsFound": 10773,
#       "dungeons": {
#         "total": 426,
#         "list": {
#           "Skeleton": 39,
#           "Spider": 34,
#           "Animal": 26,
#           "Zombie": 16,
#           "Silverfish": 12,
#           "Jungle": 6,
#           "Ice Barrows": 14,
#           "Lost Sanctuary": 4,
#           "Undergrowth Ruins": 4,
#           "Decrepit Sewers": 12,
#           "Underworld Crypt": 3,
#           "Fallen Factory": 8,
#           "Corrupted Lost Sanctuary": 37,
#           "Corrupted Sand-Swept Tomb": 53,
#           "Infested Pit": 26,
#           "Sand-Swept Tomb": 20,
#           "Corrupted Infested Pit": 22,
#           "Corrupted Decrepit Sewers": 21,
#           "Corrupted Underworld Crypt": 20,
#           "Corrupted Ice Barrows": 17,
#           "Corrupted Undergrowth Ruins": 16,
#           "Eldritch Outlook": 2,
#           "Corrupted Galleon's Graveyard": 9,
#           "Galleon's Graveyard": 5
#         }
#       },
#       "raids": {
#         "total": 427,
#         "list": {
#           "The Canyon Colossus": 195,
#           "Orphion's Nexus of Light": 79,
#           "The Nameless Anomaly": 66,
#           "Nest of the Grootslangs": 67,
#           "The Wartorn Palace": 20
#         }
#       },
#       "worldEvents": 19,
#       "lootruns": 2,
#       "caves": 132,
#       "completedQuests": 320,
#       "raidStats": {
#         "damageTaken": 25983483,
#         "damageDealt": 3157564149,
#         "healthHealed": 90159330,
#         "deaths": 153,
#         "buffsTaken": 1046,
#         "gambitsUsed": 898
#       },
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 99,
#         "list": {
#           "The Canyon Colossus": 2,
#           "Orphion's Nexus of Light": 12,
#           "Nest of the Grootslangs": 41,
#           "The Nameless Anomaly": 44,
#           "The Wartorn Palace": 0
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2014-10-20T17:11:28.515000Z",
#       "playtime": 1006.67,
#       "globalData.totalLevel": 896,
#       "globalData.mobsKilled": 327102,
#       "globalData.completedQuests": 320
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false,
#       "guildHistoryAccess": false
#     }
#   },
#   "4470c807-1394-4930-937d-1680d508d22d": {
#     "username": "KirouXD",
#     "online": false,
#     "server": "AS14",
#     "activeCharacter": "691aaebd-fdf8-4d07-91a5-24eba41035dc",
#     "nickname": null,
#     "uuid": "4470c807-1394-4930-937d-1680d508d22d",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_hero.svg",
#     "legacyRankColour": {
#       "main": "#AA00AA",
#       "sub": "#FF55FF"
#     },
#     "shortenedRank": null,
#     "supportRank": "hero",
#     "veteran": null,
#     "lastJoin": "2026-03-08T15:19:03.061000Z",
#     "ranking": {
#       "miningLevel": 531,
#       "jewelingLevel": 562,
#       "fishingLevel": 1502,
#       "woodcuttingLevel": 1793,
#       "tailoringLevel": 1864,
#       "orphionSrPlayers": 2943,
#       "orphionCompletion": 3727,
#       "namelessSrPlayers": 3739,
#       "warsCompletion": 5256,
#       "farmingLevel": 5346,
#       "totalSoloLevel": 5414,
#       "professionsSoloLevel": 5425,
#       "armouringLevel": 5510,
#       "namelessCompletion": 6424,
#       "colossusSrPlayers": 7948,
#       "colossusCompletion": 10874,
#       "grootslangSrPlayers": 12942,
#       "grootslangCompletion": 16259,
#       "combatSoloLevel": 28525,
#       "playerContent": 32760,
#       "globalPlayerContent": 60808,
#       "combatGlobalLevel": 67165,
#       "totalGlobalLevel": 81662,
#       "cookingLevel": 130114,
#       "weaponsmithingLevel": 147497,
#       "woodworkingLevel": 155574,
#       "professionsGlobalLevel": 158564,
#       "alchemismLevel": 2360742,
#       "scribingLevel": 2368657
#     },
#     "previousRanking": {},
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "CHIEF",
#       "rankStars": "\u2605\u2605\u2605\u2605"
#     },
#     "guildHistory": [
#       "25a677eb-5511-47aa-9351-ffb2d18a39ca"
#     ],
#     "firstJoin": "2025-01-04T18:35:04.361000Z",
#     "playtime": 395.17,
#     "globalData": {
#       "contentCompletion": 659,
#       "wars": 92,
#       "totalLevel": 1015,
#       "mobsKilled": 147708,
#       "chestsFound": 4104,
#       "dungeons": {
#         "total": 65,
#         "list": {
#           "Decrepit Sewers": 14,
#           "Sand-Swept Tomb": 3,
#           "Ice Barrows": 8,
#           "Corrupted Decrepit Sewers": 4,
#           "Corrupted Infested Pit": 3,
#           "Corrupted Lost Sanctuary": 7,
#           "Corrupted Underworld Crypt": 4,
#           "Corrupted Sand-Swept Tomb": 3,
#           "Corrupted Ice Barrows": 8,
#           "Corrupted Undergrowth Ruins": 3,
#           "Corrupted Galleon's Graveyard": 8
#         }
#       },
#       "raids": {
#         "total": 188,
#         "list": {
#           "The Canyon Colossus": 33,
#           "Orphion's Nexus of Light": 53,
#           "The Nameless Anomaly": 72,
#           "Nest of the Grootslangs": 30
#         }
#       },
#       "worldEvents": 7,
#       "lootruns": 3,
#       "caves": 36,
#       "completedQuests": 48,
#       "raidStats": {
#         "damageTaken": 20693577,
#         "damageDealt": 1767531856,
#         "healthHealed": 72293908,
#         "deaths": 42,
#         "buffsTaken": 507,
#         "gambitsUsed": 418
#       },
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 61,
#         "list": {
#           "The Canyon Colossus": 2,
#           "Orphion's Nexus of Light": 17,
#           "Nest of the Grootslangs": 25,
#           "The Nameless Anomaly": 17,
#           "The Wartorn Palace": 0
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2025-01-04T18:35:04.361000Z",
#       "playtime": 395.17,
#       "globalData.totalLevel": 1015,
#       "globalData.mobsKilled": 147708,
#       "globalData.completedQuests": 48
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false,
#       "guildHistoryAccess": false
#     }
#   },
#   "eb33d516-a34b-4050-bd2c-69a24bf0bd75": {
#     "username": "Chevacchi",
#     "online": false,
#     "server": "AS16",
#     "activeCharacter": "68963a27-f3cf-4475-9b24-fa3b60ac40d2",
#     "nickname": null,
#     "uuid": "eb33d516-a34b-4050-bd2c-69a24bf0bd75",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_champion.svg",
#     "legacyRankColour": {
#       "main": "#ffff55",
#       "sub": "#ffaa00"
#     },
#     "shortenedRank": null,
#     "supportRank": "champion",
#     "veteran": null,
#     "lastJoin": "2026-05-04T04:09:53.521000Z",
#     "ranking": {
#       "warsCompletion": 1389,
#       "namelessSrPlayers": 9222,
#       "colossusSrPlayers": 11482,
#       "namelessCompletion": 14039,
#       "colossusCompletion": 15313,
#       "orphionSrPlayers": 18983,
#       "grootslangSrPlayers": 21574,
#       "combatGlobalLevel": 21792,
#       "orphionCompletion": 23014,
#       "combatSoloLevel": 24438,
#       "grootslangCompletion": 25157,
#       "globalPlayerContent": 44207,
#       "playerContent": 61002,
#       "cookingLevel": 96947,
#       "farmingLevel": 110943,
#       "totalSoloLevel": 207605,
#       "alchemismLevel": 355656,
#       "scribingLevel": 383318,
#       "tailoringLevel": 386570,
#       "jewelingLevel": 391192,
#       "armouringLevel": 411110,
#       "totalGlobalLevel": 472695,
#       "professionsSoloLevel": 492936,
#       "weaponsmithingLevel": 889757,
#       "woodworkingLevel": 914046,
#       "fishingLevel": 1295651,
#       "miningLevel": 1324561,
#       "woodcuttingLevel": 1692779,
#       "professionsGlobalLevel": 3000000
#     },
#     "previousRanking": {},
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "CHIEF",
#       "rankStars": "\u2605\u2605\u2605\u2605"
#     },
#     "guildHistory": [
#       "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "93b563db-369c-4ae2-95e3-0639822449fd"
#     ],
#     "firstJoin": "2026-01-06T11:23:14.364000Z",
#     "playtime": 556.58,
#     "globalData": {
#       "contentCompletion": 830,
#       "wars": 841,
#       "totalLevel": 521,
#       "mobsKilled": 107115,
#       "chestsFound": 8,
#       "dungeons": {
#         "total": 1,
#         "list": {
#           "Eldritch Outlook": 1
#         }
#       },
#       "raids": {
#         "total": 53,
#         "list": {
#           "The Nameless Anomaly": 17,
#           "Nest of the Grootslangs": 16,
#           "The Canyon Colossus": 16,
#           "Orphion's Nexus of Light": 4
#         }
#       },
#       "worldEvents": 1,
#       "lootruns": 0,
#       "caves": 0,
#       "completedQuests": 19,
#       "raidStats": {
#         "damageTaken": 3565471,
#         "damageDealt": 603189563,
#         "healthHealed": 70695031,
#         "deaths": 60,
#         "buffsTaken": 159,
#         "gambitsUsed": 65
#       },
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 39,
#         "list": {
#           "The Canyon Colossus": 16,
#           "Orphion's Nexus of Light": 3,
#           "Nest of the Grootslangs": 5,
#           "The Nameless Anomaly": 15,
#           "The Wartorn Palace": 0
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2026-01-06T11:23:14.364000Z",
#       "playtime": 556.58,
#       "globalData.totalLevel": 521,
#       "globalData.mobsKilled": 107115,
#       "globalData.completedQuests": 19
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false,
#       "guildHistoryAccess": false
#     }
#   },
#   "e36e1abc-7682-4b65-a8d1-7222424ee59a": {
#     "username": "happyguy18",
#     "online": false,
#     "server": "NA8",
#     "activeCharacter": "c4055791-489b-42a6-8cf1-5b53336780d1",
#     "nickname": null,
#     "uuid": "e36e1abc-7682-4b65-a8d1-7222424ee59a",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_hero.svg",
#     "legacyRankColour": {
#       "main": "#AA00AA",
#       "sub": "#FF55FF"
#     },
#     "shortenedRank": null,
#     "supportRank": "hero",
#     "veteran": null,
#     "lastJoin": "2026-04-19T06:35:33.272000Z",
#     "ranking": {
#       "scribingLevel": 3492,
#       "cookingLevel": 3504,
#       "warsCompletion": 3826,
#       "totalSoloLevel": 3891,
#       "professionsSoloLevel": 3912,
#       "armouringLevel": 4210,
#       "tailoringLevel": 4289,
#       "jewelingLevel": 5072,
#       "woodcuttingLevel": 5473,
#       "fishingLevel": 5568,
#       "farmingLevel": 5758,
#       "miningLevel": 7445,
#       "namelessSrPlayers": 8161,
#       "namelessCompletion": 11826,
#       "colossusSrPlayers": 13170,
#       "grootslangSrPlayers": 13712,
#       "combatSoloLevel": 14734,
#       "grootslangCompletion": 15559,
#       "alchemismLevel": 16720,
#       "professionsGlobalLevel": 16777,
#       "orphionSrPlayers": 17250,
#       "colossusCompletion": 17819,
#       "woodworkingLevel": 20423,
#       "orphionCompletion": 20840,
#       "totalGlobalLevel": 20971,
#       "playerContent": 29939,
#       "combatGlobalLevel": 49023,
#       "globalPlayerContent": 51699,
#       "weaponsmithingLevel": 965912
#     },
#     "previousRanking": {},
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "CHIEF",
#       "rankStars": "\u2605\u2605\u2605\u2605"
#     },
#     "guildHistory": [
#       "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "ddbdac33-9f3c-4e25-af92-2071d127a246",
#       "ee860b7c-9a1d-49cf-9f19-ab673ba0f23b"
#     ],
#     "firstJoin": "2024-09-10T02:54:52.704000Z",
#     "playtime": 290.92,
#     "globalData": {
#       "contentCompletion": 781,
#       "wars": 166,
#       "totalLevel": 1228,
#       "mobsKilled": 77553,
#       "chestsFound": 480,
#       "dungeons": {
#         "total": 47,
#         "list": {
#           "Decrepit Sewers": 6,
#           "Underworld Crypt": 4,
#           "Timelost Sanctum": 1,
#           "Corrupted Infested Pit": 2,
#           "Corrupted Lost Sanctuary": 4,
#           "Corrupted Underworld Crypt": 2,
#           "Corrupted Decrepit Sewers": 1,
#           "Corrupted Sand-Swept Tomb": 1,
#           "Corrupted Ice Barrows": 1,
#           "Corrupted Galleon's Graveyard": 1,
#           "Corrupted Undergrowth Ruins": 1,
#           "Sand-Swept Tomb": 2,
#           "Ice Barrows": 7,
#           "Undergrowth Ruins": 8,
#           "Galleon's Graveyard": 2,
#           "Infested Pit": 4
#         }
#       },
#       "raids": {
#         "total": 72,
#         "list": {
#           "The Canyon Colossus": 11,
#           "Orphion's Nexus of Light": 5,
#           "The Nameless Anomaly": 25,
#           "Nest of the Grootslangs": 31
#         }
#       },
#       "worldEvents": 9,
#       "lootruns": 1,
#       "caves": 42,
#       "completedQuests": 78,
#       "raidStats": {
#         "damageTaken": 5009373,
#         "damageDealt": 630485111,
#         "healthHealed": 2481760,
#         "deaths": 38,
#         "buffsTaken": 212,
#         "gambitsUsed": 86
#       },
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
# ...
#         "gambitsUsed": 137
#       },
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0,
#           "The Wartorn Palace": 0
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2023-11-19T15:38:49.953000Z",
#       "playtime": 283.17,
#       "globalData.totalLevel": 890,
#       "globalData.mobsKilled": 77483,
#       "globalData.completedQuests": 123
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false,
#       "guildHistoryAccess": false
#     }
#   },
#   "8c8628e4-0973-48fc-baf5-70e161b91d1d": {
#     "username": "SalTev",
#     "online": false,
#     "server": "NA44",
#     "activeCharacter": "201cae6f-675c-4290-9567-9fc135d4d8ea",
#     "nickname": null,
#     "uuid": "8c8628e4-0973-48fc-baf5-70e161b91d1d",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_heroplus.svg",
#     "legacyRankColour": {
#       "main": "#bc3c7c",
#       "sub": "#c571a5"
#     },
#     "shortenedRank": null,
#     "supportRank": "heroplus",
#     "veteran": null,
#     "lastJoin": "2026-05-04T05:16:30.680000Z",
#     "ranking": {
#       "namelessSrPlayers": 2131,
#       "namelessCompletion": 3985,
#       "combatSoloLevel": 4101,
#       "frumaSrPlayers": 4840,
#       "frumaCompletion": 5202,
#       "miningLevel": 7900,
#       "orphionSrPlayers": 12631,
#       "globalPlayerContent": 12914,
#       "colossusSrPlayers": 14492,
#       "combatGlobalLevel": 14827,
#       "orphionCompletion": 15542,
#       "warsCompletion": 18004,
#       "grootslangSrPlayers": 19073,
#       "colossusCompletion": 20223,
#       "grootslangCompletion": 23562,
#       "fishingLevel": 30614,
#       "playerContent": 35266,
#       "totalSoloLevel": 46306,
#       "professionsSoloLevel": 57570,
#       "cookingLevel": 68549,
#       "jewelingLevel": 83379,
#       "woodcuttingLevel": 83979,
#       "farmingLevel": 147330,
#       "totalGlobalLevel": 194647,
#       "professionsGlobalLevel": 677398,
#       "alchemismLevel": 1493503,
#       "scribingLevel": 1510112,
#       "tailoringLevel": 1511870,
#       "armouringLevel": 1526364,
#       "weaponsmithingLevel": 1812281,
#       "woodworkingLevel": 1827182
#     },
#     "previousRanking": {},
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "RECRUIT",
#       "rankStars": null
#     },
#     "guildHistory": [
#       "80f4c5c2-cfb5-4ca0-9cdd-eaa486aed33e",
#       "be46c25a-1515-4c18-8f26-3253f9f6d5d1",
#       "ee860b7c-9a1d-49cf-9f19-ab673ba0f23b"
#     ],
#     "firstJoin": "2022-02-21T00:34:54.608000Z",
#     "playtime": 474.67,
#     "globalData": {
#       "contentCompletion": 1743,
#       "wars": 4,
#       "totalLevel": 847,
#       "mobsKilled": 151459,
#       "chestsFound": 3316,
#       "dungeons": {
#         "total": 245,
#         "list": {
#           "Decrepit Sewers": 16,
#           "Infested Pit": 37,
#           "Sand-Swept Tomb": 12,
#           "Ice Barrows": 22,
#           "Underworld Crypt": 13,
#           "Undergrowth Ruins": 32,
#           "Corrupted Decrepit Sewers": 39,
#           "Corrupted Infested Pit": 23,
#           "Corrupted Lost Sanctuary": 25,
#           "Galleon's Graveyard": 6,
#           "Corrupted Ice Barrows": 6,
#           "Corrupted Undergrowth Ruins": 3,
#           "Eldritch Outlook": 2,
#           "Fallen Factory": 3,
#           "Corrupted Sand-Swept Tomb": 6
#         }
#       },
#       "raids": {
#         "total": 179,
#         "list": {
#           "The Nameless Anomaly": 143,
#           "Nest of the Grootslangs": 18,
#           "The Canyon Colossus": 8,
#           "Orphion's Nexus of Light": 9,
#           "The Wartorn Palace": 1
#         }
#       },
#       "worldEvents": 14,
#       "lootruns": 3,
#       "caves": 129,
#       "completedQuests": 164,
#       "raidStats": {
#         "damageTaken": 13891182,
#         "damageDealt": 2032683644,
#         "healthHealed": 12130261,
#         "deaths": 68,
#         "buffsTaken": 447,
#         "gambitsUsed": 357
#       },
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 64,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 7,
#           "Nest of the Grootslangs": 5,
#           "The Nameless Anomaly": 52,
#           "The Wartorn Palace": 0
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2022-02-21T00:34:54.608000Z",
#       "playtime": 474.67,
#       "globalData.totalLevel": 847,
#       "globalData.mobsKilled": 151459,
#       "globalData.completedQuests": 164
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false,
#       "guildHistoryAccess": false
#     }
#   },
#   "9d2f6d3e-f7ef-434c-b4f6-1b0d23897855": {
#     "username": "ectez",
#     "online": false,
#     "server": "NA56",
#     "activeCharacter": "58895d2d-b960-41ad-8821-88fef2dd3a93",
#     "nickname": null,
#     "uuid": "9d2f6d3e-f7ef-434c-b4f6-1b0d23897855",
#     "rank": "Player",
#     "rankBadge": null,
#     "legacyRankColour": null,
#     "shortenedRank": null,
#     "supportRank": null,
#     "veteran": null,
#     "lastJoin": "2026-05-04T02:07:34.769000Z",
#     "ranking": {
#       "alchemismLevel": 7677,
#       "combatSoloLevel": 8267,
#       "playerContent": 8503,
#       "globalPlayerContent": 13008,
#       "farmingLevel": 14489,
#       "fishingLevel": 19611,
#       "grootslangSrPlayers": 19776,
#       "colossusSrPlayers": 21098,
#       "orphionSrPlayers": 21117,
#       "grootslangCompletion": 23498,
#       "orphionCompletion": 27152,
#       "combatGlobalLevel": 27714,
#       "colossusCompletion": 29348,
#       "totalSoloLevel": 36945,
#       "professionsSoloLevel": 48715,
#       "cookingLevel": 54079,
#       "weaponsmithingLevel": 136942,
#       "woodworkingLevel": 145723,
#       "miningLevel": 248522,
#       "totalGlobalLevel": 264382,
#       "woodcuttingLevel": 288003,
#       "professionsGlobalLevel": 632149,
#       "scribingLevel": 1312214,
#       "tailoringLevel": 1314178,
#       "jewelingLevel": 1317334,
#       "armouringLevel": 1330410
#     },
#     "previousRanking": {},
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "RECRUIT",
#       "rankStars": null
#     },
#     "guildHistory": [],
#     "firstJoin": "2020-08-19T00:55:30.633000Z",
#     "playtime": 347.92,
#     "globalData": {
#       "contentCompletion": 1743,
#       "wars": 0,
#       "totalLevel": 740,
#       "mobsKilled": 74923,
#       "chestsFound": 2178,
#       "dungeons": {
#         "total": 133,
#         "list": {
#           "Decrepit Sewers": 14,
#           "Infested Pit": 11,
#           "Lost Sanctuary": 4,
#           "Underworld Crypt": 12,
#           "Sand-Swept Tomb": 12,
#           "Undergrowth Ruins": 9,
#           "Corrupted Decrepit Sewers": 14,
#           "Corrupted Infested Pit": 8,
#           "Corrupted Underworld Crypt": 14,
#           "Corrupted Undergrowth Ruins": 7,
#           "Timelost Sanctum": 3,
#           "Fallen Factory": 1,
#           "Corrupted Ice Barrows": 5,
#           "Corrupted Sand-Swept Tomb": 3,
#           "Corrupted Galleon's Graveyard": 4,
#           "Corrupted Lost Sanctuary": 3,
#           "Ice Barrows": 4,
#           "Galleon's Graveyard": 3,
#           "Eldritch Outlook": 2
#         }
#       },
#       "raids": {
#         "total": 23,
#         "list": {
#           "The Canyon Colossus": 2,
#           "Orphion's Nexus of Light": 3,
#           "Nest of the Grootslangs": 18
#         }
#       },
#       "worldEvents": 49,
#       "lootruns": 5,
#       "caves": 181,
#       "completedQuests": 233,
#       "raidStats": {
#         "damageTaken": 1752026,
#         "damageDealt": 57043186,
#         "healthHealed": 1345954,
#         "deaths": 1,
#         "buffsTaken": 68,
#         "gambitsUsed": 20
#       },
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0,
#           "The Wartorn Palace": 0
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2020-08-19T00:55:30.633000Z",
#       "playtime": 347.92,
#       "globalData.totalLevel": 740,
#       "globalData.mobsKilled": 74923,
#       "globalData.completedQuests": 233
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false,
#       "guildHistoryAccess": false
#     }
#   },
#   "c67aa7dc-e2ae-4efd-b5bc-33e2a3109ede": {
#     "username": "IcyIce7",
#     "online": false,
#     "server": "EU24",
#     "activeCharacter": "a5179891-4254-4973-8f24-37640111b733",
#     "nickname": null,
#     "uuid": "c67aa7dc-e2ae-4efd-b5bc-33e2a3109ede",
#     "rank": "Player",
#     "rankBadge": "nextgen/badges/rank_hero.svg",
#     "legacyRankColour": {
#       "main": "#AA00AA",
#       "sub": "#FF55FF"
#     },
#     "shortenedRank": null,
#     "supportRank": "hero",
#     "veteran": false,
#     "lastJoin": "2026-04-29T17:35:16.930000Z",
#     "ranking": {
#       "combatSoloLevel": 4656,
#       "playerContent": 6454,
#       "namelessSrPlayers": 7781,
#       "colossusSrPlayers": 10122,
#       "namelessCompletion": 11631,
#       "colossusCompletion": 12984,
#       "globalPlayerContent": 16506,
#       "orphionSrPlayers": 20486,
#       "grootslangSrPlayers": 22154,
#       "grootslangCompletion": 26467,
#       "orphionCompletion": 26572,
#       "combatGlobalLevel": 28515,
#       "cookingLevel": 73454,
#       "weaponsmithingLevel": 120746,
#       "totalSoloLevel": 133278,
#       "jewelingLevel": 133826,
#       "woodworkingLevel": 141083,
#       "professionsSoloLevel": 280229,
#       "miningLevel": 299584,
#       "woodcuttingLevel": 319240,
#       "farmingLevel": 448719,
#       "totalGlobalLevel": 524206,
#       "alchemismLevel": 797227,
#       "scribingLevel": 820554,
#       "tailoringLevel": 823278,
#       "armouringLevel": 843874,
#       "fishingLevel": 1590493,
#       "professionsGlobalLevel": 3000000
#     },
#     "previousRanking": {},
#     "guild": {
#       "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#       "name": "Godly",
#       "prefix": "grey",
#       "rank": "RECRUIT",
#       "rankStars": null
#     },
#     "guildHistory": [
#       "f7e7cc4e-212d-422f-a3e6-744a8689b108"
#     ],
#     "firstJoin": "2014-05-02T11:21:59.518000Z",
#     "playtime": 620.67,
#     "globalData": {
#       "contentCompletion": 1531,
#       "wars": 0,
#       "totalLevel": 486,
#       "mobsKilled": 113181,
#       "chestsFound": 3956,
#       "dungeons": {
#         "total": 264,
#         "list": {
#           "Lost Sanctuary": 4,
#           "Ice Barrows": 18,
#           "Underworld Crypt": 12,
#           "Sand-Swept Tomb": 12,
#           "Undergrowth Ruins": 18,
#           "Galleon's Graveyard": 11,
#           "Corrupted Decrepit Sewers": 12,
#           "Corrupted Infested Pit": 8,
#           "Corrupted Lost Sanctuary": 15,
#           "Corrupted Underworld Crypt": 14,
#           "Corrupted Sand-Swept Tomb": 90,
#           "Corrupted Ice Barrows": 4,
#           "Corrupted Undergrowth Ruins": 23,
#           "Zombie": 9,
#           "Skeleton": 3,
#           "Animal": 1,
#           "Fallen Factory": 2,
#           "Infested Pit": 2,
#           "Eldritch Outlook": 1,
#           "Decrepit Sewers": 5
#         }
#       },
#       "raids": {
#         "total": 67,
#         "list": {
#           "The Canyon Colossus": 23,
#           "The Nameless Anomaly": 26,
#           "Nest of the Grootslangs": 15,
#           "Orphion's Nexus of Light": 3
#         }
#       },
#       "worldEvents": 23,
#       "lootruns": 2,
#       "caves": 177,
#       "completedQuests": 223,
#       "raidStats": {
#         "damageTaken": 5692641,
#         "damageDealt": 475381774,
#         "healthHealed": 4180250,
#         "deaths": 62,
#         "buffsTaken": 178,
#         "gambitsUsed": 60
#       },
#       "pvp": {
#         "kills": 38,
#         "deaths": 44
#       },
#       "guildRaids": {
#         "total": 3,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 3,
#           "The Wartorn Palace": 0
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2014-05-02T11:21:59.518000Z",
#       "playtime": 620.67,
#       "globalData.totalLevel": 486,
#       "globalData.mobsKilled": 113181,
#       "globalData.completedQuests": 223
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false,
#       "guildHistoryAccess": false
#     }
#   },
#   "18a32ae1-8b6e-4efb-b6e1-726dee1b467d": {
#     "username": "Purgerer",
#     "online": false,
#     "server": "EU44",
#     "activeCharacter": "46424f24-e902-4463-a439-f0de172f9ad7",
#     "nickname": null,
#     "uuid": "18a32ae1-8b6e-4efb-b6e1-726dee1b467d",
#     "rank": "Player",
#     "rankBadge": null,
#     "legacyRankColour": null,
#     "shortenedRank": null,
#     "supportRank": null,
#     "veteran": null,
#     "lastJoin": "2026-05-03T22:28:08.982000Z",
#     "ranking": {
#       "frumaCompletion": 2564,
#       "frumaSrPlayers": 2642,
#       "combatSoloLevel": 7749,
#       "namelessSrPlayers": 11516,
#       "playerContent": 13797,
#       "namelessCompletion": 16490,
#       "colossusSrPlayers": 18183,
#       "colossusCompletion": 25758,
#       "grootslangSrPlayers": 27430,
#       "orphionSrPlayers": 28887,
#       "grootslangCompletion": 33688,
#       "orphionCompletion": 45078,
#       "globalPlayerContent": 52238,
#       "cookingLevel": 58919,
#       "weaponsmithingLevel": 152534,
#       "totalSoloLevel": 159701,
#       "woodworkingLevel": 160368,
#       "combatGlobalLevel": 165463,
#       "professionsSoloLevel": 382173,
#       "fishingLevel": 481027,
#       "farmingLevel": 720722,
#       "totalGlobalLevel": 1625823,
#       "alchemismLevel": 2886407,
#       "scribingLevel": 2889147,
#       "tailoringLevel": 2889602,
#       "jewelingLevel": 2890053,
#       "armouringLevel": 2892171,
#       "miningLevel": 2987618,
#       "woodcuttingLevel": 3000000,
#       "professionsGlobalLevel": 3000000
#     },
#     "previousRanking": {},
#     "guild": null,
#     "guildHistory": [],
#     "firstJoin": "2026-03-31T20:22:36.137000Z",
#     "playtime": 51.92,
#     "globalData": {
#       "contentCompletion": 738,
#       "wars": 0,
#       "totalLevel": 169,
#       "mobsKilled": 20185,
#       "chestsFound": 346,
#       "dungeons": {
#         "total": 8,
#         "list": {
#           "Decrepit Sewers": 1,
#           "Infested Pit": 2,
#           "Ice Barrows": 1,
#           "Undergrowth Ruins": 1,
#           "Galleon's Graveyard": 1,
#           "Fallen Factory": 1,
#           "Eldritch Outlook": 1
#         }
#       },
#       "raids": {
#         "total": 35,
#         "list": {
#           "The Canyon Colossus": 4,
#           "Orphion's Nexus of Light": 1,
#           "The Nameless Anomaly": 12,
#           "Nest of the Grootslangs": 11,
#           "The Wartorn Palace": 7
#         }
#       },
#       "worldEvents": 2,
#       "lootruns": 0,
#       "caves": 82,
#       "completedQuests": 114,
#       "raidStats": {
#         "damageTaken": 3309380,
#         "damageDealt": 556935372,
#         "healthHealed": 3497348,
#         "deaths": 10,
#         "buffsTaken": 98,
#         "gambitsUsed": 32
#       },
#       "pvp": {
#         "kills": 0,
#         "deaths": 0
#       },
#       "guildRaids": {
#         "total": 0,
#         "list": {
#           "The Canyon Colossus": 0,
#           "Orphion's Nexus of Light": 0,
#           "Nest of the Grootslangs": 0,
#           "The Nameless Anomaly": 0,
#           "The Wartorn Palace": 0
#         }
#       }
#     },
#     "featuredStats": {
#       "firstJoin": "2026-03-31T20:22:36.137000Z",
#       "playtime": 51.92,
#       "globalData.totalLevel": 169,
#       "globalData.mobsKilled": 20185,
#       "globalData.completedQuests": 114
#     },
#     "wallpaper": "home",
#     "avatar": "player",
#     "restrictions": {
#       "mainAccess": false,
#       "onlineStatus": false,
#       "guildHistoryAccess": false
#     }
#   }
# }

# %%
# guild_breakdown_username = {}
# for uuid in all_members:
#     member_stats[uuid]['username'] = member_stats[uuid]
print(json.dumps(member_stats["94591244-b96c-4675-99fc-b4e9abfac6de"], indent=2))
# Out:
# {
#   "username": "cheeseball01",
#   "online": false,
#   "server": "NA28",
#   "activeCharacter": "cb1da0e5-3cfd-4c23-aa24-3bdf486c1f65",
#   "nickname": null,
#   "uuid": "94591244-b96c-4675-99fc-b4e9abfac6de",
#   "rank": "Player",
#   "rankBadge": "nextgen/badges/rank_vipplus.svg",
#   "legacyRankColour": {
#     "main": "#55ffff",
#     "sub": "#00aaaa"
#   },
#   "shortenedRank": null,
#   "supportRank": "vipplus",
#   "veteran": null,
#   "lastJoin": "2026-02-21T01:39:04.909000Z",
#   "guild": {
#     "uuid": "25a677eb-5511-47aa-9351-ffb2d18a39ca",
#     "name": "Godly",
#     "prefix": "grey",
#     "rank": "RECRUIT",
#     "rankStars": null
#   },
#   "ranking": {
#     "huntedContent": 1184,
#     "combatGlobalLevel": 2176,
#     "orphionSrPlayers": 2534,
#     "guildRaids": 3522,
#     "orphionCompletion": 3569,
#     "colossusCompletion": 3779,
#     "namelessSrPlayers": 4602,
#     "colossusSrPlayers": 4845,
#     "namelessCompletion": 5210,
#     "globalPlayerContent": 5285,
#     "grootslangCompletion": 5431,
#     "warsCompletion": 5547,
#     "totalGlobalLevel": 5626,
#     "grootslangSrPlayers": 5706,
#     "combatSoloLevel": 6093,
#     "woodcuttingLevel": 6100,
#     "farmingLevel": 6151,
#     "fishingLevel": 6220,
#     "miningLevel": 7140,
#     "professionsGlobalLevel": 12415,
#     "totalSoloLevel": 16202,
#     "professionsSoloLevel": 17554,
#     "scribingLevel": 36062,
#     "playerContent": 36899,
#     "tailoringLevel": 65093,
#     "cookingLevel": 67053,
#     "weaponsmithingLevel": 68901,
#     "armouringLevel": 113117,
#     "woodworkingLevel": 400803,
#     "alchemismLevel": 1423068,
#     "jewelingLevel": 1446469
#   },
#   "previousRanking": {},
#   "firstJoin": "2020-12-01T15:03:33.911000Z",
#   "playtime": 1786.58,
#   "globalData": {
#     "contentCompletion": 2408,
#     "wars": 80,
#     "totalLevel": 5285,
#     "mobsKilled": 745660,
#     "chestsFound": 77224,
#     "dungeons": {
#       "total": 218,
#       "list": {
#         "Decrepit Sewers": 47,
#         "Corrupted Infested Pit": 15,
#         "Corrupted Lost Sanctuary": 23,
#         "Corrupted Sand-Swept Tomb": 11,
#         "Corrupted Undergrowth Ruins": 42,
#         "Eldritch Outlook": 7,
#         "Fallen Factory": 8,
#         "Ice Barrows": 6,
#         "Corrupted Ice Barrows": 9,
#         "Corrupted Decrepit Sewers": 14,
#         "Infested Pit": 21,
#         "Corrupted Underworld Crypt": 9,
#         "Sand-Swept Tomb": 1,
#         "Corrupted Galleon's Graveyard": 3,
#         "Lost Sanctuary": 1,
#         "Underworld Crypt": 1
#       }
#     },
#     "raids": {
#       "total": 342,
#       "list": {
#         "The Canyon Colossus": 131,
#         "Nest of the Grootslangs": 79,
#         "The Nameless Anomaly": 86,
#         "Orphion's Nexus of Light": 46
#       }
#     },
#     "worldEvents": 15,
#     "lootruns": 5,
#     "caves": 110,
#     "completedQuests": 209,
#     "pvp": {
#       "kills": 0,
#       "deaths": 0
#     },
#     "guildRaids": {
#       "total": 71,
#       "list": {
#         "The Canyon Colossus": 7,
#         "Orphion's Nexus of Light": 15,
#         "Nest of the Grootslangs": 35,
#         "The Nameless Anomaly": 14
#       }
#     }
#   },
#   "featuredStats": {
#     "firstJoin": "2020-12-01T15:03:33.911000Z",
#     "playtime": 1786.58,
#     "globalData.totalLevel": 5285,
#     "globalData.mobsKilled": 745660,
#     "globalData.completedQuests": 209
#   },
#   "wallpaper": "home",
#   "avatar": "player",
#   "restrictions": {
#     "mainAccess": false,
#     "onlineStatus": false
#   }
# }

# %%
# print(member_stats['zytiv'])

# %%
incognito = []
for member in sorted(member_stats.keys()):
    if not member_stats[member]['restrictions']['mainAccess'] and not member_stats[member]['restrictions']['onlineStatus']:
        # print(member_stats[member])
        # print(f"{member}: {member_stats[member]["playtime"]} {member_stats[member]["restrictions"]}")
        # print(f"{member_stats[member]['username']}: {member_stats[member]['restrictions']}")
        pass
    else:
        # print(f"{member} icognito")
        incognito.append(member)
        print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
        print(f"{member_stats[member]['username']}: {member_stats[member]['restrictions']} : {member} incognito")
        print("++++=====================================================+++++")
# print(sorted(icongnito))
print(incognito)
# Out:
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Wispxerre: {'mainAccess': True, 'onlineStatus': False, 'guildHistoryAccess': False} : e3790cf3-d64b-402a-bd3f-a6c271ab8deb incognito
# ++++=====================================================+++++
# ['e3790cf3-d64b-402a-bd3f-a6c271ab8deb']

# %%
# yesterday = ['aqimcrafty', 'ecmz', 'krijer1', 'moondustpeachy', 'soupskids', 'white_plague']
# offline_members = ['cff26bb4-bad0-4de2-8559-19d23e2d9d41']
good_members = {k: v for k,v in member_stats.items() if k not in incognito}
print(good_members)
# Out:
# {'a8e5c7c3-444f-4436-b69f-a8db58cdf40d': {'username': 'Nqn', 'online': False, 'server': 'AS16', 'activeCharacter': '429af94a-691d-4f94-b70c-eb944c20b210', 'nickname': None, 'uuid': 'a8e5c7c3-444f-4436-b69f-a8db58cdf40d', 'rank': 'Player', 'rankBadge': 'nextgen/badges/rank_champion.svg', 'legacyRankColour': {'main': '#ffff55', 'sub': '#ffaa00'}, 'shortenedRank': None, 'supportRank': 'champion', 'veteran': None, 'lastJoin': '2026-05-21T14:10:56.734000Z', 'ranking': {'woodworkingLevel': 300, 'frumaSrPlayers': 308, 'frumaCompletion': 320, 'combatSoloLevel': 349, 'weaponsmithingLevel': 551, 'namelessSrPlayers': 638, 'scribingLevel': 686, 'jewelingLevel': 725, 'tailoringLevel': 745, 'armouringLevel': 772, 'totalSoloLevel': 797, 'professionsSoloLevel': 828, 'orphionSrPlayers': 1006, 'alchemismLevel': 1022, 'cookingLevel': 1028, 'orphionCompletion': 1297, 'namelessCompletion': 1394, 'farmingLevel': 1752, 'colossusSrPlayers': 1869, 'grootslangSrPlayers': 2044, 'woodcuttingLevel': 2225, 'warsCompletion': 2254, 'grootslangCompletion': 2302, 'colossusCompletion': 2667, 'fishingLevel': 2718, 'miningLevel': 3514, 'combatGlobalLevel': 6438, 'totalGlobalLevel': 7154, 'globalPlayerContent': 9933, 'professionsGlobalLevel': 10254, 'playerContent': 29626}, 'previousRanking': {}, 'guild': {'uuid': '25a677eb-5511-47aa-9351-ffb2d18a39ca', 'name': 'Godly', 'prefix': 'grey', 'rank': 'OWNER', 'rankStars': '★★★★★'}, 'guildHistory': ['25a677eb-5511-47aa-9351-ffb2d18a39ca'], 'firstJoin': '2022-10-27T09:09:48.757000Z', 'playtime': 1294.58, 'globalData': {'contentCompletion': 2023, 'wars': 416, 'totalLevel': 2254, 'mobsKilled': 1666446, 'chestsFound': 9675, 'dungeons': {'total': 236, 'list': {'Decrepit Sewers': 43, 'Sand-Swept Tomb': 4, 'Ice Barrows': 7, 'Eldritch Outlook': 10, "Corrupted Galleon's Graveyard": 24, 'Corrupted Decrepit Sewers': 24, 'Corrupted Infested Pit': 21, 'Corrupted Lost Sanctuary': 19, 'Corrupted Underworld Crypt': 20, 'Corrupted Sand-Swept Tomb': 24, 'Corrupted Ice Barrows': 18, 'Corrupted Undergrowth Ruins': 18, 'Underworld Crypt': 1, 'Infested Pit': 2, 'Timelost Sanctum': 1}}, 'raids': {'total': 1113, 'list': {'The Canyon Colossus': 206, "Orphion's Nexus of Light": 130, 'The Nameless Anomaly': 465, 'Nest of the Grootslangs': 206, 'The Wartorn Palace': 106}}, 'worldEvents': 26, 'lootruns': 5, 'caves': 137, 'completedQuests': 122, 'raidStats': {'damageTaken': 92365654, 'damageDealt': 18076083063, 'healthHealed': 131039087, 'deaths': 394, 'buffsTaken': 3041, 'gambitsUsed': 3106}, 'pvp': {'kills': 0, 'deaths': 0}, 'guildRaids': {'total': 302, 'list': {'The Canyon Colossus': 55, "Orphion's Nexus of Light": 35, 'Nest of the Grootslangs': 69, 'The Nameless Anomaly': 116, 'The Wartorn Palace': 27}}}, 'featuredStats': {'firstJoin': '2022-10-27T09:09:48.757000Z', 'playtime': 1294.58, 'globalData.totalLevel': 2254, 'globalData.mobsKilled': 1666446, 'globalData.completedQuests': 122}, 'wallpaper': 'home', 'avatar': 'player', 'restrictions': {'mainAccess': False, 'onlineStatus': False, 'guildHistoryAccess': False}}, '4fb7c4a3-a84e-431c-9d93-649f6391f7eb': {'username': 'SolaR8735', 'online': True, 'server': 'NA16', 'activeCharacter': 'edbce027-32a1-42c0-8507-7f4093a3aa58', 'nickname': None, 'uuid': '4fb7c4a3-a84e-431c-9d93-649f6391f7eb', 'rank': 'Player', 'rankBadge': 'nextgen/badges/rank_champion.svg', 'legacyRankColour': {'main': '#ffff55', 'sub': '#ffaa00'}, 'shortenedRank': None, 'supportRank': 'champion', 'veteran': None, 'lastJoin': '2026-05-21T20:52:14.505000Z', 'ranking': {'scribingLevel': 933, 'frumaCompletion': 1147, 'frumaSrPlayers': 1176, 'orphionSrPlayers': 1359, 'orphionCompletion': 1657, 'combatSoloLevel': 1968, 'cookingLevel': 2053, 'namelessSrPlayers': 2239, 'alchemismLevel': 2302, 'grootslangSrPlayers': 2538, 'grootslangCompletion': 2766, 'colossusSrPlayers': 2967, 'namelessCompletion': 4104, 'colossusCompletion': 4162, 'warsCompletion': 6611, 'playerContent': 12402, 'totalSoloLevel': 16802, 'professionsSoloLevel': 18997, 'globa ...

# %%
# print(json.dumps(good_members, indent=2))
# for member in good_members:
#     if not good_members[member]["lastJoin"]:
#         print(good_members[member]["username"])
#         print(json.dumps(good_members[member], indent=2))
#         print(good_members[member]["lastJoin"])

for member in sorted(good_members, key=lambda m: good_members[m]["lastJoin"]):
    print(f"{good_members[member]['username']}: {good_members[member]['lastJoin']}")
# Out:
# MelinoeNemesis: 2026-02-21T15:31:06.350000Z
# YBN: 2026-02-24T21:11:10.295000Z
# Ecmz: 2026-02-28T04:36:02.130000Z
# wrggg: 2026-03-02T21:28:50.964000Z
# KirouXD: 2026-03-08T15:19:03.061000Z
# Liciela: 2026-03-18T16:45:27.100000Z
# AmasoXd: 2026-03-30T10:05:30.723000Z
# imNaphy: 2026-04-04T20:54:17.536000Z
# Gunther_v: 2026-04-06T01:59:55.559000Z
# Feather_Storm: 2026-04-06T16:06:13.849000Z
# AlleNupY: 2026-04-08T13:31:13.503000Z
# gauvinsteven: 2026-04-09T19:43:30.241000Z
# Ryuuchen: 2026-04-10T12:09:23.668000Z
# RealArmis: 2026-04-11T01:23:55.471000Z
# Laborious: 2026-04-11T05:33:32.967000Z
# reparody: 2026-04-13T22:23:13.665000Z
# MaanBoys: 2026-04-14T05:33:27.093000Z
# eryhp: 2026-04-15T20:20:30.436000Z
# vSlqm: 2026-04-17T07:34:11.886000Z
# TheKzR: 2026-04-17T19:53:00.049000Z
# Bluvey: 2026-04-19T01:51:04.816000Z
# happyguy18: 2026-04-19T06:35:33.272000Z
# WynnDestroyer: 2026-04-22T05:38:35.892000Z
# StyNath: 2026-04-23T20:09:18.938000Z
# Firetornado2312: 2026-04-24T05:42:45.983000Z
# FireGamingDK: 2026-04-24T10:39:31.372000Z
# jeff1234567842: 2026-04-25T00:55:35.389000Z
# skrybs: 2026-04-27T00:31:29.451000Z
# cresseliah: 2026-04-27T02:10:46.494000Z
# cheeseball01: 2026-04-28T02:55:24.056000Z
# JJCourts: 2026-04-28T17:18:56.729000Z
# _N8: 2026-04-29T07:17:23.380000Z
# IcyIce7: 2026-04-29T17:35:16.930000Z
# Endyre: 2026-04-30T00:24:11.151000Z
# Couteau: 2026-04-30T01:40:45.065000Z
# TinyTurtle32011: 2026-04-30T07:10:17.091000Z
# Slickx_: 2026-05-01T04:55:57.626000Z
# omuy: 2026-05-01T05:07:12.461000Z
# CAD_Bear: 2026-05-01T05:19:21.168000Z
# _Jus10__: 2026-05-01T05:31:10.410000Z
# Shivnitzl19: 2026-05-01T11:59:20.669000Z
# _Snoopers_: 2026-05-01T18:18:34.959000Z
# EdouardpheoIII: 2026-05-01T19:28:14.823000Z
# Arctifire: 2026-05-01T20:31:09.375000Z
# BlueSkyMoose: 2026-05-02T03:53:29.264000Z
# JP_GOD_Divzer: 2026-05-02T14:01:17.938000Z
# LaserX: 2026-05-02T17:15:58.193000Z
# GigaFanDeJul: 2026-05-02T21:50:39.995000Z
# 8uc: 2026-05-02T22:05:51.024000Z
# Lesbien: 2026-05-03T04:37:27.327000Z
# Eveniji100: 2026-05-03T07:09:34.838000Z
# ewenfi: 2026-05-03T09:23:09.422000Z
# JinnMD: 2026-05-03T12:42:37.598000Z
# Skenzerite: 2026-05-03T13:52:09.841000Z
# kanyo0904: 2026-05-03T15:03:34.770000Z
# Krijer1: 2026-05-03T15:54:47.635000Z
# Mystic757: 2026-05-03T16:08:12.041000Z
# Ahmedboss891: 2026-05-03T17:43:57.713000Z
# King_Yakub: 2026-05-03T18:35:34.054000Z
# Gurlic: 2026-05-03T19:32:33.367000Z
# Purgerer: 2026-05-03T22:28:08.982000Z
# magevast9YT: 2026-05-03T23:18:13.095000Z
# Drovyxx: 2026-05-03T23:29:48.354000Z
# Thund3rMC: 2026-05-03T23:35:06.359000Z
# xEagless: 2026-05-04T00:13:22.798000Z
# WhiteNoise0113: 2026-05-04T00:17:33.052000Z
# ectez: 2026-05-04T02:07:34.769000Z
# Chevacchi: 2026-05-04T04:09:53.521000Z
# S6kuna: 2026-05-04T04:16:41.649000Z
# jayandjef: 2026-05-04T05:00:48.133000Z
# FlamePootis: 2026-05-04T05:01:29.974000Z
# SalTev: 2026-05-04T05:16:30.680000Z
# H1V: 2026-05-04T05:19:12.738000Z
# Shiverscar: 2026-05-04T05:33:01.227000Z
# CodeCrevette: 2026-05-04T06:06:44.358000Z
# Hinsis: 2026-05-04T06:21:59.858000Z
# DIVERDEEPSIX: 2026-05-04T06:31:58.506000Z
# SolaR8735: 2026-05-04T06:36:58.732000Z
# MikeyA: 2026-05-04T06:42:11.993000Z
# Kolbibi: 2026-05-04T06:42:14.038000Z
# Nqn: 2026-05-04T06:42:58.772000Z
# yoimchloe: 2026-05-04T06:45:04.272000Z
# SoftIceCream1: 2026-05-04T06:45:20.628000Z
# Eiriee: 2026-05-04T06:46:02.757000Z

# %%
# print(good_members['a8e5c7c3-444f-4436-b69f-a8db58cdf40d']['globalData']['dungeons']['list'].keys())
fallen_members = {k: v for k, v in good_members.items() if 'Fallen Factory' in good_members[k]['globalData']['dungeons']['list'].keys()}
print("Winston(Dog from Fallen Factory) Kills: \n", end="")
for member in sorted(fallen_members, key=lambda m: fallen_members[m]['globalData']['dungeons']['list']['Fallen Factory'], reverse=True)[:15]:
    print(f"{fallen_members[member]['username']}: {fallen_members[member]['globalData']['dungeons']['list']['Fallen Factory']}", end="\n ")
    # break
# Out:
# Winston(Dog from Fallen Factory) Kills:
# celxste: 25
#  Shivnitzl19: 24
#  Endyre: 22
#  wrggg: 21
#  BlueSkyMoose: 20
#  H1V: 12
#  WhiteNoise0113: 10
#  JinnMD: 10
#  ewenfi: 8
#  Thund3rMC: 8
#  cheeseball01: 8
#  EdouardpheoIII: 7
#  _Jus10__: 7
#  Ahmedboss891: 6
#  Meekio: 5

# %%
for member in sorted(good_members, key=lambda m: good_members[m]["playtime"], reverse=True):
    print(f"\t{good_members[member]["username"]}: {good_members[member]["playtime"]}")
# Out:
# 	Shivnitzl19: 6972.42
# 	WhiteNoise0113: 2872.75
# 	Budiono: 2685.33
# 	clohi: 2337.33
# 	cheeseball01: 1786.58
# 	BlueSkyMoose: 1538.17
# 	Endyre: 1504.92
# 	Liciela: 1427.17
# 	skrybs: 1170.5
# 	H1V: 1144.33
# 	JinnMD: 1080.92
# 	Rinnn0424: 1065.92
# 	EdouardpheoIII: 1002.25
# 	Tisumi: 955.92
# 	ewenfi: 954.42
# 	VenonatGX: 880.33
# 	wrggg: 865.92
# 	Laborious: 783.33
# 	LaserX: 735.67
# 	GigaFanDeJul: 698.75
# 	_N8: 609.75
# 	Nqn: 593.58
# 	Krijer1: 584.67
# 	squirley: 518.75
# 	FireGamingDK: 422.17
# 	jayandjef: 400.42
# 	Thund3rMC: 387.67
# 	KirouXD: 371.5
# 	evbubba: 364.58
# 	_Snoopers_: 360.58
# 	imNaphy: 353.5
# 	Pogo_Duck: 350.33
# 	Feather_Storm: 341.0
# 	xEagless: 332.58
# 	Chevacchi: 328.58
# 	kcsato: 325.25
# 	ZicZac: 323.08
# 	gauvinsteven: 311.83
# 	MoondustPeachy: 303.0
# 	kanyo0904: 261.42
# 	Riku_56rr: 255.58
# 	Xentell: 254.92
# 	Gurlic: 243.83
# 	jeff1234567842: 240.42
# 	ddxWeCraft: 238.08
# 	WynnDestroyer: 231.17
# 	GrayR0ot: 226.5
# 	JJCourts: 176.17
# 	Ryuuchen: 170.0
# 	White_plague: 153.75
# 	F1NLAY01: 151.5
# 	Bluvey: 150.75
# 	AlleNupY: 144.67
# 	cresseliah: 137.75
# 	StyNath: 137.33
# 	Megawati: 136.67
# 	Kanaefx: 135.67
# 	YBN: 114.83
# 	Zytiv: 112.25
# 	notBirdblade: 104.83
# 	AmasoXd: 100.5
# 	iParadox1122: 98.75
# 	TheKzR: 89.5
# 	parrandeno: 85.83
# 	S6kuna: 83.75
# 	_Hammie_: 79.92
# 	roll_54: 75.58
# 	MelinoeNemesis: 70.42
# 	nawe69: 56.42
# 	Firetornado2312: 48.33
# 	SewageFarts: 42.75
# 	erik_9453: 41.5
# 	aIfaa: 37.75
# 	GoDz_OneManArmy: 34.75
# 	vamqir: 30.67
# 	DynemoRC: 26.75
# 	ottehall: 23.25
# 	djderpcat: 23.17
# 	mirceatim: 19.17

# %%
import csv
from datetime import datetime, timezone
output_file = "./devDataCollection.csv"
headers = ["date", "uuid", "rank", "username", "lastJoined", "daysLastJoined", "playtime", "wars",  "graids", "lootruns", "raids", "totalLevel", "contentCompletion"]
time_format = "%Y-%m-%dT%H:%M:%S.%fZ"
guild_members = []
# file_exists = os.path.isfile(output_file)
# file_has_content = file_exists and os.path.getsize(output_file) > 0
now_utc = datetime.now(timezone.utc)

formatted = now_utc.strftime(time_format)
with open(output_file, "a", newline="") as f:
    writer = csv.writer(f)
    if f.tell()==0:
        writer.writerow(headers)
    
    for uuid in member_stats:
        if uuid in incognito:
            continue
        member = member_stats[uuid]
        guild_members.append(member['username'])
        # print(member['globalData']['guildRaids'])
        # print(member['globalData']['raids'])
        # print([member['globalData']['guildRaids'][raid] for raid in member['globalData']['guildRaids']])
        # print(member['lastJoin'])
        # print(f"{member['username']}: {member['guild']}")
        # print(member)
        
        days_last_joined =  now_utc - datetime.strptime((member.get('lastJoin') or "1959-05-03T21:47:01.317000Z"), time_format).replace(tzinfo=timezone.utc)
        try:
            stats = [formatted, uuid, (member.get('guild') or {'rank': 'RECRUIT'})['rank'],member["username"], member.get('lastJoin', "1959-05-03T21:47:01.317000Z"), 
                    round(days_last_joined.total_seconds()/60/60/24, 3) ,member['playtime'], member['globalData']["wars"], member['globalData']['guildRaids']['total'],
                    member['globalData']['lootruns'], member['globalData']["raids"]['total'], member["globalData"]['totalLevel'], member['globalData']['contentCompletion']]
        except:
            print(member['username'])
            print(member['globalData'])
            print(member['playtime'])
            print(member.get('guild', {'rank': 'RECRUIT'}))
        
        # print(stats)
        writer.writerow(stats)
        # pass

# %%
from datetime import datetime
output_file = "./devDataCollection.csv"
player_data = {}
with open(output_file, newline="") as f:
    reader = csv.DictReader(f)
    for row in reader:
        uuid = row['uuid']
        if uuid not in player_data:
            player_data[uuid] = []
        player_data[uuid].append(row)
print(json.dumps(player_data["c32bfbf5-9665-4ad1-837e-92fa882288a3"]))
numeric_fields = ["playtime", "wars", "graids", "lootruns", "raids", "totalLevel", "contentCompletion"]
# Prepare CSV rows
csv_rows = []
# players = ["c32bfbf5-9665-4ad1-837e-92fa882288a3", "130612b6-1d46-49c7-b06e-3200959254c7"]
players = ["c32bfbf5-9665-4ad1-837e-92fa882288a3", "f46a3aa1-ed18-48f4-bcf9-594e0ff19842"]
for player in players:
    prev = None
    player_rows = []
    for entry in player_data[player]:
        row = entry.copy()
        if prev:
            for field in numeric_fields:
                row[field] = float(entry[field]) - float(prev[field])
        else:
            for field in numeric_fields:
                row[field] = ""  # first entry has no previous
        player_rows.append(row)
        prev = entry
    csv_rows += player_rows[1:]

# Write to CSV
fieldnames = [
    "date",
    "username",
    "uuid",
    "rank",
    "daysLastJoined",
    "playtime",
    "wars",
    "graids",
    "lootruns",
    "raids",
    "totalLevel",
    "contentCompletion",
    "lastJoined"
]
with open(dev_weekly_file, "w", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(csv_rows)
with open(weekly_csv_file, "w", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(csv_rows)

print("CSV saved as output.csv")
# player_ids = ["c32bfbf5-9665-4ad1-837e-92fa882288a3", "f46a3aa1-ed18-48f4-bcf9-594e0ff19842"]
csv_rows = []
# Convert date strings to datetime objects
for player_id in players:
    player_rows = []
    for entry in player_data[player_id]:
        entry["date_dt"] = datetime.strptime(entry["date"], "%Y-%m-%dT%H:%M:%S.%fZ")

    # Sort by date

    # Fields to compute differences for
    numeric_fields = ["playtime", "wars", "graids", "lootruns", "raids", "totalLevel", "contentCompletion"]

    # Prepare CSV rows

    prev_entry = player_data[player_id][0]  # first entry is reference
    week_counter = 1  # start at week 1
    print(len(player_data[player_id]))
    for entry in player_data[player_id][1:]:  # skip first entry
        week_counter += 1

        # Only generate output for every 4th week (week 5, 9, 13, ...)
        if (week_counter - 1) % 4 == 0:  # week 5 relative to start = 5, 9, 13...

            print(f"weak counter: {week_counter}")
            print(entry)
            row = entry.copy()
            for field in numeric_fields:
                row[field] = float(entry[field]) - float(prev_entry[field])
            player_rows.append(row)
            prev_entry = entry  # update reference for next 4-week diff
    csv_rows += player_rows[:]
    # Remove temporary datetime object before writing CSV
for row in csv_rows:
    del row["date_dt"]

# Write CSV


with open(dev_monthly_file, "w", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(csv_rows)

print(f"CSV saved as {dev_monthly_file} with only 4-week intervals")
with open(monthly_csv_file, "w", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(csv_rows)
# Out:
# [{"date": "2026-01-10T23:10:20.363761Z", "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3", "rank": "STRATEGIST", "username": "StyNath", "lastJoined": "2026-01-05T22:54:55.111000Z", "daysLastJoined": "1.011", "playtime": "135.67", "wars": "9", "graids": "23", "lootruns": "1", "raids": "56", "totalLevel": "882", "contentCompletion": "551"}, {"date": "2026-01-17T23:20:31.952994Z", "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3", "rank": "STRATEGIST", "username": "StyNath", "lastJoined": "2026-01-12T22:54:55.111000Z", "daysLastJoined": "1.018", "playtime": "135.67", "wars": "9", "graids": "23", "lootruns": "1", "raids": "56", "totalLevel": "888", "contentCompletion": "558"}, {"date": "2026-01-24T23:35:33.381786Z", "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3", "rank": "STRATEGIST", "username": "StyNath", "lastJoined": "2026-01-19T23:32:38.599000Z", "daysLastJoined": "0.002", "playtime": "136.0", "wars": "31", "graids": "24", "lootruns": "21", "raids": "96", "totalLevel": "982", "contentCompletion": "571"}, {"date": "2026-02-01T00:00:28.803025Z", "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3", "rank": "STRATEGIST", "username": "StyNath", "lastJoined": "2026-01-26T23:57:39.162000Z", "daysLastJoined": "0.002", "playtime": "136.42", "wars": "9", "graids": "23", "lootruns": "1", "raids": "56", "totalLevel": "882", "contentCompletion": "551"}, {"date": "2026-02-08T00:00:41.938435Z", "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3", "rank": "STRATEGIST", "username": "StyNath", "lastJoined": "2026-02-03T23:57:39.162000Z", "daysLastJoined": "0.002", "playtime": "136.42", "wars": "9", "graids": "23", "lootruns": "1", "raids": "56", "totalLevel": "882", "contentCompletion": "551"}, {"date": "2026-02-15T00:14:52.581935Z", "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3", "rank": "STRATEGIST", "username": "StyNath", "lastJoined": "2026-02-11T00:12:04.478000Z", "daysLastJoined": "0.002", "playtime": "136.67", "wars": "9", "graids": "23", "lootruns": "1", "raids": "56", "totalLevel": "882", "contentCompletion": "551"}, {"date": "2026-02-21T23:34:41.956688Z", "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3", "rank": "STRATEGIST", "username": "StyNath", "lastJoined": "2026-02-18T00:23:29.763000Z", "daysLastJoined": "0.049", "playtime": "136.83", "wars": "9", "graids": "23", "lootruns": "1", "raids": "56", "totalLevel": "882", "contentCompletion": "551"}, {"date": "2026-03-01T00:31:13.565683Z", "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3", "rank": "STRATEGIST", "username": "StyNath", "lastJoined": "2026-02-25T00:23:29.763000Z", "daysLastJoined": "0.839", "playtime": "136.83", "wars": "9", "graids": "23", "lootruns": "1", "raids": "56", "totalLevel": "882", "contentCompletion": "551"}, {"date": "2026-03-08T00:00:23.653376Z", "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3", "rank": "STRATEGIST", "username": "StyNath", "lastJoined": "2026-02-25T21:56:01.849000Z", "daysLastJoined": "0.003", "playtime": "137.33", "wars": "9", "graids": "23", "lootruns": "1", "raids": "56", "totalLevel": "882", "contentCompletion": "551"}, {"date": "2026-05-04T05:39:08.248992Z", "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3", "rank": "STRATEGIST", "username": "StyNath", "lastJoined": "2026-04-23T20:09:18.938000Z", "daysLastJoined": "10.396", "playtime": "228.83", "wars": "11", "graids": "36", "lootruns": "1", "raids": "83", "totalLevel": "386", "contentCompletion": "822"}, {"date": "2026-05-04T05:39:22.732247Z", "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3", "rank": "STRATEGIST", "username": "StyNath", "lastJoined": "2026-04-23T20:09:18.938000Z", "daysLastJoined": "10.396", "playtime": "228.83", "wars": "11", "graids": "36", "lootruns": "1", "raids": "83", "totalLevel": "386", "contentCompletion": "822"}, {"date": "2026-05-04T05:39:43.292624Z", "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3", "rank": "STRATEGIST", "username": "StyNath", "lastJoined": "2026-04-23T20:09:18.938000Z", "daysLastJoined": "10.396", "playtime": "228.83", "wars": "11", "graids": "36", "lootruns": "1", " ...
# CSV saved as output.csv
# 28
# weak counter: 5
# {'date': '2026-02-08T00:00:41.938435Z', 'uuid': 'c32bfbf5-9665-4ad1-837e-92fa882288a3', 'rank': 'STRATEGIST', 'username': 'StyNath', 'lastJoined': '2026-02-03T23:57:39.162000Z', 'daysLastJoined': '0.002', 'playtime': '136.42', 'wars': '9', 'graids': '23', 'lootruns': '1', 'raids': '56', 'totalLevel': '882', 'contentCompletion': '551', 'date_dt': datetime.datetime(2026, 2, 8, 0, 0, 41, 938435)}
# weak counter: 9
# {'date': '2026-03-08T00:00:23.653376Z', 'uuid': 'c32bfbf5-9665-4ad1-837e-92fa882288a3', 'rank': 'STRATEGIST', 'username': 'StyNath', 'lastJoined': '2026-02-25T21:56:01.849000Z', 'daysLastJoined': '0.003', 'playtime': '137.33', 'wars': '9', 'graids': '23', 'lootruns': '1', 'raids': '56', 'totalLevel': '882', 'contentCompletion': '551', 'date_dt': datetime.datetime(2026, 3, 8, 0, 0, 23, 653376)}
# weak counter: 13
# {'date': '2026-05-04T05:40:19.394916Z', 'uuid': 'c32bfbf5-9665-4ad1-837e-92fa882288a3', 'rank': 'STRATEGIST', 'username': 'StyNath', 'lastJoined': '2026-04-23T20:09:18.938000Z', 'daysLastJoined': '10.397', 'playtime': '228.83', 'wars': '11', 'graids': '36', 'lootruns': '1', 'raids': '83', 'totalLevel': '386', 'contentCompletion': '822', 'date_dt': datetime.datetime(2026, 5, 4, 5, 40, 19, 394916)}
# weak counter: 17
# {'date': '2026-05-04T05:46:53.661487Z', 'uuid': 'c32bfbf5-9665-4ad1-837e-92fa882288a3', 'rank': 'STRATEGIST', 'username': 'StyNath', 'lastJoined': '2026-04-23T20:09:18.938000Z', 'daysLastJoined': '10.401', 'playtime': '228.83', 'wars': '11', 'graids': '36', 'lootruns': '1', 'raids': '83', 'totalLevel': '386', 'contentCompletion': '822', 'date_dt': datetime.datetime(2026, 5, 4, 5, 46, 53, 661487)}
# weak counter: 21
# {'date': '2026-05-04T05:53:12.267682Z', 'uuid': 'c32bfbf5-9665-4ad1-837e-92fa882288a3', 'rank': 'STRATEGIST', 'username': 'StyNath', 'lastJoined': '2026-04-23T20:09:18.938000Z', 'daysLastJoined': '10.405', 'playtime': '228.83', 'wars': '11', 'graids': '36', 'lootruns': '1', 'raids': '83', 'totalLevel': '386', 'contentCompletion': '822', 'date_dt': datetime.datetime(2026, 5, 4, 5, 53, 12, 267682)}
# weak counter: 25
# {'date': '2026-05-04T05:56:51.124500Z', 'uuid': 'c32bfbf5-9665-4ad1-837e-92fa882288a3', 'rank': 'STRATEGIST', 'username': 'StyNath', 'lastJoined': '2026-04-23T20:09:18.938000Z', 'daysLastJoined': '10.408', 'playtime': '228.83', 'wars': '11', 'graids': '36', 'lootruns': '1', 'raids': '83', 'totalLevel': '386', 'contentCompletion': '822', 'date_dt': datetime.datetime(2026, 5, 4, 5, 56, 51, 124500)}
# 28
# weak counter: 5
# {'date': '2026-02-08T00:00:41.938435Z', 'uuid': 'f46a3aa1-ed18-48f4-bcf9-594e0ff19842', 'rank': 'STRATEGIST', 'username': 'WhiteNoise0113', 'lastJoined': '2026-02-24T23:15:42.837000Z', 'daysLastJoined': '0.031', 'playtime': '2872.58', 'wars': '4012', 'graids': '97', 'lootruns': '5', 'raids': '261', 'totalLevel': '9528', 'contentCompletion': '3904', 'date_dt': datetime.datetime(2026, 2, 8, 0, 0, 41, 938435)}
# weak counter: 9
# {'date': '2026-03-08T00:00:23.653376Z', 'uuid': 'f46a3aa1-ed18-48f4-bcf9-594e0ff19842', 'rank': 'STRATEGIST', 'username': 'WhiteNoise0113', 'lastJoined': '2026-02-25T19:23:52.135000Z', 'daysLastJoined': '0.109', 'playtime': '2872.75', 'wars': '4012', 'graids': '97', 'lootruns': '5', 'raids': '261', 'totalLevel': '9528', 'contentCompletion': '3904', 'date_dt': datetime.datetime(2026, 3, 8, 0, 0, 23, 653376)}
# weak counter: 13
# {'date': '2026-05-04T05:40:19.394916Z', 'uuid': 'f46a3aa1-ed18-48f4-bcf9-594e0ff19842', 'rank': 'STRATEGIST', 'username': 'WhiteNoise0113', 'lastJoined': '2026-05-04T00:17:33.052000Z', 'daysLastJoined': '0.224', 'playtime': '2801.17', 'wars': '4040', 'graids': '97', 'lootruns': '5', 'raids': '261', 'totalLevel': '2779', 'contentCompletion': '3977', 'date_dt': datetime.datetime(2026, 5, 4, 5, 40, 19, 394916)}
# weak counter: 17
# {'date': '2026-05-04T05:46:53.661487Z', 'uuid': 'f46a3aa1-ed18-48f4-bcf9-594e0ff19842', 'rank': 'STRATEGIST', 'username': 'WhiteNoise0113', 'lastJoined': '2026-05-04T00:17:33.052000Z', 'daysLastJoined': '0.229', 'playtime': '2801.17', 'wars': '4040', 'graids': '97', 'lootruns': '5', 'raids': '261', 'totalLevel': '2779', 'contentCompletion': '3977', 'date_dt': datetime.datetime(2026, 5, 4, 5, 46, 53, 661487)}
# weak counter: 21
# {'date': '2026-05-04T05:53:12.267682Z', 'uuid': 'f46a3aa1-ed18-48f4-bcf9-594e0ff19842', 'rank': 'STRATEGIST', 'username': 'WhiteNoise0113', 'lastJoined': '2026-05-04T00:17:33.052000Z', 'daysLastJoined': '0.233', 'playtime': '2801.17', 'wars': '4040', 'graids': '97', 'lootruns': '5', 'raids': '261', 'totalLevel': '2779', 'contentCompletion': '3977', 'date_dt': datetime.datetime(2026, 5, 4, 5, 53, 12, 267682)}
# weak counter: 25
# {'date': '2026-05-04T05:56:51.124500Z', 'uuid': 'f46a3aa1-ed18-48f4-bcf9-594e0ff19842', 'rank': 'STRATEGIST', 'username': 'WhiteNoise0113', 'lastJoined': '2026-05-04T00:17:33.052000Z', 'daysLastJoined': '0.236', 'playtime': '2801.17', 'wars': '4040', 'graids': '97', 'lootruns': '5', 'raids': '261', 'totalLevel': '2779', 'contentCompletion': '3977', 'date_dt': datetime.datetime(2026, 5, 4, 5, 56, 51, 124500)}
# CSV saved as ./dev_monthly_data.csv with only 4-week intervals

# %%
player_data = {}
weekly_data = {}
no_weekly_data = []
monthly_data = {}
no_monthly_data = []
def subtract_date_string(day1, day2):
    filter1 = datetime.strptime(day1, time_format)
    filter2 = datetime.strptime(day2, time_format)
    days_time = filter1 - filter2
    return round(abs(days_time.total_seconds()/60/60/24), 3)

with open(output_file, "r", newline="") as f:
    reader = csv.DictReader(f)
    for row in reader:
        uuid = row['uuid']
        if uuid not in player_data:
            player_data[uuid] = []
        if len(player_data[uuid]) >= 5:
            player_data[uuid] = player_data[uuid][-4:] + [row]
        else:
            player_data[uuid].append(row)


for player in player_data:
    #  player_data[player]
    
    dates = [day['date'] for day in player_data[player]]
    # if dates[-1]==formatted:
    # if player_data[player][-1]['username']=="StyNath":
    #         print(player_data[player][-1]['username'])
    #         print(dates)
    #         print(round(subtract_date_string(dates[-1], dates[-2]), 0))
    #         print(formatted)
    #         print(len(player_data[player]) > 1 and dates[-1]==formatted and round(subtract_date_string(dates[-1], dates[-2]), 0)==7)
    # formatted = "2026-03-08T00:00:23.653376Z"
    
    
    if len(player_data[player]) > 1 and dates[-1]==formatted and round(subtract_date_string(dates[-1], dates[-2]), 0)==7:
        # print(f"Got to weekly: {player_data[player][-1]['username']}")
        weekly_data[player] = {
            "date": formatted,
            "username": player_data[player][-1]['username'], 
            "uuid": player,
            "rank": player_data[player][-1]['rank'],
            "daysLastJoined": player_data[player][-1]["daysLastJoined"],
            "playtime": round(float(player_data[player][-1]['playtime']) -float(player_data[player][-2]['playtime']), 2),
            "wars":round(float(player_data[player][-1]['wars']) -float(player_data[player][-2]['wars']),2 ),
            "graids": round(float(player_data[player][-1]['graids']) -float(player_data[player][-2]['graids']), 2),
            "lootruns": round(float(player_data[player][-1]['lootruns']) -float(player_data[player][-2]['lootruns']), 2),
            "raids": round(float(player_data[player][-1]['raids']) -float(player_data[player][-2]['raids']), 2),
            "totalLevel":round(float(player_data[player][-1]['totalLevel']) -float(player_data[player][-2]['totalLevel']), 2),
            "contentCompletion":round(float(player_data[player][-1]['contentCompletion']) -float(player_data[player][-2]['contentCompletion']), 2),
            "lastJoined": player_data[player][-1]['lastJoined']
                               }
        # print(weekly_data)
    else:
        no_weekly_data.append(player)
    this_month = [round(subtract_date_string(formatted, d), 0)<=28 for d in dates]
    oldest_this_month = 0
    for i in this_month:
        if i:
            oldest_this_month += 1
    start_day = "2026-03-01T00:00:00.000000Z"
    # start_day = "2026-01-11T00:00:00.000000Z"
    # if "StyNath" ==player_data[player][-1]['username']:
    #     print(len(player_data[player]) > 2 and sum(this_month) > 1 and round(subtract_date_string(start_day, formatted),0)%28==0)
    #     print(round(subtract_date_string(start_day, formatted),0)%28==0)
    #     print(round(subtract_date_string(start_day, formatted),0))

    
    if len(player_data[player]) > 2 and round(subtract_date_string(dates[-oldest_this_month], formatted),0)==28 and round(subtract_date_string(start_day, formatted),0)%28==0:
        month_stats = {
            "date": formatted,
            "username": player_data[player][-1]['username'], 
            "uuid": player,
            "rank": player_data[player][-1]['rank'],
            "daysLastJoined": float(player_data[player][-1]["daysLastJoined"]),
            "playtime":round(float(player_data[player][-1]['playtime']) -float(player_data[player][-oldest_this_month]['playtime']), 2),
            "wars":round(float(player_data[player][-1]['wars']) -float(player_data[player][-oldest_this_month]['wars']), 2),
            "graids":round(float(player_data[player][-1]['graids']) -float(player_data[player][-oldest_this_month]['graids']), 2),
            "lootruns": round(float(player_data[player][-1]['lootruns']) -float(player_data[player][-oldest_this_month]['lootruns']), 2),
            "raids":round(float(player_data[player][-1]['raids']) -float(player_data[player][-oldest_this_month]['raids']), 2),
            "totalLevel":round(float(player_data[player][-1]['totalLevel']) -float(player_data[player][-oldest_this_month]['totalLevel']), 2),
            "contentCompletion":round(float(player_data[player][-1]['contentCompletion']) -float(player_data[player][-oldest_this_month]['contentCompletion']), 2),
            "lastJoined": player_data[player][-1]['lastJoined']
        }
        monthly_data[player] = month_stats
        # if player_data[player][-1]['username']=="StyNath":
        #     print(json.dumps(player_data[player], indent=2))
weekly_fieldnames = set()
for data in weekly_data.values():
    weekly_fieldnames.update(data.keys())
weekly_fieldnames = list(weekly_fieldnames)  # optional: sort for consistent order

# Similarly for monthly_data
monthly_fieldnames = set()
for data in monthly_data.values():
    monthly_fieldnames.update(data.keys())
monthly_fieldnames = list(monthly_fieldnames)

# Write CSV
fieldnames = [
    "date",
    "username",
    "uuid",
    "rank",
    "daysLastJoined",
    "playtime",
    "wars",
    "graids",
    "lootruns",
    "raids",
    "totalLevel",
    "contentCompletion",
    "lastJoined"
]
with open(weekly_csv_file, "a", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    if f.tell()==0:
        writer.writeheader()
    
    # Write each player's monthly data
    for player, data in weekly_data.items():
        writer.writerow(data)

# Write CSV
with open(monthly_csv_file, "a", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    if f.tell()==0:
        writer.writeheader()
    
    # Write each player's monthly data
    for player, data in monthly_data.items():
        writer.writerow(data)

# %%
# print(weekly_data)
for player in weekly_data:
    print(player)
    print(weekly_data[player])
    # if weekly_data[player]["playtime"] > 0:
    #     print(player)
    #     print(weekly_data[player])
# Out:
# f46a3aa1-ed18-48f4-bcf9-594e0ff19842
# {'date': '2026-03-08T00:00:23.653376Z', 'username': 'WhiteNoise0113', 'uuid': 'f46a3aa1-ed18-48f4-bcf9-594e0ff19842', 'rank': 'STRATEGIST', 'daysLastJoined': '0.109', 'playtime': 0.0, 'wars': 0.0, 'graids': 0.0, 'lootruns': 0.0, 'raids': 0.0, 'totalLevel': 0.0, 'contentCompletion': 0.0, 'lastJoined': '2026-02-25T19:23:52.135000Z'}
# c32bfbf5-9665-4ad1-837e-92fa882288a3
# {'date': '2026-03-08T00:00:23.653376Z', 'username': 'StyNath', 'uuid': 'c32bfbf5-9665-4ad1-837e-92fa882288a3', 'rank': 'STRATEGIST', 'daysLastJoined': '0.003', 'playtime': 0.5, 'wars': 0.0, 'graids': 0.0, 'lootruns': 0.0, 'raids': 0.0, 'totalLevel': 0.0, 'contentCompletion': 0.0, 'lastJoined': '2026-02-25T21:56:01.849000Z'}

# %%
for player in monthly_data:
    # if monthly_data[player]["playtime"] > 0:
        print(player)
        print(monthly_data[player])
# Out:
# c32bfbf5-9665-4ad1-837e-92fa882288a3
# {'date': '2026-03-08T00:00:23.653376Z', 'username': 'StyNath', 'uuid': 'c32bfbf5-9665-4ad1-837e-92fa882288a3', 'rank': 'STRATEGIST', 'daysLastJoin': '0.003', 'playtime': 0.91, 'wars': 0.0, 'graid': 0.0, 'lootruns': 0.0, 'raids': 0.0, 'totalLevel': 0.0, 'contentCompletion': 0.0}

# %%
print(json.dumps(weekly_data["c32bfbf5-9665-4ad1-837e-92fa882288a3"], indent=2))
# Out:
# {
#   "username": "StyNath",
#   "rank": "STRATEGIST",
#   "daysLastJoin": "0.839",
#   "playtime": 0.0,
#   "wars": 0.0,
#   "graid": 0.0,
#   "lootruns": 0.0,
#   "raids": 0.0,
#   "totalLevel": 0.0,
#   "contentCompletion": 0.0
# }

# %%
print(json.dumps(monthly_data["c32bfbf5-9665-4ad1-837e-92fa882288a3"], indent=2))
# Out:
# {
#   "username": "StyNath",
#   "rank": "STRATEGIST",
#   "daysLastJoin": "0.839",
#   "playtime": 0.41,
#   "wars": 0.0,
#   "graid": 0.0,
#   "lootruns": 0.0,
#   "raids": 0.0,
#   "totalLevel": 0.0,
#   "contentCompletion": 0.0
# }

# %%
import csv
from collections import defaultdict
import plotly.graph_objects as go

numeric_fields = ["playtime", "wars", "graids", "lootruns", "raids", "totalLevel", "contentCompletion"]

data = defaultdict(lambda: defaultdict(list))

# Read CSV
with open(dev_weekly_file) as f:
    reader = csv.DictReader(f)
    for row in reader:
        key = row["uuid"]
        timestamp = row["date"]
        username = row.get("username", key)
        for field in numeric_fields:
            if row.get(field):  # only add if value exists
                data[key][field].append({"timestamp": timestamp, "value": float(row[field]), "username": username})

fig = go.Figure()
traces = []
trace_info = []

# Add traces only if there is data
for key in data:
    for field in numeric_fields:
        if data[key][field]:  # skip empty fields
            trace = go.Scatter(
                x=[entry["timestamp"] for entry in data[key][field]],
                y=[entry["value"] for entry in data[key][field]],
                mode="lines+markers",
                name=f"{data[key][field][-1]['username']} - {field}",
                visible=False
            )
            fig.add_trace(trace)
            trace_info.append((key, field))

# Player dropdown
player_buttons = []
player_keys = list(data.keys())

for key in player_keys:
    visibility = [False] * len(fig.data)
    for j, (k, f) in enumerate(trace_info):
        if k == key:
            visibility[j] = True
    # Pick first non-empty field to get username
    first_field = next((f for f in numeric_fields if data[key][f]), None)
    username = data[key][first_field][-1]['username'] if first_field else key
    player_buttons.append(dict(
        label=username,
        method="update",
        args=[{"visible": visibility},
              {"title": f"Player: {username}"}]
    ))

# Field dropdown
field_buttons = []
for field in numeric_fields:
    visibility = [False] * len(fig.data)
    for j, (k, f) in enumerate(trace_info):
        if f == field:
            visibility[j] = True
    field_buttons.append(dict(
        label=field,
        method="update",
        args=[{"visible": visibility},
              {"title": f"Field: {field}"}]
    ))

fig.update_layout(
    updatemenus=[
        dict(active=0, buttons=player_buttons, x=0, y=1.1, xanchor='left', direction='down'),
        dict(active=0, buttons=field_buttons, x=0.3, y=1.1, xanchor='left', direction='down')
    ],
    title="Interactive Player Stats"
)

weekly_html_str = fig.to_html(
    include_plotlyjs="cdn",
    full_html=False
)

# %%
numeric_fields = ["playtime", "wars", "graids", "lootruns", "raids", "totalLevel", "contentCompletion"]

data = defaultdict(lambda: defaultdict(list))

# Read CSV
with open(dev_monthly_file) as f:
    reader = csv.DictReader(f)
    for row in reader:
        key = row["uuid"]
        timestamp = row["date"]
        username = row.get("username", key)
        for field in numeric_fields:
            if row.get(field):  # only add if value exists
                data[key][field].append({"timestamp": timestamp, "value": float(row[field]), "username": username})

fig = go.Figure()
traces = []
trace_info = []

# Add traces only if there is data
for key in data:
    for field in numeric_fields:
        if data[key][field]:  # skip empty fields
            trace = go.Scatter(
                x=[entry["timestamp"] for entry in data[key][field]],
                y=[entry["value"] for entry in data[key][field]],
                mode="lines+markers",
                name=f"{data[key][field][-1]['username']} - {field}",
                visible=False
            )
            fig.add_trace(trace)
            trace_info.append((key, field))

# Player dropdown
player_buttons = []
player_keys = list(data.keys())

for key in player_keys:
    visibility = [False] * len(fig.data)
    for j, (k, f) in enumerate(trace_info):
        if k == key:
            visibility[j] = True
    # Pick first non-empty field to get username
    first_field = next((f for f in numeric_fields if data[key][f]), None)
    username = data[key][first_field][-1]['username'] if first_field else key
    player_buttons.append(dict(
        label=username,
        method="update",
        args=[{"visible": visibility},
              {"title": f"Player: {username}"}]
    ))

# Field dropdown
field_buttons = []
for field in numeric_fields:
    visibility = [False] * len(fig.data)
    for j, (k, f) in enumerate(trace_info):
        if f == field:
            visibility[j] = True
    field_buttons.append(dict(
        label=field,
        method="update",
        args=[{"visible": visibility},
              {"title": f"Field: {field}"}]
    ))

fig.update_layout(
    updatemenus=[
        dict(active=0, buttons=player_buttons, x=0, y=1.1, xanchor='left', direction='down'),
        dict(active=0, buttons=field_buttons, x=0.3, y=1.1, xanchor='left', direction='down')
    ],
    title="Interactive Player Stats"
)

monthly_html_str = fig.to_html(
    include_plotlyjs="cdn",
    full_html=False
)

# %%
import csv
weekly_data = {}
rows = []

# Step 1: Read all rows
with open(dev_weekly_file, newline="", encoding="utf-8") as f:
    reader = csv.DictReader(f)
    for row in reader:
        rows.append(row)

# Step 2: Find latest date
latest_date = max(row["date"] for row in rows)

# Step 3: Build weekly_data from rows matching latest_date
for row in rows:
    if row["date"] == latest_date:
        player = row["uuid"]
        weekly_data[player] = {
            "date": row["date"],
            "username": row["username"],
            "uuid": player,
            "rank": row["rank"],
            "daysLastJoined": row["daysLastJoined"],
            "playtime": float(row["playtime"]),
            "wars": float(row["wars"]),
            "graids": float(row["graids"]),
            "lootruns": float(row["lootruns"]),
            "raids": float(row["raids"]),
            "totalLevel": float(row["totalLevel"]),
            "contentCompletion": float(row["contentCompletion"]),
            "lastJoined": row["lastJoined"]
        }
print(json.dumps(weekly_data, indent=2))
incognito = ['cff26bb4-bad0-4de2-8559-19d23e2d9d41']
# Out:
# {
#   "c32bfbf5-9665-4ad1-837e-92fa882288a3": {
#     "date": "2026-03-08T00:00:23.653376Z",
#     "username": "StyNath",
#     "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3",
#     "rank": "STRATEGIST",
#     "daysLastJoined": "0.003",
#     "playtime": 0.5,
#     "wars": 0.0,
#     "graids": 0.0,
#     "lootruns": 0.0,
#     "raids": 0.0,
#     "totalLevel": 0.0,
#     "contentCompletion": 0.0,
#     "lastJoined": "2026-02-25T21:56:01.849000Z"
#   },
#   "f46a3aa1-ed18-48f4-bcf9-594e0ff19842": {
#     "date": "2026-03-08T00:00:23.653376Z",
#     "username": "WhiteNoise0113",
#     "uuid": "f46a3aa1-ed18-48f4-bcf9-594e0ff19842",
#     "rank": "STRATEGIST",
#     "daysLastJoined": "0.109",
#     "playtime": 0.0,
#     "wars": 0.0,
#     "graids": 0.0,
#     "lootruns": 0.0,
#     "raids": 0.0,
#     "totalLevel": 0.0,
#     "contentCompletion": 0.0,
#     "lastJoined": "2026-02-25T19:23:52.135000Z"
#   }
# }

# %%
monthly_data = {}
rows = []

# Step 1: Read all rows
with open(dev_monthly_file, newline="", encoding="utf-8") as f:
    reader = csv.DictReader(f)
    for row in reader:
        rows.append(row)

# Step 2: Find latest date
latest_date = max(row["date"] for row in rows)

# Step 3: Build weekly_data from rows matching latest_date
for row in rows:
    if row["date"] == latest_date:
        player = row["uuid"]
        monthly_data[player] = {
            "date": row["date"],
            "username": row["username"],
            "uuid": player,
            "rank": row["rank"],
            "daysLastJoined": row["daysLastJoined"],
            "playtime": float(row["playtime"]),
            "wars": float(row["wars"]),
            "graids": float(row["graids"]),
            "lootruns": float(row["lootruns"]),
            "raids": float(row["raids"]),
            "totalLevel": float(row["totalLevel"]),
            "contentCompletion": float(row["contentCompletion"]),
            "lastJoined": row["lastJoined"]
        }
print(json.dumps(monthly_data, indent=2))
# Out:
# {
#   "c32bfbf5-9665-4ad1-837e-92fa882288a3": {
#     "date": "2026-03-08T00:00:23.653376Z",
#     "username": "StyNath",
#     "uuid": "c32bfbf5-9665-4ad1-837e-92fa882288a3",
#     "rank": "STRATEGIST",
#     "daysLastJoined": "0.003",
#     "playtime": 0.910000000000025,
#     "wars": 0.0,
#     "graids": 0.0,
#     "lootruns": 0.0,
#     "raids": 0.0,
#     "totalLevel": 0.0,
#     "contentCompletion": 0.0,
#     "lastJoined": "2026-02-25T21:56:01.849000Z"
#   },
#   "f46a3aa1-ed18-48f4-bcf9-594e0ff19842": {
#     "date": "2026-03-08T00:00:23.653376Z",
#     "username": "WhiteNoise0113",
#     "uuid": "f46a3aa1-ed18-48f4-bcf9-594e0ff19842",
#     "rank": "STRATEGIST",
#     "daysLastJoined": "0.109",
#     "playtime": 0.17000000000007276,
#     "wars": 0.0,
#     "graids": 0.0,
#     "lootruns": 0.0,
#     "raids": 0.0,
#     "totalLevel": 0.0,
#     "contentCompletion": 0.0,
#     "lastJoined": "2026-02-25T19:23:52.135000Z"
#   }
# }

# %%
import html

def dict_to_html_table(pairs, value_label):
    rows = "\n".join(
        f"<tr><td>{html.escape(str(k))}</td><td>{html.escape(str(v))}</td></tr>"
        for k, v in pairs
    )
    
    return f"""
    <table border="1">
        <thead>
            <tr><th>username</th><th>{html.escape(str(value_label))}</th></tr>
        </thead>
        <tbody>
            {rows}
        </tbody>
    </table>
    """
def paired_tables_dropdown(weekly_pairs, monthly_pairs, value_label):
    weekly_rows = "\n".join(
        f"<tr><td>{html.escape(str(k))}</td><td>{html.escape(str(v))}</td></tr>"
        for k, v in weekly_pairs
    )

    monthly_rows = "\n".join(
        f"<tr><td>{html.escape(str(k))}</td><td>{html.escape(str(v))}</td></tr>"
        for k, v in monthly_pairs
    )

    return f"""
    <details style="margin-bottom: 20px;">
        <summary style="font-size: 18px; font-weight: bold; cursor: pointer;">
            {html.escape(str(value_label))}
        </summary>

        <div style="display: flex; gap: 30px; margin-top: 15px;">

            <div style="width: 50%;">
                <h3>Weekly</h3>
                <table border="1" style="border-collapse: collapse; width: 100%;">
                    <tr>
                        <th>Username</th>
                        <th>{html.escape(str(value_label))}</th>
                    </tr>
                    {weekly_rows}
                </table>
            </div>

            <div style="width: 50%;">
                <h3>Monthly</h3>
                <table border="1" style="border-collapse: collapse; width: 100%;">
                    <tr>
                        <th>Username</th>
                        <th>{html.escape(str(value_label))}</th>
                    </tr>
                    {monthly_rows}
                </table>
            </div>

        </div>
    </details>
    """

# %%
import html


def make_table(pairs, value_label):
        rows = "\n".join(
            f"<tr><td>{'N/A' if rank.lower() in ('chief', 'owner') else i}</td><td>{html.escape(str(k))}</td><td>{html.escape(str(round(v + (0 if rank.lower() in ('chief', 'owner') else 1), 2)))}</td><td>{html.escape(str(rank))}</td></tr>"
            for i, (k, v, rank) in enumerate(pairs, start=1)
        )
        return f"""
<table border="1" style="border-collapse: collapse; font-size: 14px;">
    <tr>
        <th>#</th>
        <th>Username</th>
        <th>{html.escape(str(value_label))}</th>
        <th>Rank</th>
    </tr>
{rows}
</table>
"""


def full_field_dropdown(field, asc_weekly, asc_monthly, desc_weekly, desc_monthly):
    return f"""
    <details style="margin-bottom: 30px;">
        <summary style="font-size: 20px; font-weight: bold; cursor: pointer;">
            {html.escape(field)}
        </summary>

        <div style="
            margin-top: 15px;
            display: flex;
            gap: 25px;
            flex-wrap: nowrap;
        ">

            <div>
                <h4>Top Weekly</h4>
                {make_table(asc_weekly, field)}
            </div>

            <div>
                <h4>Top Monthly</h4>
                {make_table(asc_monthly, field)}
            </div>

            <div>
                <h4>Lowest Weekly</h4>
                {make_table(desc_weekly, field)}
            </div>

            <div>
                <h4>Lowest Monthly</h4>
                {make_table(desc_monthly, field)}
            </div>

        </div>
    </details>
    """

# %%
numeric_fields = ["playtime", "wars", "graids", "lootruns", "raids", "totalLevel", "contentCompletion"]
# asc_weekly_tables = ""
# asc_monthly_tables = ""
# desc_weekly_tables = ""
# desc_monthly_tables = ""
all_tables_html = ""
# money_made_for_guild_weekly_tables = ""
# money_made_for_guild_weekly = sorted([(weekly_data[uuid]["username"], (3 * weekly_data[uuid]["graids"] + weekly_data[uuid]["wars"])/4) for uuid in weekly_data], key=lambda x: x[1], reverse=True)
# # money_made_for_guild_monthly_tables = ""
# money_made_for_guild_monthly = sorted([(monthly_data[uuid]["username"], (3 * monthly_data[uuid]["graids"] + monthly_data[uuid]["wars"])/4) for uuid in monthly_data], key=lambda x: x[1], reverse=True)
for field in numeric_fields:
    asc_weekly = sorted([(weekly_data[uuid]["username"], weekly_data[uuid][field], monthly_data[uuid]['rank']) for uuid in weekly_data], key=lambda x: x[1], reverse=True)
    asc_monthly = sorted([(monthly_data[uuid]["username"], monthly_data[uuid][field], monthly_data[uuid]['rank']) for uuid in monthly_data], key=lambda x: x[1], reverse=True)
    desc_weekly = sorted([(weekly_data[uuid]["username"], weekly_data[uuid][field], monthly_data[uuid]['rank']) for uuid in weekly_data], key=lambda x: x[1], reverse=False)
    desc_monthly = sorted([(monthly_data[uuid]["username"], monthly_data[uuid][field], monthly_data[uuid]['rank']) for uuid in monthly_data], key=lambda x: x[1], reverse=False)
    all_tables_html += full_field_dropdown(
        field,
        asc_weekly[:30],
        asc_monthly[:30],
        desc_weekly[:30],
        desc_monthly[:30]
    )

html_ = f"""
<html>
<head>
  <title>My Graph Page</title>
</head>
<body>
  <h1>Performance Rankings</h1>
  Warning icognito players: {"[member_stats[uuid]['username'] for uuid in incognito]"}
  {all_tables_html}
  <div style="display: flex; flex-direction: row">
    <h1 style="width: 50%">Weekly Graphs</h1>
    <h1>Monthly Graphs</h1>
  </div>
  <div style="display: flex; flex-direction: row">
    <div style="width: 50%">
      {weekly_html_str}
    </div>
    <div style="width: 50%">
      {monthly_html_str}
    </div>
  </div>
</body>
</html>
"""
with open("my_page.html", "w") as f:
    f.write(html_)

# %%
import csv
from datetime import datetime, timedelta
import subprocess

# venv_python = ".venv/bin/python"

# subprocess.run([venv_python, "script.py"])

# %%
start_day = "2025-10-09T08:38:37.034846Z"
for i in range(13):
    venv_python = ".venv/bin/python"
    
    subprocess.run([venv_python, "script.py", start_day], check=True)
    
    if i==12:
        break
    file_path = "weekly_data.csv"  # change this

    # --- Step 1: Read everything into memory ---
    with open(file_path, "r", newline="") as f:
        rows = list(csv.reader(f))

    # --- Step 2: Modify first column (subtract 7 days) ---
    for row in rows:
        if not row:
            continue
        if row[0] == "date":
            continue
        dt = datetime.fromisoformat(row[0].replace("Z", "+00:00"))
        new_dt = dt - timedelta(days=7)

        # Force identical formatting
        row[0] = new_dt.strftime("%Y-%m-%dT%H:%M:%S.%fZ")

    # --- Step 3: Write everything back ---
    with open(file_path, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerows(rows)

    
    

    file_path = "dataCollection.csv"  # change this

    # --- Step 1: Read everything into memory ---
    with open(file_path, "r", newline="") as f:
        rows = list(csv.reader(f))

    # --- Step 2: Modify first column (subtract 7 days) ---
    for row in rows:
        if not row:
            continue
        if row[0] == "date":
            continue
        dt = datetime.fromisoformat(row[0].replace("Z", "+00:00"))
        new_dt = dt - timedelta(days=7)

        # Force identical formatting
        row[0] = new_dt.strftime("%Y-%m-%dT%H:%M:%S.%fZ")

    # --- Step 3: Write everything back ---
    with open(file_path, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerows(rows)
    
    file_path = "monthly_data.csv"  # change this

    # --- Step 1: Read everything into memory ---
    with open(file_path, "r", newline="") as f:
        rows = list(csv.reader(f))

    # --- Step 2: Modify first column (subtract 7 days) ---
    for row in rows:
        if not row:
            continue
        if row[0] == "date":
            continue
        dt = datetime.fromisoformat(row[0].replace("Z", "+00:00"))
        new_dt = dt - timedelta(days=7)

        # Force identical formatting
        row[0] = new_dt.strftime("%Y-%m-%dT%H:%M:%S.%fZ")

    # --- Step 3: Write everything back ---
    with open(file_path, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerows(rows)
    dt = datetime.fromisoformat(start_day.replace("Z", "+00:00"))

    # Add 7 days
    new_dt = dt + timedelta(days=7)

    # Convert back to same format
    start_day = new_dt.strftime("%Y-%m-%dT%H:%M:%S.%fZ")
    print(f"{i+1}/13 complete")
# Out:
# oldest_this_month_div: 0.0
# start_day_to_today_formatted: 140.0
# 1/13 complete
# oldest_this_month_div: 7.0
# start_day_to_today_formatted: 133.0
# 2/13 complete
# oldest_this_month_div: 14.0
# start_day_to_today_formatted: 126.0
# 3/13 complete
# oldest_this_month_div: 21.0
# start_day_to_today_formatted: 119.0
# 4/13 complete
# oldest_this_month_div: 28.0
# start_day_to_today_formatted: 112.0
# 5/13 complete
# oldest_this_month_div: 28.0
# start_day_to_today_formatted: 105.0
# 6/13 complete
# oldest_this_month_div: 28.0
# start_day_to_today_formatted: 98.0
# 7/13 complete
# oldest_this_month_div: 28.0
# start_day_to_today_formatted: 91.0
# 8/13 complete
# oldest_this_month_div: 28.0
# start_day_to_today_formatted: 84.0
# 9/13 complete
# oldest_this_month_div: 28.0
# start_day_to_today_formatted: 77.0
# 10/13 complete
# oldest_this_month_div: 28.0
# start_day_to_today_formatted: 70.0
# 11/13 complete
# oldest_this_month_div: 28.0
# start_day_to_today_formatted: 63.0
# 12/13 complete
# oldest_this_month_div: 28.0
# start_day_to_today_formatted: 56.0

# %%
def weeklies_table(tomes):
        i = 0
        rows = []
        for player in tomes.keys():
            
            i += 1
            position = i
            rows.append(
                f"<tr><td>{position}</td><td>{html.escape(player)}</td><td>{html.escape(str(tomes[player]['streak']))}</td></tr>"
            )
        rows = "\n".join(rows)
        return f"""
<table border="1" style="border-collapse: collapse; font-size: 14px;">
    <tr>
        <th>#</th>
        <th>Username</th>
        <th>{html.escape(str("Weeklies"))}</th>
        <th>Rank</th>
    </tr>
{rows}
</table>
"""
tomes = {}

guild_data = guild_req.json()
# print(json.dumps(guild_data, indent=2))
for key in guild_data['members'].keys():
        if key =="total":
            continue
        for member in guild_data['members'][key]:
              exists = guild_data['members'][key].get('weekly', False)
              print(member)
              print(exists)
            #   print(guild_data['members'][key].keys())
              print(guild_data['members'][key][member].get('weekly', "huh"))
              print(json.dumps(guild_data['members'][key].get('weekly', False), indent=2))
              print(f"exists?: {guild_data['members'][key].get('weekly', False)} and completed?: {guild_data['members'][key]['weekly']['completed']} and streakmod5?: {guild_data['members'][key]['weekly']['streak']%5==0}")
              if guild_data['members'][key].get('weekly', False) and guild_data['members'][key]['weekly']['completed'] and guild_data['members'][key]['weekly']['streak']%5==0:
                tomes[member] = guild_data['members'][key]['weekly']
# Out:
# Nqn
# False
# dict_keys(['Nqn'])
# {'completed': True, 'streak': 19}
# false
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 37
#      35 print(guild_data['members'][key][member].get('weekly', "huh"))
#      36 print(json.dumps(guild_data['members'][key].get('weekly', False), indent=2))
# ---> 37 print(f"exists?: {guild_data['members'][key].get('weekly', False)} and completed?: {guild_data['members'][key]['weekly']['completed']} and streakmod5?: {guild_data['members'][key]['weekly']['streak']%5==0}")
#      38 if guild_data['members'][key].get('weekly', False) and guild_data['members'][key]['weekly']['completed'] and guild_data['members'][key]['weekly']['streak']%5==0:
#      39   tomes[member] = guild_data['members'][key]['weekly']
#
# KeyError: 'weekly'
